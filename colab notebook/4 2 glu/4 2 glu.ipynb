# %%
from google.colab import drive
drive.mount('/content/gdrive')

# To install fairseq from source and develop locally:
# !git clone https://github.com/choyi0521/fairseq
# %cd /content/fairseq
# !pip install --editable .
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive
# Cloning into 'fairseq'...
# remote: Enumerating objects: 12164, done.
# remote: Total 12164 (delta 0), reused 0 (delta 0), pack-reused 12164
# Receiving objects: 100% (12164/12164), 5.69 MiB | 3.91 MiB/s, done.
# Resolving deltas: 100% (8955/8955), done.
# /content/fairseq
# Obtaining file:///content/fairseq
# Requirement already satisfied: cffi in /usr/local/lib/python3.6/dist-packages (from fairseq==0.8.0) (1.13.2)
# Requirement already satisfied: cython in /usr/local/lib/python3.6/dist-packages (from fairseq==0.8.0) (0.29.14)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from fairseq==0.8.0) (1.17.4)
# Collecting regex
#   Downloading https://files.pythonhosted.org/packages/e3/8e/cbf2295643d7265e7883326fb4654e643bfc93b3a8a8274d8010a39d8804/regex-2019.11.1-cp36-cp36m-manylinux1_x86_64.whl (643kB)
#      |████████████████████████████████| 645kB 2.7MB/s
# Collecting sacrebleu
#   Downloading https://files.pythonhosted.org/packages/0e/e5/93d252182f7cbd4b59bb3ec5797e2ce33cfd6f5aadaf327db170cf4b7887/sacrebleu-1.4.2-py3-none-any.whl
# Requirement already satisfied: torch in /usr/local/lib/python3.6/dist-packages (from fairseq==0.8.0) (1.3.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from fairseq==0.8.0) (4.28.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.6/dist-packages (from cffi->fairseq==0.8.0) (2.19)
# Requirement already satisfied: typing in /usr/local/lib/python3.6/dist-packages (from sacrebleu->fairseq==0.8.0) (3.6.6)
# Collecting portalocker
#   Downloading https://files.pythonhosted.org/packages/91/db/7bc703c0760df726839e0699b7f78a4d8217fdc9c7fcb1b51b39c5a22a4e/portalocker-1.5.2-py2.py3-none-any.whl
# Installing collected packages: regex, portalocker, sacrebleu, fairseq
#   Running setup.py develop for fairseq
# Successfully installed fairseq portalocker-1.5.2 regex-2019.11.1 sacrebleu-1.4.2

# %%
# !git checkout dev3
# !git pull origin dev3
# Out:
# Branch 'dev3' set up to track remote branch 'dev3' from 'origin'.
# Switched to a new branch 'dev3'
# From https://github.com/choyi0521/fairseq
#  * branch            dev3       -> FETCH_HEAD
# Already up to date.

# %%
# Download and prepare the data
# %cd /content/fairseq
# %cd examples/translation/
# !bash prepare-iwslt14.sh
# %cd ../..

# Preprocess/binarize the data
TEXT="examples/translation/iwslt14.tokenized.de-en"
# !fairseq-preprocess --source-lang de --target-lang en \
    --trainpref $TEXT/train --validpref $TEXT/valid --testpref $TEXT/test \
    --destdir data-bin/iwslt14.tokenized.de-en \
    --workers 20
# Out:
# /content/fairseq
# /content/fairseq/examples/translation
# Cloning Moses github repository (for tokenization scripts)...
# Cloning into 'mosesdecoder'...
# remote: Enumerating objects: 163, done.
# remote: Counting objects: 100% (163/163), done.
# remote: Compressing objects: 100% (83/83), done.
# remote: Total 147458 (delta 101), reused 117 (delta 74), pack-reused 147295
# Receiving objects: 100% (147458/147458), 129.72 MiB | 11.66 MiB/s, done.
# Resolving deltas: 100% (113935/113935), done.
# Cloning Subword NMT repository (for BPE pre-processing)...
# Cloning into 'subword-nmt'...
# remote: Enumerating objects: 21, done.
# remote: Counting objects: 100% (21/21), done.
# remote: Compressing objects: 100% (15/15), done.
# remote: Total 530 (delta 9), reused 15 (delta 6), pack-reused 509
# Receiving objects: 100% (530/530), 224.83 KiB | 599.00 KiB/s, done.
# Resolving deltas: 100% (315/315), done.
# Downloading data from https://wit3.fbk.eu/archive/2014-01/texts/de/en/de-en.tgz...
# --2019-11-23 04:13:25--  https://wit3.fbk.eu/archive/2014-01/texts/de/en/de-en.tgz
# Resolving wit3.fbk.eu (wit3.fbk.eu)... 217.77.80.8
# Connecting to wit3.fbk.eu (wit3.fbk.eu)|217.77.80.8|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 19982877 (19M) [application/x-gzip]
# Saving to: ‘de-en.tgz’
#
# de-en.tgz           100%[===================>]  19.06M  3.48MB/s    in 7.6s
#
# 2019-11-23 04:13:34 (2.52 MB/s) - ‘de-en.tgz’ saved [19982877/19982877]
#
# Data successfully downloaded.
# de-en/
# de-en/IWSLT14.TED.dev2010.de-en.de.xml
# de-en/IWSLT14.TED.dev2010.de-en.en.xml
# de-en/IWSLT14.TED.tst2010.de-en.de.xml
# de-en/IWSLT14.TED.tst2010.de-en.en.xml
# de-en/IWSLT14.TED.tst2011.de-en.de.xml
# de-en/IWSLT14.TED.tst2011.de-en.en.xml
# de-en/IWSLT14.TED.tst2012.de-en.de.xml
# de-en/IWSLT14.TED.tst2012.de-en.en.xml
# de-en/IWSLT14.TEDX.dev2012.de-en.de.xml
# de-en/IWSLT14.TEDX.dev2012.de-en.en.xml
# de-en/README
# de-en/train.en
# de-en/train.tags.de-en.de
# de-en/train.tags.de-en.en
# pre-processing train data...
# Tokenizer Version 1.1
# Language: de
# Number of threads: 8
#
# Tokenizer Version 1.1
# Language: en
# Number of threads: 8
#
# clean-corpus.perl: processing iwslt14.tokenized.de-en/tmp/train.tags.de-en.tok.de & .en to iwslt14.tokenized.de-en/tmp/train.tags.de-en.clean, cutoff 1-175, ratio 1.5
# ..........(100000).......
# Input sentences: 174443  Output sentences:  167522
# pre-processing valid/test data...
# orig/de-en/IWSLT14.TED.dev2010.de-en.de.xml iwslt14.tokenized.de-en/tmp/IWSLT14.TED.dev2010.de-en.de
# Tokenizer Version 1.1
# Language: de
# Number of threads: 8
#
# orig/de-en/IWSLT14.TED.tst2010.de-en.de.xml iwslt14.tokenized.de-en/tmp/IWSLT14.TED.tst2010.de-en.de
# Tokenizer Version 1.1
# Language: de
# Number of threads: 8
#
# orig/de-en/IWSLT14.TED.tst2011.de-en.de.xml iwslt14.tokenized.de-en/tmp/IWSLT14.TED.tst2011.de-en.de
# Tokenizer Version 1.1
# Language: de
# Number of threads: 8
#
# orig/de-en/IWSLT14.TED.tst2012.de-en.de.xml iwslt14.tokenized.de-en/tmp/IWSLT14.TED.tst2012.de-en.de
# Tokenizer Version 1.1
# Language: de
# Number of threads: 8
#
# orig/de-en/IWSLT14.TEDX.dev2012.de-en.de.xml iwslt14.tokenized.de-en/tmp/IWSLT14.TEDX.dev2012.de-en.de
# Tokenizer Version 1.1
# Language: de
# Number of threads: 8
#
# orig/de-en/IWSLT14.TED.dev2010.de-en.en.xml iwslt14.tokenized.de-en/tmp/IWSLT14.TED.dev2010.de-en.en
# Tokenizer Version 1.1
# Language: en
# Number of threads: 8
#
# orig/de-en/IWSLT14.TED.tst2010.de-en.en.xml iwslt14.tokenized.de-en/tmp/IWSLT14.TED.tst2010.de-en.en
# Tokenizer Version 1.1
# Language: en
# Number of threads: 8
#
# orig/de-en/IWSLT14.TED.tst2011.de-en.en.xml iwslt14.tokenized.de-en/tmp/IWSLT14.TED.tst2011.de-en.en
# Tokenizer Version 1.1
# Language: en
# Number of threads: 8
#
# orig/de-en/IWSLT14.TED.tst2012.de-en.en.xml iwslt14.tokenized.de-en/tmp/IWSLT14.TED.tst2012.de-en.en
# Tokenizer Version 1.1
# Language: en
# Number of threads: 8
#
# orig/de-en/IWSLT14.TEDX.dev2012.de-en.en.xml iwslt14.tokenized.de-en/tmp/IWSLT14.TEDX.dev2012.de-en.en
# Tokenizer Version 1.1
# Language: en
# Number of threads: 8
#
# creating train, valid, test...
# learn_bpe.py on iwslt14.tokenized.de-en/tmp/train.en-de...
# subword-nmt/learn_bpe.py:267: DeprecationWarning: this script's location has moved to /content/fairseq/examples/translation/subword-nmt/subword_nmt. This symbolic link will be removed in a future version. Please point to the new location, or install the package and use the command 'subword-nmt'
#   DeprecationWarning
# apply_bpe.py to train.de...
# subword-nmt/apply_bpe.py:328: DeprecationWarning: this script's location has moved to /content/fairseq/examples/translation/subword-nmt/subword_nmt. This symbolic link will be removed in a future version. Please point to the new location, or install the package and use the command 'subword-nmt'
#   DeprecationWarning
# subword-nmt/apply_bpe.py:345: ResourceWarning: unclosed file <_io.TextIOWrapper name='iwslt14.tokenized.de-en/code' mode='r' encoding='UTF-8'>
#   args.codes = codecs.open(args.codes.name, encoding='utf-8')
# apply_bpe.py to valid.de...
# subword-nmt/apply_bpe.py:328: DeprecationWarning: this script's location has moved to /content/fairseq/examples/translation/subword-nmt/subword_nmt. This symbolic link will be removed in a future version. Please point to the new location, or install the package and use the command 'subword-nmt'
#   DeprecationWarning
# subword-nmt/apply_bpe.py:345: ResourceWarning: unclosed file <_io.TextIOWrapper name='iwslt14.tokenized.de-en/code' mode='r' encoding='UTF-8'>
#   args.codes = codecs.open(args.codes.name, encoding='utf-8')
# apply_bpe.py to test.de...
# subword-nmt/apply_bpe.py:328: DeprecationWarning: this script's location has moved to /content/fairseq/examples/translation/subword-nmt/subword_nmt. This symbolic link will be removed in a future version. Please point to the new location, or install the package and use the command 'subword-nmt'
#   DeprecationWarning
# subword-nmt/apply_bpe.py:345: ResourceWarning: unclosed file <_io.TextIOWrapper name='iwslt14.tokenized.de-en/code' mode='r' encoding='UTF-8'>
#   args.codes = codecs.open(args.codes.name, encoding='utf-8')
# apply_bpe.py to train.en...
# subword-nmt/apply_bpe.py:328: DeprecationWarning: this script's location has moved to /content/fairseq/examples/translation/subword-nmt/subword_nmt. This symbolic link will be removed in a future version. Please point to the new location, or install the package and use the command 'subword-nmt'
#   DeprecationWarning
# subword-nmt/apply_bpe.py:345: ResourceWarning: unclosed file <_io.TextIOWrapper name='iwslt14.tokenized.de-en/code' mode='r' encoding='UTF-8'>
#   args.codes = codecs.open(args.codes.name, encoding='utf-8')
# apply_bpe.py to valid.en...
# subword-nmt/apply_bpe.py:328: DeprecationWarning: this script's location has moved to /content/fairseq/examples/translation/subword-nmt/subword_nmt. This symbolic link will be removed in a future version. Please point to the new location, or install the package and use the command 'subword-nmt'
#   DeprecationWarning
# subword-nmt/apply_bpe.py:345: ResourceWarning: unclosed file <_io.TextIOWrapper name='iwslt14.tokenized.de-en/code' mode='r' encoding='UTF-8'>
#   args.codes = codecs.open(args.codes.name, encoding='utf-8')
# apply_bpe.py to test.en...
# subword-nmt/apply_bpe.py:328: DeprecationWarning: this script's location has moved to /content/fairseq/examples/translation/subword-nmt/subword_nmt. This symbolic link will be removed in a future version. Please point to the new location, or install the package and use the command 'subword-nmt'
#   DeprecationWarning
# subword-nmt/apply_bpe.py:345: ResourceWarning: unclosed file <_io.TextIOWrapper name='iwslt14.tokenized.de-en/code' mode='r' encoding='UTF-8'>
#   args.codes = codecs.open(args.codes.name, encoding='utf-8')
# /content/fairseq
# Namespace(align_suffix=None, alignfile=None, bpe=None, cpu=False, criterion='cross_entropy', dataset_impl='mmap', destdir='data-bin/iwslt14.tokenized.de-en', empty_cache_freq=0, fp16=False, fp16_init_scale=128, fp16_scale_tolerance=0.0, fp16_scale_window=None, joined_dictionary=False, log_format=None, log_interval=1000, lr_scheduler='fixed', memory_efficient_fp16=False, min_loss_scale=0.0001, no_progress_bar=False, nwordssrc=-1, nwordstgt=-1, only_source=False, optimizer='nag', padding_factor=8, seed=1, source_lang='de', srcdict=None, target_lang='en', task='translation', tbmf_wrapper=False, tensorboard_logdir='', testpref='examples/translation/iwslt14.tokenized.de-en/test', tgtdict=None, threshold_loss_scale=None, thresholdsrc=0, thresholdtgt=0, tokenizer=None, trainpref='examples/translation/iwslt14.tokenized.de-en/train', user_dir=None, validpref='examples/translation/iwslt14.tokenized.de-en/valid', workers=20)
# | [de] Dictionary: 8847 types
# | [de] examples/translation/iwslt14.tokenized.de-en/train.de: 160239 sents, 4035591 tokens, 0.0% replaced by <unk>
# | [de] Dictionary: 8847 types
# | [de] examples/translation/iwslt14.tokenized.de-en/valid.de: 7283 sents, 182592 tokens, 0.0192% replaced by <unk>
# | [de] Dictionary: 8847 types
# | [de] examples/translation/iwslt14.tokenized.de-en/test.de: 6750 sents, 161838 tokens, 0.0636% replaced by <unk>
# | [en] Dictionary: 6631 types
# | [en] examples/translation/iwslt14.tokenized.de-en/train.en: 160239 sents, 3949114 tokens, 0.0% replaced by <unk>
# | [en] Dictionary: 6631 types
# | [en] examples/translation/iwslt14.tokenized.de-en/valid.en: 7283 sents, 178622 tokens, 0.00448% replaced by <unk>
# | [en] Dictionary: 6631 types
# | [en] examples/translation/iwslt14.tokenized.de-en/test.en: 6750 sents, 156928 tokens, 0.00892% replaced by <unk>
# | Wrote preprocessed data to data-bin/iwslt14.tokenized.de-en

# %%
SAVE="/content/gdrive/My Drive/colab/payless/save_dev3/dynamic_conv_iwslt"

# Training
# %cd /content/fairseq
# !mkdir -p "{SAVE}" 
# !CUDA_VISIBLE_DEVICES=0 $(which fairseq-train) data-bin/iwslt14.tokenized.de-en \
    --encoder-conv-type ddynamic --decoder-conv-type ddynamic \
    --clip-norm 0 --optimizer adam --lr 0.0005 \
    --source-lang de --target-lang en --max-tokens 4000 --no-progress-bar \
    --log-interval 100 --min-lr '1e-09' --weight-decay 0.0001 \
    --criterion label_smoothed_cross_entropy --label-smoothing 0.1 \
    --lr-scheduler inverse_sqrt \
    --ddp-backend=no_c10d \
    --max-update 50000 --warmup-updates 4000 --warmup-init-lr '1e-07' \
    --adam-betas '(0.9, 0.98)' --keep-last-epochs 10 \
    -a lightconv_iwslt_de_en --save-dir "{SAVE}" \
    --dropout 0.3 --attention-dropout 0.1 --weight-dropout 0.1 \
    --encoder-glu 1 --decoder-glu 1 \
    --encoder-attention-heads 4 --decoder-attention-heads 4 \
    --encoder-attention-proj-heads 2 --decoder-attention-proj-heads 2 \
    --encoder-layers 7 --encoder-kernel-size-list [3,7,15,31,31,31,31] \
    2>&1 | tee "{SAVE}/train4.log"
# Out:
# /content/fairseq
# Namespace(adam_betas='(0.9, 0.98)', adam_eps=1e-08, adaptive_softmax_cutoff=None, adaptive_softmax_dropout=0, arch='lightconv_iwslt_de_en', attention_dropout=0.1, best_checkpoint_metric='loss', bpe=None, bucket_cap_mb=25, clip_norm=0.0, cpu=False, criterion='label_smoothed_cross_entropy', curriculum=0, data='data-bin/iwslt14.tokenized.de-en', dataset_impl=None, ddp_backend='no_c10d', decoder_attention_heads=4, decoder_attention_proj_heads=2, decoder_conv_dim=512, decoder_conv_type='ddynamic', decoder_embed_dim=512, decoder_embed_path=None, decoder_ffn_embed_dim=1024, decoder_glu=True, decoder_input_dim=512, decoder_kernel_size_list=[3, 7, 15, 31, 31, 31], decoder_layers=6, decoder_learned_pos=False, decoder_normalize_before=False, decoder_output_dim=512, device_id=0, disable_validation=False, distributed_backend='nccl', distributed_init_method=None, distributed_no_spawn=False, distributed_port=-1, distributed_rank=0, distributed_world_size=1, dropout=0.3, empty_cache_freq=0, encoder_attention_heads=4, encoder_attention_proj_heads=2, encoder_conv_dim=512, encoder_conv_type='ddynamic', encoder_embed_dim=512, encoder_embed_path=None, encoder_ffn_embed_dim=1024, encoder_glu=True, encoder_kernel_size_list=[3, 7, 15, 31, 31, 31, 31], encoder_layers=7, encoder_learned_pos=False, encoder_normalize_before=False, fast_stat_sync=False, find_unused_parameters=False, fix_batches_to_gpus=False, fixed_validation_seed=None, fp16=False, fp16_init_scale=128, fp16_scale_tolerance=0.0, fp16_scale_window=None, input_dropout=0.0, keep_interval_updates=-1, keep_last_epochs=10, label_smoothing=0.1, lazy_load=False, left_pad_source='True', left_pad_target='False', load_alignments=False, log_format=None, log_interval=100, lr=[0.0005], lr_scheduler='inverse_sqrt', max_epoch=0, max_sentences=None, max_sentences_valid=None, max_source_positions=1024, max_target_positions=1024, max_tokens=4000, max_tokens_valid=4000, max_update=50000, maximize_best_checkpoint_metric=False, memory_efficient_fp16=False, min_loss_scale=0.0001, min_lr=1e-09, no_epoch_checkpoints=False, no_last_checkpoints=False, no_progress_bar=True, no_save=False, no_save_optimizer_state=False, no_token_positional_embeddings=False, num_workers=1, optimizer='adam', optimizer_overrides='{}', raw_text=False, relu_dropout=0.0, required_batch_size_multiple=8, reset_dataloader=False, reset_lr_scheduler=False, reset_meters=False, reset_optimizer=False, restore_file='checkpoint_last.pt', save_dir='/content/gdrive/My Drive/colab/payless/save_dev3/dynamic_conv_iwslt', save_interval=1, save_interval_updates=0, seed=1, sentence_avg=False, share_all_embeddings=False, share_decoder_input_output_embed=False, skip_invalid_size_inputs_valid_test=False, source_lang='de', target_lang='en', task='translation', tbmf_wrapper=False, tensorboard_logdir='', threshold_loss_scale=None, tokenizer=None, train_subset='train', update_freq=[1], upsample_primary=1, use_bmuf=False, user_dir=None, valid_subset='valid', validate_interval=1, warmup_init_lr=1e-07, warmup_updates=4000, weight_decay=0.0001, weight_dropout=0.1, weight_softmax=True)
# | [de] dictionary: 8848 types
# | [en] dictionary: 6632 types
# | loaded 7283 examples from: data-bin/iwslt14.tokenized.de-en/valid.de-en.de
# | loaded 7283 examples from: data-bin/iwslt14.tokenized.de-en/valid.de-en.en
# | data-bin/iwslt14.tokenized.de-en valid de-en 7283 examples
# LightConvModel(
#   (encoder): LightConvEncoder(
#     (embed_tokens): Embedding(8848, 512, padding_idx=1)
#     (embed_positions): SinusoidalPositionalEmbedding()
#     (layers): ModuleList(
#       (0): LightConvEncoderLayer(
#         dropout=0.3, relu_dropout=0.0, input_dropout=0.0, normalize_before=False
#         (linear1): Linear(in_features=512, out_features=1024, bias=True)
#         (act): GLU(dim=-1)
#         (conv): DDynamicConv1dTBC(
#           512, kernel_size=3, padding_l=1, num_heads=4, num_proj_heads=2, weight_softmax=True, conv_bias=False, renorm_padding=False, in_proj=False, weight_dropout=0.1
#           (weight_linear): Linear(in_features=256, out_features=24, bias=False)
#         )
#         (linear2): Linear(in_features=512, out_features=512, bias=True)
#         (fc1): Linear(in_features=512, out_features=1024, bias=True)
#         (fc2): Linear(in_features=1024, out_features=512, bias=True)
#         (layer_norms): ModuleList(
#           (0): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#       (1): LightConvEncoderLayer(
#         dropout=0.3, relu_dropout=0.0, input_dropout=0.0, normalize_before=False
#         (linear1): Linear(in_features=512, out_features=1024, bias=True)
#         (act): GLU(dim=-1)
#         (conv): DDynamicConv1dTBC(
#           512, kernel_size=7, padding_l=3, num_heads=4, num_proj_heads=2, weight_softmax=True, conv_bias=False, renorm_padding=False, in_proj=False, weight_dropout=0.1
#           (weight_linear): Linear(in_features=256, out_features=56, bias=False)
#         )
#         (linear2): Linear(in_features=512, out_features=512, bias=True)
#         (fc1): Linear(in_features=512, out_features=1024, bias=True)
#         (fc2): Linear(in_features=1024, out_features=512, bias=True)
#         (layer_norms): ModuleList(
#           (0): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#       (2): LightConvEncoderLayer(
#         dropout=0.3, relu_dropout=0.0, input_dropout=0.0, normalize_before=False
#         (linear1): Linear(in_features=512, out_features=1024, bias=True)
#         (act): GLU(dim=-1)
#         (conv): DDynamicConv1dTBC(
#           512, kernel_size=15, padding_l=7, num_heads=4, num_proj_heads=2, weight_softmax=True, conv_bias=False, renorm_padding=False, in_proj=False, weight_dropout=0.1
#           (weight_linear): Linear(in_features=256, out_features=120, bias=False)
#         )
#         (linear2): Linear(in_features=512, out_features=512, bias=True)
#         (fc1): Linear(in_features=512, out_features=1024, bias=True)
#         (fc2): Linear(in_features=1024, out_features=512, bias=True)
#         (layer_norms): ModuleList(
#           (0): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#       (3): LightConvEncoderLayer(
#         dropout=0.3, relu_dropout=0.0, input_dropout=0.0, normalize_before=False
#         (linear1): Linear(in_features=512, out_features=1024, bias=True)
#         (act): GLU(dim=-1)
#         (conv): DDynamicConv1dTBC(
#           512, kernel_size=31, padding_l=15, num_heads=4, num_proj_heads=2, weight_softmax=True, conv_bias=False, renorm_padding=False, in_proj=False, weight_dropout=0.1
#           (weight_linear): Linear(in_features=256, out_features=248, bias=False)
#         )
#         (linear2): Linear(in_features=512, out_features=512, bias=True)
#         (fc1): Linear(in_features=512, out_features=1024, bias=True)
#         (fc2): Linear(in_features=1024, out_features=512, bias=True)
#         (layer_norms): ModuleList(
#           (0): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#       (4): LightConvEncoderLayer(
#         dropout=0.3, relu_dropout=0.0, input_dropout=0.0, normalize_before=False
#         (linear1): Linear(in_features=512, out_features=1024, bias=True)
#         (act): GLU(dim=-1)
#         (conv): DDynamicConv1dTBC(
#           512, kernel_size=31, padding_l=15, num_heads=4, num_proj_heads=2, weight_softmax=True, conv_bias=False, renorm_padding=False, in_proj=False, weight_dropout=0.1
#           (weight_linear): Linear(in_features=256, out_features=248, bias=False)
#         )
#         (linear2): Linear(in_features=512, out_features=512, bias=True)
#         (fc1): Linear(in_features=512, out_features=1024, bias=True)
#         (fc2): Linear(in_features=1024, out_features=512, bias=True)
#         (layer_norms): ModuleList(
#           (0): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#       (5): LightConvEncoderLayer(
#         dropout=0.3, relu_dropout=0.0, input_dropout=0.0, normalize_before=False
#         (linear1): Linear(in_features=512, out_features=1024, bias=True)
#         (act): GLU(dim=-1)
#         (conv): DDynamicConv1dTBC(
#           512, kernel_size=31, padding_l=15, num_heads=4, num_proj_heads=2, weight_softmax=True, conv_bias=False, renorm_padding=False, in_proj=False, weight_dropout=0.1
#           (weight_linear): Linear(in_features=256, out_features=248, bias=False)
#         )
#         (linear2): Linear(in_features=512, out_features=512, bias=True)
#         (fc1): Linear(in_features=512, out_features=1024, bias=True)
#         (fc2): Linear(in_features=1024, out_features=512, bias=True)
#         (layer_norms): ModuleList(
#           (0): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#       (6): LightConvEncoderLayer(
#         dropout=0.3, relu_dropout=0.0, input_dropout=0.0, normalize_before=False
#         (linear1): Linear(in_features=512, out_features=1024, bias=True)
#         (act): GLU(dim=-1)
#         (conv): DDynamicConv1dTBC(
#           512, kernel_size=31, padding_l=15, num_heads=4, num_proj_heads=2, weight_softmax=True, conv_bias=False, renorm_padding=False, in_proj=False, weight_dropout=0.1
#           (weight_linear): Linear(in_features=256, out_features=248, bias=False)
#         )
#         (linear2): Linear(in_features=512, out_features=512, bias=True)
#         (fc1): Linear(in_features=512, out_features=1024, bias=True)
#         (fc2): Linear(in_features=1024, out_features=512, bias=True)
#         (layer_norms): ModuleList(
#           (0): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#     )
#   )
#   (decoder): LightConvDecoder(
#     (embed_tokens): Embedding(6632, 512, padding_idx=1)
#     (embed_positions): SinusoidalPositionalEmbedding()
#     (layers): ModuleList(
#       (0): LightConvDecoderLayer(
#         dropout=0.3, relu_dropout=0.0, input_dropout=0.0, normalize_before=False
#         (linear1): Linear(in_features=512, out_features=1024, bias=True)
#         (act): GLU(dim=-1)
#         (conv): DDynamicConv1dTBC(
#           512, kernel_size=3, padding_l=2, num_heads=4, num_proj_heads=2, weight_softmax=True, conv_bias=False, renorm_padding=False, in_proj=False, weight_dropout=0.1
#           (weight_linear): Linear(in_features=256, out_features=24, bias=False)
#         )
#         (linear2): Linear(in_features=512, out_features=512, bias=True)
#         (conv_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): MultiheadAttention(
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=1024, bias=True)
#         (fc2): Linear(in_features=1024, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (1): LightConvDecoderLayer(
#         dropout=0.3, relu_dropout=0.0, input_dropout=0.0, normalize_before=False
#         (linear1): Linear(in_features=512, out_features=1024, bias=True)
#         (act): GLU(dim=-1)
#         (conv): DDynamicConv1dTBC(
#           512, kernel_size=7, padding_l=6, num_heads=4, num_proj_heads=2, weight_softmax=True, conv_bias=False, renorm_padding=False, in_proj=False, weight_dropout=0.1
#           (weight_linear): Linear(in_features=256, out_features=56, bias=False)
#         )
#         (linear2): Linear(in_features=512, out_features=512, bias=True)
#         (conv_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): MultiheadAttention(
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=1024, bias=True)
#         (fc2): Linear(in_features=1024, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (2): LightConvDecoderLayer(
#         dropout=0.3, relu_dropout=0.0, input_dropout=0.0, normalize_before=False
#         (linear1): Linear(in_features=512, out_features=1024, bias=True)
#         (act): GLU(dim=-1)
#         (conv): DDynamicConv1dTBC(
#           512, kernel_size=15, padding_l=14, num_heads=4, num_proj_heads=2, weight_softmax=True, conv_bias=False, renorm_padding=False, in_proj=False, weight_dropout=0.1
#           (weight_linear): Linear(in_features=256, out_features=120, bias=False)
#         )
#         (linear2): Linear(in_features=512, out_features=512, bias=True)
#         (conv_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): MultiheadAttention(
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=1024, bias=True)
#         (fc2): Linear(in_features=1024, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (3): LightConvDecoderLayer(
#         dropout=0.3, relu_dropout=0.0, input_dropout=0.0, normalize_before=False
#         (linear1): Linear(in_features=512, out_features=1024, bias=True)
#         (act): GLU(dim=-1)
#         (conv): DDynamicConv1dTBC(
#           512, kernel_size=31, padding_l=30, num_heads=4, num_proj_heads=2, weight_softmax=True, conv_bias=False, renorm_padding=False, in_proj=False, weight_dropout=0.1
#           (weight_linear): Linear(in_features=256, out_features=248, bias=False)
#         )
#         (linear2): Linear(in_features=512, out_features=512, bias=True)
#         (conv_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): MultiheadAttention(
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=1024, bias=True)
#         (fc2): Linear(in_features=1024, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (4): LightConvDecoderLayer(
#         dropout=0.3, relu_dropout=0.0, input_dropout=0.0, normalize_before=False
#         (linear1): Linear(in_features=512, out_features=1024, bias=True)
#         (act): GLU(dim=-1)
#         (conv): DDynamicConv1dTBC(
#           512, kernel_size=31, padding_l=30, num_heads=4, num_proj_heads=2, weight_softmax=True, conv_bias=False, renorm_padding=False, in_proj=False, weight_dropout=0.1
#           (weight_linear): Linear(in_features=256, out_features=248, bias=False)
#         )
#         (linear2): Linear(in_features=512, out_features=512, bias=True)
#         (conv_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): MultiheadAttention(
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=1024, bias=True)
#         (fc2): Linear(in_features=1024, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (5): LightConvDecoderLayer(
#         dropout=0.3, relu_dropout=0.0, input_dropout=0.0, normalize_before=False
#         (linear1): Linear(in_features=512, out_features=1024, bias=True)
#         (act): GLU(dim=-1)
#         (conv): DDynamicConv1dTBC(
#           512, kernel_size=31, padding_l=30, num_heads=4, num_proj_heads=2, weight_softmax=True, conv_bias=False, renorm_padding=False, in_proj=False, weight_dropout=0.1
#           (weight_linear): Linear(in_features=256, out_features=248, bias=False)
#         )
#         (linear2): Linear(in_features=512, out_features=512, bias=True)
#         (conv_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): MultiheadAttention(
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=1024, bias=True)
#         (fc2): Linear(in_features=1024, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#   )
# )
# | model lightconv_iwslt_de_en, criterion LabelSmoothedCrossEntropyCriterion
# | num. model params: 42099712 (num. trained: 42099712)
# | training on 1 GPUs
# | max tokens per GPU = 4000 and max sentences per GPU = None
# | loaded checkpoint /content/gdrive/My Drive/colab/payless/save_dev3/dynamic_conv_iwslt/checkpoint_last.pt (epoch 16 @ 18096 updates)
# | loading train data for epoch 16
# | loaded 160239 examples from: data-bin/iwslt14.tokenized.de-en/train.de-en.de
# | loaded 160239 examples from: data-bin/iwslt14.tokenized.de-en/train.de-en.en
# | data-bin/iwslt14.tokenized.de-en train de-en 160239 examples
# | epoch 017:    100 / 1131 loss=3.444, nll_loss=1.969, ppl=3.91, wps=5603, ups=2, wpb=3508.426, bsz=137.188, num_updates=18197, lr=0.000234423, gnorm=0.631, clip=0.000, oom=0.000, wall=65, train_wall=4450
# | epoch 017:    200 / 1131 loss=3.450, nll_loss=1.976, ppl=3.93, wps=5530, ups=2, wpb=3480.343, bsz=137.552, num_updates=18297, lr=0.000233781, gnorm=0.636, clip=0.000, oom=0.000, wall=129, train_wall=4513
# | epoch 017:    300 / 1131 loss=3.431, nll_loss=1.954, ppl=3.87, wps=5481, ups=2, wpb=3457.980, bsz=141.050, num_updates=18397, lr=0.000233145, gnorm=0.636, clip=0.000, oom=0.000, wall=192, train_wall=4576
# | epoch 017:    400 / 1131 loss=3.434, nll_loss=1.957, ppl=3.88, wps=5488, ups=2, wpb=3471.698, bsz=142.045, num_updates=18497, lr=0.000232514, gnorm=0.635, clip=0.000, oom=0.000, wall=256, train_wall=4639
# | epoch 017:    500 / 1131 loss=3.439, nll_loss=1.963, ppl=3.90, wps=5470, ups=2, wpb=3460.587, bsz=141.525, num_updates=18597, lr=0.000231888, gnorm=0.640, clip=0.000, oom=0.000, wall=319, train_wall=4702
# | epoch 017:    600 / 1131 loss=3.439, nll_loss=1.964, ppl=3.90, wps=5476, ups=2, wpb=3469.250, bsz=143.308, num_updates=18697, lr=0.000231267, gnorm=0.639, clip=0.000, oom=0.000, wall=383, train_wall=4765
# | epoch 017:    700 / 1131 loss=3.446, nll_loss=1.972, ppl=3.92, wps=5484, ups=2, wpb=3474.712, bsz=143.213, num_updates=18797, lr=0.000230651, gnorm=0.639, clip=0.000, oom=0.000, wall=446, train_wall=4828
# | epoch 017:    800 / 1131 loss=3.452, nll_loss=1.979, ppl=3.94, wps=5496, ups=2, wpb=3486.840, bsz=142.841, num_updates=18897, lr=0.00023004, gnorm=0.638, clip=0.000, oom=0.000, wall=510, train_wall=4892
# | epoch 017:    900 / 1131 loss=3.455, nll_loss=1.982, ppl=3.95, wps=5507, ups=2, wpb=3494.809, bsz=143.609, num_updates=18997, lr=0.000229434, gnorm=0.638, clip=0.000, oom=0.000, wall=574, train_wall=4955
# | epoch 017:   1000 / 1131 loss=3.456, nll_loss=1.983, ppl=3.95, wps=5494, ups=2, wpb=3487.558, bsz=142.649, num_updates=19097, lr=0.000228832, gnorm=0.639, clip=0.000, oom=0.000, wall=637, train_wall=5018
# | epoch 017:   1100 / 1131 loss=3.458, nll_loss=1.986, ppl=3.96, wps=5496, ups=2, wpb=3490.862, bsz=142.284, num_updates=19197, lr=0.000228236, gnorm=0.640, clip=0.000, oom=0.000, wall=701, train_wall=5081
# | epoch 017 | loss 3.461 | nll_loss 1.989 | ppl 3.97 | wps 5498 | ups 2 | wpb 3491.701 | bsz 141.679 | num_updates 19227 | lr 0.000228057 | gnorm 0.640 | clip 0.000 | oom 0.000 | wall 720 | train_wall 5100
# | epoch 017 | valid on 'valid' subset | loss 3.926 | nll_loss 2.364 | ppl 5.15 | num_updates 19227 | best_loss 3.92522
# | saved checkpoint /content/gdrive/My Drive/colab/payless/save_dev3/dynamic_conv_iwslt/checkpoint17.pt (epoch 17 @ 19227 updates) (writing took 4.77116847038269 seconds)
# | epoch 018:    100 / 1131 loss=3.419, nll_loss=1.938, ppl=3.83, wps=5560, ups=2, wpb=3566.604, bsz=124.594, num_updates=19328, lr=0.000227461, gnorm=0.625, clip=0.000, oom=0.000, wall=803, train_wall=5164
# | epoch 018:    200 / 1131 loss=3.411, nll_loss=1.930, ppl=3.81, wps=5530, ups=2, wpb=3521.866, bsz=129.632, num_updates=19428, lr=0.000226875, gnorm=0.638, clip=0.000, oom=0.000, wall=866, train_wall=5227
# | epoch 018:    300 / 1131 loss=3.410, nll_loss=1.928, ppl=3.81, wps=5490, ups=2, wpb=3487.113, bsz=131.721, num_updates=19528, lr=0.000226293, gnorm=0.645, clip=0.000, oom=0.000, wall=929, train_wall=5290
# | epoch 018:    400 / 1131 loss=3.414, nll_loss=1.933, ppl=3.82, wps=5493, ups=2, wpb=3497.157, bsz=133.167, num_updates=19628, lr=0.000225716, gnorm=0.644, clip=0.000, oom=0.000, wall=993, train_wall=5354
# | epoch 018:    500 / 1131 loss=3.417, nll_loss=1.937, ppl=3.83, wps=5492, ups=2, wpb=3494.040, bsz=134.563, num_updates=19728, lr=0.000225143, gnorm=0.646, clip=0.000, oom=0.000, wall=1057, train_wall=5416
# | epoch 018:    600 / 1131 loss=3.420, nll_loss=1.941, ppl=3.84, wps=5488, ups=2, wpb=3491.190, bsz=136.506, num_updates=19828, lr=0.000224575, gnorm=0.646, clip=0.000, oom=0.000, wall=1120, train_wall=5480
# | epoch 018:    700 / 1131 loss=3.420, nll_loss=1.941, ppl=3.84, wps=5482, ups=2, wpb=3488.147, bsz=138.328, num_updates=19928, lr=0.00022401, gnorm=0.646, clip=0.000, oom=0.000, wall=1184, train_wall=5543
# | epoch 018:    800 / 1131 loss=3.419, nll_loss=1.940, ppl=3.84, wps=5489, ups=2, wpb=3494.017, bsz=141.253, num_updates=20028, lr=0.00022345, gnorm=0.645, clip=0.000, oom=0.000, wall=1248, train_wall=5606
# | epoch 018:    900 / 1131 loss=3.421, nll_loss=1.942, ppl=3.84, wps=5486, ups=2, wpb=3491.724, bsz=141.469, num_updates=20128, lr=0.000222895, gnorm=0.646, clip=0.000, oom=0.000, wall=1311, train_wall=5669
# | epoch 018:   1000 / 1131 loss=3.424, nll_loss=1.946, ppl=3.85, wps=5479, ups=2, wpb=3486.427, bsz=141.530, num_updates=20228, lr=0.000222343, gnorm=0.647, clip=0.000, oom=0.000, wall=1375, train_wall=5732
# | epoch 018:   1100 / 1131 loss=3.426, nll_loss=1.949, ppl=3.86, wps=5482, ups=2, wpb=3489.793, bsz=141.877, num_updates=20328, lr=0.000221795, gnorm=0.646, clip=0.000, oom=0.000, wall=1439, train_wall=5796
# | epoch 018 | loss 3.428 | nll_loss 1.950 | ppl 3.86 | wps 5484 | ups 2 | wpb 3491.701 | bsz 141.679 | num_updates 20358 | lr 0.000221632 | gnorm 0.646 | clip 0.000 | oom 0.000 | wall 1458 | train_wall 5815
# | epoch 018 | valid on 'valid' subset | loss 3.911 | nll_loss 2.351 | ppl 5.10 | num_updates 20358 | best_loss 3.9111
# | saved checkpoint /content/gdrive/My Drive/colab/payless/save_dev3/dynamic_conv_iwslt/checkpoint18.pt (epoch 18 @ 20358 updates) (writing took 11.07086730003357 seconds)
# | epoch 019:    100 / 1131 loss=3.372, nll_loss=1.886, ppl=3.70, wps=5468, ups=2, wpb=3489.168, bsz=135.446, num_updates=20459, lr=0.000221084, gnorm=0.637, clip=0.000, oom=0.000, wall=1546, train_wall=5879
# | epoch 019:    200 / 1131 loss=3.364, nll_loss=1.877, ppl=3.67, wps=5455, ups=2, wpb=3468.224, bsz=140.259, num_updates=20559, lr=0.000220546, gnorm=0.640, clip=0.000, oom=0.000, wall=1610, train_wall=5942
# | epoch 019:    300 / 1131 loss=3.374, nll_loss=1.887, ppl=3.70, wps=5442, ups=2, wpb=3451.724, bsz=136.399, num_updates=20659, lr=0.000220011, gnorm=0.646, clip=0.000, oom=0.000, wall=1673, train_wall=6004
# | epoch 019:    400 / 1131 loss=3.378, nll_loss=1.892, ppl=3.71, wps=5469, ups=2, wpb=3473.918, bsz=139.052, num_updates=20759, lr=0.000219481, gnorm=0.645, clip=0.000, oom=0.000, wall=1737, train_wall=6068
# | epoch 019:    500 / 1131 loss=3.382, nll_loss=1.897, ppl=3.72, wps=5487, ups=2, wpb=3489.162, bsz=140.168, num_updates=20859, lr=0.000218954, gnorm=0.644, clip=0.000, oom=0.000, wall=1800, train_wall=6131
# | epoch 019:    600 / 1131 loss=3.385, nll_loss=1.900, ppl=3.73, wps=5471, ups=2, wpb=3477.790, bsz=139.328, num_updates=20959, lr=0.000218431, gnorm=0.646, clip=0.000, oom=0.000, wall=1864, train_wall=6194
# | epoch 019:    700 / 1131 loss=3.383, nll_loss=1.898, ppl=3.73, wps=5471, ups=2, wpb=3479.787, bsz=141.478, num_updates=21059, lr=0.000217912, gnorm=0.646, clip=0.000, oom=0.000, wall=1928, train_wall=6257
# | epoch 019:    800 / 1131 loss=3.386, nll_loss=1.902, ppl=3.74, wps=5471, ups=2, wpb=3478.600, bsz=140.654, num_updates=21159, lr=0.000217396, gnorm=0.648, clip=0.000, oom=0.000, wall=1991, train_wall=6320
# | epoch 019:    900 / 1131 loss=3.390, nll_loss=1.906, ppl=3.75, wps=5475, ups=2, wpb=3482.585, bsz=140.218, num_updates=21259, lr=0.000216885, gnorm=0.648, clip=0.000, oom=0.000, wall=2055, train_wall=6384
# | epoch 019:   1000 / 1131 loss=3.392, nll_loss=1.909, ppl=3.75, wps=5481, ups=2, wpb=3488.471, bsz=141.011, num_updates=21359, lr=0.000216376, gnorm=0.648, clip=0.000, oom=0.000, wall=2119, train_wall=6447
# | epoch 019:   1100 / 1131 loss=3.394, nll_loss=1.911, ppl=3.76, wps=5482, ups=2, wpb=3489.134, bsz=142.016, num_updates=21459, lr=0.000215871, gnorm=0.647, clip=0.000, oom=0.000, wall=2183, train_wall=6510
# | epoch 019 | loss 3.396 | nll_loss 1.913 | ppl 3.77 | wps 5484 | ups 2 | wpb 3491.701 | bsz 141.679 | num_updates 21489 | lr 0.000215721 | gnorm 0.648 | clip 0.000 | oom 0.000 | wall 2202 | train_wall 6530
# | epoch 019 | valid on 'valid' subset | loss 3.921 | nll_loss 2.357 | ppl 5.12 | num_updates 21489 | best_loss 3.9111
# | saved checkpoint /content/gdrive/My Drive/colab/payless/save_dev3/dynamic_conv_iwslt/checkpoint19.pt (epoch 19 @ 21489 updates) (writing took 4.64235520362854 seconds)
# | epoch 020:    100 / 1131 loss=3.324, nll_loss=1.830, ppl=3.55, wps=5422, ups=2, wpb=3459.000, bsz=135.921, num_updates=21590, lr=0.000215216, gnorm=0.647, clip=0.000, oom=0.000, wall=2284, train_wall=6594
# | epoch 020:    200 / 1131 loss=3.332, nll_loss=1.838, ppl=3.57, wps=5449, ups=2, wpb=3470.358, bsz=135.562, num_updates=21690, lr=0.000214719, gnorm=0.646, clip=0.000, oom=0.000, wall=2347, train_wall=6657
# | epoch 020:    300 / 1131 loss=3.344, nll_loss=1.853, ppl=3.61, wps=5478, ups=2, wpb=3484.900, bsz=136.106, num_updates=21790, lr=0.000214226, gnorm=0.647, clip=0.000, oom=0.000, wall=2411, train_wall=6720
# | epoch 020:    400 / 1131 loss=3.346, nll_loss=1.855, ppl=3.62, wps=5481, ups=2, wpb=3490.249, bsz=138.252, num_updates=21890, lr=0.000213736, gnorm=0.648, clip=0.000, oom=0.000, wall=2475, train_wall=6783
# | epoch 020:    500 / 1131 loss=3.350, nll_loss=1.860, ppl=3.63, wps=5491, ups=2, wpb=3498.699, bsz=140.277, num_updates=21990, lr=0.000213249, gnorm=0.647, clip=0.000, oom=0.000, wall=2538, train_wall=6846
# | epoch 020:    600 / 1131 loss=3.351, nll_loss=1.862, ppl=3.63, wps=5491, ups=2, wpb=3498.932, bsz=143.240, num_updates=22090, lr=0.000212766, gnorm=0.648, clip=0.000, oom=0.000, wall=2602, train_wall=6910
# | epoch 020:    700 / 1131 loss=3.353, nll_loss=1.864, ppl=3.64, wps=5496, ups=2, wpb=3501.904, bsz=143.074, num_updates=22190, lr=0.000212286, gnorm=0.647, clip=0.000, oom=0.000, wall=2666, train_wall=6973
# | epoch 020:    800 / 1131 loss=3.358, nll_loss=1.869, ppl=3.65, wps=5482, ups=2, wpb=3490.060, bsz=141.222, num_updates=22290, lr=0.000211809, gnorm=0.650, clip=0.000, oom=0.000, wall=2729, train_wall=7036
# | epoch 020:    900 / 1131 loss=3.360, nll_loss=1.872, ppl=3.66, wps=5483, ups=2, wpb=3492.119, bsz=140.714, num_updates=22390, lr=0.000211336, gnorm=0.650, clip=0.000, oom=0.000, wall=2793, train_wall=7099
# | epoch 020:   1000 / 1131 loss=3.363, nll_loss=1.875, ppl=3.67, wps=5484, ups=2, wpb=3493.976, bsz=141.817, num_updates=22490, lr=0.000210865, gnorm=0.650, clip=0.000, oom=0.000, wall=2857, train_wall=7163
# | epoch 020:   1100 / 1131 loss=3.365, nll_loss=1.878, ppl=3.68, wps=5481, ups=2, wpb=3492.361, bsz=141.863, num_updates=22590, lr=0.000210398, gnorm=0.651, clip=0.000, oom=0.000, wall=2921, train_wall=7226
# | epoch 020 | loss 3.366 | nll_loss 1.879 | ppl 3.68 | wps 5479 | ups 2 | wpb 3491.701 | bsz 141.679 | num_updates 22620 | lr 0.000210259 | gnorm 0.651 | clip 0.000 | oom 0.000 | wall 2940 | train_wall 7245
# | epoch 020 | valid on 'valid' subset | loss 3.921 | nll_loss 2.353 | ppl 5.11 | num_updates 22620 | best_loss 3.9111
# | saved checkpoint /content/gdrive/My Drive/colab/payless/save_dev3/dynamic_conv_iwslt/checkpoint20.pt (epoch 20 @ 22620 updates) (writing took 4.57740044593811 seconds)
# | epoch 021:    100 / 1131 loss=3.276, nll_loss=1.775, ppl=3.42, wps=5436, ups=2, wpb=3515.366, bsz=148.356, num_updates=22721, lr=0.000209791, gnorm=0.631, clip=0.000, oom=0.000, wall=3023, train_wall=7310
# | epoch 021:    200 / 1131 loss=3.287, nll_loss=1.788, ppl=3.45, wps=5433, ups=2, wpb=3483.294, bsz=145.910, num_updates=22821, lr=0.000209331, gnorm=0.640, clip=0.000, oom=0.000, wall=3086, train_wall=7373
# | epoch 021:    300 / 1131 loss=3.295, nll_loss=1.797, ppl=3.48, wps=5444, ups=2, wpb=3491.385, bsz=146.738, num_updates=22921, lr=0.000208873, gnorm=0.643, clip=0.000, oom=0.000, wall=3150, train_wall=7437
# | epoch 021:    400 / 1131 loss=3.307, nll_loss=1.811, ppl=3.51, wps=5436, ups=2, wpb=3475.751, bsz=142.803, num_updates=23021, lr=0.000208419, gnorm=0.649, clip=0.000, oom=0.000, wall=3214, train_wall=7499
# | epoch 021:    500 / 1131 loss=3.314, nll_loss=1.818, ppl=3.53, wps=5444, ups=2, wpb=3477.473, bsz=143.138, num_updates=23121, lr=0.000207968, gnorm=0.649, clip=0.000, oom=0.000, wall=3277, train_wall=7563
# | epoch 021:    600 / 1131 loss=3.317, nll_loss=1.822, ppl=3.54, wps=5453, ups=2, wpb=3482.561, bsz=141.444, num_updates=23221, lr=0.00020752, gnorm=0.650, clip=0.000, oom=0.000, wall=3341, train_wall=7626
# | epoch 021:    700 / 1131 loss=3.324, nll_loss=1.829, ppl=3.55, wps=5455, ups=2, wpb=3483.415, bsz=141.591, num_updates=23321, lr=0.000207074, gnorm=0.652, clip=0.000, oom=0.000, wall=3405, train_wall=7689
# | epoch 021:    800 / 1131 loss=3.328, nll_loss=1.834, ppl=3.57, wps=5446, ups=2, wpb=3472.457, bsz=141.332, num_updates=23421, lr=0.000206632, gnorm=0.655, clip=0.000, oom=0.000, wall=3468, train_wall=7752
# | epoch 021:    900 / 1131 loss=3.331, nll_loss=1.838, ppl=3.58, wps=5456, ups=2, wpb=3483.905, bsz=142.125, num_updates=23521, lr=0.000206192, gnorm=0.654, clip=0.000, oom=0.000, wall=3533, train_wall=7816
# | epoch 021:   1000 / 1131 loss=3.333, nll_loss=1.840, ppl=3.58, wps=5454, ups=2, wpb=3486.550, bsz=142.265, num_updates=23621, lr=0.000205755, gnorm=0.654, clip=0.000, oom=0.000, wall=3597, train_wall=7880
# | epoch 021:   1100 / 1131 loss=3.335, nll_loss=1.843, ppl=3.59, wps=5458, ups=2, wpb=3491.718, bsz=142.953, num_updates=23721, lr=0.000205321, gnorm=0.654, clip=0.000, oom=0.000, wall=3662, train_wall=7944
# | epoch 021 | loss 3.338 | nll_loss 1.847 | ppl 3.60 | wps 5459 | ups 2 | wpb 3491.701 | bsz 141.679 | num_updates 23751 | lr 0.000205191 | gnorm 0.655 | clip 0.000 | oom 0.000 | wall 3681 | train_wall 7963
# | epoch 021 | valid on 'valid' subset | loss 3.918 | nll_loss 2.351 | ppl 5.10 | num_updates 23751 | best_loss 3.9111
# | saved checkpoint /content/gdrive/My Drive/colab/payless/save_dev3/dynamic_conv_iwslt/checkpoint21.pt (epoch 21 @ 23751 updates) (writing took 4.688881158828735 seconds)
# | epoch 022:    100 / 1131 loss=3.288, nll_loss=1.785, ppl=3.45, wps=5360, ups=2, wpb=3432.436, bsz=126.733, num_updates=23852, lr=0.000204756, gnorm=0.661, clip=0.000, oom=0.000, wall=3763, train_wall=8027
# | epoch 022:    200 / 1131 loss=3.276, nll_loss=1.773, ppl=3.42, wps=5443, ups=2, wpb=3494.234, bsz=140.577, num_updates=23952, lr=0.000204329, gnorm=0.648, clip=0.000, oom=0.000, wall=3827, train_wall=8091
# | epoch 022:    300 / 1131 loss=3.283, nll_loss=1.783, ppl=3.44, wps=5452, ups=2, wpb=3487.462, bsz=141.236, num_updates=24052, lr=0.000203903, gnorm=0.650, clip=0.000, oom=0.000, wall=3891, train_wall=8154
# | epoch 022:    400 / 1131 loss=3.276, nll_loss=1.775, ppl=3.42, wps=5427, ups=2, wpb=3468.918, bsz=145.975, num_updates=24152, lr=0.000203481, gnorm=0.653, clip=0.000, oom=0.000, wall=3955, train_wall=8217
# | epoch 022:    500 / 1131 loss=3.284, nll_loss=1.784, ppl=3.44, wps=5443, ups=2, wpb=3477.263, bsz=144.894, num_updates=24252, lr=0.000203061, gnorm=0.654, clip=0.000, oom=0.000, wall=4018, train_wall=8281
# | epoch 022:    600 / 1131 loss=3.294, nll_loss=1.795, ppl=3.47, wps=5456, ups=2, wpb=3485.371, bsz=143.281, num_updates=24352, lr=0.000202644, gnorm=0.656, clip=0.000, oom=0.000, wall=4082, train_wall=8344
# | epoch 022:    700 / 1131 loss=3.293, nll_loss=1.794, ppl=3.47, wps=5456, ups=2, wpb=3488.231, bsz=143.726, num_updates=24452, lr=0.000202229, gnorm=0.655, clip=0.000, oom=0.000, wall=4146, train_wall=8408
# | epoch 022:    800 / 1131 loss=3.295, nll_loss=1.797, ppl=3.47, wps=5460, ups=2, wpb=3495.121, bsz=144.779, num_updates=24552, lr=0.000201816, gnorm=0.655, clip=0.000, oom=0.000, wall=4211, train_wall=8472
# | epoch 022:    900 / 1131 loss=3.302, nll_loss=1.805, ppl=3.49, wps=5456, ups=2, wpb=3491.502, bsz=143.306, num_updates=24652, lr=0.000201407, gnorm=0.657, clip=0.000, oom=0.000, wall=4275, train_wall=8535
# | epoch 022:   1000 / 1131 loss=3.309, nll_loss=1.813, ppl=3.51, wps=5451, ups=2, wpb=3487.072, bsz=140.666, num_updates=24752, lr=0.000200999, gnorm=0.659, clip=0.000, oom=0.000, wall=4339, train_wall=8599
# | epoch 022:   1100 / 1131 loss=3.312, nll_loss=1.816, ppl=3.52, wps=5457, ups=2, wpb=3491.807, bsz=141.558, num_updates=24852, lr=0.000200595, gnorm=0.659, clip=0.000, oom=0.000, wall=4403, train_wall=8662
# | epoch 022 | loss 3.313 | nll_loss 1.818 | ppl 3.52 | wps 5457 | ups 2 | wpb 3491.701 | bsz 141.679 | num_updates 24882 | lr 0.000200474 | gnorm 0.659 | clip 0.000 | oom 0.000 | wall 4422 | train_wall 8681
# | epoch 022 | valid on 'valid' subset | loss 3.920 | nll_loss 2.351 | ppl 5.10 | num_updates 24882 | best_loss 3.9111
# | saved checkpoint /content/gdrive/My Drive/colab/payless/save_dev3/dynamic_conv_iwslt/checkpoint22.pt (epoch 22 @ 24882 updates) (writing took 4.83738374710083 seconds)
# | epoch 023:    100 / 1131 loss=3.246, nll_loss=1.740, ppl=3.34, wps=5403, ups=2, wpb=3500.772, bsz=146.851, num_updates=24983, lr=0.000200068, gnorm=0.640, clip=0.000, oom=0.000, wall=4505, train_wall=8746
# | epoch 023:    200 / 1131 loss=3.265, nll_loss=1.761, ppl=3.39, wps=5476, ups=2, wpb=3535.856, bsz=140.100, num_updates=25083, lr=0.000199669, gnorm=0.645, clip=0.000, oom=0.000, wall=4569, train_wall=8810
# | epoch 023:    300 / 1131 loss=3.272, nll_loss=1.769, ppl=3.41, wps=5460, ups=2, wpb=3507.266, bsz=138.445, num_updates=25183, lr=0.000199272, gnorm=0.653, clip=0.000, oom=0.000, wall=4633, train_wall=8873
# | epoch 023:    400 / 1131 loss=3.265, nll_loss=1.761, ppl=3.39, wps=5447, ups=2, wpb=3491.818, bsz=141.387, num_updates=25283, lr=0.000198878, gnorm=0.654, clip=0.000, oom=0.000, wall=4696, train_wall=8936
# | epoch 023:    500 / 1131 loss=3.267, nll_loss=1.764, ppl=3.40, wps=5458, ups=2, wpb=3503.709, bsz=142.739, num_updates=25383, lr=0.000198485, gnorm=0.653, clip=0.000, oom=0.000, wall=4761, train_wall=9000
# | epoch 023:    600 / 1131 loss=3.280, nll_loss=1.778, ppl=3.43, wps=5457, ups=2, wpb=3496.461, bsz=138.394, num_updates=25483, lr=0.000198096, gnorm=0.658, clip=0.000, oom=0.000, wall=4824, train_wall=9063
# | epoch 023:    700 / 1131 loss=3.285, nll_loss=1.783, ppl=3.44, wps=5454, ups=2, wpb=3492.546, bsz=137.688, num_updates=25583, lr=0.000197708, gnorm=0.661, clip=0.000, oom=0.000, wall=4888, train_wall=9127
# | epoch 023:    800 / 1131 loss=3.284, nll_loss=1.783, ppl=3.44, wps=5454, ups=2, wpb=3489.687, bsz=139.644, num_updates=25683, lr=0.000197323, gnorm=0.661, clip=0.000, oom=0.000, wall=4952, train_wall=9190
# | epoch 023:    900 / 1131 loss=3.287, nll_loss=1.787, ppl=3.45, wps=5452, ups=2, wpb=3489.576, bsz=139.808, num_updates=25783, lr=0.00019694, gnorm=0.662, clip=0.000, oom=0.000, wall=5016, train_wall=9253
# | epoch 023:   1000 / 1131 loss=3.288, nll_loss=1.788, ppl=3.45, wps=5453, ups=2, wpb=3489.438, bsz=140.403, num_updates=25883, lr=0.000196559, gnorm=0.662, clip=0.000, oom=0.000, wall=5080, train_wall=9317
# | epoch 023:   1100 / 1131 loss=3.288, nll_loss=1.788, ppl=3.45, wps=5449, ups=2, wpb=3490.091, bsz=141.231, num_updates=25983, lr=0.00019618, gnorm=0.662, clip=0.000, oom=0.000, wall=5145, train_wall=9381
# | epoch 023 | loss 3.288 | nll_loss 1.788 | ppl 3.45 | wps 5450 | ups 2 | wpb 3491.701 | bsz 141.679 | num_updates 26013 | lr 0.000196067 | gnorm 0.662 | clip 0.000 | oom 0.000 | wall 5164 | train_wall 9400
# | epoch 023 | valid on 'valid' subset | loss 3.923 | nll_loss 2.355 | ppl 5.12 | num_updates 26013 | best_loss 3.9111
# | saved checkpoint /content/gdrive/My Drive/colab/payless/save_dev3/dynamic_conv_iwslt/checkpoint23.pt (epoch 23 @ 26013 updates) (writing took 4.9654998779296875 seconds)
# | epoch 024:    100 / 1131 loss=3.210, nll_loss=1.698, ppl=3.25, wps=5378, ups=2, wpb=3474.535, bsz=149.307, num_updates=26114, lr=0.000195688, gnorm=0.650, clip=0.000, oom=0.000, wall=5247, train_wall=9465
# | epoch 024:    200 / 1131 loss=3.233, nll_loss=1.724, ppl=3.30, wps=5438, ups=2, wpb=3489.632, bsz=141.970, num_updates=26214, lr=0.000195314, gnorm=0.655, clip=0.000, oom=0.000, wall=5311, train_wall=9528
# | epoch 024:    300 / 1131 loss=3.248, nll_loss=1.741, ppl=3.34, wps=5453, ups=2, wpb=3489.027, bsz=138.179, num_updates=26314, lr=0.000194943, gnorm=0.662, clip=0.000, oom=0.000, wall=5374, train_wall=9591
# | epoch 024:    400 / 1131 loss=3.245, nll_loss=1.738, ppl=3.33, wps=5447, ups=2, wpb=3487.040, bsz=139.012, num_updates=26414, lr=0.000194573, gnorm=0.663, clip=0.000, oom=0.000, wall=5438, train_wall=9655
# | epoch 024:    500 / 1131 loss=3.250, nll_loss=1.744, ppl=3.35, wps=5449, ups=2, wpb=3485.293, bsz=139.257, num_updates=26514, lr=0.000194206, gnorm=0.665, clip=0.000, oom=0.000, wall=5502, train_wall=9718
# | epoch 024:    600 / 1131 loss=3.254, nll_loss=1.748, ppl=3.36, wps=5452, ups=2, wpb=3486.499, bsz=139.913, num_updates=26614, lr=0.000193841, gnorm=0.665, clip=0.000, oom=0.000, wall=5566, train_wall=9781
# | epoch 024:    700 / 1131 loss=3.254, nll_loss=1.748, ppl=3.36, wps=5459, ups=2, wpb=3494.181, bsz=140.371, num_updates=26714, lr=0.000193478, gnorm=0.664, clip=0.000, oom=0.000, wall=5630, train_wall=9845
# | epoch 024:    800 / 1131 loss=3.256, nll_loss=1.751, ppl=3.37, wps=5460, ups=2, wpb=3496.223, bsz=140.365, num_updates=26814, lr=0.000193116, gnorm=0.664, clip=0.000, oom=0.000, wall=5695, train_wall=9909
# | epoch 024:    900 / 1131 loss=3.259, nll_loss=1.755, ppl=3.37, wps=5456, ups=2, wpb=3491.495, bsz=141.052, num_updates=26914, lr=0.000192757, gnorm=0.666, clip=0.000, oom=0.000, wall=5758, train_wall=9972
# | epoch 024:   1000 / 1131 loss=3.262, nll_loss=1.757, ppl=3.38, wps=5456, ups=2, wpb=3493.110, bsz=141.801, num_updates=27014, lr=0.0001924, gnorm=0.666, clip=0.000, oom=0.000, wall=5823, train_wall=10036
# | epoch 024:   1100 / 1131 loss=3.265, nll_loss=1.761, ppl=3.39, wps=5457, ups=2, wpb=3491.548, bsz=142.117, num_updates=27114, lr=0.000192045, gnorm=0.667, clip=0.000, oom=0.000, wall=5886, train_wall=10099
# | epoch 024 | loss 3.266 | nll_loss 1.762 | ppl 3.39 | wps 5457 | ups 2 | wpb 3491.701 | bsz 141.679 | num_updates 27144 | lr 0.000191939 | gnorm 0.667 | clip 0.000 | oom 0.000 | wall 5905 | train_wall 10118
# | epoch 024 | valid on 'valid' subset | loss 3.919 | nll_loss 2.350 | ppl 5.10 | num_updates 27144 | best_loss 3.9111
# | saved checkpoint /content/gdrive/My Drive/colab/payless/save_dev3/dynamic_conv_iwslt/checkpoint24.pt (epoch 24 @ 27144 updates) (writing took 4.628965616226196 seconds)
# | epoch 025:    100 / 1131 loss=3.180, nll_loss=1.661, ppl=3.16, wps=5365, ups=2, wpb=3426.891, bsz=133.782, num_updates=27245, lr=0.000191583, gnorm=0.661, clip=0.000, oom=0.000, wall=5987, train_wall=10182
# | epoch 025:    200 / 1131 loss=3.193, nll_loss=1.678, ppl=3.20, wps=5463, ups=2, wpb=3499.294, bsz=142.368, num_updates=27345, lr=0.000191232, gnorm=0.657, clip=0.000, oom=0.000, wall=6051, train_wall=10246
# | epoch 025:    300 / 1131 loss=3.201, nll_loss=1.687, ppl=3.22, wps=5472, ups=2, wpb=3502.631, bsz=143.256, num_updates=27445, lr=0.000190883, gnorm=0.658, clip=0.000, oom=0.000, wall=6115, train_wall=10309
# | epoch 025:    400 / 1131 loss=3.206, nll_loss=1.693, ppl=3.23, wps=5458, ups=2, wpb=3491.853, bsz=141.903, num_updates=27545, lr=0.000190537, gnorm=0.663, clip=0.000, oom=0.000, wall=6179, train_wall=10373
# | epoch 025:    500 / 1131 loss=3.217, nll_loss=1.705, ppl=3.26, wps=5456, ups=2, wpb=3490.461, bsz=141.395, num_updates=27645, lr=0.000190192, gnorm=0.666, clip=0.000, oom=0.000, wall=6243, train_wall=10436
# | epoch 025:    600 / 1131 loss=3.226, nll_loss=1.715, ppl=3.28, wps=5475, ups=2, wpb=3506.962, bsz=140.391, num_updates=27745, lr=0.000189849, gnorm=0.665, clip=0.000, oom=0.000, wall=6308, train_wall=10500
# | epoch 025:    700 / 1131 loss=3.233, nll_loss=1.724, ppl=3.30, wps=5466, ups=2, wpb=3497.418, bsz=138.954, num_updates=27845, lr=0.000189507, gnorm=0.669, clip=0.000, oom=0.000, wall=6371, train_wall=10563
# | epoch 025:    800 / 1131 loss=3.237, nll_loss=1.728, ppl=3.31, wps=5463, ups=2, wpb=3494.496, bsz=137.996, num_updates=27945, lr=0.000189168, gnorm=0.670, clip=0.000, oom=0.000, wall=6435, train_wall=10627
# | epoch 025:    900 / 1131 loss=3.239, nll_loss=1.730, ppl=3.32, wps=5456, ups=2, wpb=3490.186, bsz=139.195, num_updates=28045, lr=0.000188831, gnorm=0.670, clip=0.000, oom=0.000, wall=6499, train_wall=10690
# | epoch 025:   1000 / 1131 loss=3.238, nll_loss=1.730, ppl=3.32, wps=5458, ups=2, wpb=3494.894, bsz=141.282, num_updates=28145, lr=0.000188495, gnorm=0.669, clip=0.000, oom=0.000, wall=6564, train_wall=10754
# | epoch 025:   1100 / 1131 loss=3.244, nll_loss=1.737, ppl=3.33, wps=5464, ups=2, wpb=3495.530, bsz=141.667, num_updates=28245, lr=0.000188161, gnorm=0.670, clip=0.000, oom=0.000, wall=6627, train_wall=10817
# | epoch 025 | loss 3.245 | nll_loss 1.738 | ppl 3.34 | wps 5461 | ups 2 | wpb 3491.701 | bsz 141.679 | num_updates 28275 | lr 0.000188061 | gnorm 0.671 | clip 0.000 | oom 0.000 | wall 6646 | train_wall 10836
# | epoch 025 | valid on 'valid' subset | loss 3.920 | nll_loss 2.350 | ppl 5.10 | num_updates 28275 | best_loss 3.9111
# | saved checkpoint /content/gdrive/My Drive/colab/payless/save_dev3/dynamic_conv_iwslt/checkpoint25.pt (epoch 25 @ 28275 updates) (writing took 4.9217352867126465 seconds)
# | epoch 026:    100 / 1131 loss=3.134, nll_loss=1.613, ppl=3.06, wps=5443, ups=2, wpb=3507.564, bsz=164.911, num_updates=28376, lr=0.000187726, gnorm=0.642, clip=0.000, oom=0.000, wall=6729, train_wall=10900
# | epoch 026:    200 / 1131 loss=3.167, nll_loss=1.649, ppl=3.14, wps=5477, ups=2, wpb=3520.706, bsz=150.965, num_updates=28476, lr=0.000187396, gnorm=0.653, clip=0.000, oom=0.000, wall=6793, train_wall=10964
# | epoch 026:    300 / 1131 loss=3.175, nll_loss=1.657, ppl=3.15, wps=5472, ups=2, wpb=3510.867, bsz=150.166, num_updates=28576, lr=0.000187068, gnorm=0.656, clip=0.000, oom=0.000, wall=6857, train_wall=11028
# | epoch 026:    400 / 1131 loss=3.186, nll_loss=1.670, ppl=3.18, wps=5460, ups=2, wpb=3498.486, bsz=144.399, num_updates=28676, lr=0.000186741, gnorm=0.663, clip=0.000, oom=0.000, wall=6920, train_wall=11091
# | epoch 026:    500 / 1131 loss=3.196, nll_loss=1.681, ppl=3.21, wps=5452, ups=2, wpb=3487.733, bsz=142.723, num_updates=28776, lr=0.000186417, gnorm=0.666, clip=0.000, oom=0.000, wall=6984, train_wall=11154
# | epoch 026:    600 / 1131 loss=3.199, nll_loss=1.685, ppl=3.21, wps=5447, ups=2, wpb=3486.950, bsz=142.083, num_updates=28876, lr=0.000186094, gnorm=0.668, clip=0.000, oom=0.000, wall=7048, train_wall=11218
# | epoch 026:    700 / 1131 loss=3.206, nll_loss=1.693, ppl=3.23, wps=5457, ups=2, wpb=3489.291, bsz=141.444, num_updates=28976, lr=0.000185772, gnorm=0.669, clip=0.000, oom=0.000, wall=7112, train_wall=11281
# | epoch 026:    800 / 1131 loss=3.212, nll_loss=1.700, ppl=3.25, wps=5463, ups=2, wpb=3487.793, bsz=140.335, num_updates=29076, lr=0.000185452, gnorm=0.671, clip=0.000, oom=0.000, wall=7175, train_wall=11343
# | epoch 026:    900 / 1131 loss=3.214, nll_loss=1.702, ppl=3.25, wps=5472, ups=2, wpb=3493.284, bsz=141.496, num_updates=29176, lr=0.000185134, gnorm=0.671, clip=0.000, oom=0.000, wall=7239, train_wall=11407
# | epoch 026:   1000 / 1131 loss=3.222, nll_loss=1.711, ppl=3.27, wps=5485, ups=2, wpb=3496.195, bsz=142.018, num_updates=29276, lr=0.000184818, gnorm=0.672, clip=0.000, oom=0.000, wall=7301, train_wall=11469
# | epoch 026:   1100 / 1131 loss=3.223, nll_loss=1.713, ppl=3.28, wps=5485, ups=2, wpb=3494.808, bsz=142.358, num_updates=29376, lr=0.000184503, gnorm=0.672, clip=0.000, oom=0.000, wall=7365, train_wall=11532
# | epoch 026 | loss 3.224 | nll_loss 1.714 | ppl 3.28 | wps 5481 | ups 2 | wpb 3491.701 | bsz 141.679 | num_updates 29406 | lr 0.000184409 | gnorm 0.673 | clip 0.000 | oom 0.000 | wall 7384 | train_wall 11551
# | epoch 026 | valid on 'valid' subset | loss 3.936 | nll_loss 2.369 | ppl 5.16 | num_updates 29406 | best_loss 3.9111
# | saved checkpoint /content/gdrive/My Drive/colab/payless/save_dev3/dynamic_conv_iwslt/checkpoint26.pt (epoch 26 @ 29406 updates) (writing took 5.474182605743408 seconds)
# | epoch 027:    100 / 1131 loss=3.153, nll_loss=1.631, ppl=3.10, wps=5483, ups=2, wpb=3522.356, bsz=141.465, num_updates=29507, lr=0.000184093, gnorm=0.657, clip=0.000, oom=0.000, wall=7467, train_wall=11616
# | epoch 027:    200 / 1131 loss=3.155, nll_loss=1.635, ppl=3.11, wps=5472, ups=2, wpb=3486.831, bsz=149.612, num_updates=29607, lr=0.000183782, gnorm=0.664, clip=0.000, oom=0.000, wall=7530, train_wall=11678
# | epoch 027:    300 / 1131 loss=3.164, nll_loss=1.644, ppl=3.13, wps=5467, ups=2, wpb=3481.243, bsz=145.037, num_updates=29707, lr=0.000183472, gnorm=0.669, clip=0.000, oom=0.000, wall=7594, train_wall=11741
# | epoch 027:    400 / 1131 loss=3.175, nll_loss=1.657, ppl=3.15, wps=5477, ups=2, wpb=3488.297, bsz=143.122, num_updates=29807, lr=0.000183164, gnorm=0.670, clip=0.000, oom=0.000, wall=7657, train_wall=11805
# | epoch 027:    500 / 1131 loss=3.177, nll_loss=1.659, ppl=3.16, wps=5482, ups=2, wpb=3495.521, bsz=143.026, num_updates=29907, lr=0.000182858, gnorm=0.670, clip=0.000, oom=0.000, wall=7721, train_wall=11868
# | epoch 027:    600 / 1131 loss=3.182, nll_loss=1.664, ppl=3.17, wps=5497, ups=2, wpb=3500.369, bsz=144.200, num_updates=30007, lr=0.000182553, gnorm=0.671, clip=0.000, oom=0.000, wall=7785, train_wall=11931
# | epoch 027:    700 / 1131 loss=3.191, nll_loss=1.675, ppl=3.19, wps=5502, ups=2, wpb=3499.906, bsz=142.231, num_updates=30107, lr=0.000182249, gnorm=0.674, clip=0.000, oom=0.000, wall=7848, train_wall=11994
# ...
# | epoch 039:   1000 / 1131 loss=3.021, nll_loss=1.476, ppl=2.78, wps=5496, ups=2, wpb=3497.826, bsz=142.009, num_updates=43979, lr=0.000150792, gnorm=0.715, clip=0.000, oom=0.000, wall=16877, train_wall=20746
# | epoch 039:   1100 / 1131 loss=3.023, nll_loss=1.478, ppl=2.79, wps=5492, ups=2, wpb=3494.713, bsz=141.885, num_updates=44079, lr=0.000150621, gnorm=0.716, clip=0.000, oom=0.000, wall=16941, train_wall=20810
# | epoch 039 | loss 3.025 | nll_loss 1.481 | ppl 2.79 | wps 5490 | ups 2 | wpb 3491.701 | bsz 141.679 | num_updates 44109 | lr 0.000150569 | gnorm 0.717 | clip 0.000 | oom 0.000 | wall 16960 | train_wall 20828
# | epoch 039 | valid on 'valid' subset | loss 3.958 | nll_loss 2.393 | ppl 5.25 | num_updates 44109 | best_loss 3.9111
# | saved checkpoint /content/gdrive/My Drive/colab/payless/save_dev3/dynamic_conv_iwslt/checkpoint39.pt (epoch 39 @ 44109 updates) (writing took 5.258158206939697 seconds)
# | epoch 040:    100 / 1131 loss=2.983, nll_loss=1.430, ppl=2.69, wps=5369, ups=2, wpb=3412.040, bsz=123.723, num_updates=44210, lr=0.000150397, gnorm=0.723, clip=0.000, oom=0.000, wall=17042, train_wall=20892
# | epoch 040:    200 / 1131 loss=2.975, nll_loss=1.422, ppl=2.68, wps=5409, ups=2, wpb=3427.199, bsz=132.697, num_updates=44310, lr=0.000150227, gnorm=0.717, clip=0.000, oom=0.000, wall=17105, train_wall=20955
# | epoch 040:    300 / 1131 loss=2.981, nll_loss=1.428, ppl=2.69, wps=5426, ups=2, wpb=3446.910, bsz=131.907, num_updates=44410, lr=0.000150058, gnorm=0.717, clip=0.000, oom=0.000, wall=17169, train_wall=21018
# | epoch 040:    400 / 1131 loss=2.993, nll_loss=1.441, ppl=2.72, wps=5451, ups=2, wpb=3465.671, bsz=131.070, num_updates=44510, lr=0.000149889, gnorm=0.720, clip=0.000, oom=0.000, wall=17232, train_wall=21081
# | epoch 040:    500 / 1131 loss=2.998, nll_loss=1.448, ppl=2.73, wps=5460, ups=2, wpb=3467.411, bsz=132.772, num_updates=44610, lr=0.000149721, gnorm=0.722, clip=0.000, oom=0.000, wall=17296, train_wall=21144
# | epoch 040:    600 / 1131 loss=2.998, nll_loss=1.448, ppl=2.73, wps=5462, ups=2, wpb=3469.631, bsz=135.493, num_updates=44710, lr=0.000149554, gnorm=0.721, clip=0.000, oom=0.000, wall=17359, train_wall=21207
# | epoch 040:    700 / 1131 loss=2.998, nll_loss=1.449, ppl=2.73, wps=5464, ups=2, wpb=3474.101, bsz=137.699, num_updates=44810, lr=0.000149387, gnorm=0.720, clip=0.000, oom=0.000, wall=17423, train_wall=21270
# | epoch 040:    800 / 1131 loss=3.003, nll_loss=1.455, ppl=2.74, wps=5472, ups=2, wpb=3478.930, bsz=138.286, num_updates=44910, lr=0.00014922, gnorm=0.721, clip=0.000, oom=0.000, wall=17487, train_wall=21334
# | epoch 040:    900 / 1131 loss=3.006, nll_loss=1.459, ppl=2.75, wps=5470, ups=2, wpb=3476.736, bsz=138.982, num_updates=45010, lr=0.000149055, gnorm=0.721, clip=0.000, oom=0.000, wall=17550, train_wall=21396
# | epoch 040:   1000 / 1131 loss=3.010, nll_loss=1.463, ppl=2.76, wps=5475, ups=2, wpb=3479.652, bsz=139.388, num_updates=45110, lr=0.000148889, gnorm=0.722, clip=0.000, oom=0.000, wall=17614, train_wall=21459
# | epoch 040:   1100 / 1131 loss=3.013, nll_loss=1.467, ppl=2.76, wps=5487, ups=2, wpb=3491.003, bsz=141.856, num_updates=45210, lr=0.000148725, gnorm=0.720, clip=0.000, oom=0.000, wall=17678, train_wall=21523
# | epoch 040 | loss 3.013 | nll_loss 1.467 | ppl 2.77 | wps 5487 | ups 2 | wpb 3491.701 | bsz 141.679 | num_updates 45240 | lr 0.000148675 | gnorm 0.720 | clip 0.000 | oom 0.000 | wall 17697 | train_wall 21542
# | epoch 040 | valid on 'valid' subset | loss 3.968 | nll_loss 2.400 | ppl 5.28 | num_updates 45240 | best_loss 3.9111
# | saved checkpoint /content/gdrive/My Drive/colab/payless/save_dev3/dynamic_conv_iwslt/checkpoint40.pt (epoch 40 @ 45240 updates) (writing took 5.0938849449157715 seconds)
# | epoch 041:    100 / 1131 loss=2.964, nll_loss=1.411, ppl=2.66, wps=5508, ups=2, wpb=3551.337, bsz=148.356, num_updates=45341, lr=0.00014851, gnorm=0.696, clip=0.000, oom=0.000, wall=17780, train_wall=21607
# | epoch 041:    200 / 1131 loss=2.963, nll_loss=1.410, ppl=2.66, wps=5491, ups=2, wpb=3516.055, bsz=146.070, num_updates=45441, lr=0.000148346, gnorm=0.703, clip=0.000, oom=0.000, wall=17844, train_wall=21670
# | epoch 041:    300 / 1131 loss=2.963, nll_loss=1.409, ppl=2.66, wps=5482, ups=2, wpb=3501.797, bsz=147.402, num_updates=45541, lr=0.000148183, gnorm=0.706, clip=0.000, oom=0.000, wall=17907, train_wall=21733
# | epoch 041:    400 / 1131 loss=2.970, nll_loss=1.418, ppl=2.67, wps=5498, ups=2, wpb=3513.100, bsz=146.015, num_updates=45641, lr=0.000148021, gnorm=0.707, clip=0.000, oom=0.000, wall=17971, train_wall=21797
# | epoch 041:    500 / 1131 loss=2.978, nll_loss=1.427, ppl=2.69, wps=5507, ups=2, wpb=3520.152, bsz=144.094, num_updates=45741, lr=0.000147859, gnorm=0.709, clip=0.000, oom=0.000, wall=18035, train_wall=21860
# | epoch 041:    600 / 1131 loss=2.983, nll_loss=1.433, ppl=2.70, wps=5508, ups=2, wpb=3517.977, bsz=144.930, num_updates=45841, lr=0.000147697, gnorm=0.712, clip=0.000, oom=0.000, wall=18099, train_wall=21923
# | epoch 041:    700 / 1131 loss=2.987, nll_loss=1.437, ppl=2.71, wps=5494, ups=2, wpb=3503.223, bsz=144.341, num_updates=45941, lr=0.000147537, gnorm=0.715, clip=0.000, oom=0.000, wall=18162, train_wall=21986
# | epoch 041:    800 / 1131 loss=2.987, nll_loss=1.437, ppl=2.71, wps=5487, ups=2, wpb=3496.377, bsz=145.517, num_updates=46041, lr=0.000147376, gnorm=0.717, clip=0.000, oom=0.000, wall=18225, train_wall=22049
# | epoch 041:    900 / 1131 loss=2.992, nll_loss=1.442, ppl=2.72, wps=5485, ups=2, wpb=3493.572, bsz=143.679, num_updates=46141, lr=0.000147217, gnorm=0.720, clip=0.000, oom=0.000, wall=18289, train_wall=22112
# | epoch 041:   1000 / 1131 loss=2.996, nll_loss=1.448, ppl=2.73, wps=5480, ups=2, wpb=3489.206, bsz=142.009, num_updates=46241, lr=0.000147057, gnorm=0.722, clip=0.000, oom=0.000, wall=18352, train_wall=22175
# | epoch 041:   1100 / 1131 loss=3.000, nll_loss=1.453, ppl=2.74, wps=5486, ups=2, wpb=3491.368, bsz=142.052, num_updates=46341, lr=0.000146898, gnorm=0.723, clip=0.000, oom=0.000, wall=18416, train_wall=22238
# | epoch 041 | loss 3.002 | nll_loss 1.454 | ppl 2.74 | wps 5487 | ups 2 | wpb 3491.701 | bsz 141.679 | num_updates 46371 | lr 0.000146851 | gnorm 0.723 | clip 0.000 | oom 0.000 | wall 18435 | train_wall 22257
# | epoch 041 | valid on 'valid' subset | loss 3.970 | nll_loss 2.399 | ppl 5.27 | num_updates 46371 | best_loss 3.9111
# | saved checkpoint /content/gdrive/My Drive/colab/payless/save_dev3/dynamic_conv_iwslt/checkpoint41.pt (epoch 41 @ 46371 updates) (writing took 4.648782968521118 seconds)
# | epoch 042:    100 / 1131 loss=2.959, nll_loss=1.403, ppl=2.65, wps=5443, ups=2, wpb=3474.871, bsz=136.634, num_updates=46472, lr=0.000146691, gnorm=0.715, clip=0.000, oom=0.000, wall=18517, train_wall=22321
# | epoch 042:    200 / 1131 loss=2.959, nll_loss=1.403, ppl=2.64, wps=5449, ups=2, wpb=3466.796, bsz=135.363, num_updates=46572, lr=0.000146534, gnorm=0.717, clip=0.000, oom=0.000, wall=18580, train_wall=22384
# | epoch 042:    300 / 1131 loss=2.968, nll_loss=1.414, ppl=2.66, wps=5453, ups=2, wpb=3454.854, bsz=136.133, num_updates=46672, lr=0.000146377, gnorm=0.724, clip=0.000, oom=0.000, wall=18643, train_wall=22446
# | epoch 042:    400 / 1131 loss=2.971, nll_loss=1.417, ppl=2.67, wps=5455, ups=2, wpb=3454.192, bsz=133.845, num_updates=46772, lr=0.00014622, gnorm=0.726, clip=0.000, oom=0.000, wall=18706, train_wall=22509
# | epoch 042:    500 / 1131 loss=2.976, nll_loss=1.422, ppl=2.68, wps=5470, ups=2, wpb=3468.475, bsz=134.180, num_updates=46872, lr=0.000146064, gnorm=0.727, clip=0.000, oom=0.000, wall=18770, train_wall=22572
# | epoch 042:    600 / 1131 loss=2.980, nll_loss=1.427, ppl=2.69, wps=5476, ups=2, wpb=3472.639, bsz=133.617, num_updates=46972, lr=0.000145908, gnorm=0.728, clip=0.000, oom=0.000, wall=18833, train_wall=22635
# | epoch 042:    700 / 1131 loss=2.982, nll_loss=1.429, ppl=2.69, wps=5471, ups=2, wpb=3471.826, bsz=136.331, num_updates=47072, lr=0.000145753, gnorm=0.728, clip=0.000, oom=0.000, wall=18897, train_wall=22698
# | epoch 042:    800 / 1131 loss=2.984, nll_loss=1.432, ppl=2.70, wps=5487, ups=2, wpb=3488.954, bsz=137.788, num_updates=47172, lr=0.000145599, gnorm=0.726, clip=0.000, oom=0.000, wall=18961, train_wall=22762
# | epoch 042:    900 / 1131 loss=2.986, nll_loss=1.435, ppl=2.70, wps=5482, ups=2, wpb=3483.915, bsz=139.747, num_updates=47272, lr=0.000145445, gnorm=0.727, clip=0.000, oom=0.000, wall=19025, train_wall=22825
# | epoch 042:   1000 / 1131 loss=2.988, nll_loss=1.438, ppl=2.71, wps=5482, ups=2, wpb=3483.971, bsz=140.899, num_updates=47372, lr=0.000145291, gnorm=0.727, clip=0.000, oom=0.000, wall=19088, train_wall=22888
# | epoch 042:   1100 / 1131 loss=2.991, nll_loss=1.441, ppl=2.72, wps=5483, ups=2, wpb=3489.008, bsz=141.238, num_updates=47472, lr=0.000145138, gnorm=0.727, clip=0.000, oom=0.000, wall=19153, train_wall=22952
# | epoch 042 | loss 2.992 | nll_loss 1.442 | ppl 2.72 | wps 5485 | ups 2 | wpb 3491.701 | bsz 141.679 | num_updates 47502 | lr 0.000145092 | gnorm 0.726 | clip 0.000 | oom 0.000 | wall 19172 | train_wall 22971
# | epoch 042 | valid on 'valid' subset | loss 3.993 | nll_loss 2.423 | ppl 5.36 | num_updates 47502 | best_loss 3.9111
# | saved checkpoint /content/gdrive/My Drive/colab/payless/save_dev3/dynamic_conv_iwslt/checkpoint42.pt (epoch 42 @ 47502 updates) (writing took 5.038205862045288 seconds)
# | epoch 043:    100 / 1131 loss=2.962, nll_loss=1.408, ppl=2.65, wps=5519, ups=2, wpb=3535.822, bsz=139.881, num_updates=47603, lr=0.000144938, gnorm=0.714, clip=0.000, oom=0.000, wall=19254, train_wall=23035
# | epoch 043:    200 / 1131 loss=2.953, nll_loss=1.398, ppl=2.64, wps=5472, ups=2, wpb=3490.214, bsz=153.075, num_updates=47703, lr=0.000144786, gnorm=0.714, clip=0.000, oom=0.000, wall=19318, train_wall=23098
# | epoch 043:    300 / 1131 loss=2.958, nll_loss=1.403, ppl=2.65, wps=5462, ups=2, wpb=3472.080, bsz=146.179, num_updates=47803, lr=0.000144635, gnorm=0.723, clip=0.000, oom=0.000, wall=19381, train_wall=23161
# | epoch 043:    400 / 1131 loss=2.959, nll_loss=1.404, ppl=2.65, wps=5473, ups=2, wpb=3480.132, bsz=140.948, num_updates=47903, lr=0.000144484, gnorm=0.724, clip=0.000, oom=0.000, wall=19445, train_wall=23224
# | epoch 043:    500 / 1131 loss=2.962, nll_loss=1.407, ppl=2.65, wps=5477, ups=2, wpb=3486.631, bsz=139.289, num_updates=48003, lr=0.000144333, gnorm=0.724, clip=0.000, oom=0.000, wall=19509, train_wall=23288
# | epoch 043:    600 / 1131 loss=2.967, nll_loss=1.413, ppl=2.66, wps=5476, ups=2, wpb=3485.351, bsz=139.754, num_updates=48103, lr=0.000144183, gnorm=0.727, clip=0.000, oom=0.000, wall=19572, train_wall=23351
# | epoch 043:    700 / 1131 loss=2.970, nll_loss=1.416, ppl=2.67, wps=5475, ups=2, wpb=3479.439, bsz=140.257, num_updates=48203, lr=0.000144033, gnorm=0.729, clip=0.000, oom=0.000, wall=19635, train_wall=23413
# | epoch 043:    800 / 1131 loss=2.974, nll_loss=1.421, ppl=2.68, wps=5481, ups=2, wpb=3483.483, bsz=141.831, num_updates=48303, lr=0.000143884, gnorm=0.729, clip=0.000, oom=0.000, wall=19699, train_wall=23476
# | epoch 043:    900 / 1131 loss=2.976, nll_loss=1.424, ppl=2.68, wps=5479, ups=2, wpb=3483.055, bsz=141.042, num_updates=48403, lr=0.000143735, gnorm=0.730, clip=0.000, oom=0.000, wall=19762, train_wall=23539
# | epoch 043:   1000 / 1131 loss=2.979, nll_loss=1.427, ppl=2.69, wps=5485, ups=2, wpb=3487.145, bsz=140.970, num_updates=48503, lr=0.000143587, gnorm=0.730, clip=0.000, oom=0.000, wall=19826, train_wall=23603
# | epoch 043:   1100 / 1131 loss=2.981, nll_loss=1.429, ppl=2.69, wps=5490, ups=2, wpb=3493.742, bsz=141.848, num_updates=48603, lr=0.000143439, gnorm=0.729, clip=0.000, oom=0.000, wall=19890, train_wall=23666
# | epoch 043 | loss 2.981 | nll_loss 1.429 | ppl 2.69 | wps 5486 | ups 2 | wpb 3491.701 | bsz 141.679 | num_updates 48633 | lr 0.000143395 | gnorm 0.729 | clip 0.000 | oom 0.000 | wall 19910 | train_wall 23685
# | epoch 043 | valid on 'valid' subset | loss 3.990 | nll_loss 2.418 | ppl 5.34 | num_updates 48633 | best_loss 3.9111
# | saved checkpoint /content/gdrive/My Drive/colab/payless/save_dev3/dynamic_conv_iwslt/checkpoint43.pt (epoch 43 @ 48633 updates) (writing took 5.381484031677246 seconds)
# | epoch 044:    100 / 1131 loss=2.932, nll_loss=1.372, ppl=2.59, wps=5469, ups=2, wpb=3522.752, bsz=134.495, num_updates=48734, lr=0.000143246, gnorm=0.717, clip=0.000, oom=0.000, wall=19993, train_wall=23750
# | epoch 044:    200 / 1131 loss=2.931, nll_loss=1.370, ppl=2.58, wps=5432, ups=2, wpb=3462.562, bsz=136.199, num_updates=48834, lr=0.0001431, gnorm=0.726, clip=0.000, oom=0.000, wall=20056, train_wall=23813
# | epoch 044:    300 / 1131 loss=2.934, nll_loss=1.374, ppl=2.59, wps=5420, ups=2, wpb=3452.455, bsz=139.000, num_updates=48934, lr=0.000142953, gnorm=0.726, clip=0.000, oom=0.000, wall=20119, train_wall=23876
# | epoch 044:    400 / 1131 loss=2.936, nll_loss=1.378, ppl=2.60, wps=5454, ups=2, wpb=3479.928, bsz=149.663, num_updates=49034, lr=0.000142808, gnorm=0.722, clip=0.000, oom=0.000, wall=20183, train_wall=23939
# | epoch 044:    500 / 1131 loss=2.946, nll_loss=1.389, ppl=2.62, wps=5470, ups=2, wpb=3496.986, bsz=146.329, num_updates=49134, lr=0.000142662, gnorm=0.723, clip=0.000, oom=0.000, wall=20248, train_wall=24003
# | epoch 044:    600 / 1131 loss=2.950, nll_loss=1.394, ppl=2.63, wps=5482, ups=2, wpb=3507.433, bsz=145.569, num_updates=49234, lr=0.000142517, gnorm=0.722, clip=0.000, oom=0.000, wall=20312, train_wall=24067
# | epoch 044:    700 / 1131 loss=2.957, nll_loss=1.402, ppl=2.64, wps=5488, ups=2, wpb=3507.509, bsz=145.437, num_updates=49334, lr=0.000142373, gnorm=0.724, clip=0.000, oom=0.000, wall=20376, train_wall=24130
# | epoch 044:    800 / 1131 loss=2.960, nll_loss=1.406, ppl=2.65, wps=5482, ups=2, wpb=3501.464, bsz=143.589, num_updates=49434, lr=0.000142229, gnorm=0.726, clip=0.000, oom=0.000, wall=20439, train_wall=24193
# | epoch 044:    900 / 1131 loss=2.960, nll_loss=1.405, ppl=2.65, wps=5471, ups=2, wpb=3491.553, bsz=144.123, num_updates=49534, lr=0.000142085, gnorm=0.727, clip=0.000, oom=0.000, wall=20503, train_wall=24256
# | epoch 044:   1000 / 1131 loss=2.964, nll_loss=1.409, ppl=2.66, wps=5463, ups=2, wpb=3485.258, bsz=142.600, num_updates=49634, lr=0.000141942, gnorm=0.730, clip=0.000, oom=0.000, wall=20566, train_wall=24319
# | epoch 044:   1100 / 1131 loss=2.968, nll_loss=1.415, ppl=2.67, wps=5473, ups=2, wpb=3491.745, bsz=141.340, num_updates=49734, lr=0.000141799, gnorm=0.731, clip=0.000, oom=0.000, wall=20630, train_wall=24382
# | epoch 044 | loss 2.970 | nll_loss 1.416 | ppl 2.67 | wps 5475 | ups 2 | wpb 3491.701 | bsz 141.679 | num_updates 49764 | lr 0.000141756 | gnorm 0.731 | clip 0.000 | oom 0.000 | wall 20649 | train_wall 24401
# | epoch 044 | valid on 'valid' subset | loss 3.980 | nll_loss 2.412 | ppl 5.32 | num_updates 49764 | best_loss 3.9111
# | saved checkpoint /content/gdrive/My Drive/colab/payless/save_dev3/dynamic_conv_iwslt/checkpoint44.pt (epoch 44 @ 49764 updates) (writing took 4.914334297180176 seconds)
# | epoch 045:    100 / 1131 loss=2.928, nll_loss=1.369, ppl=2.58, wps=5481, ups=2, wpb=3536.970, bsz=143.129, num_updates=49865, lr=0.000141613, gnorm=0.712, clip=0.000, oom=0.000, wall=20732, train_wall=24466
# | epoch 045:    200 / 1131 loss=2.923, nll_loss=1.363, ppl=2.57, wps=5490, ups=2, wpb=3538.562, bsz=150.965, num_updates=49965, lr=0.000141471, gnorm=0.715, clip=0.000, oom=0.000, wall=20796, train_wall=24530
# | epoch 045 | loss 2.923 | nll_loss 1.363 | ppl 2.57 | wps 5484 | ups 2 | wpb 3526.945 | bsz 148.576 | num_updates 50000 | lr 0.000141421 | gnorm 0.716 | clip 0.000 | oom 0.000 | wall 20818 | train_wall 24552
# | epoch 045 | valid on 'valid' subset | loss 3.995 | nll_loss 2.426 | ppl 5.37 | num_updates 50000 | best_loss 3.9111
# | saved checkpoint /content/gdrive/My Drive/colab/payless/save_dev3/dynamic_conv_iwslt/checkpoint_last.pt (epoch 45 @ 50000 updates) (writing took 2.4548215866088867 seconds)
# | done training in 20831.4 seconds

# %%
# !python scripts/average_checkpoints.py --inputs "{SAVE}" \
    --num-epoch-checkpoints 10 --output "{SAVE}/checkpoint_last10_avg.pt"

# Evaluation
# !CUDA_VISIBLE_DEVICES=0 fairseq-generate data-bin/iwslt14.tokenized.de-en --path "{SAVE}/checkpoint_last10_avg.pt" --batch-size 128 --beam 4 --remove-bpe --lenpen 1 --gen-subset test --quiet
# Out:
# Namespace(checkpoint_upper_bound=None, inputs=['/content/gdrive/My Drive/colab/payless/save_dev3/dynamic_conv_iwslt'], num_epoch_checkpoints=10, num_update_checkpoints=None, output='/content/gdrive/My Drive/colab/payless/save_dev3/dynamic_conv_iwslt/checkpoint_last10_avg.pt')
# averaging checkpoints:  ['/content/gdrive/My Drive/colab/payless/save_dev3/dynamic_conv_iwslt/checkpoint44.pt', '/content/gdrive/My Drive/colab/payless/save_dev3/dynamic_conv_iwslt/checkpoint43.pt', '/content/gdrive/My Drive/colab/payless/save_dev3/dynamic_conv_iwslt/checkpoint42.pt', '/content/gdrive/My Drive/colab/payless/save_dev3/dynamic_conv_iwslt/checkpoint41.pt', '/content/gdrive/My Drive/colab/payless/save_dev3/dynamic_conv_iwslt/checkpoint40.pt', '/content/gdrive/My Drive/colab/payless/save_dev3/dynamic_conv_iwslt/checkpoint39.pt', '/content/gdrive/My Drive/colab/payless/save_dev3/dynamic_conv_iwslt/checkpoint38.pt', '/content/gdrive/My Drive/colab/payless/save_dev3/dynamic_conv_iwslt/checkpoint37.pt', '/content/gdrive/My Drive/colab/payless/save_dev3/dynamic_conv_iwslt/checkpoint36.pt', '/content/gdrive/My Drive/colab/payless/save_dev3/dynamic_conv_iwslt/checkpoint35.pt']
# Finished writing averaged checkpoint to /content/gdrive/My Drive/colab/payless/save_dev3/dynamic_conv_iwslt/checkpoint_last10_avg.pt.
# Namespace(beam=4, bpe=None, cpu=False, criterion='cross_entropy', data='data-bin/iwslt14.tokenized.de-en', dataset_impl=None, decoding_format=None, diverse_beam_groups=-1, diverse_beam_strength=0.5, empty_cache_freq=0, force_anneal=None, fp16=False, fp16_init_scale=128, fp16_scale_tolerance=0.0, fp16_scale_window=None, gen_subset='test', iter_decode_eos_penalty=0.0, iter_decode_force_max_iter=False, iter_decode_max_iter=10, lazy_load=False, left_pad_source='True', left_pad_target='False', lenpen=1.0, load_alignments=False, log_format=None, log_interval=1000, lr_scheduler='fixed', lr_shrink=0.1, match_source_len=False, max_len_a=0, max_len_b=200, max_sentences=128, max_source_positions=1024, max_target_positions=1024, max_tokens=None, memory_efficient_fp16=False, min_len=1, min_loss_scale=0.0001, model_overrides='{}', momentum=0.99, nbest=1, no_beamable_mm=False, no_early_stop=False, no_progress_bar=False, no_repeat_ngram_size=0, num_shards=1, num_workers=1, optimizer='nag', path='/content/gdrive/My Drive/colab/payless/save_dev3/dynamic_conv_iwslt/checkpoint_last10_avg.pt', prefix_size=0, print_alignment=False, print_step=False, quiet=True, raw_text=False, remove_bpe='@@ ', replace_unk=None, required_batch_size_multiple=8, results_path=None, sacrebleu=False, sampling=False, sampling_topk=-1, sampling_topp=-1.0, score_reference=False, seed=1, shard_id=0, skip_invalid_size_inputs_valid_test=False, source_lang=None, target_lang=None, task='translation', tbmf_wrapper=False, temperature=1.0, tensorboard_logdir='', threshold_loss_scale=None, tokenizer=None, unkpen=0, unnormalized=False, upsample_primary=1, user_dir=None, warmup_updates=0, weight_decay=0.0)
# | [de] dictionary: 8848 types
# | [en] dictionary: 6632 types
# | loaded 6750 examples from: data-bin/iwslt14.tokenized.de-en/test.de-en.de
# | loaded 6750 examples from: data-bin/iwslt14.tokenized.de-en/test.de-en.en
# | data-bin/iwslt14.tokenized.de-en test de-en 6750 examples
# | loading model(s) from /content/gdrive/My Drive/colab/payless/save_dev3/dynamic_conv_iwslt/checkpoint_last10_avg.pt
# | Translated 6750 sentences (148307 tokens) in 76.1s (88.69 sentences/s, 1948.68 tokens/s)
# | Generate test with beam=4: BLEU4 = 34.49, 69.0/43.2/29.1/20.0 (BP=0.951, ratio=0.952, syslen=124916, reflen=131161)
