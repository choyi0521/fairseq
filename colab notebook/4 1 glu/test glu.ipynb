# %%
from google.colab import drive
drive.mount('/content/gdrive')

# To install fairseq from source and develop locally:
# !git clone https://github.com/choyi0521/fairseq
# %cd /content/fairseq
# !pip install --editable .
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive
# Cloning into 'fairseq'...
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 11951 (delta 0), reused 1 (delta 0), pack-reused 11945
# Receiving objects: 100% (11951/11951), 5.57 MiB | 10.70 MiB/s, done.
# Resolving deltas: 100% (8892/8892), done.
# /content/fairseq
# Obtaining file:///content/fairseq
# Requirement already satisfied: cffi in /usr/local/lib/python3.6/dist-packages (from fairseq==0.8.0) (1.13.2)
# Requirement already satisfied: cython in /usr/local/lib/python3.6/dist-packages (from fairseq==0.8.0) (0.29.14)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from fairseq==0.8.0) (1.17.4)
# Collecting regex
#   Downloading https://files.pythonhosted.org/packages/e3/8e/cbf2295643d7265e7883326fb4654e643bfc93b3a8a8274d8010a39d8804/regex-2019.11.1-cp36-cp36m-manylinux1_x86_64.whl (643kB)
#      |████████████████████████████████| 645kB 4.9MB/s
# Collecting sacrebleu
#   Downloading https://files.pythonhosted.org/packages/0e/e5/93d252182f7cbd4b59bb3ec5797e2ce33cfd6f5aadaf327db170cf4b7887/sacrebleu-1.4.2-py3-none-any.whl
# Requirement already satisfied: torch in /usr/local/lib/python3.6/dist-packages (from fairseq==0.8.0) (1.3.1+cu100)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from fairseq==0.8.0) (4.28.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.6/dist-packages (from cffi->fairseq==0.8.0) (2.19)
# Collecting portalocker
#   Downloading https://files.pythonhosted.org/packages/91/db/7bc703c0760df726839e0699b7f78a4d8217fdc9c7fcb1b51b39c5a22a4e/portalocker-1.5.2-py2.py3-none-any.whl
# Requirement already satisfied: typing in /usr/local/lib/python3.6/dist-packages (from sacrebleu->fairseq==0.8.0) (3.6.6)
# Installing collected packages: regex, portalocker, sacrebleu, fairseq
#   Running setup.py develop for fairseq
# Successfully installed fairseq portalocker-1.5.2 regex-2019.11.1 sacrebleu-1.4.2

# %%
# !git checkout dev
# !git pull origin dev
# Out:
# Branch 'dev' set up to track remote branch 'dev' from 'origin'.
# Switched to a new branch 'dev'
# From https://github.com/choyi0521/fairseq
#  * branch            dev        -> FETCH_HEAD
# Already up to date.

# %%
# Download and prepare the data
# %cd /content/fairseq
# %cd examples/translation/
# !bash prepare-iwslt14.sh
# %cd ../..

# Preprocess/binarize the data
TEXT="examples/translation/iwslt14.tokenized.de-en"
# !fairseq-preprocess --source-lang de --target-lang en \
    --trainpref $TEXT/train --validpref $TEXT/valid --testpref $TEXT/test \
    --destdir data-bin/iwslt14.tokenized.de-en \
    --workers 20
# Out:
# /content/fairseq
# /content/fairseq/examples/translation
# Cloning Moses github repository (for tokenization scripts)...
# Cloning into 'mosesdecoder'...
# remote: Enumerating objects: 163, done.
# remote: Counting objects: 100% (163/163), done.
# remote: Compressing objects: 100% (83/83), done.
# remote: Total 147458 (delta 101), reused 117 (delta 74), pack-reused 147295
# Receiving objects: 100% (147458/147458), 129.72 MiB | 25.47 MiB/s, done.
# Resolving deltas: 100% (113934/113934), done.
# Cloning Subword NMT repository (for BPE pre-processing)...
# Cloning into 'subword-nmt'...
# remote: Enumerating objects: 21, done.
# remote: Counting objects: 100% (21/21), done.
# remote: Compressing objects: 100% (15/15), done.
# remote: Total 530 (delta 9), reused 15 (delta 6), pack-reused 509
# Receiving objects: 100% (530/530), 224.83 KiB | 1.91 MiB/s, done.
# Resolving deltas: 100% (315/315), done.
# Downloading data from https://wit3.fbk.eu/archive/2014-01/texts/de/en/de-en.tgz...
# --2019-11-16 08:53:54--  https://wit3.fbk.eu/archive/2014-01/texts/de/en/de-en.tgz
# Resolving wit3.fbk.eu (wit3.fbk.eu)... 217.77.80.8
# Connecting to wit3.fbk.eu (wit3.fbk.eu)|217.77.80.8|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 19982877 (19M) [application/x-gzip]
# Saving to: ‘de-en.tgz’
#
# de-en.tgz           100%[===================>]  19.06M  6.04MB/s    in 4.6s
#
# 2019-11-16 08:53:59 (4.12 MB/s) - ‘de-en.tgz’ saved [19982877/19982877]
#
# Data successfully downloaded.
# de-en/
# de-en/IWSLT14.TED.dev2010.de-en.de.xml
# de-en/IWSLT14.TED.dev2010.de-en.en.xml
# de-en/IWSLT14.TED.tst2010.de-en.de.xml
# de-en/IWSLT14.TED.tst2010.de-en.en.xml
# de-en/IWSLT14.TED.tst2011.de-en.de.xml
# de-en/IWSLT14.TED.tst2011.de-en.en.xml
# de-en/IWSLT14.TED.tst2012.de-en.de.xml
# de-en/IWSLT14.TED.tst2012.de-en.en.xml
# de-en/IWSLT14.TEDX.dev2012.de-en.de.xml
# de-en/IWSLT14.TEDX.dev2012.de-en.en.xml
# de-en/README
# de-en/train.en
# de-en/train.tags.de-en.de
# de-en/train.tags.de-en.en
# pre-processing train data...
# Tokenizer Version 1.1
# Language: de
# Number of threads: 8
#
# Tokenizer Version 1.1
# Language: en
# Number of threads: 8
#
# clean-corpus.perl: processing iwslt14.tokenized.de-en/tmp/train.tags.de-en.tok.de & .en to iwslt14.tokenized.de-en/tmp/train.tags.de-en.clean, cutoff 1-175, ratio 1.5
# ..........(100000).......
# Input sentences: 174443  Output sentences:  167522
# pre-processing valid/test data...
# orig/de-en/IWSLT14.TED.dev2010.de-en.de.xml iwslt14.tokenized.de-en/tmp/IWSLT14.TED.dev2010.de-en.de
# Tokenizer Version 1.1
# Language: de
# Number of threads: 8
#
# orig/de-en/IWSLT14.TED.tst2010.de-en.de.xml iwslt14.tokenized.de-en/tmp/IWSLT14.TED.tst2010.de-en.de
# Tokenizer Version 1.1
# Language: de
# Number of threads: 8
#
# orig/de-en/IWSLT14.TED.tst2011.de-en.de.xml iwslt14.tokenized.de-en/tmp/IWSLT14.TED.tst2011.de-en.de
# Tokenizer Version 1.1
# Language: de
# Number of threads: 8
#
# orig/de-en/IWSLT14.TED.tst2012.de-en.de.xml iwslt14.tokenized.de-en/tmp/IWSLT14.TED.tst2012.de-en.de
# Tokenizer Version 1.1
# Language: de
# Number of threads: 8
#
# orig/de-en/IWSLT14.TEDX.dev2012.de-en.de.xml iwslt14.tokenized.de-en/tmp/IWSLT14.TEDX.dev2012.de-en.de
# Tokenizer Version 1.1
# Language: de
# Number of threads: 8
#
# orig/de-en/IWSLT14.TED.dev2010.de-en.en.xml iwslt14.tokenized.de-en/tmp/IWSLT14.TED.dev2010.de-en.en
# Tokenizer Version 1.1
# Language: en
# Number of threads: 8
#
# orig/de-en/IWSLT14.TED.tst2010.de-en.en.xml iwslt14.tokenized.de-en/tmp/IWSLT14.TED.tst2010.de-en.en
# Tokenizer Version 1.1
# Language: en
# Number of threads: 8
#
# orig/de-en/IWSLT14.TED.tst2011.de-en.en.xml iwslt14.tokenized.de-en/tmp/IWSLT14.TED.tst2011.de-en.en
# Tokenizer Version 1.1
# Language: en
# Number of threads: 8
#
# orig/de-en/IWSLT14.TED.tst2012.de-en.en.xml iwslt14.tokenized.de-en/tmp/IWSLT14.TED.tst2012.de-en.en
# Tokenizer Version 1.1
# Language: en
# Number of threads: 8
#
# orig/de-en/IWSLT14.TEDX.dev2012.de-en.en.xml iwslt14.tokenized.de-en/tmp/IWSLT14.TEDX.dev2012.de-en.en
# Tokenizer Version 1.1
# Language: en
# Number of threads: 8
#
# creating train, valid, test...
# learn_bpe.py on iwslt14.tokenized.de-en/tmp/train.en-de...
# subword-nmt/learn_bpe.py:267: DeprecationWarning: this script's location has moved to /content/fairseq/examples/translation/subword-nmt/subword_nmt. This symbolic link will be removed in a future version. Please point to the new location, or install the package and use the command 'subword-nmt'
#   DeprecationWarning
# apply_bpe.py to train.de...
# subword-nmt/apply_bpe.py:328: DeprecationWarning: this script's location has moved to /content/fairseq/examples/translation/subword-nmt/subword_nmt. This symbolic link will be removed in a future version. Please point to the new location, or install the package and use the command 'subword-nmt'
#   DeprecationWarning
# subword-nmt/apply_bpe.py:345: ResourceWarning: unclosed file <_io.TextIOWrapper name='iwslt14.tokenized.de-en/code' mode='r' encoding='UTF-8'>
#   args.codes = codecs.open(args.codes.name, encoding='utf-8')
# apply_bpe.py to valid.de...
# subword-nmt/apply_bpe.py:328: DeprecationWarning: this script's location has moved to /content/fairseq/examples/translation/subword-nmt/subword_nmt. This symbolic link will be removed in a future version. Please point to the new location, or install the package and use the command 'subword-nmt'
#   DeprecationWarning
# subword-nmt/apply_bpe.py:345: ResourceWarning: unclosed file <_io.TextIOWrapper name='iwslt14.tokenized.de-en/code' mode='r' encoding='UTF-8'>
#   args.codes = codecs.open(args.codes.name, encoding='utf-8')
# apply_bpe.py to test.de...
# subword-nmt/apply_bpe.py:328: DeprecationWarning: this script's location has moved to /content/fairseq/examples/translation/subword-nmt/subword_nmt. This symbolic link will be removed in a future version. Please point to the new location, or install the package and use the command 'subword-nmt'
#   DeprecationWarning
# subword-nmt/apply_bpe.py:345: ResourceWarning: unclosed file <_io.TextIOWrapper name='iwslt14.tokenized.de-en/code' mode='r' encoding='UTF-8'>
#   args.codes = codecs.open(args.codes.name, encoding='utf-8')
# apply_bpe.py to train.en...
# subword-nmt/apply_bpe.py:328: DeprecationWarning: this script's location has moved to /content/fairseq/examples/translation/subword-nmt/subword_nmt. This symbolic link will be removed in a future version. Please point to the new location, or install the package and use the command 'subword-nmt'
#   DeprecationWarning
# subword-nmt/apply_bpe.py:345: ResourceWarning: unclosed file <_io.TextIOWrapper name='iwslt14.tokenized.de-en/code' mode='r' encoding='UTF-8'>
#   args.codes = codecs.open(args.codes.name, encoding='utf-8')
# apply_bpe.py to valid.en...
# subword-nmt/apply_bpe.py:328: DeprecationWarning: this script's location has moved to /content/fairseq/examples/translation/subword-nmt/subword_nmt. This symbolic link will be removed in a future version. Please point to the new location, or install the package and use the command 'subword-nmt'
#   DeprecationWarning
# subword-nmt/apply_bpe.py:345: ResourceWarning: unclosed file <_io.TextIOWrapper name='iwslt14.tokenized.de-en/code' mode='r' encoding='UTF-8'>
#   args.codes = codecs.open(args.codes.name, encoding='utf-8')
# apply_bpe.py to test.en...
# subword-nmt/apply_bpe.py:328: DeprecationWarning: this script's location has moved to /content/fairseq/examples/translation/subword-nmt/subword_nmt. This symbolic link will be removed in a future version. Please point to the new location, or install the package and use the command 'subword-nmt'
#   DeprecationWarning
# subword-nmt/apply_bpe.py:345: ResourceWarning: unclosed file <_io.TextIOWrapper name='iwslt14.tokenized.de-en/code' mode='r' encoding='UTF-8'>
#   args.codes = codecs.open(args.codes.name, encoding='utf-8')
# /content/fairseq
# Namespace(align_suffix=None, alignfile=None, bpe=None, cpu=False, criterion='cross_entropy', dataset_impl='mmap', destdir='data-bin/iwslt14.tokenized.de-en', empty_cache_freq=0, fp16=False, fp16_init_scale=128, fp16_scale_tolerance=0.0, fp16_scale_window=None, joined_dictionary=False, log_format=None, log_interval=1000, lr_scheduler='fixed', memory_efficient_fp16=False, min_loss_scale=0.0001, no_progress_bar=False, nwordssrc=-1, nwordstgt=-1, only_source=False, optimizer='nag', padding_factor=8, seed=1, source_lang='de', srcdict=None, target_lang='en', task='translation', tbmf_wrapper=False, tensorboard_logdir='', testpref='examples/translation/iwslt14.tokenized.de-en/test', tgtdict=None, threshold_loss_scale=None, thresholdsrc=0, thresholdtgt=0, tokenizer=None, trainpref='examples/translation/iwslt14.tokenized.de-en/train', user_dir=None, validpref='examples/translation/iwslt14.tokenized.de-en/valid', workers=20)
# | [de] Dictionary: 8847 types
# | [de] examples/translation/iwslt14.tokenized.de-en/train.de: 160239 sents, 4035591 tokens, 0.0% replaced by <unk>
# | [de] Dictionary: 8847 types
# | [de] examples/translation/iwslt14.tokenized.de-en/valid.de: 7283 sents, 182592 tokens, 0.0192% replaced by <unk>
# | [de] Dictionary: 8847 types
# | [de] examples/translation/iwslt14.tokenized.de-en/test.de: 6750 sents, 161838 tokens, 0.0636% replaced by <unk>
# | [en] Dictionary: 6631 types
# | [en] examples/translation/iwslt14.tokenized.de-en/train.en: 160239 sents, 3949114 tokens, 0.0% replaced by <unk>
# | [en] Dictionary: 6631 types
# | [en] examples/translation/iwslt14.tokenized.de-en/valid.en: 7283 sents, 178622 tokens, 0.00448% replaced by <unk>
# | [en] Dictionary: 6631 types
# | [en] examples/translation/iwslt14.tokenized.de-en/test.en: 6750 sents, 156928 tokens, 0.00892% replaced by <unk>
# | Wrote preprocessed data to data-bin/iwslt14.tokenized.de-en

# %%
SAVE="/content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt"

# Training
# %cd /content/fairseq
# !mkdir -p "{SAVE}" 
# !CUDA_VISIBLE_DEVICES=0 $(which fairseq-train) data-bin/iwslt14.tokenized.de-en \
    --encoder-conv-type dynamic --decoder-conv-type dynamic \
    --clip-norm 0 --optimizer adam --lr 0.0005 \
    --source-lang de --target-lang en --max-tokens 4000 --no-progress-bar \
    --log-interval 100 --min-lr '1e-09' --weight-decay 0.0001 \
    --criterion label_smoothed_cross_entropy --label-smoothing 0.1 \
    --lr-scheduler inverse_sqrt \
    --ddp-backend=no_c10d \
    --max-update 50000 --warmup-updates 4000 --warmup-init-lr '1e-07' \
    --adam-betas '(0.9, 0.98)' --keep-last-epochs 10 \
    -a lightconv_iwslt_de_en --save-dir "{SAVE}" \
    --dropout 0.3 --attention-dropout 0.1 --weight-dropout 0.1 \
    --encoder-glu 1 --decoder-glu 1
# Out:
# /content/fairseq
# Namespace(adam_betas='(0.9, 0.98)', adam_eps=1e-08, adaptive_softmax_cutoff=None, adaptive_softmax_dropout=0, arch='lightconv_iwslt_de_en', attention_dropout=0.1, best_checkpoint_metric='loss', bpe=None, bucket_cap_mb=25, clip_norm=0.0, cpu=False, criterion='label_smoothed_cross_entropy', curriculum=0, data='data-bin/iwslt14.tokenized.de-en', dataset_impl=None, ddp_backend='no_c10d', decoder_attention_heads=4, decoder_attention_proj_heads=128, decoder_conv_dim=512, decoder_conv_type='dynamic', decoder_embed_dim=512, decoder_embed_path=None, decoder_ffn_embed_dim=1024, decoder_glu=True, decoder_input_dim=512, decoder_kernel_size_list=[3, 7, 15, 31, 31, 31], decoder_layers=6, decoder_learned_pos=False, decoder_normalize_before=False, decoder_output_dim=512, device_id=0, disable_validation=False, distributed_backend='nccl', distributed_init_method=None, distributed_no_spawn=False, distributed_port=-1, distributed_rank=0, distributed_world_size=1, dropout=0.3, empty_cache_freq=0, encoder_attention_heads=4, encoder_attention_proj_heads=128, encoder_conv_dim=512, encoder_conv_type='dynamic', encoder_embed_dim=512, encoder_embed_path=None, encoder_ffn_embed_dim=1024, encoder_glu=True, encoder_kernel_size_list=[3, 7, 15, 31, 31, 31, 31], encoder_layers=7, encoder_learned_pos=False, encoder_normalize_before=False, fast_stat_sync=False, find_unused_parameters=False, fix_batches_to_gpus=False, fixed_validation_seed=None, fp16=False, fp16_init_scale=128, fp16_scale_tolerance=0.0, fp16_scale_window=None, input_dropout=0.0, keep_interval_updates=-1, keep_last_epochs=10, label_smoothing=0.1, lazy_load=False, left_pad_source='True', left_pad_target='False', load_alignments=False, log_format=None, log_interval=100, lr=[0.0005], lr_scheduler='inverse_sqrt', max_epoch=0, max_sentences=None, max_sentences_valid=None, max_source_positions=1024, max_target_positions=1024, max_tokens=4000, max_tokens_valid=4000, max_update=50000, maximize_best_checkpoint_metric=False, memory_efficient_fp16=False, min_loss_scale=0.0001, min_lr=1e-09, no_epoch_checkpoints=False, no_last_checkpoints=False, no_progress_bar=True, no_save=False, no_save_optimizer_state=False, no_token_positional_embeddings=False, num_workers=1, optimizer='adam', optimizer_overrides='{}', raw_text=False, relu_dropout=0.0, required_batch_size_multiple=8, reset_dataloader=False, reset_lr_scheduler=False, reset_meters=False, reset_optimizer=False, restore_file='checkpoint_last.pt', save_dir='/content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt', save_interval=1, save_interval_updates=0, seed=1, sentence_avg=False, share_all_embeddings=False, share_decoder_input_output_embed=False, skip_invalid_size_inputs_valid_test=False, source_lang='de', target_lang='en', task='translation', tbmf_wrapper=False, tensorboard_logdir='', threshold_loss_scale=None, tokenizer=None, train_subset='train', update_freq=[1], upsample_primary=1, use_bmuf=False, user_dir=None, valid_subset='valid', validate_interval=1, warmup_init_lr=1e-07, warmup_updates=4000, weight_decay=0.0001, weight_dropout=0.1, weight_softmax=True)
# | [de] dictionary: 8848 types
# | [en] dictionary: 6632 types
# | loaded 7283 examples from: data-bin/iwslt14.tokenized.de-en/valid.de-en.de
# | loaded 7283 examples from: data-bin/iwslt14.tokenized.de-en/valid.de-en.en
# | data-bin/iwslt14.tokenized.de-en valid de-en 7283 examples
# No module named 'dynamicconv_cuda'
# No module named 'dynamicconv_cuda'
# No module named 'dynamicconv_cuda'
# No module named 'dynamicconv_cuda'
# No module named 'dynamicconv_cuda'
# No module named 'dynamicconv_cuda'
# No module named 'dynamicconv_cuda'
# No module named 'dynamicconv_cuda'
# No module named 'dynamicconv_cuda'
# No module named 'dynamicconv_cuda'
# No module named 'dynamicconv_cuda'
# No module named 'dynamicconv_cuda'
# No module named 'dynamicconv_cuda'
# LightConvModel(
#   (encoder): LightConvEncoder(
#     (embed_tokens): Embedding(8848, 512, padding_idx=1)
#     (embed_positions): SinusoidalPositionalEmbedding()
#     (layers): ModuleList(
#       (0): LightConvEncoderLayer(
#         dropout=0.3, relu_dropout=0.0, input_dropout=0.0, normalize_before=False
#         (linear1): Linear(in_features=512, out_features=1024, bias=True)
#         (act): GLU(dim=-1)
#         (conv): DynamicConv1dTBC(
#           512, kernel_size=3, padding_l=1, num_heads=4, weight_softmax=True, conv_bias=False, renorm_padding=False, in_proj=False, weight_dropout=0.1
#           (weight_linear): Linear(in_features=512, out_features=12, bias=False)
#         )
#         (linear2): Linear(in_features=512, out_features=512, bias=True)
#         (fc1): Linear(in_features=512, out_features=1024, bias=True)
#         (fc2): Linear(in_features=1024, out_features=512, bias=True)
#         (layer_norms): ModuleList(
#           (0): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#       (1): LightConvEncoderLayer(
#         dropout=0.3, relu_dropout=0.0, input_dropout=0.0, normalize_before=False
#         (linear1): Linear(in_features=512, out_features=1024, bias=True)
#         (act): GLU(dim=-1)
#         (conv): DynamicConv1dTBC(
#           512, kernel_size=7, padding_l=3, num_heads=4, weight_softmax=True, conv_bias=False, renorm_padding=False, in_proj=False, weight_dropout=0.1
#           (weight_linear): Linear(in_features=512, out_features=28, bias=False)
#         )
#         (linear2): Linear(in_features=512, out_features=512, bias=True)
#         (fc1): Linear(in_features=512, out_features=1024, bias=True)
#         (fc2): Linear(in_features=1024, out_features=512, bias=True)
#         (layer_norms): ModuleList(
#           (0): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#       (2): LightConvEncoderLayer(
#         dropout=0.3, relu_dropout=0.0, input_dropout=0.0, normalize_before=False
#         (linear1): Linear(in_features=512, out_features=1024, bias=True)
#         (act): GLU(dim=-1)
#         (conv): DynamicConv1dTBC(
#           512, kernel_size=15, padding_l=7, num_heads=4, weight_softmax=True, conv_bias=False, renorm_padding=False, in_proj=False, weight_dropout=0.1
#           (weight_linear): Linear(in_features=512, out_features=60, bias=False)
#         )
#         (linear2): Linear(in_features=512, out_features=512, bias=True)
#         (fc1): Linear(in_features=512, out_features=1024, bias=True)
#         (fc2): Linear(in_features=1024, out_features=512, bias=True)
#         (layer_norms): ModuleList(
#           (0): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#       (3): LightConvEncoderLayer(
#         dropout=0.3, relu_dropout=0.0, input_dropout=0.0, normalize_before=False
#         (linear1): Linear(in_features=512, out_features=1024, bias=True)
#         (act): GLU(dim=-1)
#         (conv): DynamicConv1dTBC(
#           512, kernel_size=31, padding_l=15, num_heads=4, weight_softmax=True, conv_bias=False, renorm_padding=False, in_proj=False, weight_dropout=0.1
#           (weight_linear): Linear(in_features=512, out_features=124, bias=False)
#         )
#         (linear2): Linear(in_features=512, out_features=512, bias=True)
#         (fc1): Linear(in_features=512, out_features=1024, bias=True)
#         (fc2): Linear(in_features=1024, out_features=512, bias=True)
#         (layer_norms): ModuleList(
#           (0): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#       (4): LightConvEncoderLayer(
#         dropout=0.3, relu_dropout=0.0, input_dropout=0.0, normalize_before=False
#         (linear1): Linear(in_features=512, out_features=1024, bias=True)
#         (act): GLU(dim=-1)
#         (conv): DynamicConv1dTBC(
#           512, kernel_size=31, padding_l=15, num_heads=4, weight_softmax=True, conv_bias=False, renorm_padding=False, in_proj=False, weight_dropout=0.1
#           (weight_linear): Linear(in_features=512, out_features=124, bias=False)
#         )
#         (linear2): Linear(in_features=512, out_features=512, bias=True)
#         (fc1): Linear(in_features=512, out_features=1024, bias=True)
#         (fc2): Linear(in_features=1024, out_features=512, bias=True)
#         (layer_norms): ModuleList(
#           (0): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#       (5): LightConvEncoderLayer(
#         dropout=0.3, relu_dropout=0.0, input_dropout=0.0, normalize_before=False
#         (linear1): Linear(in_features=512, out_features=1024, bias=True)
#         (act): GLU(dim=-1)
#         (conv): DynamicConv1dTBC(
#           512, kernel_size=31, padding_l=15, num_heads=4, weight_softmax=True, conv_bias=False, renorm_padding=False, in_proj=False, weight_dropout=0.1
#           (weight_linear): Linear(in_features=512, out_features=124, bias=False)
#         )
#         (linear2): Linear(in_features=512, out_features=512, bias=True)
#         (fc1): Linear(in_features=512, out_features=1024, bias=True)
#         (fc2): Linear(in_features=1024, out_features=512, bias=True)
#         (layer_norms): ModuleList(
#           (0): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#       (6): LightConvEncoderLayer(
#         dropout=0.3, relu_dropout=0.0, input_dropout=0.0, normalize_before=False
#         (linear1): Linear(in_features=512, out_features=1024, bias=True)
#         (act): GLU(dim=-1)
#         (conv): DynamicConv1dTBC(
#           512, kernel_size=31, padding_l=15, num_heads=4, weight_softmax=True, conv_bias=False, renorm_padding=False, in_proj=False, weight_dropout=0.1
#           (weight_linear): Linear(in_features=512, out_features=124, bias=False)
#         )
#         (linear2): Linear(in_features=512, out_features=512, bias=True)
#         (fc1): Linear(in_features=512, out_features=1024, bias=True)
#         (fc2): Linear(in_features=1024, out_features=512, bias=True)
#         (layer_norms): ModuleList(
#           (0): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#     )
#   )
#   (decoder): LightConvDecoder(
#     (embed_tokens): Embedding(6632, 512, padding_idx=1)
#     (embed_positions): SinusoidalPositionalEmbedding()
#     (layers): ModuleList(
#       (0): LightConvDecoderLayer(
#         dropout=0.3, relu_dropout=0.0, input_dropout=0.0, normalize_before=False
#         (linear1): Linear(in_features=512, out_features=1024, bias=True)
#         (act): GLU(dim=-1)
#         (conv): DynamicConv1dTBC(
#           512, kernel_size=3, padding_l=2, num_heads=4, weight_softmax=True, conv_bias=False, renorm_padding=False, in_proj=False, weight_dropout=0.1
#           (weight_linear): Linear(in_features=512, out_features=12, bias=False)
#         )
#         (linear2): Linear(in_features=512, out_features=512, bias=True)
#         (conv_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): MultiheadAttention(
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=1024, bias=True)
#         (fc2): Linear(in_features=1024, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (1): LightConvDecoderLayer(
#         dropout=0.3, relu_dropout=0.0, input_dropout=0.0, normalize_before=False
#         (linear1): Linear(in_features=512, out_features=1024, bias=True)
#         (act): GLU(dim=-1)
#         (conv): DynamicConv1dTBC(
#           512, kernel_size=7, padding_l=6, num_heads=4, weight_softmax=True, conv_bias=False, renorm_padding=False, in_proj=False, weight_dropout=0.1
#           (weight_linear): Linear(in_features=512, out_features=28, bias=False)
#         )
#         (linear2): Linear(in_features=512, out_features=512, bias=True)
#         (conv_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): MultiheadAttention(
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=1024, bias=True)
#         (fc2): Linear(in_features=1024, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (2): LightConvDecoderLayer(
#         dropout=0.3, relu_dropout=0.0, input_dropout=0.0, normalize_before=False
#         (linear1): Linear(in_features=512, out_features=1024, bias=True)
#         (act): GLU(dim=-1)
#         (conv): DynamicConv1dTBC(
#           512, kernel_size=15, padding_l=14, num_heads=4, weight_softmax=True, conv_bias=False, renorm_padding=False, in_proj=False, weight_dropout=0.1
#           (weight_linear): Linear(in_features=512, out_features=60, bias=False)
#         )
#         (linear2): Linear(in_features=512, out_features=512, bias=True)
#         (conv_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): MultiheadAttention(
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=1024, bias=True)
#         (fc2): Linear(in_features=1024, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (3): LightConvDecoderLayer(
#         dropout=0.3, relu_dropout=0.0, input_dropout=0.0, normalize_before=False
#         (linear1): Linear(in_features=512, out_features=1024, bias=True)
#         (act): GLU(dim=-1)
#         (conv): DynamicConv1dTBC(
#           512, kernel_size=31, padding_l=30, num_heads=4, weight_softmax=True, conv_bias=False, renorm_padding=False, in_proj=False, weight_dropout=0.1
#           (weight_linear): Linear(in_features=512, out_features=124, bias=False)
#         )
#         (linear2): Linear(in_features=512, out_features=512, bias=True)
#         (conv_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): MultiheadAttention(
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=1024, bias=True)
#         (fc2): Linear(in_features=1024, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (4): LightConvDecoderLayer(
#         dropout=0.3, relu_dropout=0.0, input_dropout=0.0, normalize_before=False
#         (linear1): Linear(in_features=512, out_features=1024, bias=True)
#         (act): GLU(dim=-1)
#         (conv): DynamicConv1dTBC(
#           512, kernel_size=31, padding_l=30, num_heads=4, weight_softmax=True, conv_bias=False, renorm_padding=False, in_proj=False, weight_dropout=0.1
#           (weight_linear): Linear(in_features=512, out_features=124, bias=False)
#         )
#         (linear2): Linear(in_features=512, out_features=512, bias=True)
#         (conv_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): MultiheadAttention(
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=1024, bias=True)
#         (fc2): Linear(in_features=1024, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (5): LightConvDecoderLayer(
#         dropout=0.3, relu_dropout=0.0, input_dropout=0.0, normalize_before=False
#         (linear1): Linear(in_features=512, out_features=1024, bias=True)
#         (act): GLU(dim=-1)
#         (conv): DynamicConv1dTBC(
#           512, kernel_size=31, padding_l=30, num_heads=4, weight_softmax=True, conv_bias=False, renorm_padding=False, in_proj=False, weight_dropout=0.1
#           (weight_linear): Linear(in_features=512, out_features=124, bias=False)
#         )
#         (linear2): Linear(in_features=512, out_features=512, bias=True)
#         (conv_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): MultiheadAttention(
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=1024, bias=True)
#         (fc2): Linear(in_features=1024, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#   )
# )
# | model lightconv_iwslt_de_en, criterion LabelSmoothedCrossEntropyCriterion
# | num. model params: 42099712 (num. trained: 42099712)
# | training on 1 GPUs
# | max tokens per GPU = 4000 and max sentences per GPU = None
# | no existing checkpoint found /content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint_last.pt
# | loading train data for epoch 0
# | loaded 160239 examples from: data-bin/iwslt14.tokenized.de-en/train.de-en.de
# | loaded 160239 examples from: data-bin/iwslt14.tokenized.de-en/train.de-en.en
# | data-bin/iwslt14.tokenized.de-en train de-en 160239 examples
# | epoch 001:    100 / 1131 loss=12.224, nll_loss=12.086, ppl=4347.32, wps=17082, ups=5, wpb=3503.178, bsz=123.723, num_updates=101, lr=1.27225e-05, gnorm=2.906, clip=0.000, oom=0.000, wall=22, train_wall=20
# | epoch 001:    200 / 1131 loss=11.455, nll_loss=11.224, ppl=2391.50, wps=16949, ups=5, wpb=3464.259, bsz=133.095, num_updates=201, lr=2.522e-05, gnorm=2.236, clip=0.000, oom=0.000, wall=42, train_wall=40
# | epoch 001:    300 / 1131 loss=10.947, nll_loss=10.648, ppl=1604.66, wps=16992, ups=5, wpb=3481.402, bsz=132.306, num_updates=301, lr=3.77175e-05, gnorm=1.923, clip=0.000, oom=0.000, wall=63, train_wall=61
# | epoch 001:    400 / 1131 loss=10.585, nll_loss=10.230, ppl=1201.31, wps=17055, ups=5, wpb=3496.042, bsz=134.943, num_updates=401, lr=5.0215e-05, gnorm=1.797, clip=0.000, oom=0.000, wall=84, train_wall=81
# | epoch 001:    500 / 1131 loss=10.298, nll_loss=9.896, ppl=952.97, wps=17051, ups=5, wpb=3502.858, bsz=141.395, num_updates=501, lr=6.27125e-05, gnorm=1.772, clip=0.000, oom=0.000, wall=104, train_wall=101
# | epoch 001:    600 / 1131 loss=10.089, nll_loss=9.653, ppl=805.27, wps=17015, ups=5, wpb=3490.700, bsz=141.243, num_updates=601, lr=7.521e-05, gnorm=1.718, clip=0.000, oom=0.000, wall=125, train_wall=121
# | epoch 001:    700 / 1131 loss=9.894, nll_loss=9.427, ppl=688.29, wps=17055, ups=5, wpb=3488.882, bsz=142.937, num_updates=701, lr=8.77075e-05, gnorm=1.689, clip=0.000, oom=0.000, wall=145, train_wall=141
# | epoch 001:    800 / 1131 loss=9.746, nll_loss=9.254, ppl=610.47, wps=17051, ups=5, wpb=3485.935, bsz=141.782, num_updates=801, lr=0.000100205, gnorm=1.656, clip=0.000, oom=0.000, wall=165, train_wall=161
# | epoch 001:    900 / 1131 loss=9.599, nll_loss=9.083, ppl=542.46, wps=17065, ups=5, wpb=3492.103, bsz=142.294, num_updates=901, lr=0.000112702, gnorm=1.627, clip=0.000, oom=0.000, wall=186, train_wall=182
# | epoch 001:   1000 / 1131 loss=9.474, nll_loss=8.938, ppl=490.60, wps=17056, ups=5, wpb=3490.413, bsz=142.249, num_updates=1001, lr=0.0001252, gnorm=1.593, clip=0.000, oom=0.000, wall=206, train_wall=202
# | epoch 001:   1100 / 1131 loss=9.359, nll_loss=8.804, ppl=446.97, wps=17059, ups=5, wpb=3491.418, bsz=141.870, num_updates=1101, lr=0.000137697, gnorm=1.561, clip=0.000, oom=0.000, wall=227, train_wall=222
# | epoch 001 | loss 9.326 | nll_loss 8.766 | ppl 435.40 | wps 17056 | ups 5 | wpb 3491.701 | bsz 141.679 | num_updates 1131 | lr 0.000141447 | gnorm 1.552 | clip 0.000 | oom 0.000 | wall 233 | train_wall 228
# | epoch 001 | valid on 'valid' subset | loss 7.891 | nll_loss 7.022 | ppl 129.97 | num_updates 1131
# | saved checkpoint /content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint1.pt (epoch 1 @ 1131 updates) (writing took 6.864075422286987 seconds)
# | epoch 002:    100 / 1131 loss=7.967, nll_loss=7.189, ppl=145.94, wps=16318, ups=5, wpb=3517.208, bsz=135.040, num_updates=1232, lr=0.000154069, gnorm=1.180, clip=0.000, oom=0.000, wall=265, train_wall=250
# | epoch 002:    200 / 1131 loss=7.850, nll_loss=7.054, ppl=132.89, wps=16661, ups=5, wpb=3513.721, bsz=150.920, num_updates=1332, lr=0.000166567, gnorm=1.254, clip=0.000, oom=0.000, wall=286, train_wall=270
# | epoch 002:    300 / 1131 loss=7.824, nll_loss=7.023, ppl=130.05, wps=16672, ups=5, wpb=3481.591, bsz=147.585, num_updates=1432, lr=0.000179064, gnorm=1.271, clip=0.000, oom=0.000, wall=306, train_wall=290
# | epoch 002:    400 / 1131 loss=7.767, nll_loss=6.957, ppl=124.25, wps=16834, ups=5, wpb=3501.506, bsz=146.012, num_updates=1532, lr=0.000191562, gnorm=1.237, clip=0.000, oom=0.000, wall=327, train_wall=310
# | epoch 002:    500 / 1131 loss=7.720, nll_loss=6.903, ppl=119.66, wps=16881, ups=5, wpb=3497.337, bsz=143.727, num_updates=1632, lr=0.000204059, gnorm=1.220, clip=0.000, oom=0.000, wall=347, train_wall=330
# | epoch 002:    600 / 1131 loss=7.666, nll_loss=6.840, ppl=114.53, wps=16922, ups=5, wpb=3500.067, bsz=143.945, num_updates=1732, lr=0.000216557, gnorm=1.211, clip=0.000, oom=0.000, wall=368, train_wall=351
# | epoch 002:    700 / 1131 loss=7.596, nll_loss=6.759, ppl=108.31, wps=16979, ups=5, wpb=3506.722, bsz=145.151, num_updates=1832, lr=0.000229054, gnorm=1.200, clip=0.000, oom=0.000, wall=388, train_wall=371
# | epoch 002:    800 / 1131 loss=7.550, nll_loss=6.706, ppl=104.39, wps=16975, ups=5, wpb=3498.361, bsz=143.390, num_updates=1932, lr=0.000241552, gnorm=1.188, clip=0.000, oom=0.000, wall=409, train_wall=391
# | epoch 002:    900 / 1131 loss=7.494, nll_loss=6.642, ppl=99.87, wps=16982, ups=5, wpb=3495.448, bsz=143.306, num_updates=2032, lr=0.000254049, gnorm=1.177, clip=0.000, oom=0.000, wall=429, train_wall=411
# | epoch 002:   1000 / 1131 loss=7.440, nll_loss=6.580, ppl=95.65, wps=17001, ups=5, wpb=3496.944, bsz=142.664, num_updates=2132, lr=0.000266547, gnorm=1.171, clip=0.000, oom=0.000, wall=449, train_wall=431
# | epoch 002:   1100 / 1131 loss=7.385, nll_loss=6.516, ppl=91.55, wps=16997, ups=5, wpb=3492.152, bsz=142.669, num_updates=2232, lr=0.000279044, gnorm=1.162, clip=0.000, oom=0.000, wall=470, train_wall=451
# | epoch 002 | loss 7.373 | nll_loss 6.502 | ppl 90.62 | wps 16998 | ups 5 | wpb 3491.701 | bsz 141.679 | num_updates 2262 | lr 0.000282793 | gnorm 1.159 | clip 0.000 | oom 0.000 | wall 476 | train_wall 457
# | epoch 002 | valid on 'valid' subset | loss 6.451 | nll_loss 5.337 | ppl 40.42 | num_updates 2262 | best_loss 6.4511
# | saved checkpoint /content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint2.pt (epoch 2 @ 2262 updates) (writing took 6.433699607849121 seconds)
# | epoch 003:    100 / 1131 loss=6.563, nll_loss=5.569, ppl=47.48, wps=16203, ups=5, wpb=3504.099, bsz=146.535, num_updates=2363, lr=0.000295416, gnorm=1.054, clip=0.000, oom=0.000, wall=508, train_wall=479
# | epoch 003:    200 / 1131 loss=6.594, nll_loss=5.603, ppl=48.60, wps=16585, ups=5, wpb=3486.910, bsz=136.358, num_updates=2463, lr=0.000307913, gnorm=1.067, clip=0.000, oom=0.000, wall=528, train_wall=499
# | epoch 003:    300 / 1131 loss=6.537, nll_loss=5.537, ppl=46.43, wps=16677, ups=5, wpb=3470.525, bsz=135.894, num_updates=2563, lr=0.000320411, gnorm=1.049, clip=0.000, oom=0.000, wall=549, train_wall=519
# | epoch 003:    400 / 1131 loss=6.451, nll_loss=5.438, ppl=43.34, wps=16771, ups=5, wpb=3482.204, bsz=138.813, num_updates=2663, lr=0.000332908, gnorm=1.036, clip=0.000, oom=0.000, wall=569, train_wall=539
# | epoch 003:    500 / 1131 loss=6.421, nll_loss=5.402, ppl=42.27, wps=16800, ups=5, wpb=3480.048, bsz=136.830, num_updates=2763, lr=0.000345406, gnorm=1.037, clip=0.000, oom=0.000, wall=590, train_wall=559
# | epoch 003:    600 / 1131 loss=6.363, nll_loss=5.333, ppl=40.32, wps=16820, ups=5, wpb=3482.953, bsz=138.329, num_updates=2863, lr=0.000357903, gnorm=1.030, clip=0.000, oom=0.000, wall=610, train_wall=579
# | epoch 003:    700 / 1131 loss=6.300, nll_loss=5.260, ppl=38.33, wps=16861, ups=5, wpb=3493.351, bsz=141.398, num_updates=2963, lr=0.000370401, gnorm=1.029, clip=0.000, oom=0.000, wall=631, train_wall=600
# | epoch 003:    800 / 1131 loss=6.253, nll_loss=5.205, ppl=36.89, wps=16852, ups=5, wpb=3490.936, bsz=141.353, num_updates=3063, lr=0.000382898, gnorm=1.022, clip=0.000, oom=0.000, wall=652, train_wall=620
# | epoch 003:    900 / 1131 loss=6.209, nll_loss=5.153, ppl=35.58, wps=16868, ups=5, wpb=3491.760, bsz=140.786, num_updates=3163, lr=0.000395396, gnorm=1.014, clip=0.000, oom=0.000, wall=672, train_wall=640
# | epoch 003:   1000 / 1131 loss=6.161, nll_loss=5.098, ppl=34.24, wps=16868, ups=5, wpb=3489.918, bsz=140.963, num_updates=3263, lr=0.000407893, gnorm=1.008, clip=0.000, oom=0.000, wall=693, train_wall=660
# | epoch 003:   1100 / 1131 loss=6.113, nll_loss=5.040, ppl=32.91, wps=16870, ups=5, wpb=3492.458, bsz=141.777, num_updates=3363, lr=0.000420391, gnorm=1.003, clip=0.000, oom=0.000, wall=714, train_wall=681
# | epoch 003 | loss 6.103 | nll_loss 5.029 | ppl 32.66 | wps 16866 | ups 5 | wpb 3491.701 | bsz 141.679 | num_updates 3393 | lr 0.00042414 | gnorm 1.003 | clip 0.000 | oom 0.000 | wall 720 | train_wall 687
# | epoch 003 | valid on 'valid' subset | loss 5.327 | nll_loss 3.991 | ppl 15.91 | num_updates 3393 | best_loss 5.32748
# | saved checkpoint /content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint3.pt (epoch 3 @ 3393 updates) (writing took 6.7123260498046875 seconds)
# | epoch 004:    100 / 1131 loss=5.444, nll_loss=4.260, ppl=19.16, wps=16237, ups=5, wpb=3496.941, bsz=142.099, num_updates=3494, lr=0.000436763, gnorm=0.895, clip=0.000, oom=0.000, wall=752, train_wall=708
# | epoch 004:    200 / 1131 loss=5.450, nll_loss=4.266, ppl=19.24, wps=16557, ups=5, wpb=3487.055, bsz=138.866, num_updates=3594, lr=0.00044926, gnorm=0.901, clip=0.000, oom=0.000, wall=773, train_wall=728
# | epoch 004:    300 / 1131 loss=5.418, nll_loss=4.228, ppl=18.74, wps=16701, ups=5, wpb=3490.502, bsz=137.276, num_updates=3694, lr=0.000461758, gnorm=0.901, clip=0.000, oom=0.000, wall=793, train_wall=749
# | epoch 004:    400 / 1131 loss=5.407, nll_loss=4.213, ppl=18.55, wps=16777, ups=5, wpb=3496.112, bsz=135.678, num_updates=3794, lr=0.000474255, gnorm=0.902, clip=0.000, oom=0.000, wall=814, train_wall=769
# | epoch 004:    500 / 1131 loss=5.392, nll_loss=4.196, ppl=18.33, wps=16787, ups=5, wpb=3485.806, bsz=135.263, num_updates=3894, lr=0.000486753, gnorm=0.905, clip=0.000, oom=0.000, wall=834, train_wall=789
# | epoch 004:    600 / 1131 loss=5.366, nll_loss=4.166, ppl=17.95, wps=16788, ups=5, wpb=3485.730, bsz=136.038, num_updates=3994, lr=0.00049925, gnorm=0.902, clip=0.000, oom=0.000, wall=855, train_wall=809
# | epoch 004:    700 / 1131 loss=5.331, nll_loss=4.124, ppl=17.44, wps=16829, ups=5, wpb=3494.829, bsz=138.281, num_updates=4094, lr=0.000494227, gnorm=0.894, clip=0.000, oom=0.000, wall=876, train_wall=830
# | epoch 004:    800 / 1131 loss=5.308, nll_loss=4.097, ppl=17.12, wps=16810, ups=5, wpb=3486.479, bsz=138.516, num_updates=4194, lr=0.000488299, gnorm=0.892, clip=0.000, oom=0.000, wall=897, train_wall=850
# | epoch 004:    900 / 1131 loss=5.278, nll_loss=4.063, ppl=16.72, wps=16818, ups=5, wpb=3486.191, bsz=139.746, num_updates=4294, lr=0.00048258, gnorm=0.887, clip=0.000, oom=0.000, wall=917, train_wall=870
# | epoch 004:   1000 / 1131 loss=5.247, nll_loss=4.027, ppl=16.31, wps=16819, ups=5, wpb=3487.905, bsz=140.922, num_updates=4394, lr=0.000477057, gnorm=0.881, clip=0.000, oom=0.000, wall=938, train_wall=890
# | epoch 004:   1100 / 1131 loss=5.219, nll_loss=3.995, ppl=15.94, wps=16834, ups=5, wpb=3491.833, bsz=141.209, num_updates=4494, lr=0.000471719, gnorm=0.873, clip=0.000, oom=0.000, wall=959, train_wall=911
# | epoch 004 | loss 5.210 | nll_loss 3.984 | ppl 15.83 | wps 16829 | ups 5 | wpb 3491.701 | bsz 141.679 | num_updates 4524 | lr 0.000470152 | gnorm 0.871 | clip 0.000 | oom 0.000 | wall 965 | train_wall 917
# | epoch 004 | valid on 'valid' subset | loss 4.779 | nll_loss 3.341 | ppl 10.13 | num_updates 4524 | best_loss 4.77881
# | saved checkpoint /content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint4.pt (epoch 4 @ 4524 updates) (writing took 7.336956977844238 seconds)
# | epoch 005:    100 / 1131 loss=4.794, nll_loss=3.506, ppl=11.36, wps=16051, ups=5, wpb=3472.307, bsz=145.584, num_updates=4625, lr=0.000464991, gnorm=0.800, clip=0.000, oom=0.000, wall=998, train_wall=938
# | epoch 005:    200 / 1131 loss=4.806, nll_loss=3.519, ppl=11.47, wps=16372, ups=5, wpb=3458.662, bsz=140.020, num_updates=4725, lr=0.000460044, gnorm=0.803, clip=0.000, oom=0.000, wall=1019, train_wall=958
# | epoch 005:    300 / 1131 loss=4.766, nll_loss=3.473, ppl=11.10, wps=16564, ups=5, wpb=3485.987, bsz=146.339, num_updates=4825, lr=0.000455251, gnorm=0.793, clip=0.000, oom=0.000, wall=1039, train_wall=979
# | epoch 005:    400 / 1131 loss=4.767, nll_loss=3.474, ppl=11.11, wps=16660, ups=5, wpb=3486.753, bsz=142.843, num_updates=4925, lr=0.000450606, gnorm=0.791, clip=0.000, oom=0.000, wall=1060, train_wall=999
# | epoch 005:    500 / 1131 loss=4.765, nll_loss=3.472, ppl=11.09, wps=16719, ups=5, wpb=3491.852, bsz=140.375, num_updates=5025, lr=0.0004461, gnorm=0.784, clip=0.000, oom=0.000, wall=1081, train_wall=1019
# | epoch 005:    600 / 1131 loss=4.770, nll_loss=3.478, ppl=11.14, wps=16747, ups=5, wpb=3488.155, bsz=137.784, num_updates=5125, lr=0.000441726, gnorm=0.788, clip=0.000, oom=0.000, wall=1101, train_wall=1039
# | epoch 005:    700 / 1131 loss=4.743, nll_loss=3.447, ppl=10.91, wps=16795, ups=5, wpb=3497.107, bsz=141.238, num_updates=5225, lr=0.000437479, gnorm=0.780, clip=0.000, oom=0.000, wall=1122, train_wall=1060
# | epoch 005:    800 / 1131 loss=4.733, nll_loss=3.435, ppl=10.81, wps=16819, ups=5, wpb=3500.608, bsz=141.432, num_updates=5325, lr=0.000433351, gnorm=0.779, clip=0.000, oom=0.000, wall=1143, train_wall=1080
# | epoch 005:    900 / 1131 loss=4.721, nll_loss=3.422, ppl=10.72, wps=16839, ups=5, wpb=3502.876, bsz=142.365, num_updates=5425, lr=0.000429339, gnorm=0.777, clip=0.000, oom=0.000, wall=1164, train_wall=1101
# | epoch 005:   1000 / 1131 loss=4.717, nll_loss=3.417, ppl=10.68, wps=16827, ups=5, wpb=3492.042, bsz=141.673, num_updates=5525, lr=0.000425436, gnorm=0.777, clip=0.000, oom=0.000, wall=1184, train_wall=1120
# | epoch 005:   1100 / 1131 loss=4.705, nll_loss=3.404, ppl=10.59, wps=16835, ups=5, wpb=3491.882, bsz=141.623, num_updates=5625, lr=0.000421637, gnorm=0.773, clip=0.000, oom=0.000, wall=1204, train_wall=1141
# | epoch 005 | loss 4.702 | nll_loss 3.401 | ppl 10.56 | wps 16833 | ups 5 | wpb 3491.701 | bsz 141.679 | num_updates 5655 | lr 0.000420517 | gnorm 0.773 | clip 0.000 | oom 0.000 | wall 1211 | train_wall 1147
# | epoch 005 | valid on 'valid' subset | loss 4.495 | nll_loss 3.010 | ppl 8.06 | num_updates 5655 | best_loss 4.49495
# | saved checkpoint /content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint5.pt (epoch 5 @ 5655 updates) (writing took 7.081428050994873 seconds)
# | epoch 006:    100 / 1131 loss=4.409, nll_loss=3.067, ppl=8.38, wps=16167, ups=5, wpb=3537.505, bsz=142.881, num_updates=5756, lr=0.000416811, gnorm=0.706, clip=0.000, oom=0.000, wall=1244, train_wall=1168
# | epoch 006:    200 / 1131 loss=4.411, nll_loss=3.070, ppl=8.40, wps=16489, ups=5, wpb=3503.806, bsz=147.776, num_updates=5856, lr=0.000413237, gnorm=0.717, clip=0.000, oom=0.000, wall=1264, train_wall=1189
# | epoch 006:    300 / 1131 loss=4.437, nll_loss=3.099, ppl=8.57, wps=16507, ups=5, wpb=3469.272, bsz=143.704, num_updates=5956, lr=0.000409753, gnorm=0.727, clip=0.000, oom=0.000, wall=1285, train_wall=1209
# | epoch 006:    400 / 1131 loss=4.435, nll_loss=3.096, ppl=8.55, wps=16572, ups=5, wpb=3467.115, bsz=142.860, num_updates=6056, lr=0.000406356, gnorm=0.726, clip=0.000, oom=0.000, wall=1305, train_wall=1229
# | epoch 006:    500 / 1131 loss=4.436, nll_loss=3.098, ppl=8.56, wps=16707, ups=5, wpb=3481.910, bsz=142.098, num_updates=6156, lr=0.000403042, gnorm=0.723, clip=0.000, oom=0.000, wall=1326, train_wall=1249
# | epoch 006:    600 / 1131 loss=4.437, nll_loss=3.099, ppl=8.57, wps=16750, ups=5, wpb=3479.839, bsz=140.364, num_updates=6256, lr=0.000399808, gnorm=0.721, clip=0.000, oom=0.000, wall=1346, train_wall=1269
# | epoch 006:    700 / 1131 loss=4.433, nll_loss=3.094, ppl=8.54, wps=16790, ups=5, wpb=3481.966, bsz=142.298, num_updates=6356, lr=0.000396651, gnorm=0.727, clip=0.000, oom=0.000, wall=1367, train_wall=1289
# | epoch 006:    800 / 1131 loss=4.422, nll_loss=3.082, ppl=8.47, wps=16818, ups=5, wpb=3491.240, bsz=143.479, num_updates=6456, lr=0.000393567, gnorm=0.721, clip=0.000, oom=0.000, wall=1388, train_wall=1310
# | epoch 006:    900 / 1131 loss=4.419, nll_loss=3.079, ppl=8.45, wps=16845, ups=5, wpb=3495.008, bsz=143.120, num_updates=6556, lr=0.000390553, gnorm=0.720, clip=0.000, oom=0.000, wall=1408, train_wall=1330
# | epoch 006:   1000 / 1131 loss=4.420, nll_loss=3.081, ppl=8.46, wps=16827, ups=5, wpb=3489.187, bsz=142.105, num_updates=6656, lr=0.000387609, gnorm=0.720, clip=0.000, oom=0.000, wall=1429, train_wall=1350
# | epoch 006:   1100 / 1131 loss=4.412, nll_loss=3.071, ppl=8.40, wps=16835, ups=5, wpb=3493.069, bsz=142.459, num_updates=6756, lr=0.000384729, gnorm=0.717, clip=0.000, oom=0.000, wall=1450, train_wall=1371
# | epoch 006 | loss 4.414 | nll_loss 3.073 | ppl 8.42 | wps 16833 | ups 5 | wpb 3491.701 | bsz 141.679 | num_updates 6786 | lr 0.000383878 | gnorm 0.717 | clip 0.000 | oom 0.000 | wall 1456 | train_wall 1377
# | epoch 006 | valid on 'valid' subset | loss 4.326 | nll_loss 2.827 | ppl 7.10 | num_updates 6786 | best_loss 4.32647
# | saved checkpoint /content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint6.pt (epoch 6 @ 6786 updates) (writing took 7.558446168899536 seconds)
# | epoch 007:    100 / 1131 loss=4.219, nll_loss=2.851, ppl=7.22, wps=16373, ups=5, wpb=3537.089, bsz=143.366, num_updates=6887, lr=0.000381053, gnorm=0.667, clip=0.000, oom=0.000, wall=1489, train_wall=1398
# | epoch 007:    200 / 1131 loss=4.197, nll_loss=2.827, ppl=7.09, wps=16631, ups=5, wpb=3535.478, bsz=148.259, num_updates=6987, lr=0.000378316, gnorm=0.671, clip=0.000, oom=0.000, wall=1510, train_wall=1419
# | epoch 007:    300 / 1131 loss=4.186, nll_loss=2.813, ppl=7.03, wps=16690, ups=5, wpb=3526.950, bsz=150.671, num_updates=7087, lr=0.000375637, gnorm=0.679, clip=0.000, oom=0.000, wall=1531, train_wall=1439
# | epoch 007:    400 / 1131 loss=4.194, nll_loss=2.823, ppl=7.07, wps=16734, ups=5, wpb=3517.384, bsz=148.449, num_updates=7187, lr=0.000373015, gnorm=0.681, clip=0.000, oom=0.000, wall=1552, train_wall=1459
# | epoch 007:    500 / 1131 loss=4.211, nll_loss=2.842, ppl=7.17, wps=16724, ups=5, wpb=3502.467, bsz=143.984, num_updates=7287, lr=0.000370447, gnorm=0.685, clip=0.000, oom=0.000, wall=1572, train_wall=1480
# | epoch 007:    600 / 1131 loss=4.218, nll_loss=2.851, ppl=7.21, wps=16774, ups=5, wpb=3498.038, bsz=142.536, num_updates=7387, lr=0.000367931, gnorm=0.686, clip=0.000, oom=0.000, wall=1593, train_wall=1500
# | epoch 007:    700 / 1131 loss=4.227, nll_loss=2.861, ppl=7.27, wps=16757, ups=5, wpb=3484.919, bsz=140.974, num_updates=7487, lr=0.000365465, gnorm=0.691, clip=0.000, oom=0.000, wall=1613, train_wall=1520
# | epoch 007:    800 / 1131 loss=4.228, nll_loss=2.862, ppl=7.27, wps=16818, ups=5, wpb=3489.649, bsz=141.382, num_updates=7587, lr=0.000363049, gnorm=0.690, clip=0.000, oom=0.000, wall=1634, train_wall=1540
# | epoch 007:    900 / 1131 loss=4.225, nll_loss=2.859, ppl=7.26, wps=16850, ups=5, wpb=3494.154, bsz=141.797, num_updates=7687, lr=0.00036068, gnorm=0.690, clip=0.000, oom=0.000, wall=1654, train_wall=1560
# | epoch 007:   1000 / 1131 loss=4.224, nll_loss=2.857, ppl=7.25, wps=16864, ups=5, wpb=3495.764, bsz=141.657, num_updates=7787, lr=0.000358356, gnorm=0.688, clip=0.000, oom=0.000, wall=1675, train_wall=1580
# | epoch 007:   1100 / 1131 loss=4.224, nll_loss=2.858, ppl=7.25, wps=16853, ups=5, wpb=3492.284, bsz=141.609, num_updates=7887, lr=0.000356077, gnorm=0.688, clip=0.000, oom=0.000, wall=1695, train_wall=1600
# | epoch 007 | loss 4.222 | nll_loss 2.856 | ppl 7.24 | wps 16852 | ups 5 | wpb 3491.701 | bsz 141.679 | num_updates 7917 | lr 0.000355402 | gnorm 0.688 | clip 0.000 | oom 0.000 | wall 1702 | train_wall 1606
# | epoch 007 | valid on 'valid' subset | loss 4.235 | nll_loss 2.715 | ppl 6.56 | num_updates 7917 | best_loss 4.23459
# | saved checkpoint /content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint7.pt (epoch 7 @ 7917 updates) (writing took 7.6624181270599365 seconds)
# | epoch 008:    100 / 1131 loss=3.989, nll_loss=2.591, ppl=6.02, wps=16111, ups=5, wpb=3504.495, bsz=159.129, num_updates=8018, lr=0.000353156, gnorm=0.658, clip=0.000, oom=0.000, wall=1735, train_wall=1628
# | epoch 008:    200 / 1131 loss=4.032, nll_loss=2.639, ppl=6.23, wps=16566, ups=5, wpb=3526.134, bsz=153.194, num_updates=8118, lr=0.000350974, gnorm=0.658, clip=0.000, oom=0.000, wall=1756, train_wall=1648
# | epoch 008:    300 / 1131 loss=4.052, nll_loss=2.663, ppl=6.33, wps=16691, ups=5, wpb=3517.824, bsz=147.744, num_updates=8218, lr=0.000348832, gnorm=0.662, clip=0.000, oom=0.000, wall=1776, train_wall=1669
# | epoch 008:    400 / 1131 loss=4.064, nll_loss=2.676, ppl=6.39, wps=16719, ups=5, wpb=3509.683, bsz=145.594, num_updates=8318, lr=0.000346729, gnorm=0.664, clip=0.000, oom=0.000, wall=1797, train_wall=1689
# | epoch 008:    500 / 1131 loss=4.067, nll_loss=2.680, ppl=6.41, wps=16679, ups=5, wpb=3485.583, bsz=145.275, num_updates=8418, lr=0.000344664, gnorm=0.669, clip=0.000, oom=0.000, wall=1818, train_wall=1709
# | epoch 008:    600 / 1131 loss=4.075, nll_loss=2.689, ppl=6.45, wps=16706, ups=5, wpb=3485.967, bsz=144.691, num_updates=8518, lr=0.000342635, gnorm=0.670, clip=0.000, oom=0.000, wall=1838, train_wall=1729
# | epoch 008:    700 / 1131 loss=4.075, nll_loss=2.689, ppl=6.45, wps=16725, ups=5, wpb=3486.106, bsz=144.866, num_updates=8618, lr=0.000340641, gnorm=0.670, clip=0.000, oom=0.000, wall=1859, train_wall=1750
# | epoch 008:    800 / 1131 loss=4.075, nll_loss=2.689, ppl=6.45, wps=16776, ups=5, wpb=3494.222, bsz=144.668, num_updates=8718, lr=0.000338682, gnorm=0.671, clip=0.000, oom=0.000, wall=1880, train_wall=1770
# | epoch 008:    900 / 1131 loss=4.083, nll_loss=2.698, ppl=6.49, wps=16791, ups=5, wpb=3491.938, bsz=142.232, num_updates=8818, lr=0.000336756, gnorm=0.672, clip=0.000, oom=0.000, wall=1900, train_wall=1790
# | epoch 008:   1000 / 1131 loss=4.081, nll_loss=2.696, ppl=6.48, wps=16807, ups=5, wpb=3495.145, bsz=142.249, num_updates=8918, lr=0.000334862, gnorm=0.671, clip=0.000, oom=0.000, wall=1921, train_wall=1811
# | epoch 008:   1100 / 1131 loss=4.084, nll_loss=2.700, ppl=6.50, wps=16798, ups=5, wpb=3489.301, bsz=141.797, num_updates=9018, lr=0.000333, gnorm=0.671, clip=0.000, oom=0.000, wall=1942, train_wall=1831
# | epoch 008 | loss 4.085 | nll_loss 2.700 | ppl 6.50 | wps 16813 | ups 5 | wpb 3491.701 | bsz 141.679 | num_updates 9048 | lr 0.000332448 | gnorm 0.671 | clip 0.000 | oom 0.000 | wall 1948 | train_wall 1837
# | epoch 008 | valid on 'valid' subset | loss 4.160 | nll_loss 2.630 | ppl 6.19 | num_updates 9048 | best_loss 4.16044
# | saved checkpoint /content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint8.pt (epoch 8 @ 9048 updates) (writing took 7.78082537651062 seconds)
# | epoch 009:    100 / 1131 loss=3.928, nll_loss=2.521, ppl=5.74, wps=15992, ups=5, wpb=3468.772, bsz=140.277, num_updates=9149, lr=0.000330608, gnorm=0.656, clip=0.000, oom=0.000, wall=1981, train_wall=1858
# | epoch 009:    200 / 1131 loss=3.929, nll_loss=2.522, ppl=5.75, wps=16483, ups=5, wpb=3505.562, bsz=139.741, num_updates=9249, lr=0.000328816, gnorm=0.650, clip=0.000, oom=0.000, wall=2002, train_wall=1879
# | epoch 009:    300 / 1131 loss=3.936, nll_loss=2.530, ppl=5.77, wps=16621, ups=5, wpb=3501.282, bsz=142.379, num_updates=9349, lr=0.000327052, gnorm=0.657, clip=0.000, oom=0.000, wall=2023, train_wall=1899
# | epoch 009:    400 / 1131 loss=3.952, nll_loss=2.548, ppl=5.85, wps=16759, ups=5, wpb=3509.037, bsz=140.688, num_updates=9449, lr=0.000325317, gnorm=0.656, clip=0.000, oom=0.000, wall=2043, train_wall=1919
# | epoch 009:    500 / 1131 loss=3.957, nll_loss=2.554, ppl=5.87, wps=16769, ups=5, wpb=3501.331, bsz=142.164, num_updates=9549, lr=0.000323609, gnorm=0.656, clip=0.000, oom=0.000, wall=2064, train_wall=1939
# | epoch 009:    600 / 1131 loss=3.962, nll_loss=2.560, ppl=5.90, wps=16783, ups=5, wpb=3495.923, bsz=142.561, num_updates=9649, lr=0.000321928, gnorm=0.658, clip=0.000, oom=0.000, wall=2085, train_wall=1959
# | epoch 009:    700 / 1131 loss=3.968, nll_loss=2.567, ppl=5.93, wps=16790, ups=5, wpb=3491.205, bsz=140.552, num_updates=9749, lr=0.000320273, gnorm=0.659, clip=0.000, oom=0.000, wall=2105, train_wall=1980
# | epoch 009:    800 / 1131 loss=3.970, nll_loss=2.569, ppl=5.94, wps=16829, ups=5, wpb=3499.643, bsz=141.742, num_updates=9849, lr=0.000318643, gnorm=0.660, clip=0.000, oom=0.000, wall=2126, train_wall=2000
# | epoch 009:    900 / 1131 loss=3.971, nll_loss=2.571, ppl=5.94, wps=16840, ups=5, wpb=3495.212, bsz=141.992, num_updates=9949, lr=0.000317037, gnorm=0.662, clip=0.000, oom=0.000, wall=2146, train_wall=2020
# | epoch 009:   1000 / 1131 loss=3.973, nll_loss=2.573, ppl=5.95, wps=16811, ups=5, wpb=3488.602, bsz=141.857, num_updates=10049, lr=0.000315456, gnorm=0.663, clip=0.000, oom=0.000, wall=2167, train_wall=2040
# | epoch 009:   1100 / 1131 loss=3.975, nll_loss=2.576, ppl=5.96, wps=16834, ups=5, wpb=3491.737, bsz=141.311, num_updates=10149, lr=0.000313898, gnorm=0.662, clip=0.000, oom=0.000, wall=2188, train_wall=2061
# | epoch 009 | loss 3.975 | nll_loss 2.576 | ppl 5.96 | wps 16833 | ups 5 | wpb 3491.701 | bsz 141.679 | num_updates 10179 | lr 0.000313435 | gnorm 0.662 | clip 0.000 | oom 0.000 | wall 2194 | train_wall 2067
# | epoch 009 | valid on 'valid' subset | loss 4.117 | nll_loss 2.578 | ppl 5.97 | num_updates 10179 | best_loss 4.11672
# | saved checkpoint /content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint9.pt (epoch 9 @ 10179 updates) (writing took 7.468746185302734 seconds)
# | epoch 010:    100 / 1131 loss=3.823, nll_loss=2.403, ppl=5.29, wps=16326, ups=5, wpb=3571.129, bsz=153.505, num_updates=10280, lr=0.000311891, gnorm=0.632, clip=0.000, oom=0.000, wall=2227, train_wall=2088
# | epoch 010:    200 / 1131 loss=3.858, nll_loss=2.442, ppl=5.43, wps=16533, ups=5, wpb=3507.100, bsz=141.373, num_updates=10380, lr=0.000310385, gnorm=0.645, clip=0.000, oom=0.000, wall=2248, train_wall=2108
# | epoch 010:    300 / 1131 loss=3.860, nll_loss=2.444, ppl=5.44, wps=16727, ups=5, wpb=3520.950, bsz=142.485, num_updates=10480, lr=0.000308901, gnorm=0.643, clip=0.000, oom=0.000, wall=2268, train_wall=2129
# | epoch 010:    400 / 1131 loss=3.857, nll_loss=2.440, ppl=5.43, wps=16770, ups=5, wpb=3516.070, bsz=144.459, num_updates=10580, lr=0.000307438, gnorm=0.644, clip=0.000, oom=0.000, wall=2289, train_wall=2149
# | epoch 010:    500 / 1131 loss=3.871, nll_loss=2.456, ppl=5.49, wps=16748, ups=5, wpb=3495.551, bsz=142.084, num_updates=10680, lr=0.000305995, gnorm=0.650, clip=0.000, oom=0.000, wall=2310, train_wall=2169
# | epoch 010:    600 / 1131 loss=3.878, nll_loss=2.465, ppl=5.52, wps=16785, ups=5, wpb=3496.346, bsz=141.351, num_updates=10780, lr=0.000304572, gnorm=0.650, clip=0.000, oom=0.000, wall=2330, train_wall=2189
# | epoch 010:    700 / 1131 loss=3.881, nll_loss=2.468, ppl=5.53, wps=16772, ups=5, wpb=3491.471, bsz=141.912, num_updates=10880, lr=0.00030317, gnorm=0.652, clip=0.000, oom=0.000, wall=2351, train_wall=2210
# | epoch 010:    800 / 1131 loss=3.883, nll_loss=2.471, ppl=5.54, wps=16794, ups=5, wpb=3493.187, bsz=141.393, num_updates=10980, lr=0.000301786, gnorm=0.652, clip=0.000, oom=0.000, wall=2372, train_wall=2230
# | epoch 010:    900 / 1131 loss=3.887, nll_loss=2.475, ppl=5.56, wps=16839, ups=5, wpb=3500.839, bsz=140.767, num_updates=11080, lr=0.000300421, gnorm=0.652, clip=0.000, oom=0.000, wall=2392, train_wall=2250
# | epoch 010:   1000 / 1131 loss=3.884, nll_loss=2.472, ppl=5.55, wps=16842, ups=5, wpb=3498.915, bsz=141.857, num_updates=11180, lr=0.000299074, gnorm=0.653, clip=0.000, oom=0.000, wall=2413, train_wall=2270
# | epoch 010:   1100 / 1131 loss=3.882, nll_loss=2.470, ppl=5.54, wps=16828, ups=5, wpb=3492.833, bsz=142.851, num_updates=11280, lr=0.000297746, gnorm=0.653, clip=0.000, oom=0.000, wall=2434, train_wall=2291
# | epoch 010 | loss 3.885 | nll_loss 2.474 | ppl 5.55 | wps 16824 | ups 5 | wpb 3491.701 | bsz 141.679 | num_updates 11310 | lr 0.000297351 | gnorm 0.654 | clip 0.000 | oom 0.000 | wall 2440 | train_wall 2297
# | epoch 010 | valid on 'valid' subset | loss 4.065 | nll_loss 2.528 | ppl 5.77 | num_updates 11310 | best_loss 4.06549
# | saved checkpoint /content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint10.pt (epoch 10 @ 11310 updates) (writing took 7.209383249282837 seconds)
# | epoch 011:    100 / 1131 loss=3.815, nll_loss=2.392, ppl=5.25, wps=15965, ups=5, wpb=3450.624, bsz=129.426, num_updates=11411, lr=0.000296032, gnorm=0.654, clip=0.000, oom=0.000, wall=2473, train_wall=2318
# | epoch 011:    200 / 1131 loss=3.806, nll_loss=2.382, ppl=5.21, wps=16255, ups=5, wpb=3423.697, bsz=135.085, num_updates=11511, lr=0.000294743, gnorm=0.656, clip=0.000, oom=0.000, wall=2493, train_wall=2338
# | epoch 011:    300 / 1131 loss=3.815, nll_loss=2.392, ppl=5.25, wps=16576, ups=5, wpb=3476.498, bsz=134.698, num_updates=11611, lr=0.000293471, gnorm=0.649, clip=0.000, oom=0.000, wall=2514, train_wall=2359
# | epoch 011:    400 / 1131 loss=3.806, nll_loss=2.382, ppl=5.21, wps=16700, ups=5, wpb=3486.007, bsz=138.414, num_updates=11711, lr=0.000292215, gnorm=0.649, clip=0.000, oom=0.000, wall=2534, train_wall=2379
# | epoch 011:    500 / 1131 loss=3.800, nll_loss=2.375, ppl=5.19, wps=16695, ups=5, wpb=3482.870, bsz=141.844, num_updates=11811, lr=0.000290976, gnorm=0.649, clip=0.000, oom=0.000, wall=2555, train_wall=2399
# | epoch 011:    600 / 1131 loss=3.795, nll_loss=2.370, ppl=5.17, wps=16727, ups=5, wpb=3483.607, bsz=144.932, num_updates=11911, lr=0.000289752, gnorm=0.648, clip=0.000, oom=0.000, wall=2576, train_wall=2419
# ...
# | epoch 039:   1000 / 1131 loss=3.064, nll_loss=1.525, ppl=2.88, wps=16883, ups=5, wpb=3497.826, bsz=142.009, num_updates=43979, lr=0.000150792, gnorm=0.737, clip=0.000, oom=0.000, wall=9502, train_wall=8940
# | epoch 039:   1100 / 1131 loss=3.066, nll_loss=1.527, ppl=2.88, wps=16873, ups=5, wpb=3494.713, bsz=141.885, num_updates=44079, lr=0.000150621, gnorm=0.738, clip=0.000, oom=0.000, wall=9522, train_wall=8960
# | epoch 039 | loss 3.068 | nll_loss 1.529 | ppl 2.89 | wps 16866 | ups 5 | wpb 3491.701 | bsz 141.679 | num_updates 44109 | lr 0.000150569 | gnorm 0.739 | clip 0.000 | oom 0.000 | wall 9528 | train_wall 8966
# | epoch 039 | valid on 'valid' subset | loss 3.966 | nll_loss 2.399 | ppl 5.27 | num_updates 44109 | best_loss 3.92794
# | saved checkpoint /content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint39.pt (epoch 39 @ 44109 updates) (writing took 4.914588451385498 seconds)
# | epoch 040:    100 / 1131 loss=3.027, nll_loss=1.478, ppl=2.79, wps=15979, ups=5, wpb=3412.040, bsz=123.723, num_updates=44210, lr=0.000150397, gnorm=0.747, clip=0.000, oom=0.000, wall=9559, train_wall=8987
# | epoch 040:    200 / 1131 loss=3.019, nll_loss=1.470, ppl=2.77, wps=16327, ups=5, wpb=3427.199, bsz=132.697, num_updates=44310, lr=0.000150227, gnorm=0.741, clip=0.000, oom=0.000, wall=9579, train_wall=9007
# | epoch 040:    300 / 1131 loss=3.025, nll_loss=1.476, ppl=2.78, wps=16522, ups=5, wpb=3446.910, bsz=131.907, num_updates=44410, lr=0.000150058, gnorm=0.741, clip=0.000, oom=0.000, wall=9600, train_wall=9028
# | epoch 040:    400 / 1131 loss=3.037, nll_loss=1.491, ppl=2.81, wps=16646, ups=5, wpb=3465.671, bsz=131.070, num_updates=44510, lr=0.000149889, gnorm=0.745, clip=0.000, oom=0.000, wall=9621, train_wall=9048
# | epoch 040:    500 / 1131 loss=3.042, nll_loss=1.497, ppl=2.82, wps=16695, ups=5, wpb=3467.411, bsz=132.772, num_updates=44610, lr=0.000149721, gnorm=0.747, clip=0.000, oom=0.000, wall=9641, train_wall=9068
# | epoch 040:    600 / 1131 loss=3.042, nll_loss=1.498, ppl=2.82, wps=16717, ups=5, wpb=3469.631, bsz=135.493, num_updates=44710, lr=0.000149554, gnorm=0.745, clip=0.000, oom=0.000, wall=9662, train_wall=9088
# | epoch 040:    700 / 1131 loss=3.042, nll_loss=1.498, ppl=2.82, wps=16729, ups=5, wpb=3474.101, bsz=137.699, num_updates=44810, lr=0.000149387, gnorm=0.743, clip=0.000, oom=0.000, wall=9683, train_wall=9109
# | epoch 040:    800 / 1131 loss=3.046, nll_loss=1.503, ppl=2.83, wps=16767, ups=5, wpb=3478.930, bsz=138.286, num_updates=44910, lr=0.00014922, gnorm=0.744, clip=0.000, oom=0.000, wall=9703, train_wall=9129
# | epoch 040:    900 / 1131 loss=3.050, nll_loss=1.508, ppl=2.84, wps=16786, ups=5, wpb=3476.736, bsz=138.982, num_updates=45010, lr=0.000149055, gnorm=0.745, clip=0.000, oom=0.000, wall=9724, train_wall=9149
# | epoch 040:   1000 / 1131 loss=3.054, nll_loss=1.512, ppl=2.85, wps=16806, ups=5, wpb=3479.652, bsz=139.388, num_updates=45110, lr=0.000148889, gnorm=0.746, clip=0.000, oom=0.000, wall=9744, train_wall=9169
# | epoch 040:   1100 / 1131 loss=3.056, nll_loss=1.515, ppl=2.86, wps=16840, ups=5, wpb=3491.003, bsz=141.856, num_updates=45210, lr=0.000148725, gnorm=0.744, clip=0.000, oom=0.000, wall=9765, train_wall=9190
# | epoch 040 | loss 3.056 | nll_loss 1.515 | ppl 2.86 | wps 16836 | ups 5 | wpb 3491.701 | bsz 141.679 | num_updates 45240 | lr 0.000148675 | gnorm 0.744 | clip 0.000 | oom 0.000 | wall 9772 | train_wall 9196
# | epoch 040 | valid on 'valid' subset | loss 3.975 | nll_loss 2.406 | ppl 5.30 | num_updates 45240 | best_loss 3.92794
# | saved checkpoint /content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint40.pt (epoch 40 @ 45240 updates) (writing took 4.9728147983551025 seconds)
# | epoch 041:    100 / 1131 loss=3.007, nll_loss=1.459, ppl=2.75, wps=16516, ups=5, wpb=3551.337, bsz=148.356, num_updates=45341, lr=0.00014851, gnorm=0.720, clip=0.000, oom=0.000, wall=9802, train_wall=9217
# | epoch 041:    200 / 1131 loss=3.005, nll_loss=1.457, ppl=2.75, wps=16627, ups=5, wpb=3516.055, bsz=146.070, num_updates=45441, lr=0.000148346, gnorm=0.725, clip=0.000, oom=0.000, wall=9823, train_wall=9238
# | epoch 041:    300 / 1131 loss=3.005, nll_loss=1.457, ppl=2.74, wps=16630, ups=5, wpb=3501.797, bsz=147.402, num_updates=45541, lr=0.000148183, gnorm=0.729, clip=0.000, oom=0.000, wall=9844, train_wall=9258
# | epoch 041:    400 / 1131 loss=3.013, nll_loss=1.466, ppl=2.76, wps=16681, ups=5, wpb=3513.100, bsz=146.015, num_updates=45641, lr=0.000148021, gnorm=0.730, clip=0.000, oom=0.000, wall=9865, train_wall=9279
# | epoch 041:    500 / 1131 loss=3.021, nll_loss=1.475, ppl=2.78, wps=16681, ups=5, wpb=3520.152, bsz=144.094, num_updates=45741, lr=0.000147859, gnorm=0.732, clip=0.000, oom=0.000, wall=9886, train_wall=9299
# | epoch 041:    600 / 1131 loss=3.026, nll_loss=1.481, ppl=2.79, wps=16649, ups=5, wpb=3517.977, bsz=144.930, num_updates=45841, lr=0.000147697, gnorm=0.736, clip=0.000, oom=0.000, wall=9907, train_wall=9320
# | epoch 041:    700 / 1131 loss=3.030, nll_loss=1.485, ppl=2.80, wps=16568, ups=5, wpb=3503.223, bsz=144.341, num_updates=45941, lr=0.000147537, gnorm=0.739, clip=0.000, oom=0.000, wall=9929, train_wall=9341
# | epoch 041:    800 / 1131 loss=3.030, nll_loss=1.485, ppl=2.80, wps=16548, ups=5, wpb=3496.377, bsz=145.517, num_updates=46041, lr=0.000147376, gnorm=0.742, clip=0.000, oom=0.000, wall=9950, train_wall=9362
# | epoch 041:    900 / 1131 loss=3.035, nll_loss=1.491, ppl=2.81, wps=16543, ups=5, wpb=3493.572, bsz=143.679, num_updates=46141, lr=0.000147217, gnorm=0.744, clip=0.000, oom=0.000, wall=9971, train_wall=9382
# | epoch 041:   1000 / 1131 loss=3.040, nll_loss=1.496, ppl=2.82, wps=16527, ups=5, wpb=3489.206, bsz=142.009, num_updates=46241, lr=0.000147057, gnorm=0.747, clip=0.000, oom=0.000, wall=9992, train_wall=9403
# | epoch 041:   1100 / 1131 loss=3.044, nll_loss=1.501, ppl=2.83, wps=16541, ups=5, wpb=3491.368, bsz=142.052, num_updates=46341, lr=0.000146898, gnorm=0.747, clip=0.000, oom=0.000, wall=10013, train_wall=9423
# | epoch 041 | loss 3.046 | nll_loss 1.503 | ppl 2.83 | wps 16541 | ups 5 | wpb 3491.701 | bsz 141.679 | num_updates 46371 | lr 0.000146851 | gnorm 0.748 | clip 0.000 | oom 0.000 | wall 10019 | train_wall 9429
# | epoch 041 | valid on 'valid' subset | loss 3.975 | nll_loss 2.403 | ppl 5.29 | num_updates 46371 | best_loss 3.92794
# | saved checkpoint /content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint41.pt (epoch 41 @ 46371 updates) (writing took 4.973881483078003 seconds)
# | epoch 042:    100 / 1131 loss=2.998, nll_loss=1.447, ppl=2.73, wps=15825, ups=5, wpb=3474.871, bsz=136.634, num_updates=46472, lr=0.000146691, gnorm=0.734, clip=0.000, oom=0.000, wall=10050, train_wall=9451
# | epoch 042:    200 / 1131 loss=3.001, nll_loss=1.450, ppl=2.73, wps=16185, ups=5, wpb=3466.796, bsz=135.363, num_updates=46572, lr=0.000146534, gnorm=0.738, clip=0.000, oom=0.000, wall=10071, train_wall=9471
# | epoch 042:    300 / 1131 loss=3.011, nll_loss=1.462, ppl=2.75, wps=16339, ups=5, wpb=3454.854, bsz=136.133, num_updates=46672, lr=0.000146377, gnorm=0.746, clip=0.000, oom=0.000, wall=10092, train_wall=9492
# | epoch 042:    400 / 1131 loss=3.015, nll_loss=1.466, ppl=2.76, wps=16455, ups=5, wpb=3454.192, bsz=133.845, num_updates=46772, lr=0.00014622, gnorm=0.749, clip=0.000, oom=0.000, wall=10112, train_wall=9512
# | epoch 042:    500 / 1131 loss=3.019, nll_loss=1.471, ppl=2.77, wps=16578, ups=5, wpb=3468.475, bsz=134.180, num_updates=46872, lr=0.000146064, gnorm=0.749, clip=0.000, oom=0.000, wall=10133, train_wall=9532
# | epoch 042:    600 / 1131 loss=3.023, nll_loss=1.475, ppl=2.78, wps=16632, ups=5, wpb=3472.639, bsz=133.617, num_updates=46972, lr=0.000145908, gnorm=0.751, clip=0.000, oom=0.000, wall=10153, train_wall=9552
# | epoch 042:    700 / 1131 loss=3.024, nll_loss=1.476, ppl=2.78, wps=16644, ups=5, wpb=3471.826, bsz=136.331, num_updates=47072, lr=0.000145753, gnorm=0.751, clip=0.000, oom=0.000, wall=10174, train_wall=9573
# | epoch 042:    800 / 1131 loss=3.026, nll_loss=1.479, ppl=2.79, wps=16730, ups=5, wpb=3488.954, bsz=137.788, num_updates=47172, lr=0.000145599, gnorm=0.748, clip=0.000, oom=0.000, wall=10195, train_wall=9593
# | epoch 042:    900 / 1131 loss=3.028, nll_loss=1.481, ppl=2.79, wps=16725, ups=5, wpb=3483.915, bsz=139.747, num_updates=47272, lr=0.000145445, gnorm=0.749, clip=0.000, oom=0.000, wall=10216, train_wall=9613
# | epoch 042:   1000 / 1131 loss=3.029, nll_loss=1.484, ppl=2.80, wps=16743, ups=5, wpb=3483.971, bsz=140.899, num_updates=47372, lr=0.000145291, gnorm=0.749, clip=0.000, oom=0.000, wall=10236, train_wall=9633
# | epoch 042:   1100 / 1131 loss=3.033, nll_loss=1.488, ppl=2.80, wps=16760, ups=5, wpb=3489.008, bsz=141.238, num_updates=47472, lr=0.000145138, gnorm=0.750, clip=0.000, oom=0.000, wall=10257, train_wall=9654
# | epoch 042 | loss 3.033 | nll_loss 1.489 | ppl 2.81 | wps 16762 | ups 5 | wpb 3491.701 | bsz 141.679 | num_updates 47502 | lr 0.000145092 | gnorm 0.749 | clip 0.000 | oom 0.000 | wall 10263 | train_wall 9660
# | epoch 042 | valid on 'valid' subset | loss 3.996 | nll_loss 2.423 | ppl 5.36 | num_updates 47502 | best_loss 3.92794
# | saved checkpoint /content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint42.pt (epoch 42 @ 47502 updates) (writing took 4.7366437911987305 seconds)
# | epoch 043:    100 / 1131 loss=3.008, nll_loss=1.459, ppl=2.75, wps=16489, ups=5, wpb=3535.822, bsz=139.881, num_updates=47603, lr=0.000144938, gnorm=0.735, clip=0.000, oom=0.000, wall=10294, train_wall=9681
# | epoch 043:    200 / 1131 loss=2.995, nll_loss=1.445, ppl=2.72, wps=16543, ups=5, wpb=3490.214, bsz=153.075, num_updates=47703, lr=0.000144786, gnorm=0.737, clip=0.000, oom=0.000, wall=10314, train_wall=9702
# | epoch 043:    300 / 1131 loss=3.000, nll_loss=1.449, ppl=2.73, wps=16621, ups=5, wpb=3472.080, bsz=146.179, num_updates=47803, lr=0.000144635, gnorm=0.745, clip=0.000, oom=0.000, wall=10335, train_wall=9722
# | epoch 043:    400 / 1131 loss=3.002, nll_loss=1.451, ppl=2.73, wps=16720, ups=5, wpb=3480.132, bsz=140.948, num_updates=47903, lr=0.000144484, gnorm=0.748, clip=0.000, oom=0.000, wall=10355, train_wall=9742
# | epoch 043:    500 / 1131 loss=3.005, nll_loss=1.455, ppl=2.74, wps=16774, ups=5, wpb=3486.631, bsz=139.289, num_updates=48003, lr=0.000144333, gnorm=0.748, clip=0.000, oom=0.000, wall=10376, train_wall=9762
# | epoch 043:    600 / 1131 loss=3.010, nll_loss=1.460, ppl=2.75, wps=16791, ups=5, wpb=3485.351, bsz=139.754, num_updates=48103, lr=0.000144183, gnorm=0.750, clip=0.000, oom=0.000, wall=10397, train_wall=9782
# | epoch 043:    700 / 1131 loss=3.012, nll_loss=1.463, ppl=2.76, wps=16805, ups=5, wpb=3479.439, bsz=140.257, num_updates=48203, lr=0.000144033, gnorm=0.752, clip=0.000, oom=0.000, wall=10417, train_wall=9802
# | epoch 043:    800 / 1131 loss=3.016, nll_loss=1.468, ppl=2.77, wps=16846, ups=5, wpb=3483.483, bsz=141.831, num_updates=48303, lr=0.000143884, gnorm=0.752, clip=0.000, oom=0.000, wall=10438, train_wall=9823
# | epoch 043:    900 / 1131 loss=3.018, nll_loss=1.471, ppl=2.77, wps=16848, ups=5, wpb=3483.055, bsz=141.042, num_updates=48403, lr=0.000143735, gnorm=0.753, clip=0.000, oom=0.000, wall=10458, train_wall=9843
# | epoch 043:   1000 / 1131 loss=3.021, nll_loss=1.474, ppl=2.78, wps=16875, ups=5, wpb=3487.145, bsz=140.970, num_updates=48503, lr=0.000143587, gnorm=0.753, clip=0.000, oom=0.000, wall=10479, train_wall=9863
# | epoch 043:   1100 / 1131 loss=3.023, nll_loss=1.476, ppl=2.78, wps=16896, ups=5, wpb=3493.742, bsz=141.848, num_updates=48603, lr=0.000143439, gnorm=0.752, clip=0.000, oom=0.000, wall=10500, train_wall=9883
# | epoch 043 | loss 3.023 | nll_loss 1.476 | ppl 2.78 | wps 16887 | ups 5 | wpb 3491.701 | bsz 141.679 | num_updates 48633 | lr 0.000143395 | gnorm 0.752 | clip 0.000 | oom 0.000 | wall 10506 | train_wall 9889
# | epoch 043 | valid on 'valid' subset | loss 3.989 | nll_loss 2.417 | ppl 5.34 | num_updates 48633 | best_loss 3.92794
# | saved checkpoint /content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint43.pt (epoch 43 @ 48633 updates) (writing took 5.194172620773315 seconds)
# | epoch 044:    100 / 1131 loss=2.974, nll_loss=1.418, ppl=2.67, wps=16485, ups=5, wpb=3522.752, bsz=134.495, num_updates=48734, lr=0.000143246, gnorm=0.742, clip=0.000, oom=0.000, wall=10536, train_wall=9910
# | epoch 044:    200 / 1131 loss=2.973, nll_loss=1.417, ppl=2.67, wps=16552, ups=5, wpb=3462.562, bsz=136.199, num_updates=48834, lr=0.0001431, gnorm=0.750, clip=0.000, oom=0.000, wall=10557, train_wall=9931
# | epoch 044:    300 / 1131 loss=2.977, nll_loss=1.421, ppl=2.68, wps=16555, ups=5, wpb=3452.455, bsz=139.000, num_updates=48934, lr=0.000142953, gnorm=0.753, clip=0.000, oom=0.000, wall=10578, train_wall=9951
# | epoch 044:    400 / 1131 loss=2.980, nll_loss=1.427, ppl=2.69, wps=16675, ups=5, wpb=3479.928, bsz=149.663, num_updates=49034, lr=0.000142808, gnorm=0.749, clip=0.000, oom=0.000, wall=10598, train_wall=9971
# | epoch 044:    500 / 1131 loss=2.990, nll_loss=1.438, ppl=2.71, wps=16759, ups=5, wpb=3496.986, bsz=146.329, num_updates=49134, lr=0.000142662, gnorm=0.750, clip=0.000, oom=0.000, wall=10619, train_wall=9992
# | epoch 044:    600 / 1131 loss=2.993, nll_loss=1.442, ppl=2.72, wps=16822, ups=5, wpb=3507.433, bsz=145.569, num_updates=49234, lr=0.000142517, gnorm=0.748, clip=0.000, oom=0.000, wall=10640, train_wall=10012
# | epoch 044:    700 / 1131 loss=3.000, nll_loss=1.450, ppl=2.73, wps=16838, ups=5, wpb=3507.509, bsz=145.437, num_updates=49334, lr=0.000142373, gnorm=0.749, clip=0.000, oom=0.000, wall=10661, train_wall=10032
# | epoch 044:    800 / 1131 loss=3.004, nll_loss=1.454, ppl=2.74, wps=16827, ups=5, wpb=3501.464, bsz=143.589, num_updates=49434, lr=0.000142229, gnorm=0.751, clip=0.000, oom=0.000, wall=10681, train_wall=10053
# | epoch 044:    900 / 1131 loss=3.003, nll_loss=1.454, ppl=2.74, wps=16802, ups=5, wpb=3491.553, bsz=144.123, num_updates=49534, lr=0.000142085, gnorm=0.752, clip=0.000, oom=0.000, wall=10702, train_wall=10073
# | epoch 044:   1000 / 1131 loss=3.007, nll_loss=1.458, ppl=2.75, wps=16790, ups=5, wpb=3485.258, bsz=142.600, num_updates=49634, lr=0.000141942, gnorm=0.755, clip=0.000, oom=0.000, wall=10723, train_wall=10093
# | epoch 044:   1100 / 1131 loss=3.012, nll_loss=1.463, ppl=2.76, wps=16833, ups=5, wpb=3491.745, bsz=141.340, num_updates=49734, lr=0.000141799, gnorm=0.756, clip=0.000, oom=0.000, wall=10743, train_wall=10113
# | epoch 044 | loss 3.013 | nll_loss 1.465 | ppl 2.76 | wps 16834 | ups 5 | wpb 3491.701 | bsz 141.679 | num_updates 49764 | lr 0.000141756 | gnorm 0.756 | clip 0.000 | oom 0.000 | wall 10749 | train_wall 10119
# | epoch 044 | valid on 'valid' subset | loss 3.976 | nll_loss 2.407 | ppl 5.30 | num_updates 49764 | best_loss 3.92794
# | saved checkpoint /content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint44.pt (epoch 44 @ 49764 updates) (writing took 5.229656934738159 seconds)
# | epoch 045:    100 / 1131 loss=2.968, nll_loss=1.413, ppl=2.66, wps=16518, ups=5, wpb=3536.970, bsz=143.129, num_updates=49865, lr=0.000141613, gnorm=0.737, clip=0.000, oom=0.000, wall=10780, train_wall=10140
# | epoch 045:    200 / 1131 loss=2.963, nll_loss=1.407, ppl=2.65, wps=16723, ups=5, wpb=3538.562, bsz=150.965, num_updates=49965, lr=0.000141471, gnorm=0.738, clip=0.000, oom=0.000, wall=10801, train_wall=10161
# | epoch 045 | loss 2.964 | nll_loss 1.408 | ppl 2.65 | wps 16737 | ups 5 | wpb 3526.945 | bsz 148.576 | num_updates 50000 | lr 0.000141421 | gnorm 0.741 | clip 0.000 | oom 0.000 | wall 10808 | train_wall 10168
# | epoch 045 | valid on 'valid' subset | loss 3.997 | nll_loss 2.426 | ppl 5.37 | num_updates 50000 | best_loss 3.92794
# | saved checkpoint /content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint_last.pt (epoch 45 @ 50000 updates) (writing took 2.2713520526885986 seconds)
# | done training in 10812.7 seconds

# %%
# !python scripts/average_checkpoints.py --inputs "{SAVE}" \
    --num-epoch-checkpoints 10 --output "{SAVE}/checkpoint_last10_avg.pt"

# Evaluation
# !CUDA_VISIBLE_DEVICES=0 fairseq-generate data-bin/iwslt14.tokenized.de-en --path "{SAVE}/checkpoint_last10_avg.pt" --batch-size 128 --beam 4 --remove-bpe --lenpen 1 --gen-subset test --quiet
# Out:
# Namespace(checkpoint_upper_bound=None, inputs=['/content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt'], num_epoch_checkpoints=10, num_update_checkpoints=None, output='/content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint_last10_avg.pt')
# averaging checkpoints:  ['/content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint44.pt', '/content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint43.pt', '/content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint42.pt', '/content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint41.pt', '/content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint40.pt', '/content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint39.pt', '/content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint38.pt', '/content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint37.pt', '/content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint36.pt', '/content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint35.pt']
# Finished writing averaged checkpoint to /content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint_last10_avg.pt.
# Namespace(beam=4, bpe=None, cpu=False, criterion='cross_entropy', data='data-bin/iwslt14.tokenized.de-en', dataset_impl=None, decoding_format=None, diverse_beam_groups=-1, diverse_beam_strength=0.5, empty_cache_freq=0, force_anneal=None, fp16=False, fp16_init_scale=128, fp16_scale_tolerance=0.0, fp16_scale_window=None, gen_subset='test', iter_decode_eos_penalty=0.0, iter_decode_force_max_iter=False, iter_decode_max_iter=10, lazy_load=False, left_pad_source='True', left_pad_target='False', lenpen=1.0, load_alignments=False, log_format=None, log_interval=1000, lr_scheduler='fixed', lr_shrink=0.1, match_source_len=False, max_len_a=0, max_len_b=200, max_sentences=128, max_source_positions=1024, max_target_positions=1024, max_tokens=None, memory_efficient_fp16=False, min_len=1, min_loss_scale=0.0001, model_overrides='{}', momentum=0.99, nbest=1, no_beamable_mm=False, no_early_stop=False, no_progress_bar=False, no_repeat_ngram_size=0, num_shards=1, num_workers=1, optimizer='nag', path='/content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint_last10_avg.pt', prefix_size=0, print_alignment=False, print_step=False, quiet=True, raw_text=False, remove_bpe='@@ ', replace_unk=None, required_batch_size_multiple=8, results_path=None, sacrebleu=False, sampling=False, sampling_topk=-1, sampling_topp=-1.0, score_reference=False, seed=1, shard_id=0, skip_invalid_size_inputs_valid_test=False, source_lang=None, target_lang=None, task='translation', tbmf_wrapper=False, temperature=1.0, tensorboard_logdir='', threshold_loss_scale=None, tokenizer=None, unkpen=0, unnormalized=False, upsample_primary=1, user_dir=None, warmup_updates=0, weight_decay=0.0)
# | [de] dictionary: 8848 types
# | [en] dictionary: 6632 types
# | loaded 6750 examples from: data-bin/iwslt14.tokenized.de-en/test.de-en.de
# | loaded 6750 examples from: data-bin/iwslt14.tokenized.de-en/test.de-en.en
# | data-bin/iwslt14.tokenized.de-en test de-en 6750 examples
# | loading model(s) from /content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint_last10_avg.pt
# No module named 'dynamicconv_cuda'
# No module named 'dynamicconv_cuda'
# No module named 'dynamicconv_cuda'
# No module named 'dynamicconv_cuda'
# No module named 'dynamicconv_cuda'
# No module named 'dynamicconv_cuda'
# No module named 'dynamicconv_cuda'
# No module named 'dynamicconv_cuda'
# No module named 'dynamicconv_cuda'
# No module named 'dynamicconv_cuda'
# No module named 'dynamicconv_cuda'
# No module named 'dynamicconv_cuda'
# No module named 'dynamicconv_cuda'
# | Translated 6750 sentences (148063 tokens) in 24.9s (271.57 sentences/s, 5957.05 tokens/s)
# | Generate test with beam=4: BLEU4 = 34.24, 68.9/43.1/28.9/19.8 (BP=0.948, ratio=0.950, syslen=124560, reflen=131161)
