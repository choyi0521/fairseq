# %%
from google.colab import drive
drive.mount('/content/gdrive')

# To install fairseq from source and develop locally:
# !git clone https://github.com/choyi0521/fairseq
# %cd /content/fairseq
# !pip install --editable .
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive
# Cloning into 'fairseq'...
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 12169 (delta 0), reused 1 (delta 0), pack-reused 12164
# Receiving objects: 100% (12169/12169), 5.70 MiB | 6.82 MiB/s, done.
# Resolving deltas: 100% (8955/8955), done.
# /content/fairseq
# Obtaining file:///content/fairseq
# Requirement already satisfied: cffi in /usr/local/lib/python3.6/dist-packages (from fairseq==0.8.0) (1.13.2)
# Requirement already satisfied: cython in /usr/local/lib/python3.6/dist-packages (from fairseq==0.8.0) (0.29.14)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from fairseq==0.8.0) (1.17.4)
# Collecting regex
#   Downloading https://files.pythonhosted.org/packages/e3/8e/cbf2295643d7265e7883326fb4654e643bfc93b3a8a8274d8010a39d8804/regex-2019.11.1-cp36-cp36m-manylinux1_x86_64.whl (643kB)
#      |████████████████████████████████| 645kB 10.1MB/s
# Collecting sacrebleu
#   Downloading https://files.pythonhosted.org/packages/0e/e5/93d252182f7cbd4b59bb3ec5797e2ce33cfd6f5aadaf327db170cf4b7887/sacrebleu-1.4.2-py3-none-any.whl
# Requirement already satisfied: torch in /usr/local/lib/python3.6/dist-packages (from fairseq==0.8.0) (1.3.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from fairseq==0.8.0) (4.28.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.6/dist-packages (from cffi->fairseq==0.8.0) (2.19)
# Requirement already satisfied: typing in /usr/local/lib/python3.6/dist-packages (from sacrebleu->fairseq==0.8.0) (3.6.6)
# Collecting portalocker
#   Downloading https://files.pythonhosted.org/packages/91/db/7bc703c0760df726839e0699b7f78a4d8217fdc9c7fcb1b51b39c5a22a4e/portalocker-1.5.2-py2.py3-none-any.whl
# Installing collected packages: regex, portalocker, sacrebleu, fairseq
#   Running setup.py develop for fairseq
# Successfully installed fairseq portalocker-1.5.2 regex-2019.11.1 sacrebleu-1.4.2

# %%
# !git checkout dev5
# !git pull origin dev5
# Out:
# Branch 'dev5' set up to track remote branch 'dev5' from 'origin'.
# Switched to a new branch 'dev5'
# From https://github.com/choyi0521/fairseq
#  * branch            dev5       -> FETCH_HEAD
# Already up to date.

# %%
# Download and prepare the data
# %cd /content/fairseq
# %cd examples/translation/
# !bash prepare-iwslt14.sh
# %cd ../..

# Preprocess/binarize the data
TEXT="examples/translation/iwslt14.tokenized.de-en"
# !fairseq-preprocess --source-lang de --target-lang en \
    --trainpref $TEXT/train --validpref $TEXT/valid --testpref $TEXT/test \
    --destdir data-bin/iwslt14.tokenized.de-en \
    --workers 20
# Out:
# /content/fairseq
# /content/fairseq/examples/translation
# Cloning Moses github repository (for tokenization scripts)...
# Cloning into 'mosesdecoder'...
# remote: Enumerating objects: 169, done.
# remote: Counting objects: 100% (169/169), done.
# remote: Compressing objects: 100% (89/89), done.
# remote: Total 147464 (delta 104), reused 118 (delta 74), pack-reused 147295
# Receiving objects: 100% (147464/147464), 129.73 MiB | 22.06 MiB/s, done.
# Resolving deltas: 100% (113938/113938), done.
# Cloning Subword NMT repository (for BPE pre-processing)...
# Cloning into 'subword-nmt'...
# remote: Enumerating objects: 29, done.
# remote: Counting objects: 100% (29/29), done.
# remote: Compressing objects: 100% (22/22), done.
# remote: Total 538 (delta 10), reused 21 (delta 7), pack-reused 509
# Receiving objects: 100% (538/538), 226.98 KiB | 798.00 KiB/s, done.
# Resolving deltas: 100% (316/316), done.
# Downloading data from https://wit3.fbk.eu/archive/2014-01/texts/de/en/de-en.tgz...
# --2019-12-02 08:36:09--  https://wit3.fbk.eu/archive/2014-01/texts/de/en/de-en.tgz
# Resolving wit3.fbk.eu (wit3.fbk.eu)... 217.77.80.8
# Connecting to wit3.fbk.eu (wit3.fbk.eu)|217.77.80.8|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 19982877 (19M) [application/x-gzip]
# Saving to: ‘de-en.tgz’
#
# de-en.tgz           100%[===================>]  19.06M  31.3MB/s    in 0.6s
#
# 2019-12-02 08:36:10 (31.3 MB/s) - ‘de-en.tgz’ saved [19982877/19982877]
#
# Data successfully downloaded.
# de-en/
# de-en/IWSLT14.TED.dev2010.de-en.de.xml
# de-en/IWSLT14.TED.dev2010.de-en.en.xml
# de-en/IWSLT14.TED.tst2010.de-en.de.xml
# de-en/IWSLT14.TED.tst2010.de-en.en.xml
# de-en/IWSLT14.TED.tst2011.de-en.de.xml
# de-en/IWSLT14.TED.tst2011.de-en.en.xml
# de-en/IWSLT14.TED.tst2012.de-en.de.xml
# de-en/IWSLT14.TED.tst2012.de-en.en.xml
# de-en/IWSLT14.TEDX.dev2012.de-en.de.xml
# de-en/IWSLT14.TEDX.dev2012.de-en.en.xml
# de-en/README
# de-en/train.en
# de-en/train.tags.de-en.de
# de-en/train.tags.de-en.en
# pre-processing train data...
# Tokenizer Version 1.1
# Language: de
# Number of threads: 8
#
# Tokenizer Version 1.1
# Language: en
# Number of threads: 8
#
# clean-corpus.perl: processing iwslt14.tokenized.de-en/tmp/train.tags.de-en.tok.de & .en to iwslt14.tokenized.de-en/tmp/train.tags.de-en.clean, cutoff 1-175, ratio 1.5
# ..........(100000).......
# Input sentences: 174443  Output sentences:  167522
# pre-processing valid/test data...
# orig/de-en/IWSLT14.TED.dev2010.de-en.de.xml iwslt14.tokenized.de-en/tmp/IWSLT14.TED.dev2010.de-en.de
# Tokenizer Version 1.1
# Language: de
# Number of threads: 8
#
# orig/de-en/IWSLT14.TED.tst2010.de-en.de.xml iwslt14.tokenized.de-en/tmp/IWSLT14.TED.tst2010.de-en.de
# Tokenizer Version 1.1
# Language: de
# Number of threads: 8
#
# orig/de-en/IWSLT14.TED.tst2011.de-en.de.xml iwslt14.tokenized.de-en/tmp/IWSLT14.TED.tst2011.de-en.de
# Tokenizer Version 1.1
# Language: de
# Number of threads: 8
#
# orig/de-en/IWSLT14.TED.tst2012.de-en.de.xml iwslt14.tokenized.de-en/tmp/IWSLT14.TED.tst2012.de-en.de
# Tokenizer Version 1.1
# Language: de
# Number of threads: 8
#
# orig/de-en/IWSLT14.TEDX.dev2012.de-en.de.xml iwslt14.tokenized.de-en/tmp/IWSLT14.TEDX.dev2012.de-en.de
# Tokenizer Version 1.1
# Language: de
# Number of threads: 8
#
# orig/de-en/IWSLT14.TED.dev2010.de-en.en.xml iwslt14.tokenized.de-en/tmp/IWSLT14.TED.dev2010.de-en.en
# Tokenizer Version 1.1
# Language: en
# Number of threads: 8
#
# orig/de-en/IWSLT14.TED.tst2010.de-en.en.xml iwslt14.tokenized.de-en/tmp/IWSLT14.TED.tst2010.de-en.en
# Tokenizer Version 1.1
# Language: en
# Number of threads: 8
#
# orig/de-en/IWSLT14.TED.tst2011.de-en.en.xml iwslt14.tokenized.de-en/tmp/IWSLT14.TED.tst2011.de-en.en
# Tokenizer Version 1.1
# Language: en
# Number of threads: 8
#
# orig/de-en/IWSLT14.TED.tst2012.de-en.en.xml iwslt14.tokenized.de-en/tmp/IWSLT14.TED.tst2012.de-en.en
# Tokenizer Version 1.1
# Language: en
# Number of threads: 8
#
# orig/de-en/IWSLT14.TEDX.dev2012.de-en.en.xml iwslt14.tokenized.de-en/tmp/IWSLT14.TEDX.dev2012.de-en.en
# Tokenizer Version 1.1
# Language: en
# Number of threads: 8
#
# creating train, valid, test...
# learn_bpe.py on iwslt14.tokenized.de-en/tmp/train.en-de...
# subword-nmt/learn_bpe.py:267: DeprecationWarning: this script's location has moved to /content/fairseq/examples/translation/subword-nmt/subword_nmt. This symbolic link will be removed in a future version. Please point to the new location, or install the package and use the command 'subword-nmt'
#   DeprecationWarning
# apply_bpe.py to train.de...
# subword-nmt/apply_bpe.py:328: DeprecationWarning: this script's location has moved to /content/fairseq/examples/translation/subword-nmt/subword_nmt. This symbolic link will be removed in a future version. Please point to the new location, or install the package and use the command 'subword-nmt'
#   DeprecationWarning
# subword-nmt/apply_bpe.py:345: ResourceWarning: unclosed file <_io.TextIOWrapper name='iwslt14.tokenized.de-en/code' mode='r' encoding='UTF-8'>
#   args.codes = codecs.open(args.codes.name, encoding='utf-8')
# apply_bpe.py to valid.de...
# subword-nmt/apply_bpe.py:328: DeprecationWarning: this script's location has moved to /content/fairseq/examples/translation/subword-nmt/subword_nmt. This symbolic link will be removed in a future version. Please point to the new location, or install the package and use the command 'subword-nmt'
#   DeprecationWarning
# subword-nmt/apply_bpe.py:345: ResourceWarning: unclosed file <_io.TextIOWrapper name='iwslt14.tokenized.de-en/code' mode='r' encoding='UTF-8'>
#   args.codes = codecs.open(args.codes.name, encoding='utf-8')
# apply_bpe.py to test.de...
# subword-nmt/apply_bpe.py:328: DeprecationWarning: this script's location has moved to /content/fairseq/examples/translation/subword-nmt/subword_nmt. This symbolic link will be removed in a future version. Please point to the new location, or install the package and use the command 'subword-nmt'
#   DeprecationWarning
# subword-nmt/apply_bpe.py:345: ResourceWarning: unclosed file <_io.TextIOWrapper name='iwslt14.tokenized.de-en/code' mode='r' encoding='UTF-8'>
#   args.codes = codecs.open(args.codes.name, encoding='utf-8')
# apply_bpe.py to train.en...
# subword-nmt/apply_bpe.py:328: DeprecationWarning: this script's location has moved to /content/fairseq/examples/translation/subword-nmt/subword_nmt. This symbolic link will be removed in a future version. Please point to the new location, or install the package and use the command 'subword-nmt'
#   DeprecationWarning
# subword-nmt/apply_bpe.py:345: ResourceWarning: unclosed file <_io.TextIOWrapper name='iwslt14.tokenized.de-en/code' mode='r' encoding='UTF-8'>
#   args.codes = codecs.open(args.codes.name, encoding='utf-8')
# apply_bpe.py to valid.en...
# subword-nmt/apply_bpe.py:328: DeprecationWarning: this script's location has moved to /content/fairseq/examples/translation/subword-nmt/subword_nmt. This symbolic link will be removed in a future version. Please point to the new location, or install the package and use the command 'subword-nmt'
#   DeprecationWarning
# subword-nmt/apply_bpe.py:345: ResourceWarning: unclosed file <_io.TextIOWrapper name='iwslt14.tokenized.de-en/code' mode='r' encoding='UTF-8'>
#   args.codes = codecs.open(args.codes.name, encoding='utf-8')
# apply_bpe.py to test.en...
# subword-nmt/apply_bpe.py:328: DeprecationWarning: this script's location has moved to /content/fairseq/examples/translation/subword-nmt/subword_nmt. This symbolic link will be removed in a future version. Please point to the new location, or install the package and use the command 'subword-nmt'
#   DeprecationWarning
# subword-nmt/apply_bpe.py:345: ResourceWarning: unclosed file <_io.TextIOWrapper name='iwslt14.tokenized.de-en/code' mode='r' encoding='UTF-8'>
#   args.codes = codecs.open(args.codes.name, encoding='utf-8')
# /content/fairseq
# Namespace(align_suffix=None, alignfile=None, bpe=None, cpu=False, criterion='cross_entropy', dataset_impl='mmap', destdir='data-bin/iwslt14.tokenized.de-en', empty_cache_freq=0, fp16=False, fp16_init_scale=128, fp16_scale_tolerance=0.0, fp16_scale_window=None, joined_dictionary=False, log_format=None, log_interval=1000, lr_scheduler='fixed', memory_efficient_fp16=False, min_loss_scale=0.0001, no_progress_bar=False, nwordssrc=-1, nwordstgt=-1, only_source=False, optimizer='nag', padding_factor=8, seed=1, source_lang='de', srcdict=None, target_lang='en', task='translation', tbmf_wrapper=False, tensorboard_logdir='', testpref='examples/translation/iwslt14.tokenized.de-en/test', tgtdict=None, threshold_loss_scale=None, thresholdsrc=0, thresholdtgt=0, tokenizer=None, trainpref='examples/translation/iwslt14.tokenized.de-en/train', user_dir=None, validpref='examples/translation/iwslt14.tokenized.de-en/valid', workers=20)
# | [de] Dictionary: 8847 types
# | [de] examples/translation/iwslt14.tokenized.de-en/train.de: 160239 sents, 4035591 tokens, 0.0% replaced by <unk>
# | [de] Dictionary: 8847 types
# | [de] examples/translation/iwslt14.tokenized.de-en/valid.de: 7283 sents, 182592 tokens, 0.0192% replaced by <unk>
# | [de] Dictionary: 8847 types
# | [de] examples/translation/iwslt14.tokenized.de-en/test.de: 6750 sents, 161838 tokens, 0.0636% replaced by <unk>
# | [en] Dictionary: 6631 types
# | [en] examples/translation/iwslt14.tokenized.de-en/train.en: 160239 sents, 3949114 tokens, 0.0% replaced by <unk>
# | [en] Dictionary: 6631 types
# | [en] examples/translation/iwslt14.tokenized.de-en/valid.en: 7283 sents, 178622 tokens, 0.00448% replaced by <unk>
# | [en] Dictionary: 6631 types
# | [en] examples/translation/iwslt14.tokenized.de-en/test.en: 6750 sents, 156928 tokens, 0.00892% replaced by <unk>
# | Wrote preprocessed data to data-bin/iwslt14.tokenized.de-en

# %%
SAVE="/content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt"

# %%
# Training
# %cd /content/fairseq
# !mkdir -p "{SAVE}" 
# !CUDA_VISIBLE_DEVICES=0 $(which fairseq-train) data-bin/iwslt14.tokenized.de-en \
    --encoder-conv-type ddynamic --decoder-conv-type ddynamic \
    --clip-norm 0 --optimizer adam --lr 0.0005 \
    --source-lang de --target-lang en --max-tokens 4000 --no-progress-bar \
    --log-interval 100 --min-lr '1e-09' --weight-decay 0.0001 \
    --criterion label_smoothed_cross_entropy --label-smoothing 0.1 \
    --lr-scheduler inverse_sqrt \
    --ddp-backend=no_c10d \
    --max-update 50000 --warmup-updates 4000 --warmup-init-lr '1e-07' \
    --adam-betas '(0.9, 0.98)' --keep-last-epochs 10 \
    -a lightconv_iwslt_de_en --save-dir "{SAVE}" \
    --dropout 0.3 --attention-dropout 0.1 --weight-dropout 0.1 \
    --encoder-glu 0 --decoder-glu 0 \
    --encoder-gau 0 --decoder-gau 0 \
    --conv-mixed 0 \
    --encoder-attention-heads 2 --decoder-attention-heads 2 \
    --encoder-attention-proj-heads 2 --decoder-attention-proj-heads 2 \
    2>&1 | tee "{SAVE}/train1.log"
# Out:
# /content/fairseq
# Namespace(adam_betas='(0.9, 0.98)', adam_eps=1e-08, adaptive_softmax_cutoff=None, adaptive_softmax_dropout=0, arch='lightconv_iwslt_de_en', attention_dropout=0.1, best_checkpoint_metric='loss', bpe=None, bucket_cap_mb=25, clip_norm=0.0, conv_mixed=False, cpu=False, criterion='label_smoothed_cross_entropy', curriculum=0, data='data-bin/iwslt14.tokenized.de-en', dataset_impl=None, ddp_backend='no_c10d', decoder_attention_heads=2, decoder_attention_proj_heads=2, decoder_conv_dim=512, decoder_conv_type='ddynamic', decoder_embed_dim=512, decoder_embed_path=None, decoder_ffn_embed_dim=1024, decoder_gau=False, decoder_glu=False, decoder_input_dim=512, decoder_kernel_size_list=[3, 7, 15, 31, 31, 31], decoder_layers=6, decoder_learned_pos=False, decoder_normalize_before=False, decoder_output_dim=512, device_id=0, disable_validation=False, distributed_backend='nccl', distributed_init_method=None, distributed_no_spawn=False, distributed_port=-1, distributed_rank=0, distributed_world_size=1, dropout=0.3, empty_cache_freq=0, encoder_attention_heads=2, encoder_attention_proj_heads=2, encoder_conv_dim=512, encoder_conv_type='ddynamic', encoder_embed_dim=512, encoder_embed_path=None, encoder_ffn_embed_dim=1024, encoder_gau=False, encoder_glu=False, encoder_kernel_size_list=[3, 7, 15, 31, 31, 31, 31], encoder_layers=7, encoder_learned_pos=False, encoder_normalize_before=False, fast_stat_sync=False, find_unused_parameters=False, fix_batches_to_gpus=False, fixed_validation_seed=None, fp16=False, fp16_init_scale=128, fp16_scale_tolerance=0.0, fp16_scale_window=None, input_dropout=0.0, keep_interval_updates=-1, keep_last_epochs=10, label_smoothing=0.1, lazy_load=False, left_pad_source='True', left_pad_target='False', load_alignments=False, log_format=None, log_interval=100, lr=[0.0005], lr_scheduler='inverse_sqrt', max_epoch=0, max_sentences=None, max_sentences_valid=None, max_source_positions=1024, max_target_positions=1024, max_tokens=4000, max_tokens_valid=4000, max_update=50000, maximize_best_checkpoint_metric=False, memory_efficient_fp16=False, min_loss_scale=0.0001, min_lr=1e-09, no_epoch_checkpoints=False, no_last_checkpoints=False, no_progress_bar=True, no_save=False, no_save_optimizer_state=False, no_token_positional_embeddings=False, num_workers=1, optimizer='adam', optimizer_overrides='{}', raw_text=False, relu_dropout=0.0, required_batch_size_multiple=8, reset_dataloader=False, reset_lr_scheduler=False, reset_meters=False, reset_optimizer=False, restore_file='checkpoint_last.pt', save_dir='/content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt', save_interval=1, save_interval_updates=0, seed=1, sentence_avg=False, share_all_embeddings=False, share_decoder_input_output_embed=False, skip_invalid_size_inputs_valid_test=False, source_lang='de', target_lang='en', task='translation', tbmf_wrapper=False, tensorboard_logdir='', threshold_loss_scale=None, tokenizer=None, train_subset='train', update_freq=[1], upsample_primary=1, use_bmuf=False, user_dir=None, valid_subset='valid', validate_interval=1, warmup_init_lr=1e-07, warmup_updates=4000, weight_decay=0.0001, weight_dropout=0.1, weight_softmax=True)
# | [de] dictionary: 8848 types
# | [en] dictionary: 6632 types
# | loaded 7283 examples from: data-bin/iwslt14.tokenized.de-en/valid.de-en.de
# | loaded 7283 examples from: data-bin/iwslt14.tokenized.de-en/valid.de-en.en
# | data-bin/iwslt14.tokenized.de-en valid de-en 7283 examples
# LightConvModel(
#   (encoder): LightConvEncoder(
#     (embed_tokens): Embedding(8848, 512, padding_idx=1)
#     (embed_positions): SinusoidalPositionalEmbedding()
#     (layers): ModuleList(
#       (0): LightConvEncoderLayer(
#         dropout=0.3, relu_dropout=0.0, input_dropout=0.0, normalize_before=False
#         (linear1): Linear(in_features=512, out_features=512, bias=True)
#         (conv): DDynamicConv1dTBC(
#           512, kernel_size=3, padding_l=1, num_heads=2, num_proj_heads=2, conv_mixed=False, weight_softmax=True, conv_bias=False, renorm_padding=False, in_proj=False, weight_dropout=0.1
#           (weight_linear): Linear(in_features=256, out_features=12, bias=False)
#         )
#         (linear2): Linear(in_features=512, out_features=512, bias=True)
#         (fc1): Linear(in_features=512, out_features=1024, bias=True)
#         (fc2): Linear(in_features=1024, out_features=512, bias=True)
#         (layer_norms): ModuleList(
#           (0): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#       (1): LightConvEncoderLayer(
#         dropout=0.3, relu_dropout=0.0, input_dropout=0.0, normalize_before=False
#         (linear1): Linear(in_features=512, out_features=512, bias=True)
#         (conv): DDynamicConv1dTBC(
#           512, kernel_size=7, padding_l=3, num_heads=2, num_proj_heads=2, conv_mixed=False, weight_softmax=True, conv_bias=False, renorm_padding=False, in_proj=False, weight_dropout=0.1
#           (weight_linear): Linear(in_features=256, out_features=28, bias=False)
#         )
#         (linear2): Linear(in_features=512, out_features=512, bias=True)
#         (fc1): Linear(in_features=512, out_features=1024, bias=True)
#         (fc2): Linear(in_features=1024, out_features=512, bias=True)
#         (layer_norms): ModuleList(
#           (0): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#       (2): LightConvEncoderLayer(
#         dropout=0.3, relu_dropout=0.0, input_dropout=0.0, normalize_before=False
#         (linear1): Linear(in_features=512, out_features=512, bias=True)
#         (conv): DDynamicConv1dTBC(
#           512, kernel_size=15, padding_l=7, num_heads=2, num_proj_heads=2, conv_mixed=False, weight_softmax=True, conv_bias=False, renorm_padding=False, in_proj=False, weight_dropout=0.1
#           (weight_linear): Linear(in_features=256, out_features=60, bias=False)
#         )
#         (linear2): Linear(in_features=512, out_features=512, bias=True)
#         (fc1): Linear(in_features=512, out_features=1024, bias=True)
#         (fc2): Linear(in_features=1024, out_features=512, bias=True)
#         (layer_norms): ModuleList(
#           (0): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#       (3): LightConvEncoderLayer(
#         dropout=0.3, relu_dropout=0.0, input_dropout=0.0, normalize_before=False
#         (linear1): Linear(in_features=512, out_features=512, bias=True)
#         (conv): DDynamicConv1dTBC(
#           512, kernel_size=31, padding_l=15, num_heads=2, num_proj_heads=2, conv_mixed=False, weight_softmax=True, conv_bias=False, renorm_padding=False, in_proj=False, weight_dropout=0.1
#           (weight_linear): Linear(in_features=256, out_features=124, bias=False)
#         )
#         (linear2): Linear(in_features=512, out_features=512, bias=True)
#         (fc1): Linear(in_features=512, out_features=1024, bias=True)
#         (fc2): Linear(in_features=1024, out_features=512, bias=True)
#         (layer_norms): ModuleList(
#           (0): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#       (4): LightConvEncoderLayer(
#         dropout=0.3, relu_dropout=0.0, input_dropout=0.0, normalize_before=False
#         (linear1): Linear(in_features=512, out_features=512, bias=True)
#         (conv): DDynamicConv1dTBC(
#           512, kernel_size=31, padding_l=15, num_heads=2, num_proj_heads=2, conv_mixed=False, weight_softmax=True, conv_bias=False, renorm_padding=False, in_proj=False, weight_dropout=0.1
#           (weight_linear): Linear(in_features=256, out_features=124, bias=False)
#         )
#         (linear2): Linear(in_features=512, out_features=512, bias=True)
#         (fc1): Linear(in_features=512, out_features=1024, bias=True)
#         (fc2): Linear(in_features=1024, out_features=512, bias=True)
#         (layer_norms): ModuleList(
#           (0): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#       (5): LightConvEncoderLayer(
#         dropout=0.3, relu_dropout=0.0, input_dropout=0.0, normalize_before=False
#         (linear1): Linear(in_features=512, out_features=512, bias=True)
#         (conv): DDynamicConv1dTBC(
#           512, kernel_size=31, padding_l=15, num_heads=2, num_proj_heads=2, conv_mixed=False, weight_softmax=True, conv_bias=False, renorm_padding=False, in_proj=False, weight_dropout=0.1
#           (weight_linear): Linear(in_features=256, out_features=124, bias=False)
#         )
#         (linear2): Linear(in_features=512, out_features=512, bias=True)
#         (fc1): Linear(in_features=512, out_features=1024, bias=True)
#         (fc2): Linear(in_features=1024, out_features=512, bias=True)
#         (layer_norms): ModuleList(
#           (0): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#       (6): LightConvEncoderLayer(
#         dropout=0.3, relu_dropout=0.0, input_dropout=0.0, normalize_before=False
#         (linear1): Linear(in_features=512, out_features=512, bias=True)
#         (conv): DDynamicConv1dTBC(
#           512, kernel_size=31, padding_l=15, num_heads=2, num_proj_heads=2, conv_mixed=False, weight_softmax=True, conv_bias=False, renorm_padding=False, in_proj=False, weight_dropout=0.1
#           (weight_linear): Linear(in_features=256, out_features=124, bias=False)
#         )
#         (linear2): Linear(in_features=512, out_features=512, bias=True)
#         (fc1): Linear(in_features=512, out_features=1024, bias=True)
#         (fc2): Linear(in_features=1024, out_features=512, bias=True)
#         (layer_norms): ModuleList(
#           (0): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#     )
#   )
#   (decoder): LightConvDecoder(
#     (embed_tokens): Embedding(6632, 512, padding_idx=1)
#     (embed_positions): SinusoidalPositionalEmbedding()
#     (layers): ModuleList(
#       (0): LightConvDecoderLayer(
#         dropout=0.3, relu_dropout=0.0, input_dropout=0.0, normalize_before=False
#         (linear1): Linear(in_features=512, out_features=512, bias=True)
#         (conv): DDynamicConv1dTBC(
#           512, kernel_size=3, padding_l=2, num_heads=2, num_proj_heads=2, conv_mixed=False, weight_softmax=True, conv_bias=False, renorm_padding=False, in_proj=False, weight_dropout=0.1
#           (weight_linear): Linear(in_features=256, out_features=12, bias=False)
#         )
#         (linear2): Linear(in_features=512, out_features=512, bias=True)
#         (conv_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): MultiheadAttention(
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=1024, bias=True)
#         (fc2): Linear(in_features=1024, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (1): LightConvDecoderLayer(
#         dropout=0.3, relu_dropout=0.0, input_dropout=0.0, normalize_before=False
#         (linear1): Linear(in_features=512, out_features=512, bias=True)
#         (conv): DDynamicConv1dTBC(
#           512, kernel_size=7, padding_l=6, num_heads=2, num_proj_heads=2, conv_mixed=False, weight_softmax=True, conv_bias=False, renorm_padding=False, in_proj=False, weight_dropout=0.1
#           (weight_linear): Linear(in_features=256, out_features=28, bias=False)
#         )
#         (linear2): Linear(in_features=512, out_features=512, bias=True)
#         (conv_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): MultiheadAttention(
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=1024, bias=True)
#         (fc2): Linear(in_features=1024, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (2): LightConvDecoderLayer(
#         dropout=0.3, relu_dropout=0.0, input_dropout=0.0, normalize_before=False
#         (linear1): Linear(in_features=512, out_features=512, bias=True)
#         (conv): DDynamicConv1dTBC(
#           512, kernel_size=15, padding_l=14, num_heads=2, num_proj_heads=2, conv_mixed=False, weight_softmax=True, conv_bias=False, renorm_padding=False, in_proj=False, weight_dropout=0.1
#           (weight_linear): Linear(in_features=256, out_features=60, bias=False)
#         )
#         (linear2): Linear(in_features=512, out_features=512, bias=True)
#         (conv_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): MultiheadAttention(
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=1024, bias=True)
#         (fc2): Linear(in_features=1024, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (3): LightConvDecoderLayer(
#         dropout=0.3, relu_dropout=0.0, input_dropout=0.0, normalize_before=False
#         (linear1): Linear(in_features=512, out_features=512, bias=True)
#         (conv): DDynamicConv1dTBC(
#           512, kernel_size=31, padding_l=30, num_heads=2, num_proj_heads=2, conv_mixed=False, weight_softmax=True, conv_bias=False, renorm_padding=False, in_proj=False, weight_dropout=0.1
#           (weight_linear): Linear(in_features=256, out_features=124, bias=False)
#         )
#         (linear2): Linear(in_features=512, out_features=512, bias=True)
#         (conv_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): MultiheadAttention(
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=1024, bias=True)
#         (fc2): Linear(in_features=1024, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (4): LightConvDecoderLayer(
#         dropout=0.3, relu_dropout=0.0, input_dropout=0.0, normalize_before=False
#         (linear1): Linear(in_features=512, out_features=512, bias=True)
#         (conv): DDynamicConv1dTBC(
#           512, kernel_size=31, padding_l=30, num_heads=2, num_proj_heads=2, conv_mixed=False, weight_softmax=True, conv_bias=False, renorm_padding=False, in_proj=False, weight_dropout=0.1
#           (weight_linear): Linear(in_features=256, out_features=124, bias=False)
#         )
#         (linear2): Linear(in_features=512, out_features=512, bias=True)
#         (conv_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): MultiheadAttention(
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=1024, bias=True)
#         (fc2): Linear(in_features=1024, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (5): LightConvDecoderLayer(
#         dropout=0.3, relu_dropout=0.0, input_dropout=0.0, normalize_before=False
#         (linear1): Linear(in_features=512, out_features=512, bias=True)
#         (conv): DDynamicConv1dTBC(
#           512, kernel_size=31, padding_l=30, num_heads=2, num_proj_heads=2, conv_mixed=False, weight_softmax=True, conv_bias=False, renorm_padding=False, in_proj=False, weight_dropout=0.1
#           (weight_linear): Linear(in_features=256, out_features=124, bias=False)
#         )
#         (linear2): Linear(in_features=512, out_features=512, bias=True)
#         (conv_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): MultiheadAttention(
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=1024, bias=True)
#         (fc2): Linear(in_features=1024, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#   )
# )
# | model lightconv_iwslt_de_en, criterion LabelSmoothedCrossEntropyCriterion
# | num. model params: 38411776 (num. trained: 38411776)
# | training on 1 GPUs
# | max tokens per GPU = 4000 and max sentences per GPU = None
# | loaded checkpoint /content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint_last.pt (epoch 19 @ 21489 updates)
# | loading train data for epoch 19
# | loaded 160239 examples from: data-bin/iwslt14.tokenized.de-en/train.de-en.de
# | loaded 160239 examples from: data-bin/iwslt14.tokenized.de-en/train.de-en.en
# | data-bin/iwslt14.tokenized.de-en train de-en 160239 examples
# | epoch 020:    100 / 1131 loss=3.459, nll_loss=1.985, ppl=3.96, wps=17084, ups=5, wpb=3459.000, bsz=135.921, num_updates=21590, lr=0.000215216, gnorm=0.730, clip=0.000, oom=0.000, wall=22, train_wall=12172
# | epoch 020:    200 / 1131 loss=3.467, nll_loss=1.994, ppl=3.98, wps=17086, ups=5, wpb=3470.358, bsz=135.562, num_updates=21690, lr=0.000214719, gnorm=0.725, clip=0.000, oom=0.000, wall=43, train_wall=12191
# | epoch 020:    300 / 1131 loss=3.478, nll_loss=2.007, ppl=4.02, wps=17194, ups=5, wpb=3484.900, bsz=136.106, num_updates=21790, lr=0.000214226, gnorm=0.726, clip=0.000, oom=0.000, wall=63, train_wall=12211
# | epoch 020:    400 / 1131 loss=3.480, nll_loss=2.009, ppl=4.02, wps=17172, ups=5, wpb=3490.249, bsz=138.252, num_updates=21890, lr=0.000213736, gnorm=0.727, clip=0.000, oom=0.000, wall=83, train_wall=12231
# | epoch 020:    500 / 1131 loss=3.482, nll_loss=2.012, ppl=4.03, wps=17201, ups=5, wpb=3498.699, bsz=140.277, num_updates=21990, lr=0.000213249, gnorm=0.725, clip=0.000, oom=0.000, wall=104, train_wall=12251
# | epoch 020:    600 / 1131 loss=3.483, nll_loss=2.013, ppl=4.04, wps=17209, ups=5, wpb=3498.932, bsz=143.240, num_updates=22090, lr=0.000212766, gnorm=0.726, clip=0.000, oom=0.000, wall=124, train_wall=12271
# | epoch 020:    700 / 1131 loss=3.484, nll_loss=2.014, ppl=4.04, wps=17231, ups=5, wpb=3501.904, bsz=143.074, num_updates=22190, lr=0.000212286, gnorm=0.725, clip=0.000, oom=0.000, wall=144, train_wall=12291
# | epoch 020:    800 / 1131 loss=3.489, nll_loss=2.020, ppl=4.06, wps=17199, ups=5, wpb=3490.060, bsz=141.222, num_updates=22290, lr=0.000211809, gnorm=0.728, clip=0.000, oom=0.000, wall=164, train_wall=12311
# | epoch 020:    900 / 1131 loss=3.491, nll_loss=2.022, ppl=4.06, wps=17200, ups=5, wpb=3492.119, bsz=140.714, num_updates=22390, lr=0.000211336, gnorm=0.729, clip=0.000, oom=0.000, wall=185, train_wall=12331
# | epoch 020:   1000 / 1131 loss=3.492, nll_loss=2.024, ppl=4.07, wps=17219, ups=5, wpb=3493.976, bsz=141.817, num_updates=22490, lr=0.000210865, gnorm=0.728, clip=0.000, oom=0.000, wall=205, train_wall=12350
# | epoch 020:   1100 / 1131 loss=3.495, nll_loss=2.027, ppl=4.07, wps=17217, ups=5, wpb=3492.361, bsz=141.863, num_updates=22590, lr=0.000210398, gnorm=0.729, clip=0.000, oom=0.000, wall=225, train_wall=12370
# | epoch 020 | loss 3.496 | nll_loss 2.028 | ppl 4.08 | wps 17209 | ups 5 | wpb 3491.701 | bsz 141.679 | num_updates 22620 | lr 0.000210259 | gnorm 0.729 | clip 0.000 | oom 0.000 | wall 231 | train_wall 12376
# | epoch 020 | valid on 'valid' subset | loss 3.926 | nll_loss 2.369 | ppl 5.17 | num_updates 22620 | best_loss 3.92327
# | saved checkpoint /content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint20.pt (epoch 20 @ 22620 updates) (writing took 3.5380451679229736 seconds)
# | epoch 021:    100 / 1131 loss=3.404, nll_loss=1.922, ppl=3.79, wps=16662, ups=5, wpb=3515.366, bsz=148.356, num_updates=22721, lr=0.000209791, gnorm=0.706, clip=0.000, oom=0.000, wall=260, train_wall=12397
# | epoch 021:    200 / 1131 loss=3.418, nll_loss=1.938, ppl=3.83, wps=16849, ups=5, wpb=3483.294, bsz=145.910, num_updates=22821, lr=0.000209331, gnorm=0.717, clip=0.000, oom=0.000, wall=280, train_wall=12417
# | epoch 021:    300 / 1131 loss=3.426, nll_loss=1.948, ppl=3.86, wps=17019, ups=5, wpb=3491.385, bsz=146.738, num_updates=22921, lr=0.000208873, gnorm=0.719, clip=0.000, oom=0.000, wall=300, train_wall=12436
# | epoch 021:    400 / 1131 loss=3.441, nll_loss=1.964, ppl=3.90, wps=17050, ups=5, wpb=3475.751, bsz=142.803, num_updates=23021, lr=0.000208419, gnorm=0.727, clip=0.000, oom=0.000, wall=320, train_wall=12456
# | epoch 021:    500 / 1131 loss=3.446, nll_loss=1.971, ppl=3.92, wps=17099, ups=5, wpb=3477.473, bsz=143.138, num_updates=23121, lr=0.000207968, gnorm=0.727, clip=0.000, oom=0.000, wall=340, train_wall=12476
# | epoch 021:    600 / 1131 loss=3.450, nll_loss=1.975, ppl=3.93, wps=17139, ups=5, wpb=3482.561, bsz=141.444, num_updates=23221, lr=0.00020752, gnorm=0.727, clip=0.000, oom=0.000, wall=361, train_wall=12496
# | epoch 021:    700 / 1131 loss=3.456, nll_loss=1.982, ppl=3.95, wps=17153, ups=5, wpb=3483.415, bsz=141.591, num_updates=23321, lr=0.000207074, gnorm=0.730, clip=0.000, oom=0.000, wall=381, train_wall=12515
# | epoch 021:    800 / 1131 loss=3.461, nll_loss=1.987, ppl=3.96, wps=17137, ups=5, wpb=3472.457, bsz=141.332, num_updates=23421, lr=0.000206632, gnorm=0.733, clip=0.000, oom=0.000, wall=401, train_wall=12535
# | epoch 021:    900 / 1131 loss=3.463, nll_loss=1.990, ppl=3.97, wps=17175, ups=5, wpb=3483.905, bsz=142.125, num_updates=23521, lr=0.000206192, gnorm=0.732, clip=0.000, oom=0.000, wall=421, train_wall=12555
# | epoch 021:   1000 / 1131 loss=3.464, nll_loss=1.991, ppl=3.98, wps=17174, ups=5, wpb=3486.550, bsz=142.265, num_updates=23621, lr=0.000205755, gnorm=0.731, clip=0.000, oom=0.000, wall=442, train_wall=12575
# | epoch 021:   1100 / 1131 loss=3.466, nll_loss=1.994, ppl=3.98, wps=17200, ups=5, wpb=3491.718, bsz=142.953, num_updates=23721, lr=0.000205321, gnorm=0.732, clip=0.000, oom=0.000, wall=462, train_wall=12595
# | epoch 021 | loss 3.469 | nll_loss 1.998 | ppl 3.99 | wps 17205 | ups 5 | wpb 3491.701 | bsz 141.679 | num_updates 23751 | lr 0.000205191 | gnorm 0.733 | clip 0.000 | oom 0.000 | wall 468 | train_wall 12601
# | epoch 021 | valid on 'valid' subset | loss 3.915 | nll_loss 2.356 | ppl 5.12 | num_updates 23751 | best_loss 3.9155
# | saved checkpoint /content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint21.pt (epoch 21 @ 23751 updates) (writing took 8.313978910446167 seconds)
# | epoch 022:    100 / 1131 loss=3.428, nll_loss=1.948, ppl=3.86, wps=16339, ups=5, wpb=3432.436, bsz=126.733, num_updates=23852, lr=0.000204756, gnorm=0.744, clip=0.000, oom=0.000, wall=501, train_wall=12621
# | epoch 022:    200 / 1131 loss=3.408, nll_loss=1.927, ppl=3.80, wps=16836, ups=5, wpb=3494.234, bsz=140.577, num_updates=23952, lr=0.000204329, gnorm=0.726, clip=0.000, oom=0.000, wall=522, train_wall=12641
# | epoch 022:    300 / 1131 loss=3.417, nll_loss=1.937, ppl=3.83, wps=17004, ups=5, wpb=3487.462, bsz=141.236, num_updates=24052, lr=0.000203903, gnorm=0.729, clip=0.000, oom=0.000, wall=542, train_wall=12661
# | epoch 022:    400 / 1131 loss=3.409, nll_loss=1.929, ppl=3.81, wps=16949, ups=5, wpb=3468.918, bsz=145.975, num_updates=24152, lr=0.000203481, gnorm=0.737, clip=0.000, oom=0.000, wall=562, train_wall=12681
# | epoch 022:    500 / 1131 loss=3.417, nll_loss=1.937, ppl=3.83, wps=16994, ups=5, wpb=3477.263, bsz=144.894, num_updates=24252, lr=0.000203061, gnorm=0.735, clip=0.000, oom=0.000, wall=583, train_wall=12701
# | epoch 022:    600 / 1131 loss=3.428, nll_loss=1.949, ppl=3.86, wps=17056, ups=5, wpb=3485.371, bsz=143.281, num_updates=24352, lr=0.000202644, gnorm=0.736, clip=0.000, oom=0.000, wall=603, train_wall=12721
# | epoch 022:    700 / 1131 loss=3.425, nll_loss=1.946, ppl=3.85, wps=17087, ups=5, wpb=3488.231, bsz=143.726, num_updates=24452, lr=0.000202229, gnorm=0.734, clip=0.000, oom=0.000, wall=623, train_wall=12741
# | epoch 022:    800 / 1131 loss=3.427, nll_loss=1.949, ppl=3.86, wps=17113, ups=5, wpb=3495.121, bsz=144.779, num_updates=24552, lr=0.000201816, gnorm=0.733, clip=0.000, oom=0.000, wall=644, train_wall=12761
# | epoch 022:    900 / 1131 loss=3.435, nll_loss=1.958, ppl=3.88, wps=17103, ups=5, wpb=3491.502, bsz=143.306, num_updates=24652, lr=0.000201407, gnorm=0.735, clip=0.000, oom=0.000, wall=664, train_wall=12781
# | epoch 022:   1000 / 1131 loss=3.442, nll_loss=1.966, ppl=3.91, wps=17096, ups=5, wpb=3487.072, bsz=140.666, num_updates=24752, lr=0.000200999, gnorm=0.737, clip=0.000, oom=0.000, wall=684, train_wall=12800
# | epoch 022:   1100 / 1131 loss=3.444, nll_loss=1.968, ppl=3.91, wps=17121, ups=5, wpb=3491.807, bsz=141.558, num_updates=24852, lr=0.000200595, gnorm=0.737, clip=0.000, oom=0.000, wall=705, train_wall=12820
# | epoch 022 | loss 3.445 | nll_loss 1.970 | ppl 3.92 | wps 17117 | ups 5 | wpb 3491.701 | bsz 141.679 | num_updates 24882 | lr 0.000200474 | gnorm 0.738 | clip 0.000 | oom 0.000 | wall 711 | train_wall 12826
# | epoch 022 | valid on 'valid' subset | loss 3.918 | nll_loss 2.358 | ppl 5.13 | num_updates 24882 | best_loss 3.9155
# | saved checkpoint /content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint22.pt (epoch 22 @ 24882 updates) (writing took 4.237692594528198 seconds)
# | epoch 023:    100 / 1131 loss=3.380, nll_loss=1.895, ppl=3.72, wps=16562, ups=5, wpb=3500.772, bsz=146.851, num_updates=24983, lr=0.000200068, gnorm=0.718, clip=0.000, oom=0.000, wall=740, train_wall=12847
# | epoch 023:    200 / 1131 loss=3.400, nll_loss=1.917, ppl=3.78, wps=17037, ups=5, wpb=3535.856, bsz=140.100, num_updates=25083, lr=0.000199669, gnorm=0.722, clip=0.000, oom=0.000, wall=760, train_wall=12867
# | epoch 023:    300 / 1131 loss=3.408, nll_loss=1.926, ppl=3.80, wps=17071, ups=5, wpb=3507.266, bsz=138.445, num_updates=25183, lr=0.000199272, gnorm=0.730, clip=0.000, oom=0.000, wall=780, train_wall=12887
# | epoch 023:    400 / 1131 loss=3.399, nll_loss=1.916, ppl=3.77, wps=17061, ups=5, wpb=3491.818, bsz=141.387, num_updates=25283, lr=0.000198878, gnorm=0.732, clip=0.000, oom=0.000, wall=801, train_wall=12907
# | epoch 023:    500 / 1131 loss=3.402, nll_loss=1.920, ppl=3.78, wps=17115, ups=5, wpb=3503.709, bsz=142.739, num_updates=25383, lr=0.000198485, gnorm=0.730, clip=0.000, oom=0.000, wall=821, train_wall=12927
# | epoch 023:    600 / 1131 loss=3.416, nll_loss=1.935, ppl=3.82, wps=17132, ups=5, wpb=3496.461, bsz=138.394, num_updates=25483, lr=0.000198096, gnorm=0.736, clip=0.000, oom=0.000, wall=841, train_wall=12946
# | epoch 023:    700 / 1131 loss=3.421, nll_loss=1.941, ppl=3.84, wps=17125, ups=5, wpb=3492.546, bsz=137.688, num_updates=25583, lr=0.000197708, gnorm=0.739, clip=0.000, oom=0.000, wall=862, train_wall=12966
# | epoch 023:    800 / 1131 loss=3.420, nll_loss=1.940, ppl=3.84, wps=17128, ups=5, wpb=3489.687, bsz=139.644, num_updates=25683, lr=0.000197323, gnorm=0.740, clip=0.000, oom=0.000, wall=882, train_wall=12986
# | epoch 023:    900 / 1131 loss=3.423, nll_loss=1.944, ppl=3.85, wps=17129, ups=5, wpb=3489.576, bsz=139.808, num_updates=25783, lr=0.00019694, gnorm=0.740, clip=0.000, oom=0.000, wall=902, train_wall=13006
# | epoch 023:   1000 / 1131 loss=3.423, nll_loss=1.944, ppl=3.85, wps=17124, ups=5, wpb=3489.438, bsz=140.403, num_updates=25883, lr=0.000196559, gnorm=0.740, clip=0.000, oom=0.000, wall=923, train_wall=13026
# | epoch 023:   1100 / 1131 loss=3.423, nll_loss=1.944, ppl=3.85, wps=17117, ups=5, wpb=3490.091, bsz=141.231, num_updates=25983, lr=0.00019618, gnorm=0.739, clip=0.000, oom=0.000, wall=943, train_wall=13046
# | epoch 023 | loss 3.423 | nll_loss 1.944 | ppl 3.85 | wps 17120 | ups 5 | wpb 3491.701 | bsz 141.679 | num_updates 26013 | lr 0.000196067 | gnorm 0.740 | clip 0.000 | oom 0.000 | wall 949 | train_wall 13052
# | epoch 023 | valid on 'valid' subset | loss 3.919 | nll_loss 2.355 | ppl 5.12 | num_updates 26013 | best_loss 3.9155
# | saved checkpoint /content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint23.pt (epoch 23 @ 26013 updates) (writing took 3.7273123264312744 seconds)
# | epoch 024:    100 / 1131 loss=3.345, nll_loss=1.855, ppl=3.62, wps=16516, ups=5, wpb=3474.535, bsz=149.307, num_updates=26114, lr=0.000195688, gnorm=0.727, clip=0.000, oom=0.000, wall=978, train_wall=13073
# | epoch 024:    200 / 1131 loss=3.372, nll_loss=1.884, ppl=3.69, wps=16869, ups=5, wpb=3489.632, bsz=141.970, num_updates=26214, lr=0.000195314, gnorm=0.734, clip=0.000, oom=0.000, wall=998, train_wall=13093
# | epoch 024:    300 / 1131 loss=3.386, nll_loss=1.901, ppl=3.73, wps=16934, ups=5, wpb=3489.027, bsz=138.179, num_updates=26314, lr=0.000194943, gnorm=0.739, clip=0.000, oom=0.000, wall=1019, train_wall=13113
# | epoch 024:    400 / 1131 loss=3.384, nll_loss=1.898, ppl=3.73, wps=16977, ups=5, wpb=3487.040, bsz=139.012, num_updates=26414, lr=0.000194573, gnorm=0.741, clip=0.000, oom=0.000, wall=1039, train_wall=13132
# | epoch 024:    500 / 1131 loss=3.388, nll_loss=1.903, ppl=3.74, wps=16992, ups=5, wpb=3485.293, bsz=139.257, num_updates=26514, lr=0.000194206, gnorm=0.743, clip=0.000, oom=0.000, wall=1059, train_wall=13152
# | epoch 024:    600 / 1131 loss=3.392, nll_loss=1.907, ppl=3.75, wps=17031, ups=5, wpb=3486.499, bsz=139.913, num_updates=26614, lr=0.000193841, gnorm=0.744, clip=0.000, oom=0.000, wall=1080, train_wall=13172
# | epoch 024:    700 / 1131 loss=3.391, nll_loss=1.906, ppl=3.75, wps=17061, ups=5, wpb=3494.181, bsz=140.371, num_updates=26714, lr=0.000193478, gnorm=0.741, clip=0.000, oom=0.000, wall=1100, train_wall=13192
# | epoch 024:    800 / 1131 loss=3.393, nll_loss=1.908, ppl=3.75, wps=17055, ups=5, wpb=3496.223, bsz=140.365, num_updates=26814, lr=0.000193116, gnorm=0.742, clip=0.000, oom=0.000, wall=1121, train_wall=13212
# | epoch 024:    900 / 1131 loss=3.396, nll_loss=1.912, ppl=3.76, wps=17050, ups=5, wpb=3491.495, bsz=141.052, num_updates=26914, lr=0.000192757, gnorm=0.744, clip=0.000, oom=0.000, wall=1141, train_wall=13232
# | epoch 024:   1000 / 1131 loss=3.398, nll_loss=1.915, ppl=3.77, wps=17045, ups=5, wpb=3493.110, bsz=141.801, num_updates=27014, lr=0.0001924, gnorm=0.745, clip=0.000, oom=0.000, wall=1162, train_wall=13253
# | epoch 024:   1100 / 1131 loss=3.401, nll_loss=1.918, ppl=3.78, wps=17052, ups=5, wpb=3491.548, bsz=142.117, num_updates=27114, lr=0.000192045, gnorm=0.745, clip=0.000, oom=0.000, wall=1182, train_wall=13272
# | epoch 024 | loss 3.402 | nll_loss 1.919 | ppl 3.78 | wps 17048 | ups 5 | wpb 3491.701 | bsz 141.679 | num_updates 27144 | lr 0.000191939 | gnorm 0.745 | clip 0.000 | oom 0.000 | wall 1188 | train_wall 13278
# | epoch 024 | valid on 'valid' subset | loss 3.910 | nll_loss 2.347 | ppl 5.09 | num_updates 27144 | best_loss 3.90969
# | saved checkpoint /content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint24.pt (epoch 24 @ 27144 updates) (writing took 6.219074726104736 seconds)
# | epoch 025:    100 / 1131 loss=3.321, nll_loss=1.824, ppl=3.54, wps=16240, ups=5, wpb=3426.891, bsz=133.782, num_updates=27245, lr=0.000191583, gnorm=0.739, clip=0.000, oom=0.000, wall=1219, train_wall=13299
# | epoch 025:    200 / 1131 loss=3.331, nll_loss=1.837, ppl=3.57, wps=16863, ups=5, wpb=3499.294, bsz=142.368, num_updates=27345, lr=0.000191232, gnorm=0.733, clip=0.000, oom=0.000, wall=1240, train_wall=13319
# | epoch 025:    300 / 1131 loss=3.339, nll_loss=1.846, ppl=3.60, wps=16979, ups=5, wpb=3502.631, bsz=143.256, num_updates=27445, lr=0.000190883, gnorm=0.734, clip=0.000, oom=0.000, wall=1260, train_wall=13339
# | epoch 025:    400 / 1131 loss=3.345, nll_loss=1.853, ppl=3.61, wps=16959, ups=5, wpb=3491.853, bsz=141.903, num_updates=27545, lr=0.000190537, gnorm=0.742, clip=0.000, oom=0.000, wall=1281, train_wall=13359
# | epoch 025:    500 / 1131 loss=3.356, nll_loss=1.865, ppl=3.64, wps=16981, ups=5, wpb=3490.461, bsz=141.395, num_updates=27645, lr=0.000190192, gnorm=0.744, clip=0.000, oom=0.000, wall=1301, train_wall=13379
# | epoch 025:    600 / 1131 loss=3.364, nll_loss=1.875, ppl=3.67, wps=17048, ups=5, wpb=3506.962, bsz=140.391, num_updates=27745, lr=0.000189849, gnorm=0.742, clip=0.000, oom=0.000, wall=1322, train_wall=13399
# | epoch 025:    700 / 1131 loss=3.372, nll_loss=1.884, ppl=3.69, wps=17040, ups=5, wpb=3497.418, bsz=138.954, num_updates=27845, lr=0.000189507, gnorm=0.747, clip=0.000, oom=0.000, wall=1342, train_wall=13419
# | epoch 025:    800 / 1131 loss=3.375, nll_loss=1.888, ppl=3.70, wps=17030, ups=5, wpb=3494.496, bsz=137.996, num_updates=27945, lr=0.000189168, gnorm=0.747, clip=0.000, oom=0.000, wall=1363, train_wall=13439
# | epoch 025:    900 / 1131 loss=3.377, nll_loss=1.890, ppl=3.71, wps=17001, ups=5, wpb=3490.186, bsz=139.195, num_updates=28045, lr=0.000188831, gnorm=0.748, clip=0.000, oom=0.000, wall=1383, train_wall=13459
# | epoch 025:   1000 / 1131 loss=3.375, nll_loss=1.889, ppl=3.70, wps=17009, ups=5, wpb=3494.894, bsz=141.282, num_updates=28145, lr=0.000188495, gnorm=0.746, clip=0.000, oom=0.000, wall=1404, train_wall=13480
# | epoch 025:   1100 / 1131 loss=3.381, nll_loss=1.895, ppl=3.72, wps=17031, ups=5, wpb=3495.530, bsz=141.667, num_updates=28245, lr=0.000188161, gnorm=0.747, clip=0.000, oom=0.000, wall=1424, train_wall=13500
# | epoch 025 | loss 3.382 | nll_loss 1.897 | ppl 3.72 | wps 17022 | ups 5 | wpb 3491.701 | bsz 141.679 | num_updates 28275 | lr 0.000188061 | gnorm 0.748 | clip 0.000 | oom 0.000 | wall 1430 | train_wall 13505
# | epoch 025 | valid on 'valid' subset | loss 3.913 | nll_loss 2.351 | ppl 5.10 | num_updates 28275 | best_loss 3.90969
# | saved checkpoint /content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint25.pt (epoch 25 @ 28275 updates) (writing took 4.2340521812438965 seconds)
# | epoch 026:    100 / 1131 loss=3.266, nll_loss=1.764, ppl=3.40, wps=16455, ups=5, wpb=3507.564, bsz=164.911, num_updates=28376, lr=0.000187726, gnorm=0.719, clip=0.000, oom=0.000, wall=1460, train_wall=13526
# | epoch 026:    200 / 1131 loss=3.303, nll_loss=1.805, ppl=3.49, wps=16780, ups=5, wpb=3520.706, bsz=150.965, num_updates=28476, lr=0.000187396, gnorm=0.730, clip=0.000, oom=0.000, wall=1480, train_wall=13547
# | epoch 026:    300 / 1131 loss=3.310, nll_loss=1.813, ppl=3.51, wps=16893, ups=5, wpb=3510.867, bsz=150.166, num_updates=28576, lr=0.000187068, gnorm=0.732, clip=0.000, oom=0.000, wall=1501, train_wall=13566
# | epoch 026:    400 / 1131 loss=3.324, nll_loss=1.829, ppl=3.55, wps=16908, ups=5, wpb=3498.486, bsz=144.399, num_updates=28676, lr=0.000186741, gnorm=0.740, clip=0.000, oom=0.000, wall=1521, train_wall=13586
# | epoch 026:    500 / 1131 loss=3.334, nll_loss=1.840, ppl=3.58, wps=16895, ups=5, wpb=3487.733, bsz=142.723, num_updates=28776, lr=0.000186417, gnorm=0.744, clip=0.000, oom=0.000, wall=1541, train_wall=13606
# | epoch 026:    600 / 1131 loss=3.337, nll_loss=1.844, ppl=3.59, wps=16896, ups=5, wpb=3486.950, bsz=142.083, num_updates=28876, lr=0.000186094, gnorm=0.746, clip=0.000, oom=0.000, wall=1562, train_wall=13627
# | epoch 026:    700 / 1131 loss=3.345, nll_loss=1.853, ppl=3.61, wps=16918, ups=5, wpb=3489.291, bsz=141.444, num_updates=28976, lr=0.000185772, gnorm=0.747, clip=0.000, oom=0.000, wall=1583, train_wall=13647
# | epoch 026:    800 / 1131 loss=3.352, nll_loss=1.861, ppl=3.63, wps=16941, ups=5, wpb=3487.793, bsz=140.335, num_updates=29076, lr=0.000185452, gnorm=0.749, clip=0.000, oom=0.000, wall=1603, train_wall=13667
# | epoch 026:    900 / 1131 loss=3.353, nll_loss=1.862, ppl=3.64, wps=16972, ups=5, wpb=3493.284, bsz=141.496, num_updates=29176, lr=0.000185134, gnorm=0.748, clip=0.000, oom=0.000, wall=1623, train_wall=13687
# | epoch 026:   1000 / 1131 loss=3.361, nll_loss=1.872, ppl=3.66, wps=16999, ups=5, wpb=3496.195, bsz=142.018, num_updates=29276, lr=0.000184818, gnorm=0.749, clip=0.000, oom=0.000, wall=1644, train_wall=13707
# | epoch 026:   1100 / 1131 loss=3.361, nll_loss=1.872, ppl=3.66, wps=17002, ups=5, wpb=3494.808, bsz=142.358, num_updates=29376, lr=0.000184503, gnorm=0.749, clip=0.000, oom=0.000, wall=1664, train_wall=13727
# | epoch 026 | loss 3.362 | nll_loss 1.873 | ppl 3.66 | wps 16994 | ups 5 | wpb 3491.701 | bsz 141.679 | num_updates 29406 | lr 0.000184409 | gnorm 0.751 | clip 0.000 | oom 0.000 | wall 1670 | train_wall 13732
# | epoch 026 | valid on 'valid' subset | loss 3.917 | nll_loss 2.357 | ppl 5.12 | num_updates 29406 | best_loss 3.90969
# | saved checkpoint /content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint26.pt (epoch 26 @ 29406 updates) (writing took 4.111401557922363 seconds)
# | epoch 027:    100 / 1131 loss=3.291, nll_loss=1.792, ppl=3.46, wps=16723, ups=5, wpb=3522.356, bsz=141.465, num_updates=29507, lr=0.000184093, gnorm=0.735, clip=0.000, oom=0.000, wall=1699, train_wall=13753
# | epoch 027:    200 / 1131 loss=3.294, nll_loss=1.795, ppl=3.47, wps=16834, ups=5, wpb=3486.831, bsz=149.612, num_updates=29607, lr=0.000183782, gnorm=0.740, clip=0.000, oom=0.000, wall=1720, train_wall=13773
# | epoch 027:    300 / 1131 loss=3.305, nll_loss=1.807, ppl=3.50, wps=16853, ups=5, wpb=3481.243, bsz=145.037, num_updates=29707, lr=0.000183472, gnorm=0.746, clip=0.000, oom=0.000, wall=1740, train_wall=13793
# | epoch 027:    400 / 1131 loss=3.316, nll_loss=1.819, ppl=3.53, wps=16927, ups=5, wpb=3488.297, bsz=143.122, num_updates=29807, lr=0.000183164, gnorm=0.746, clip=0.000, oom=0.000, wall=1761, train_wall=13813
# | epoch 027:    500 / 1131 loss=3.318, nll_loss=1.822, ppl=3.54, wps=16963, ups=5, wpb=3495.521, bsz=143.026, num_updates=29907, lr=0.000182858, gnorm=0.746, clip=0.000, oom=0.000, wall=1781, train_wall=13833
# | epoch 027:    600 / 1131 loss=3.321, nll_loss=1.826, ppl=3.55, wps=17001, ups=5, wpb=3500.369, bsz=144.200, num_updates=30007, lr=0.000182553, gnorm=0.747, clip=0.000, oom=0.000, wall=1802, train_wall=13854
# | epoch 027:    700 / 1131 loss=3.331, nll_loss=1.837, ppl=3.57, wps=17028, ups=5, wpb=3499.906, bsz=142.231, num_updates=30107, lr=0.000182249, gnorm=0.751, clip=0.000, oom=0.000, wall=1822, train_wall=13873
# | epoch 027:    800 / 1131 loss=3.333, nll_loss=1.839, ppl=3.58, wps=16999, ups=5, wpb=3490.444, bsz=142.341, num_updates=30207, lr=0.000181948, gnorm=0.752, clip=0.000, oom=0.000, wall=1843, train_wall=13893
# | epoch 027:    900 / 1131 loss=3.338, nll_loss=1.845, ppl=3.59, wps=17014, ups=5, wpb=3494.223, bsz=142.587, num_updates=30307, lr=0.000181647, gnorm=0.752, clip=0.000, oom=0.000, wall=1863, train_wall=13913
# | epoch 027:   1000 / 1131 loss=3.341, nll_loss=1.849, ppl=3.60, wps=17016, ups=5, wpb=3493.848, bsz=141.505, num_updates=30407, lr=0.000181348, gnorm=0.754, clip=0.000, oom=0.000, wall=1884, train_wall=13933
# | epoch 027:   1100 / 1131 loss=3.344, nll_loss=1.852, ppl=3.61, wps=17006, ups=5, wpb=3490.492, bsz=141.144, num_updates=30507, lr=0.000181051, gnorm=0.755, clip=0.000, oom=0.000, wall=1904, train_wall=13954
# | epoch 027 | loss 3.343 | nll_loss 1.851 | ppl 3.61 | wps 17009 | ups 5 | wpb 3491.701 | bsz 141.679 | num_updates 30537 | lr 0.000180962 | gnorm 0.755 | clip 0.000 | oom 0.000 | wall 1910 | train_wall 13960
# | epoch 027 | valid on 'valid' subset | loss 3.920 | nll_loss 2.361 | ppl 5.14 | num_updates 30537 | best_loss 3.90969
# | saved checkpoint /content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint27.pt (epoch 27 @ 30537 updates) (writing took 3.790883779525757 seconds)
# | epoch 028:    100 / 1131 loss=3.293, nll_loss=1.792, ppl=3.46, wps=16383, ups=5, wpb=3475.762, bsz=133.465, num_updates=30638, lr=0.000180663, gnorm=0.757, clip=0.000, oom=0.000, wall=1939, train_wall=13980
# | epoch 028:    200 / 1131 loss=3.297, nll_loss=1.796, ppl=3.47, wps=16701, ups=5, wpb=3478.363, bsz=139.980, num_updates=30738, lr=0.000180369, gnorm=0.756, clip=0.000, oom=0.000, wall=1960, train_wall=14000
# | epoch 028:    300 / 1131 loss=3.296, nll_loss=1.796, ppl=3.47, wps=16795, ups=5, wpb=3468.638, bsz=139.615, num_updates=30838, lr=0.000180076, gnorm=0.757, clip=0.000, oom=0.000, wall=1980, train_wall=14020
# | epoch 028:    400 / 1131 loss=3.302, nll_loss=1.803, ppl=3.49, wps=16926, ups=5, wpb=3491.853, bsz=142.484, num_updates=30938, lr=0.000179785, gnorm=0.754, clip=0.000, oom=0.000, wall=2001, train_wall=14040
# | epoch 028:    500 / 1131 loss=3.307, nll_loss=1.808, ppl=3.50, wps=16878, ups=5, wpb=3473.112, bsz=139.527, num_updates=31038, lr=0.000179495, gnorm=0.760, clip=0.000, oom=0.000, wall=2021, train_wall=14060
# | epoch 028:    600 / 1131 loss=3.309, nll_loss=1.811, ppl=3.51, wps=16887, ups=5, wpb=3465.792, bsz=139.592, num_updates=31138, lr=0.000179207, gnorm=0.761, clip=0.000, oom=0.000, wall=2041, train_wall=14080
# | epoch 028:    700 / 1131 loss=3.307, nll_loss=1.809, ppl=3.50, wps=16923, ups=5, wpb=3479.250, bsz=142.173, num_updates=31238, lr=0.00017892, gnorm=0.757, clip=0.000, oom=0.000, wall=2062, train_wall=14100
# | epoch 028:    800 / 1131 loss=3.313, nll_loss=1.815, ppl=3.52, wps=16935, ups=5, wpb=3482.266, bsz=141.002, num_updates=31338, lr=0.000178634, gnorm=0.758, clip=0.000, oom=0.000, wall=2082, train_wall=14121
# | epoch 028:    900 / 1131 loss=3.316, nll_loss=1.819, ppl=3.53, wps=16948, ups=5, wpb=3483.667, bsz=141.131, num_updates=31438, lr=0.00017835, gnorm=0.759, clip=0.000, oom=0.000, wall=2103, train_wall=14141
# | epoch 028:   1000 / 1131 loss=3.321, nll_loss=1.825, ppl=3.54, wps=16954, ups=5, wpb=3484.015, bsz=141.466, num_updates=31538, lr=0.000178067, gnorm=0.758, clip=0.000, oom=0.000, wall=2123, train_wall=14161
# | epoch 028:   1100 / 1131 loss=3.324, nll_loss=1.829, ppl=3.55, wps=16985, ups=5, wpb=3491.555, bsz=142.052, num_updates=31638, lr=0.000177785, gnorm=0.758, clip=0.000, oom=0.000, wall=2144, train_wall=14181
# | epoch 028 | loss 3.327 | nll_loss 1.832 | ppl 3.56 | wps 16990 | ups 5 | wpb 3491.701 | bsz 141.679 | num_updates 31668 | lr 0.000177701 | gnorm 0.758 | clip 0.000 | oom 0.000 | wall 2150 | train_wall 14187
# | epoch 028 | valid on 'valid' subset | loss 3.895 | nll_loss 2.328 | ppl 5.02 | num_updates 31668 | best_loss 3.89502
# | saved checkpoint /content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint28.pt (epoch 28 @ 31668 updates) (writing took 6.86653733253479 seconds)
# | epoch 029:    100 / 1131 loss=3.281, nll_loss=1.778, ppl=3.43, wps=16108, ups=5, wpb=3485.089, bsz=143.762, num_updates=31769, lr=0.000177418, gnorm=0.756, clip=0.000, oom=0.000, wall=2183, train_wall=14208
# | epoch 029:    200 / 1131 loss=3.289, nll_loss=1.787, ppl=3.45, wps=16457, ups=5, wpb=3461.169, bsz=134.766, num_updates=31869, lr=0.00017714, gnorm=0.763, clip=0.000, oom=0.000, wall=2203, train_wall=14228
# | epoch 029:    300 / 1131 loss=3.284, nll_loss=1.782, ppl=3.44, wps=16679, ups=5, wpb=3483.983, bsz=139.110, num_updates=31969, lr=0.000176862, gnorm=0.755, clip=0.000, oom=0.000, wall=2224, train_wall=14248
# | epoch 029:    400 / 1131 loss=3.292, nll_loss=1.790, ppl=3.46, wps=16722, ups=5, wpb=3466.546, bsz=138.554, num_updates=32069, lr=0.000176586, gnorm=0.761, clip=0.000, oom=0.000, wall=2244, train_wall=14268
# | epoch 029:    500 / 1131 loss=3.291, nll_loss=1.790, ppl=3.46, wps=16795, ups=5, wpb=3488.327, bsz=141.860, num_updates=32169, lr=0.000176312, gnorm=0.757, clip=0.000, oom=0.000, wall=2265, train_wall=14289
# | epoch 029:    600 / 1131 loss=3.296, nll_loss=1.796, ppl=3.47, wps=16864, ups=5, wpb=3498.110, bsz=143.148, num_updates=32269, lr=0.000176038, gnorm=0.757, clip=0.000, oom=0.000, wall=2285, train_wall=14309
# | epoch 029:    700 / 1131 loss=3.296, nll_loss=1.796, ppl=3.47, wps=16923, ups=5, wpb=3505.790, bsz=144.217, num_updates=32369, lr=0.000175766, gnorm=0.758, clip=0.000, oom=0.000, wall=2306, train_wall=14329
# | epoch 029:    800 / 1131 loss=3.300, nll_loss=1.801, ppl=3.48, wps=16902, ups=5, wpb=3489.056, bsz=141.433, num_updates=32469, lr=0.000175495, gnorm=0.762, clip=0.000, oom=0.000, wall=2326, train_wall=14349
# | epoch 029:    900 / 1131 loss=3.305, nll_loss=1.807, ppl=3.50, wps=16877, ups=5, wpb=3477.526, bsz=140.625, num_updates=32569, lr=0.000175226, gnorm=0.766, clip=0.000, oom=0.000, wall=2346, train_wall=14368
# | epoch 029:   1000 / 1131 loss=3.307, nll_loss=1.809, ppl=3.50, wps=16936, ups=5, wpb=3490.198, bsz=142.385, num_updates=32669, lr=0.000174957, gnorm=0.763, clip=0.000, oom=0.000, wall=2367, train_wall=14389
# | epoch 029:   1100 / 1131 loss=3.311, nll_loss=1.813, ppl=3.51, wps=16933, ups=5, wpb=3490.081, bsz=141.645, num_updates=32769, lr=0.00017469, gnorm=0.765, clip=0.000, oom=0.000, wall=2388, train_wall=14409
# | epoch 029 | loss 3.312 | nll_loss 1.814 | ppl 3.52 | wps 16941 | ups 5 | wpb 3491.701 | bsz 141.679 | num_updates 32799 | lr 0.00017461 | gnorm 0.765 | clip 0.000 | oom 0.000 | wall 2394 | train_wall 14415
# | epoch 029 | valid on 'valid' subset | loss 3.903 | nll_loss 2.337 | ppl 5.05 | num_updates 32799 | best_loss 3.89502
# | saved checkpoint /content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint29.pt (epoch 29 @ 32799 updates) (writing took 4.608478307723999 seconds)
# | epoch 030:    100 / 1131 loss=3.274, nll_loss=1.769, ppl=3.41, wps=16254, ups=5, wpb=3476.911, bsz=136.000, num_updates=32900, lr=0.000174342, gnorm=0.758, clip=0.000, oom=0.000, wall=2424, train_wall=14436
# | epoch 030:    200 / 1131 loss=3.275, nll_loss=1.770, ppl=3.41, wps=16567, ups=5, wpb=3492.085, bsz=131.697, num_updates=33000, lr=0.000174078, gnorm=0.760, clip=0.000, oom=0.000, wall=2444, train_wall=14456
# | epoch 030:    300 / 1131 loss=3.268, nll_loss=1.763, ppl=3.39, wps=16780, ups=5, wpb=3506.146, bsz=141.233, num_updates=33100, lr=0.000173814, gnorm=0.755, clip=0.000, oom=0.000, wall=2465, train_wall=14476
# | epoch 030:    400 / 1131 loss=3.275, nll_loss=1.772, ppl=3.41, wps=16846, ups=5, wpb=3498.469, bsz=143.160, num_updates=33200, lr=0.000173553, gnorm=0.759, clip=0.000, oom=0.000, wall=2485, train_wall=14496
# | epoch 030:    500 / 1131 loss=3.276, nll_loss=1.772, ppl=3.42, wps=16868, ups=5, wpb=3494.319, bsz=142.353, num_updates=33300, lr=0.000173292, gnorm=0.760, clip=0.000, oom=0.000, wall=2506, train_wall=14516
# | epoch 030:    600 / 1131 loss=3.277, nll_loss=1.774, ppl=3.42, wps=16915, ups=5, wpb=3498.735, bsz=142.401, num_updates=33400, lr=0.000173032, gnorm=0.761, clip=0.000, oom=0.000, wall=2526, train_wall=14536
# ...
# | epoch 039:   1000 / 1131 loss=3.175, nll_loss=1.655, ppl=3.15, wps=16983, ups=5, wpb=3497.826, bsz=142.009, num_updates=43979, lr=0.000150792, gnorm=0.794, clip=0.000, oom=0.000, wall=4778, train_wall=16665
# | epoch 039:   1100 / 1131 loss=3.177, nll_loss=1.657, ppl=3.15, wps=16979, ups=5, wpb=3494.713, bsz=141.885, num_updates=44079, lr=0.000150621, gnorm=0.794, clip=0.000, oom=0.000, wall=4799, train_wall=16685
# | epoch 039 | loss 3.179 | nll_loss 1.659 | ppl 3.16 | wps 16969 | ups 5 | wpb 3491.701 | bsz 141.679 | num_updates 44109 | lr 0.000150569 | gnorm 0.795 | clip 0.000 | oom 0.000 | wall 4805 | train_wall 16691
# | epoch 039 | valid on 'valid' subset | loss 3.909 | nll_loss 2.344 | ppl 5.08 | num_updates 44109 | best_loss 3.88953
# | saved checkpoint /content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint39.pt (epoch 39 @ 44109 updates) (writing took 4.68520712852478 seconds)
# | epoch 040:    100 / 1131 loss=3.147, nll_loss=1.620, ppl=3.07, wps=15980, ups=5, wpb=3412.040, bsz=123.723, num_updates=44210, lr=0.000150397, gnorm=0.804, clip=0.000, oom=0.000, wall=4835, train_wall=16712
# | epoch 040:    200 / 1131 loss=3.135, nll_loss=1.607, ppl=3.05, wps=16347, ups=5, wpb=3427.199, bsz=132.697, num_updates=44310, lr=0.000150227, gnorm=0.798, clip=0.000, oom=0.000, wall=4855, train_wall=16732
# | epoch 040:    300 / 1131 loss=3.140, nll_loss=1.613, ppl=3.06, wps=16511, ups=5, wpb=3446.910, bsz=131.907, num_updates=44410, lr=0.000150058, gnorm=0.797, clip=0.000, oom=0.000, wall=4876, train_wall=16752
# | epoch 040:    400 / 1131 loss=3.152, nll_loss=1.626, ppl=3.09, wps=16641, ups=5, wpb=3465.671, bsz=131.070, num_updates=44510, lr=0.000149889, gnorm=0.800, clip=0.000, oom=0.000, wall=4897, train_wall=16773
# | epoch 040:    500 / 1131 loss=3.156, nll_loss=1.631, ppl=3.10, wps=16706, ups=5, wpb=3467.411, bsz=132.772, num_updates=44610, lr=0.000149721, gnorm=0.803, clip=0.000, oom=0.000, wall=4917, train_wall=16793
# | epoch 040:    600 / 1131 loss=3.155, nll_loss=1.631, ppl=3.10, wps=16747, ups=5, wpb=3469.631, bsz=135.493, num_updates=44710, lr=0.000149554, gnorm=0.802, clip=0.000, oom=0.000, wall=4938, train_wall=16813
# | epoch 040:    700 / 1131 loss=3.154, nll_loss=1.630, ppl=3.09, wps=16790, ups=5, wpb=3474.101, bsz=137.699, num_updates=44810, lr=0.000149387, gnorm=0.799, clip=0.000, oom=0.000, wall=4958, train_wall=16833
# | epoch 040:    800 / 1131 loss=3.158, nll_loss=1.635, ppl=3.11, wps=16854, ups=5, wpb=3478.930, bsz=138.286, num_updates=44910, lr=0.00014922, gnorm=0.801, clip=0.000, oom=0.000, wall=4978, train_wall=16853
# | epoch 040:    900 / 1131 loss=3.162, nll_loss=1.640, ppl=3.12, wps=16883, ups=5, wpb=3476.736, bsz=138.982, num_updates=45010, lr=0.000149055, gnorm=0.802, clip=0.000, oom=0.000, wall=4999, train_wall=16872
# | epoch 040:   1000 / 1131 loss=3.166, nll_loss=1.644, ppl=3.13, wps=16908, ups=5, wpb=3479.652, bsz=139.388, num_updates=45110, lr=0.000148889, gnorm=0.802, clip=0.000, oom=0.000, wall=5019, train_wall=16892
# | epoch 040:   1100 / 1131 loss=3.168, nll_loss=1.646, ppl=3.13, wps=16951, ups=5, wpb=3491.003, bsz=141.856, num_updates=45210, lr=0.000148725, gnorm=0.799, clip=0.000, oom=0.000, wall=5040, train_wall=16913
# | epoch 040 | loss 3.168 | nll_loss 1.647 | ppl 3.13 | wps 16952 | ups 5 | wpb 3491.701 | bsz 141.679 | num_updates 45240 | lr 0.000148675 | gnorm 0.799 | clip 0.000 | oom 0.000 | wall 5046 | train_wall 16919
# | epoch 040 | valid on 'valid' subset | loss 3.915 | nll_loss 2.349 | ppl 5.09 | num_updates 45240 | best_loss 3.88953
# | saved checkpoint /content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint40.pt (epoch 40 @ 45240 updates) (writing took 4.169727325439453 seconds)
# | epoch 041:    100 / 1131 loss=3.114, nll_loss=1.584, ppl=3.00, wps=16755, ups=5, wpb=3551.337, bsz=148.356, num_updates=45341, lr=0.00014851, gnorm=0.771, clip=0.000, oom=0.000, wall=5075, train_wall=16940
# | epoch 041:    200 / 1131 loss=3.116, nll_loss=1.587, ppl=3.00, wps=16882, ups=5, wpb=3516.055, bsz=146.070, num_updates=45441, lr=0.000148346, gnorm=0.780, clip=0.000, oom=0.000, wall=5096, train_wall=16960
# | epoch 041:    300 / 1131 loss=3.116, nll_loss=1.587, ppl=3.00, wps=16910, ups=5, wpb=3501.797, bsz=147.402, num_updates=45541, lr=0.000148183, gnorm=0.783, clip=0.000, oom=0.000, wall=5116, train_wall=16980
# | epoch 041:    400 / 1131 loss=3.125, nll_loss=1.597, ppl=3.03, wps=17013, ups=5, wpb=3513.100, bsz=146.015, num_updates=45641, lr=0.000148021, gnorm=0.784, clip=0.000, oom=0.000, wall=5137, train_wall=17000
# | epoch 041:    500 / 1131 loss=3.133, nll_loss=1.606, ppl=3.05, wps=17079, ups=5, wpb=3520.152, bsz=144.094, num_updates=45741, lr=0.000147859, gnorm=0.786, clip=0.000, oom=0.000, wall=5157, train_wall=17020
# | epoch 041:    600 / 1131 loss=3.138, nll_loss=1.613, ppl=3.06, wps=17061, ups=5, wpb=3517.977, bsz=144.930, num_updates=45841, lr=0.000147697, gnorm=0.790, clip=0.000, oom=0.000, wall=5178, train_wall=17040
# | epoch 041:    700 / 1131 loss=3.142, nll_loss=1.617, ppl=3.07, wps=17026, ups=5, wpb=3503.223, bsz=144.341, num_updates=45941, lr=0.000147537, gnorm=0.793, clip=0.000, oom=0.000, wall=5198, train_wall=17060
# | epoch 041:    800 / 1131 loss=3.142, nll_loss=1.617, ppl=3.07, wps=17034, ups=5, wpb=3496.377, bsz=145.517, num_updates=46041, lr=0.000147376, gnorm=0.796, clip=0.000, oom=0.000, wall=5218, train_wall=17080
# | epoch 041:    900 / 1131 loss=3.148, nll_loss=1.624, ppl=3.08, wps=17047, ups=5, wpb=3493.572, bsz=143.679, num_updates=46141, lr=0.000147217, gnorm=0.799, clip=0.000, oom=0.000, wall=5239, train_wall=17099
# | epoch 041:   1000 / 1131 loss=3.153, nll_loss=1.629, ppl=3.09, wps=17046, ups=5, wpb=3489.206, bsz=142.009, num_updates=46241, lr=0.000147057, gnorm=0.801, clip=0.000, oom=0.000, wall=5259, train_wall=17119
# | epoch 041:   1100 / 1131 loss=3.157, nll_loss=1.634, ppl=3.10, wps=17069, ups=5, wpb=3491.368, bsz=142.052, num_updates=46341, lr=0.000146898, gnorm=0.801, clip=0.000, oom=0.000, wall=5279, train_wall=17139
# | epoch 041 | loss 3.159 | nll_loss 1.636 | ppl 3.11 | wps 17075 | ups 5 | wpb 3491.701 | bsz 141.679 | num_updates 46371 | lr 0.000146851 | gnorm 0.802 | clip 0.000 | oom 0.000 | wall 5285 | train_wall 17145
# | epoch 041 | valid on 'valid' subset | loss 3.911 | nll_loss 2.344 | ppl 5.08 | num_updates 46371 | best_loss 3.88953
# | saved checkpoint /content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint41.pt (epoch 41 @ 46371 updates) (writing took 4.156376361846924 seconds)
# | epoch 042:    100 / 1131 loss=3.117, nll_loss=1.587, ppl=3.00, wps=16494, ups=5, wpb=3474.871, bsz=136.634, num_updates=46472, lr=0.000146691, gnorm=0.791, clip=0.000, oom=0.000, wall=5314, train_wall=17166
# | epoch 042:    200 / 1131 loss=3.120, nll_loss=1.590, ppl=3.01, wps=16803, ups=5, wpb=3466.796, bsz=135.363, num_updates=46572, lr=0.000146534, gnorm=0.797, clip=0.000, oom=0.000, wall=5335, train_wall=17185
# | epoch 042:    300 / 1131 loss=3.130, nll_loss=1.602, ppl=3.03, wps=16901, ups=5, wpb=3454.854, bsz=136.133, num_updates=46672, lr=0.000146377, gnorm=0.803, clip=0.000, oom=0.000, wall=5355, train_wall=17205
# | epoch 042:    400 / 1131 loss=3.133, nll_loss=1.605, ppl=3.04, wps=16933, ups=5, wpb=3454.192, bsz=133.845, num_updates=46772, lr=0.00014622, gnorm=0.807, clip=0.000, oom=0.000, wall=5375, train_wall=17225
# | epoch 042:    500 / 1131 loss=3.136, nll_loss=1.609, ppl=3.05, wps=16996, ups=5, wpb=3468.475, bsz=134.180, num_updates=46872, lr=0.000146064, gnorm=0.807, clip=0.000, oom=0.000, wall=5395, train_wall=17245
# | epoch 042:    600 / 1131 loss=3.140, nll_loss=1.613, ppl=3.06, wps=17032, ups=5, wpb=3472.639, bsz=133.617, num_updates=46972, lr=0.000145908, gnorm=0.809, clip=0.000, oom=0.000, wall=5416, train_wall=17265
# | epoch 042:    700 / 1131 loss=3.142, nll_loss=1.615, ppl=3.06, wps=17027, ups=5, wpb=3471.826, bsz=136.331, num_updates=47072, lr=0.000145753, gnorm=0.809, clip=0.000, oom=0.000, wall=5436, train_wall=17285
# | epoch 042:    800 / 1131 loss=3.142, nll_loss=1.616, ppl=3.07, wps=17093, ups=5, wpb=3488.954, bsz=137.788, num_updates=47172, lr=0.000145599, gnorm=0.805, clip=0.000, oom=0.000, wall=5457, train_wall=17305
# | epoch 042:    900 / 1131 loss=3.144, nll_loss=1.618, ppl=3.07, wps=17072, ups=5, wpb=3483.915, bsz=139.747, num_updates=47272, lr=0.000145445, gnorm=0.806, clip=0.000, oom=0.000, wall=5477, train_wall=17325
# | epoch 042:   1000 / 1131 loss=3.145, nll_loss=1.620, ppl=3.07, wps=17083, ups=5, wpb=3483.971, bsz=140.899, num_updates=47372, lr=0.000145291, gnorm=0.806, clip=0.000, oom=0.000, wall=5497, train_wall=17345
# | epoch 042:   1100 / 1131 loss=3.148, nll_loss=1.623, ppl=3.08, wps=17093, ups=5, wpb=3489.008, bsz=141.238, num_updates=47472, lr=0.000145138, gnorm=0.805, clip=0.000, oom=0.000, wall=5518, train_wall=17365
# | epoch 042 | loss 3.148 | nll_loss 1.623 | ppl 3.08 | wps 17093 | ups 5 | wpb 3491.701 | bsz 141.679 | num_updates 47502 | lr 0.000145092 | gnorm 0.805 | clip 0.000 | oom 0.000 | wall 5524 | train_wall 17371
# | epoch 042 | valid on 'valid' subset | loss 3.925 | nll_loss 2.358 | ppl 5.13 | num_updates 47502 | best_loss 3.88953
# | saved checkpoint /content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint42.pt (epoch 42 @ 47502 updates) (writing took 4.101444721221924 seconds)
# | epoch 043:    100 / 1131 loss=3.122, nll_loss=1.593, ppl=3.02, wps=16723, ups=5, wpb=3535.822, bsz=139.881, num_updates=47603, lr=0.000144938, gnorm=0.790, clip=0.000, oom=0.000, wall=5553, train_wall=17392
# | epoch 043:    200 / 1131 loss=3.108, nll_loss=1.578, ppl=2.99, wps=16821, ups=5, wpb=3490.214, bsz=153.075, num_updates=47703, lr=0.000144786, gnorm=0.794, clip=0.000, oom=0.000, wall=5574, train_wall=17412
# | epoch 043:    300 / 1131 loss=3.116, nll_loss=1.586, ppl=3.00, wps=16891, ups=5, wpb=3472.080, bsz=146.179, num_updates=47803, lr=0.000144635, gnorm=0.803, clip=0.000, oom=0.000, wall=5594, train_wall=17431
# | epoch 043:    400 / 1131 loss=3.119, nll_loss=1.589, ppl=3.01, wps=16955, ups=5, wpb=3480.132, bsz=140.948, num_updates=47903, lr=0.000144484, gnorm=0.805, clip=0.000, oom=0.000, wall=5614, train_wall=17451
# | epoch 043:    500 / 1131 loss=3.122, nll_loss=1.593, ppl=3.02, wps=16988, ups=5, wpb=3486.631, bsz=139.289, num_updates=48003, lr=0.000144333, gnorm=0.805, clip=0.000, oom=0.000, wall=5635, train_wall=17471
# | epoch 043:    600 / 1131 loss=3.128, nll_loss=1.599, ppl=3.03, wps=17006, ups=5, wpb=3485.351, bsz=139.754, num_updates=48103, lr=0.000144183, gnorm=0.808, clip=0.000, oom=0.000, wall=5655, train_wall=17491
# | epoch 043:    700 / 1131 loss=3.130, nll_loss=1.602, ppl=3.04, wps=17002, ups=5, wpb=3479.439, bsz=140.257, num_updates=48203, lr=0.000144033, gnorm=0.809, clip=0.000, oom=0.000, wall=5675, train_wall=17511
# | epoch 043:    800 / 1131 loss=3.133, nll_loss=1.606, ppl=3.04, wps=17043, ups=5, wpb=3483.483, bsz=141.831, num_updates=48303, lr=0.000143884, gnorm=0.809, clip=0.000, oom=0.000, wall=5696, train_wall=17531
# | epoch 043:    900 / 1131 loss=3.136, nll_loss=1.609, ppl=3.05, wps=17042, ups=5, wpb=3483.055, bsz=141.042, num_updates=48403, lr=0.000143735, gnorm=0.810, clip=0.000, oom=0.000, wall=5716, train_wall=17551
# | epoch 043:   1000 / 1131 loss=3.138, nll_loss=1.612, ppl=3.06, wps=17075, ups=5, wpb=3487.145, bsz=140.970, num_updates=48503, lr=0.000143587, gnorm=0.810, clip=0.000, oom=0.000, wall=5736, train_wall=17571
# | epoch 043:   1100 / 1131 loss=3.139, nll_loss=1.613, ppl=3.06, wps=17107, ups=5, wpb=3493.742, bsz=141.848, num_updates=48603, lr=0.000143439, gnorm=0.809, clip=0.000, oom=0.000, wall=5757, train_wall=17591
# | epoch 043 | loss 3.139 | nll_loss 1.613 | ppl 3.06 | wps 17096 | ups 5 | wpb 3491.701 | bsz 141.679 | num_updates 48633 | lr 0.000143395 | gnorm 0.809 | clip 0.000 | oom 0.000 | wall 5763 | train_wall 17597
# | epoch 043 | valid on 'valid' subset | loss 3.924 | nll_loss 2.354 | ppl 5.11 | num_updates 48633 | best_loss 3.88953
# | saved checkpoint /content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint43.pt (epoch 43 @ 48633 updates) (writing took 4.5661585330963135 seconds)
# | epoch 044:    100 / 1131 loss=3.088, nll_loss=1.553, ppl=2.93, wps=16643, ups=5, wpb=3522.752, bsz=134.495, num_updates=48734, lr=0.000143246, gnorm=0.795, clip=0.000, oom=0.000, wall=5792, train_wall=17618
# | epoch 044:    200 / 1131 loss=3.092, nll_loss=1.557, ppl=2.94, wps=16770, ups=5, wpb=3462.562, bsz=136.199, num_updates=48834, lr=0.0001431, gnorm=0.807, clip=0.000, oom=0.000, wall=5813, train_wall=17637
# | epoch 044:    300 / 1131 loss=3.094, nll_loss=1.560, ppl=2.95, wps=16791, ups=5, wpb=3452.455, bsz=139.000, num_updates=48934, lr=0.000142953, gnorm=0.809, clip=0.000, oom=0.000, wall=5833, train_wall=17657
# | epoch 044:    400 / 1131 loss=3.094, nll_loss=1.562, ppl=2.95, wps=16956, ups=5, wpb=3479.928, bsz=149.663, num_updates=49034, lr=0.000142808, gnorm=0.803, clip=0.000, oom=0.000, wall=5853, train_wall=17677
# | epoch 044:    500 / 1131 loss=3.106, nll_loss=1.574, ppl=2.98, wps=17023, ups=5, wpb=3496.986, bsz=146.329, num_updates=49134, lr=0.000142662, gnorm=0.803, clip=0.000, oom=0.000, wall=5874, train_wall=17697
# | epoch 044:    600 / 1131 loss=3.110, nll_loss=1.579, ppl=2.99, wps=17073, ups=5, wpb=3507.433, bsz=145.569, num_updates=49234, lr=0.000142517, gnorm=0.803, clip=0.000, oom=0.000, wall=5895, train_wall=17718
# | epoch 044:    700 / 1131 loss=3.116, nll_loss=1.587, ppl=3.00, wps=17090, ups=5, wpb=3507.509, bsz=145.437, num_updates=49334, lr=0.000142373, gnorm=0.804, clip=0.000, oom=0.000, wall=5915, train_wall=17738
# | epoch 044:    800 / 1131 loss=3.120, nll_loss=1.591, ppl=3.01, wps=17070, ups=5, wpb=3501.464, bsz=143.589, num_updates=49434, lr=0.000142229, gnorm=0.806, clip=0.000, oom=0.000, wall=5935, train_wall=17757
# | epoch 044:    900 / 1131 loss=3.119, nll_loss=1.590, ppl=3.01, wps=17045, ups=5, wpb=3491.553, bsz=144.123, num_updates=49534, lr=0.000142085, gnorm=0.808, clip=0.000, oom=0.000, wall=5956, train_wall=17777
# | epoch 044:   1000 / 1131 loss=3.123, nll_loss=1.595, ppl=3.02, wps=17023, ups=5, wpb=3485.258, bsz=142.600, num_updates=49634, lr=0.000141942, gnorm=0.811, clip=0.000, oom=0.000, wall=5976, train_wall=17797
# | epoch 044:   1100 / 1131 loss=3.128, nll_loss=1.600, ppl=3.03, wps=17059, ups=5, wpb=3491.745, bsz=141.340, num_updates=49734, lr=0.000141799, gnorm=0.812, clip=0.000, oom=0.000, wall=5996, train_wall=17817
# | epoch 044 | loss 3.129 | nll_loss 1.602 | ppl 3.03 | wps 17064 | ups 5 | wpb 3491.701 | bsz 141.679 | num_updates 49764 | lr 0.000141756 | gnorm 0.812 | clip 0.000 | oom 0.000 | wall 6003 | train_wall 17823
# | epoch 044 | valid on 'valid' subset | loss 3.912 | nll_loss 2.346 | ppl 5.09 | num_updates 49764 | best_loss 3.88953
# | saved checkpoint /content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint44.pt (epoch 44 @ 49764 updates) (writing took 4.349078416824341 seconds)
# | epoch 045:    100 / 1131 loss=3.084, nll_loss=1.550, ppl=2.93, wps=16717, ups=5, wpb=3536.970, bsz=143.129, num_updates=49865, lr=0.000141613, gnorm=0.789, clip=0.000, oom=0.000, wall=6032, train_wall=17844
# | epoch 045:    200 / 1131 loss=3.077, nll_loss=1.542, ppl=2.91, wps=16983, ups=5, wpb=3538.562, bsz=150.965, num_updates=49965, lr=0.000141471, gnorm=0.792, clip=0.000, oom=0.000, wall=6052, train_wall=17864
# | epoch 045 | loss 3.078 | nll_loss 1.543 | ppl 2.91 | wps 17009 | ups 5 | wpb 3526.945 | bsz 148.576 | num_updates 50000 | lr 0.000141421 | gnorm 0.794 | clip 0.000 | oom 0.000 | wall 6060 | train_wall 17871
# | epoch 045 | valid on 'valid' subset | loss 3.929 | nll_loss 2.359 | ppl 5.13 | num_updates 50000 | best_loss 3.88953
# | saved checkpoint /content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint_last.pt (epoch 45 @ 50000 updates) (writing took 1.9591238498687744 seconds)
# | done training in 6063.6 seconds

# %%
# !python scripts/average_checkpoints.py --inputs "{SAVE}" \
    --num-epoch-checkpoints 10 --output "{SAVE}/checkpoint_last10_avg.pt"

# Evaluation
# !CUDA_VISIBLE_DEVICES=0 fairseq-generate data-bin/iwslt14.tokenized.de-en --path "{SAVE}/checkpoint_last10_avg.pt" --batch-size 128 --beam 4 --remove-bpe --lenpen 1 --gen-subset test --quiet
# Out:
# Namespace(checkpoint_upper_bound=None, inputs=['/content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt'], num_epoch_checkpoints=10, num_update_checkpoints=None, output='/content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint_last10_avg.pt')
# averaging checkpoints:  ['/content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint44.pt', '/content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint43.pt', '/content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint42.pt', '/content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint41.pt', '/content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint40.pt', '/content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint39.pt', '/content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint38.pt', '/content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint37.pt', '/content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint36.pt', '/content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint35.pt']
# Finished writing averaged checkpoint to /content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint_last10_avg.pt.
# Namespace(beam=4, bpe=None, cpu=False, criterion='cross_entropy', data='data-bin/iwslt14.tokenized.de-en', dataset_impl=None, decoding_format=None, diverse_beam_groups=-1, diverse_beam_strength=0.5, empty_cache_freq=0, force_anneal=None, fp16=False, fp16_init_scale=128, fp16_scale_tolerance=0.0, fp16_scale_window=None, gen_subset='test', iter_decode_eos_penalty=0.0, iter_decode_force_max_iter=False, iter_decode_max_iter=10, lazy_load=False, left_pad_source='True', left_pad_target='False', lenpen=1.0, load_alignments=False, log_format=None, log_interval=1000, lr_scheduler='fixed', lr_shrink=0.1, match_source_len=False, max_len_a=0, max_len_b=200, max_sentences=128, max_source_positions=1024, max_target_positions=1024, max_tokens=None, memory_efficient_fp16=False, min_len=1, min_loss_scale=0.0001, model_overrides='{}', momentum=0.99, nbest=1, no_beamable_mm=False, no_early_stop=False, no_progress_bar=False, no_repeat_ngram_size=0, num_shards=1, num_workers=1, optimizer='nag', path='/content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint_last10_avg.pt', prefix_size=0, print_alignment=False, print_step=False, quiet=True, raw_text=False, remove_bpe='@@ ', replace_unk=None, required_batch_size_multiple=8, results_path=None, sacrebleu=False, sampling=False, sampling_topk=-1, sampling_topp=-1.0, score_reference=False, seed=1, shard_id=0, skip_invalid_size_inputs_valid_test=False, source_lang=None, target_lang=None, task='translation', tbmf_wrapper=False, temperature=1.0, tensorboard_logdir='', threshold_loss_scale=None, tokenizer=None, unkpen=0, unnormalized=False, upsample_primary=1, user_dir=None, warmup_updates=0, weight_decay=0.0)
# | [de] dictionary: 8848 types
# | [en] dictionary: 6632 types
# | loaded 6750 examples from: data-bin/iwslt14.tokenized.de-en/test.de-en.de
# | loaded 6750 examples from: data-bin/iwslt14.tokenized.de-en/test.de-en.en
# | data-bin/iwslt14.tokenized.de-en test de-en 6750 examples
# | loading model(s) from /content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint_last10_avg.pt
# | Translated 6750 sentences (148008 tokens) in 27.2s (248.05 sentences/s, 5438.95 tokens/s)
# | Generate test with beam=4: BLEU4 = 34.60, 69.0/43.4/29.3/20.1 (BP=0.949, ratio=0.951, syslen=124680, reflen=131161)

# %%
# Evaluation
# !CUDA_VISIBLE_DEVICES=0 fairseq-generate data-bin/iwslt14.tokenized.de-en --path "{SAVE}/checkpoint_best.pt" --batch-size 128 --beam 4 --remove-bpe --lenpen 1 --gen-subset test --quiet
# Out:
# Namespace(beam=4, bpe=None, cpu=False, criterion='cross_entropy', data='data-bin/iwslt14.tokenized.de-en', dataset_impl=None, decoding_format=None, diverse_beam_groups=-1, diverse_beam_strength=0.5, empty_cache_freq=0, force_anneal=None, fp16=False, fp16_init_scale=128, fp16_scale_tolerance=0.0, fp16_scale_window=None, gen_subset='test', iter_decode_eos_penalty=0.0, iter_decode_force_max_iter=False, iter_decode_max_iter=10, lazy_load=False, left_pad_source='True', left_pad_target='False', lenpen=1.0, load_alignments=False, log_format=None, log_interval=1000, lr_scheduler='fixed', lr_shrink=0.1, match_source_len=False, max_len_a=0, max_len_b=200, max_sentences=128, max_source_positions=1024, max_target_positions=1024, max_tokens=None, memory_efficient_fp16=False, min_len=1, min_loss_scale=0.0001, model_overrides='{}', momentum=0.99, nbest=1, no_beamable_mm=False, no_early_stop=False, no_progress_bar=False, no_repeat_ngram_size=0, num_shards=1, num_workers=1, optimizer='nag', path='/content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint_best.pt', prefix_size=0, print_alignment=False, print_step=False, quiet=True, raw_text=False, remove_bpe='@@ ', replace_unk=None, required_batch_size_multiple=8, results_path=None, sacrebleu=False, sampling=False, sampling_topk=-1, sampling_topp=-1.0, score_reference=False, seed=1, shard_id=0, skip_invalid_size_inputs_valid_test=False, source_lang=None, target_lang=None, task='translation', tbmf_wrapper=False, temperature=1.0, tensorboard_logdir='', threshold_loss_scale=None, tokenizer=None, unkpen=0, unnormalized=False, upsample_primary=1, user_dir=None, warmup_updates=0, weight_decay=0.0)
# | [de] dictionary: 8848 types
# | [en] dictionary: 6632 types
# | loaded 6750 examples from: data-bin/iwslt14.tokenized.de-en/test.de-en.de
# | loaded 6750 examples from: data-bin/iwslt14.tokenized.de-en/test.de-en.en
# | data-bin/iwslt14.tokenized.de-en test de-en 6750 examples
# | loading model(s) from /content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint_best.pt
# | Translated 6750 sentences (148886 tokens) in 24.5s (275.84 sentences/s, 6084.15 tokens/s)
# | Generate test with beam=4: BLEU4 = 34.23, 68.5/42.7/28.6/19.5 (BP=0.958, ratio=0.959, syslen=125744, reflen=131161)
