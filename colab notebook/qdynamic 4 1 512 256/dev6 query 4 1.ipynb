# %%
from google.colab import drive
drive.mount('/content/gdrive')

# To install fairseq from source and develop locally:
# !git clone https://github.com/choyi0521/fairseq
# %cd /content/fairseq
# !pip install --editable .
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive
# Cloning into 'fairseq'...
# remote: Enumerating objects: 12181, done.
# remote: Total 12181 (delta 0), reused 0 (delta 0), pack-reused 12181
# Receiving objects: 100% (12181/12181), 5.70 MiB | 7.21 MiB/s, done.
# Resolving deltas: 100% (8975/8975), done.
# /content/fairseq
# Obtaining file:///content/fairseq
# Requirement already satisfied: cffi in /usr/local/lib/python3.6/dist-packages (from fairseq==0.8.0) (1.13.2)
# Requirement already satisfied: cython in /usr/local/lib/python3.6/dist-packages (from fairseq==0.8.0) (0.29.14)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from fairseq==0.8.0) (1.17.4)
# Collecting regex
#   Downloading https://files.pythonhosted.org/packages/e3/8e/cbf2295643d7265e7883326fb4654e643bfc93b3a8a8274d8010a39d8804/regex-2019.11.1-cp36-cp36m-manylinux1_x86_64.whl (643kB)
#      |████████████████████████████████| 645kB 6.8MB/s
# Collecting sacrebleu
#   Downloading https://files.pythonhosted.org/packages/45/31/1a135b964c169984b27fb2f7a50280fa7f8e6d9d404d8a9e596180487fd1/sacrebleu-1.4.3-py3-none-any.whl
# Requirement already satisfied: torch in /usr/local/lib/python3.6/dist-packages (from fairseq==0.8.0) (1.3.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from fairseq==0.8.0) (4.28.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.6/dist-packages (from cffi->fairseq==0.8.0) (2.19)
# Requirement already satisfied: typing in /usr/local/lib/python3.6/dist-packages (from sacrebleu->fairseq==0.8.0) (3.6.6)
# Collecting portalocker
#   Downloading https://files.pythonhosted.org/packages/91/db/7bc703c0760df726839e0699b7f78a4d8217fdc9c7fcb1b51b39c5a22a4e/portalocker-1.5.2-py2.py3-none-any.whl
# Installing collected packages: regex, portalocker, sacrebleu, fairseq
#   Running setup.py develop for fairseq
# Successfully installed fairseq portalocker-1.5.2 regex-2019.11.1 sacrebleu-1.4.3

# %%
# !git checkout dev6
# !git pull origin dev6
# Out:
# Branch 'dev6' set up to track remote branch 'dev6' from 'origin'.
# Switched to a new branch 'dev6'
# From https://github.com/choyi0521/fairseq
#  * branch            dev6       -> FETCH_HEAD
# Already up to date.

# %%
# Download and prepare the data
# %cd /content/fairseq
# %cd examples/translation/
# !bash prepare-iwslt14.sh
# %cd ../..

# Preprocess/binarize the data
TEXT="examples/translation/iwslt14.tokenized.de-en"
# !fairseq-preprocess --source-lang de --target-lang en \
    --trainpref $TEXT/train --validpref $TEXT/valid --testpref $TEXT/test \
    --destdir data-bin/iwslt14.tokenized.de-en \
    --workers 20
# Out:
# /content/fairseq
# /content/fairseq/examples/translation
# Cloning Moses github repository (for tokenization scripts)...
# Cloning into 'mosesdecoder'...
# remote: Enumerating objects: 169, done.
# remote: Counting objects: 100% (169/169), done.
# remote: Compressing objects: 100% (89/89), done.
# remote: Total 147464 (delta 104), reused 118 (delta 74), pack-reused 147295
# Receiving objects: 100% (147464/147464), 129.73 MiB | 19.14 MiB/s, done.
# Resolving deltas: 100% (113938/113938), done.
# Cloning Subword NMT repository (for BPE pre-processing)...
# Cloning into 'subword-nmt'...
# remote: Enumerating objects: 29, done.
# remote: Counting objects: 100% (29/29), done.
# remote: Compressing objects: 100% (22/22), done.
# remote: Total 538 (delta 10), reused 21 (delta 7), pack-reused 509
# Receiving objects: 100% (538/538), 226.98 KiB | 782.00 KiB/s, done.
# Resolving deltas: 100% (316/316), done.
# Downloading data from https://wit3.fbk.eu/archive/2014-01/texts/de/en/de-en.tgz...
# --2019-12-06 11:05:04--  https://wit3.fbk.eu/archive/2014-01/texts/de/en/de-en.tgz
# Resolving wit3.fbk.eu (wit3.fbk.eu)... 217.77.80.8
# Connecting to wit3.fbk.eu (wit3.fbk.eu)|217.77.80.8|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 19982877 (19M) [application/x-gzip]
# Saving to: ‘de-en.tgz’
#
# de-en.tgz           100%[===================>]  19.06M  36.8MB/s    in 0.5s
#
# 2019-12-06 11:05:04 (36.8 MB/s) - ‘de-en.tgz’ saved [19982877/19982877]
#
# Data successfully downloaded.
# de-en/
# de-en/IWSLT14.TED.dev2010.de-en.de.xml
# de-en/IWSLT14.TED.dev2010.de-en.en.xml
# de-en/IWSLT14.TED.tst2010.de-en.de.xml
# de-en/IWSLT14.TED.tst2010.de-en.en.xml
# de-en/IWSLT14.TED.tst2011.de-en.de.xml
# de-en/IWSLT14.TED.tst2011.de-en.en.xml
# de-en/IWSLT14.TED.tst2012.de-en.de.xml
# de-en/IWSLT14.TED.tst2012.de-en.en.xml
# de-en/IWSLT14.TEDX.dev2012.de-en.de.xml
# de-en/IWSLT14.TEDX.dev2012.de-en.en.xml
# de-en/README
# de-en/train.en
# de-en/train.tags.de-en.de
# de-en/train.tags.de-en.en
# pre-processing train data...
# Tokenizer Version 1.1
# Language: de
# Number of threads: 8
#
# Tokenizer Version 1.1
# Language: en
# Number of threads: 8
#
# clean-corpus.perl: processing iwslt14.tokenized.de-en/tmp/train.tags.de-en.tok.de & .en to iwslt14.tokenized.de-en/tmp/train.tags.de-en.clean, cutoff 1-175, ratio 1.5
# ..........(100000).......
# Input sentences: 174443  Output sentences:  167522
# pre-processing valid/test data...
# orig/de-en/IWSLT14.TED.dev2010.de-en.de.xml iwslt14.tokenized.de-en/tmp/IWSLT14.TED.dev2010.de-en.de
# Tokenizer Version 1.1
# Language: de
# Number of threads: 8
#
# orig/de-en/IWSLT14.TED.tst2010.de-en.de.xml iwslt14.tokenized.de-en/tmp/IWSLT14.TED.tst2010.de-en.de
# Tokenizer Version 1.1
# Language: de
# Number of threads: 8
#
# orig/de-en/IWSLT14.TED.tst2011.de-en.de.xml iwslt14.tokenized.de-en/tmp/IWSLT14.TED.tst2011.de-en.de
# Tokenizer Version 1.1
# Language: de
# Number of threads: 8
#
# orig/de-en/IWSLT14.TED.tst2012.de-en.de.xml iwslt14.tokenized.de-en/tmp/IWSLT14.TED.tst2012.de-en.de
# Tokenizer Version 1.1
# Language: de
# Number of threads: 8
#
# orig/de-en/IWSLT14.TEDX.dev2012.de-en.de.xml iwslt14.tokenized.de-en/tmp/IWSLT14.TEDX.dev2012.de-en.de
# Tokenizer Version 1.1
# Language: de
# Number of threads: 8
#
# orig/de-en/IWSLT14.TED.dev2010.de-en.en.xml iwslt14.tokenized.de-en/tmp/IWSLT14.TED.dev2010.de-en.en
# Tokenizer Version 1.1
# Language: en
# Number of threads: 8
#
# orig/de-en/IWSLT14.TED.tst2010.de-en.en.xml iwslt14.tokenized.de-en/tmp/IWSLT14.TED.tst2010.de-en.en
# Tokenizer Version 1.1
# Language: en
# Number of threads: 8
#
# orig/de-en/IWSLT14.TED.tst2011.de-en.en.xml iwslt14.tokenized.de-en/tmp/IWSLT14.TED.tst2011.de-en.en
# Tokenizer Version 1.1
# Language: en
# Number of threads: 8
#
# orig/de-en/IWSLT14.TED.tst2012.de-en.en.xml iwslt14.tokenized.de-en/tmp/IWSLT14.TED.tst2012.de-en.en
# Tokenizer Version 1.1
# Language: en
# Number of threads: 8
#
# orig/de-en/IWSLT14.TEDX.dev2012.de-en.en.xml iwslt14.tokenized.de-en/tmp/IWSLT14.TEDX.dev2012.de-en.en
# Tokenizer Version 1.1
# Language: en
# Number of threads: 8
#
# creating train, valid, test...
# learn_bpe.py on iwslt14.tokenized.de-en/tmp/train.en-de...
# subword-nmt/learn_bpe.py:267: DeprecationWarning: this script's location has moved to /content/fairseq/examples/translation/subword-nmt/subword_nmt. This symbolic link will be removed in a future version. Please point to the new location, or install the package and use the command 'subword-nmt'
#   DeprecationWarning
# apply_bpe.py to train.de...
# subword-nmt/apply_bpe.py:328: DeprecationWarning: this script's location has moved to /content/fairseq/examples/translation/subword-nmt/subword_nmt. This symbolic link will be removed in a future version. Please point to the new location, or install the package and use the command 'subword-nmt'
#   DeprecationWarning
# subword-nmt/apply_bpe.py:345: ResourceWarning: unclosed file <_io.TextIOWrapper name='iwslt14.tokenized.de-en/code' mode='r' encoding='UTF-8'>
#   args.codes = codecs.open(args.codes.name, encoding='utf-8')
# apply_bpe.py to valid.de...
# subword-nmt/apply_bpe.py:328: DeprecationWarning: this script's location has moved to /content/fairseq/examples/translation/subword-nmt/subword_nmt. This symbolic link will be removed in a future version. Please point to the new location, or install the package and use the command 'subword-nmt'
#   DeprecationWarning
# subword-nmt/apply_bpe.py:345: ResourceWarning: unclosed file <_io.TextIOWrapper name='iwslt14.tokenized.de-en/code' mode='r' encoding='UTF-8'>
#   args.codes = codecs.open(args.codes.name, encoding='utf-8')
# apply_bpe.py to test.de...
# subword-nmt/apply_bpe.py:328: DeprecationWarning: this script's location has moved to /content/fairseq/examples/translation/subword-nmt/subword_nmt. This symbolic link will be removed in a future version. Please point to the new location, or install the package and use the command 'subword-nmt'
#   DeprecationWarning
# subword-nmt/apply_bpe.py:345: ResourceWarning: unclosed file <_io.TextIOWrapper name='iwslt14.tokenized.de-en/code' mode='r' encoding='UTF-8'>
#   args.codes = codecs.open(args.codes.name, encoding='utf-8')
# apply_bpe.py to train.en...
# subword-nmt/apply_bpe.py:328: DeprecationWarning: this script's location has moved to /content/fairseq/examples/translation/subword-nmt/subword_nmt. This symbolic link will be removed in a future version. Please point to the new location, or install the package and use the command 'subword-nmt'
#   DeprecationWarning
# subword-nmt/apply_bpe.py:345: ResourceWarning: unclosed file <_io.TextIOWrapper name='iwslt14.tokenized.de-en/code' mode='r' encoding='UTF-8'>
#   args.codes = codecs.open(args.codes.name, encoding='utf-8')
# apply_bpe.py to valid.en...
# subword-nmt/apply_bpe.py:328: DeprecationWarning: this script's location has moved to /content/fairseq/examples/translation/subword-nmt/subword_nmt. This symbolic link will be removed in a future version. Please point to the new location, or install the package and use the command 'subword-nmt'
#   DeprecationWarning
# subword-nmt/apply_bpe.py:345: ResourceWarning: unclosed file <_io.TextIOWrapper name='iwslt14.tokenized.de-en/code' mode='r' encoding='UTF-8'>
#   args.codes = codecs.open(args.codes.name, encoding='utf-8')
# apply_bpe.py to test.en...
# subword-nmt/apply_bpe.py:328: DeprecationWarning: this script's location has moved to /content/fairseq/examples/translation/subword-nmt/subword_nmt. This symbolic link will be removed in a future version. Please point to the new location, or install the package and use the command 'subword-nmt'
#   DeprecationWarning
# subword-nmt/apply_bpe.py:345: ResourceWarning: unclosed file <_io.TextIOWrapper name='iwslt14.tokenized.de-en/code' mode='r' encoding='UTF-8'>
#   args.codes = codecs.open(args.codes.name, encoding='utf-8')
# /content/fairseq
# Namespace(align_suffix=None, alignfile=None, bpe=None, cpu=False, criterion='cross_entropy', dataset_impl='mmap', destdir='data-bin/iwslt14.tokenized.de-en', empty_cache_freq=0, fp16=False, fp16_init_scale=128, fp16_scale_tolerance=0.0, fp16_scale_window=None, joined_dictionary=False, log_format=None, log_interval=1000, lr_scheduler='fixed', memory_efficient_fp16=False, min_loss_scale=0.0001, no_progress_bar=False, nwordssrc=-1, nwordstgt=-1, only_source=False, optimizer='nag', padding_factor=8, seed=1, source_lang='de', srcdict=None, target_lang='en', task='translation', tbmf_wrapper=False, tensorboard_logdir='', testpref='examples/translation/iwslt14.tokenized.de-en/test', tgtdict=None, threshold_loss_scale=None, thresholdsrc=0, thresholdtgt=0, tokenizer=None, trainpref='examples/translation/iwslt14.tokenized.de-en/train', user_dir=None, validpref='examples/translation/iwslt14.tokenized.de-en/valid', workers=20)
# | [de] Dictionary: 8847 types
# | [de] examples/translation/iwslt14.tokenized.de-en/train.de: 160239 sents, 4035591 tokens, 0.0% replaced by <unk>
# | [de] Dictionary: 8847 types
# | [de] examples/translation/iwslt14.tokenized.de-en/valid.de: 7283 sents, 182592 tokens, 0.0192% replaced by <unk>
# | [de] Dictionary: 8847 types
# | [de] examples/translation/iwslt14.tokenized.de-en/test.de: 6750 sents, 161838 tokens, 0.0636% replaced by <unk>
# | [en] Dictionary: 6631 types
# | [en] examples/translation/iwslt14.tokenized.de-en/train.en: 160239 sents, 3949114 tokens, 0.0% replaced by <unk>
# | [en] Dictionary: 6631 types
# | [en] examples/translation/iwslt14.tokenized.de-en/valid.en: 7283 sents, 178622 tokens, 0.00448% replaced by <unk>
# | [en] Dictionary: 6631 types
# | [en] examples/translation/iwslt14.tokenized.de-en/test.en: 6750 sents, 156928 tokens, 0.00892% replaced by <unk>
# | Wrote preprocessed data to data-bin/iwslt14.tokenized.de-en

# %%
SAVE="/content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt"

# %%
# Training
# %cd /content/fairseq
# !mkdir -p "{SAVE}" 
# !CUDA_VISIBLE_DEVICES=0 $(which fairseq-train) data-bin/iwslt14.tokenized.de-en \
    --encoder-conv-type ddynamic --decoder-conv-type ddynamic \
    --clip-norm 0 --optimizer adam --lr 0.0005 \
    --source-lang de --target-lang en --max-tokens 4000 --no-progress-bar \
    --log-interval 100 --min-lr '1e-09' --weight-decay 0.0001 \
    --criterion label_smoothed_cross_entropy --label-smoothing 0.1 \
    --lr-scheduler inverse_sqrt \
    --ddp-backend=no_c10d \
    --max-update 80000 --warmup-updates 4000 --warmup-init-lr '1e-07' \
    --adam-betas '(0.9, 0.98)' \
    -a lightconv_iwslt_de_en --save-dir "{SAVE}" \
    --dropout 0.3 --attention-dropout 0.1 --weight-dropout 0.1 \
    --encoder-glu 0 --decoder-glu 0 \
    --encoder-gau 0 --decoder-gau 0 \
    --conv-mixed 0 \
    --encoder-conv-dim 512 --decoder-conv-dim 512 \
    --encoder-query-dim 256 --decoder-query-dim 256 \
    --encoder-attention-heads 4 --decoder-attention-heads 4 \
    --encoder-attention-query-heads 1 --decoder-attention-query-heads 1 \
    2>&1 | tee "{SAVE}/train2.log"
# Out:
# /content/fairseq
# Namespace(adam_betas='(0.9, 0.98)', adam_eps=1e-08, adaptive_softmax_cutoff=None, adaptive_softmax_dropout=0, arch='lightconv_iwslt_de_en', attention_dropout=0.1, best_checkpoint_metric='loss', bpe=None, bucket_cap_mb=25, clip_norm=0.0, conv_mixed=False, cpu=False, criterion='label_smoothed_cross_entropy', curriculum=0, data='data-bin/iwslt14.tokenized.de-en', dataset_impl=None, ddp_backend='no_c10d', decoder_attention_heads=4, decoder_attention_query_heads=1, decoder_conv_dim=512, decoder_conv_type='ddynamic', decoder_embed_dim=512, decoder_embed_path=None, decoder_ffn_embed_dim=1024, decoder_gau=False, decoder_glu=False, decoder_input_dim=512, decoder_kernel_size_list=[3, 7, 15, 31, 31, 31], decoder_layers=6, decoder_learned_pos=False, decoder_normalize_before=False, decoder_output_dim=512, decoder_query_dim=256, device_id=0, disable_validation=False, distributed_backend='nccl', distributed_init_method=None, distributed_no_spawn=False, distributed_port=-1, distributed_rank=0, distributed_world_size=1, dropout=0.3, empty_cache_freq=0, encoder_attention_heads=4, encoder_attention_query_heads=1, encoder_conv_dim=512, encoder_conv_type='ddynamic', encoder_embed_dim=512, encoder_embed_path=None, encoder_ffn_embed_dim=1024, encoder_gau=False, encoder_glu=False, encoder_kernel_size_list=[3, 7, 15, 31, 31, 31, 31], encoder_layers=7, encoder_learned_pos=False, encoder_normalize_before=False, encoder_query_dim=512, fast_stat_sync=False, find_unused_parameters=False, fix_batches_to_gpus=False, fixed_validation_seed=None, fp16=False, fp16_init_scale=128, fp16_scale_tolerance=0.0, fp16_scale_window=None, input_dropout=0.0, keep_interval_updates=-1, keep_last_epochs=-1, label_smoothing=0.1, lazy_load=False, left_pad_source='True', left_pad_target='False', load_alignments=False, log_format=None, log_interval=100, lr=[0.0005], lr_scheduler='inverse_sqrt', max_epoch=0, max_sentences=None, max_sentences_valid=None, max_source_positions=1024, max_target_positions=1024, max_tokens=4000, max_tokens_valid=4000, max_update=80000, maximize_best_checkpoint_metric=False, memory_efficient_fp16=False, min_loss_scale=0.0001, min_lr=1e-09, no_epoch_checkpoints=False, no_last_checkpoints=False, no_progress_bar=True, no_save=False, no_save_optimizer_state=False, no_token_positional_embeddings=False, num_workers=1, optimizer='adam', optimizer_overrides='{}', raw_text=False, relu_dropout=0.0, required_batch_size_multiple=8, reset_dataloader=False, reset_lr_scheduler=False, reset_meters=False, reset_optimizer=False, restore_file='checkpoint_last.pt', save_dir='/content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt', save_interval=1, save_interval_updates=0, seed=1, sentence_avg=False, share_all_embeddings=False, share_decoder_input_output_embed=False, skip_invalid_size_inputs_valid_test=False, source_lang='de', target_lang='en', task='translation', tbmf_wrapper=False, tensorboard_logdir='', threshold_loss_scale=None, tokenizer=None, train_subset='train', update_freq=[1], upsample_primary=1, use_bmuf=False, user_dir=None, valid_subset='valid', validate_interval=1, warmup_init_lr=1e-07, warmup_updates=4000, weight_decay=0.0001, weight_dropout=0.1, weight_softmax=True)
# | [de] dictionary: 8848 types
# | [en] dictionary: 6632 types
# | loaded 7283 examples from: data-bin/iwslt14.tokenized.de-en/valid.de-en.de
# | loaded 7283 examples from: data-bin/iwslt14.tokenized.de-en/valid.de-en.en
# | data-bin/iwslt14.tokenized.de-en valid de-en 7283 examples
# LightConvModel(
#   (encoder): LightConvEncoder(
#     (embed_tokens): Embedding(8848, 512, padding_idx=1)
#     (embed_positions): SinusoidalPositionalEmbedding()
#     (layers): ModuleList(
#       (0): LightConvEncoderLayer(
#         dropout=0.3, relu_dropout=0.0, input_dropout=0.0, normalize_before=False
#         (linear1): Linear(in_features=512, out_features=512, bias=True)
#         (linear1_query): Linear(in_features=512, out_features=512, bias=True)
#         (conv): DDynamicConv1dTBC(
#           512, kernel_size=3, padding_l=1, num_heads=4, num_proj_heads=1, conv_mixed=False, weight_softmax=True, conv_bias=False, renorm_padding=False, in_proj=False, weight_dropout=0.1
#           (weight_linear): Linear(in_features=512, out_features=12, bias=False)
#         )
#         (linear2): Linear(in_features=512, out_features=512, bias=True)
#         (fc1): Linear(in_features=512, out_features=1024, bias=True)
#         (fc2): Linear(in_features=1024, out_features=512, bias=True)
#         (layer_norms): ModuleList(
#           (0): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#       (1): LightConvEncoderLayer(
#         dropout=0.3, relu_dropout=0.0, input_dropout=0.0, normalize_before=False
#         (linear1): Linear(in_features=512, out_features=512, bias=True)
#         (linear1_query): Linear(in_features=512, out_features=512, bias=True)
#         (conv): DDynamicConv1dTBC(
#           512, kernel_size=7, padding_l=3, num_heads=4, num_proj_heads=1, conv_mixed=False, weight_softmax=True, conv_bias=False, renorm_padding=False, in_proj=False, weight_dropout=0.1
#           (weight_linear): Linear(in_features=512, out_features=28, bias=False)
#         )
#         (linear2): Linear(in_features=512, out_features=512, bias=True)
#         (fc1): Linear(in_features=512, out_features=1024, bias=True)
#         (fc2): Linear(in_features=1024, out_features=512, bias=True)
#         (layer_norms): ModuleList(
#           (0): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#       (2): LightConvEncoderLayer(
#         dropout=0.3, relu_dropout=0.0, input_dropout=0.0, normalize_before=False
#         (linear1): Linear(in_features=512, out_features=512, bias=True)
#         (linear1_query): Linear(in_features=512, out_features=512, bias=True)
#         (conv): DDynamicConv1dTBC(
#           512, kernel_size=15, padding_l=7, num_heads=4, num_proj_heads=1, conv_mixed=False, weight_softmax=True, conv_bias=False, renorm_padding=False, in_proj=False, weight_dropout=0.1
#           (weight_linear): Linear(in_features=512, out_features=60, bias=False)
#         )
#         (linear2): Linear(in_features=512, out_features=512, bias=True)
#         (fc1): Linear(in_features=512, out_features=1024, bias=True)
#         (fc2): Linear(in_features=1024, out_features=512, bias=True)
#         (layer_norms): ModuleList(
#           (0): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#       (3): LightConvEncoderLayer(
#         dropout=0.3, relu_dropout=0.0, input_dropout=0.0, normalize_before=False
#         (linear1): Linear(in_features=512, out_features=512, bias=True)
#         (linear1_query): Linear(in_features=512, out_features=512, bias=True)
#         (conv): DDynamicConv1dTBC(
#           512, kernel_size=31, padding_l=15, num_heads=4, num_proj_heads=1, conv_mixed=False, weight_softmax=True, conv_bias=False, renorm_padding=False, in_proj=False, weight_dropout=0.1
#           (weight_linear): Linear(in_features=512, out_features=124, bias=False)
#         )
#         (linear2): Linear(in_features=512, out_features=512, bias=True)
#         (fc1): Linear(in_features=512, out_features=1024, bias=True)
#         (fc2): Linear(in_features=1024, out_features=512, bias=True)
#         (layer_norms): ModuleList(
#           (0): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#       (4): LightConvEncoderLayer(
#         dropout=0.3, relu_dropout=0.0, input_dropout=0.0, normalize_before=False
#         (linear1): Linear(in_features=512, out_features=512, bias=True)
#         (linear1_query): Linear(in_features=512, out_features=512, bias=True)
#         (conv): DDynamicConv1dTBC(
#           512, kernel_size=31, padding_l=15, num_heads=4, num_proj_heads=1, conv_mixed=False, weight_softmax=True, conv_bias=False, renorm_padding=False, in_proj=False, weight_dropout=0.1
#           (weight_linear): Linear(in_features=512, out_features=124, bias=False)
#         )
#         (linear2): Linear(in_features=512, out_features=512, bias=True)
#         (fc1): Linear(in_features=512, out_features=1024, bias=True)
#         (fc2): Linear(in_features=1024, out_features=512, bias=True)
#         (layer_norms): ModuleList(
#           (0): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#       (5): LightConvEncoderLayer(
#         dropout=0.3, relu_dropout=0.0, input_dropout=0.0, normalize_before=False
#         (linear1): Linear(in_features=512, out_features=512, bias=True)
#         (linear1_query): Linear(in_features=512, out_features=512, bias=True)
#         (conv): DDynamicConv1dTBC(
#           512, kernel_size=31, padding_l=15, num_heads=4, num_proj_heads=1, conv_mixed=False, weight_softmax=True, conv_bias=False, renorm_padding=False, in_proj=False, weight_dropout=0.1
#           (weight_linear): Linear(in_features=512, out_features=124, bias=False)
#         )
#         (linear2): Linear(in_features=512, out_features=512, bias=True)
#         (fc1): Linear(in_features=512, out_features=1024, bias=True)
#         (fc2): Linear(in_features=1024, out_features=512, bias=True)
#         (layer_norms): ModuleList(
#           (0): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#       (6): LightConvEncoderLayer(
#         dropout=0.3, relu_dropout=0.0, input_dropout=0.0, normalize_before=False
#         (linear1): Linear(in_features=512, out_features=512, bias=True)
#         (linear1_query): Linear(in_features=512, out_features=512, bias=True)
#         (conv): DDynamicConv1dTBC(
#           512, kernel_size=31, padding_l=15, num_heads=4, num_proj_heads=1, conv_mixed=False, weight_softmax=True, conv_bias=False, renorm_padding=False, in_proj=False, weight_dropout=0.1
#           (weight_linear): Linear(in_features=512, out_features=124, bias=False)
#         )
#         (linear2): Linear(in_features=512, out_features=512, bias=True)
#         (fc1): Linear(in_features=512, out_features=1024, bias=True)
#         (fc2): Linear(in_features=1024, out_features=512, bias=True)
#         (layer_norms): ModuleList(
#           (0): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#     )
#   )
#   (decoder): LightConvDecoder(
#     (embed_tokens): Embedding(6632, 512, padding_idx=1)
#     (embed_positions): SinusoidalPositionalEmbedding()
#     (layers): ModuleList(
#       (0): LightConvDecoderLayer(
#         dropout=0.3, relu_dropout=0.0, input_dropout=0.0, normalize_before=False
#         (linear1): Linear(in_features=512, out_features=512, bias=True)
#         (linear1_query): Linear(in_features=512, out_features=256, bias=True)
#         (conv): DDynamicConv1dTBC(
#           512, kernel_size=3, padding_l=2, num_heads=4, num_proj_heads=1, conv_mixed=False, weight_softmax=True, conv_bias=False, renorm_padding=False, in_proj=False, query_size=256, weight_dropout=0.1
#           (weight_linear): Linear(in_features=256, out_features=12, bias=False)
#         )
#         (linear2): Linear(in_features=512, out_features=512, bias=True)
#         (conv_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): MultiheadAttention(
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=1024, bias=True)
#         (fc2): Linear(in_features=1024, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (1): LightConvDecoderLayer(
#         dropout=0.3, relu_dropout=0.0, input_dropout=0.0, normalize_before=False
#         (linear1): Linear(in_features=512, out_features=512, bias=True)
#         (linear1_query): Linear(in_features=512, out_features=256, bias=True)
#         (conv): DDynamicConv1dTBC(
#           512, kernel_size=7, padding_l=6, num_heads=4, num_proj_heads=1, conv_mixed=False, weight_softmax=True, conv_bias=False, renorm_padding=False, in_proj=False, query_size=256, weight_dropout=0.1
#           (weight_linear): Linear(in_features=256, out_features=28, bias=False)
#         )
#         (linear2): Linear(in_features=512, out_features=512, bias=True)
#         (conv_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): MultiheadAttention(
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=1024, bias=True)
#         (fc2): Linear(in_features=1024, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (2): LightConvDecoderLayer(
#         dropout=0.3, relu_dropout=0.0, input_dropout=0.0, normalize_before=False
#         (linear1): Linear(in_features=512, out_features=512, bias=True)
#         (linear1_query): Linear(in_features=512, out_features=256, bias=True)
#         (conv): DDynamicConv1dTBC(
#           512, kernel_size=15, padding_l=14, num_heads=4, num_proj_heads=1, conv_mixed=False, weight_softmax=True, conv_bias=False, renorm_padding=False, in_proj=False, query_size=256, weight_dropout=0.1
#           (weight_linear): Linear(in_features=256, out_features=60, bias=False)
#         )
#         (linear2): Linear(in_features=512, out_features=512, bias=True)
#         (conv_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): MultiheadAttention(
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=1024, bias=True)
#         (fc2): Linear(in_features=1024, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (3): LightConvDecoderLayer(
#         dropout=0.3, relu_dropout=0.0, input_dropout=0.0, normalize_before=False
#         (linear1): Linear(in_features=512, out_features=512, bias=True)
#         (linear1_query): Linear(in_features=512, out_features=256, bias=True)
#         (conv): DDynamicConv1dTBC(
#           512, kernel_size=31, padding_l=30, num_heads=4, num_proj_heads=1, conv_mixed=False, weight_softmax=True, conv_bias=False, renorm_padding=False, in_proj=False, query_size=256, weight_dropout=0.1
#           (weight_linear): Linear(in_features=256, out_features=124, bias=False)
#         )
#         (linear2): Linear(in_features=512, out_features=512, bias=True)
#         (conv_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): MultiheadAttention(
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=1024, bias=True)
#         (fc2): Linear(in_features=1024, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (4): LightConvDecoderLayer(
#         dropout=0.3, relu_dropout=0.0, input_dropout=0.0, normalize_before=False
#         (linear1): Linear(in_features=512, out_features=512, bias=True)
#         (linear1_query): Linear(in_features=512, out_features=256, bias=True)
#         (conv): DDynamicConv1dTBC(
#           512, kernel_size=31, padding_l=30, num_heads=4, num_proj_heads=1, conv_mixed=False, weight_softmax=True, conv_bias=False, renorm_padding=False, in_proj=False, query_size=256, weight_dropout=0.1
#           (weight_linear): Linear(in_features=256, out_features=124, bias=False)
#         )
#         (linear2): Linear(in_features=512, out_features=512, bias=True)
#         (conv_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): MultiheadAttention(
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=1024, bias=True)
#         (fc2): Linear(in_features=1024, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (5): LightConvDecoderLayer(
#         dropout=0.3, relu_dropout=0.0, input_dropout=0.0, normalize_before=False
#         (linear1): Linear(in_features=512, out_features=512, bias=True)
#         (linear1_query): Linear(in_features=512, out_features=256, bias=True)
#         (conv): DDynamicConv1dTBC(
#           512, kernel_size=31, padding_l=30, num_heads=4, num_proj_heads=1, conv_mixed=False, weight_softmax=True, conv_bias=False, renorm_padding=False, in_proj=False, query_size=256, weight_dropout=0.1
#           (weight_linear): Linear(in_features=256, out_features=124, bias=False)
#         )
#         (linear2): Linear(in_features=512, out_features=512, bias=True)
#         (conv_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): MultiheadAttention(
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=1024, bias=True)
#         (fc2): Linear(in_features=1024, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#   )
# )
# | model lightconv_iwslt_de_en, criterion LabelSmoothedCrossEntropyCriterion
# | num. model params: 41190912 (num. trained: 41190912)
# | training on 1 GPUs
# | max tokens per GPU = 4000 and max sentences per GPU = None
# | loaded checkpoint /content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint_last.pt (epoch 43 @ 48633 updates)
# | loading train data for epoch 43
# | loaded 160239 examples from: data-bin/iwslt14.tokenized.de-en/train.de-en.de
# | loaded 160239 examples from: data-bin/iwslt14.tokenized.de-en/train.de-en.en
# | data-bin/iwslt14.tokenized.de-en train de-en 160239 examples
# | epoch 044:    100 / 1131 loss=3.346, nll_loss=1.856, ppl=3.62, wps=5965, ups=2, wpb=3522.752, bsz=134.495, num_updates=48734, lr=0.000143246, gnorm=0.852, clip=0.000, oom=0.000, wall=62, train_wall=28746
# | epoch 044:    200 / 1131 loss=3.352, nll_loss=1.863, ppl=3.64, wps=5863, ups=2, wpb=3462.562, bsz=136.199, num_updates=48834, lr=0.0001431, gnorm=0.864, clip=0.000, oom=0.000, wall=121, train_wall=28805
# | epoch 044:    300 / 1131 loss=3.354, nll_loss=1.866, ppl=3.65, wps=5831, ups=2, wpb=3452.455, bsz=139.000, num_updates=48934, lr=0.000142953, gnorm=0.866, clip=0.000, oom=0.000, wall=180, train_wall=28864
# | epoch 044:    400 / 1131 loss=3.350, nll_loss=1.862, ppl=3.64, wps=5862, ups=2, wpb=3479.928, bsz=149.663, num_updates=49034, lr=0.000142808, gnorm=0.858, clip=0.000, oom=0.000, wall=240, train_wall=28923
# | epoch 044:    500 / 1131 loss=3.362, nll_loss=1.876, ppl=3.67, wps=5873, ups=2, wpb=3496.986, bsz=146.329, num_updates=49134, lr=0.000142662, gnorm=0.858, clip=0.000, oom=0.000, wall=300, train_wall=28983
# | epoch 044:    600 / 1131 loss=3.365, nll_loss=1.879, ppl=3.68, wps=5882, ups=2, wpb=3507.433, bsz=145.569, num_updates=49234, lr=0.000142517, gnorm=0.856, clip=0.000, oom=0.000, wall=360, train_wall=29042
# | epoch 044:    700 / 1131 loss=3.371, nll_loss=1.886, ppl=3.70, wps=5886, ups=2, wpb=3507.509, bsz=145.437, num_updates=49334, lr=0.000142373, gnorm=0.856, clip=0.000, oom=0.000, wall=420, train_wall=29101
# | epoch 044:    800 / 1131 loss=3.375, nll_loss=1.891, ppl=3.71, wps=5876, ups=2, wpb=3501.464, bsz=143.589, num_updates=49434, lr=0.000142229, gnorm=0.859, clip=0.000, oom=0.000, wall=479, train_wall=29160
# | epoch 044:    900 / 1131 loss=3.375, nll_loss=1.891, ppl=3.71, wps=5862, ups=2, wpb=3491.553, bsz=144.123, num_updates=49534, lr=0.000142085, gnorm=0.861, clip=0.000, oom=0.000, wall=539, train_wall=29219
# | epoch 044:   1000 / 1131 loss=3.380, nll_loss=1.896, ppl=3.72, wps=5853, ups=2, wpb=3485.258, bsz=142.600, num_updates=49634, lr=0.000141942, gnorm=0.864, clip=0.000, oom=0.000, wall=598, train_wall=29278
# | epoch 044:   1100 / 1131 loss=3.384, nll_loss=1.902, ppl=3.74, wps=5862, ups=2, wpb=3491.745, bsz=141.340, num_updates=49734, lr=0.000141799, gnorm=0.864, clip=0.000, oom=0.000, wall=658, train_wall=29337
# | epoch 044 | loss 3.385 | nll_loss 1.903 | ppl 3.74 | wps 5863 | ups 2 | wpb 3491.701 | bsz 141.679 | num_updates 49764 | lr 0.000141756 | gnorm 0.864 | clip 0.000 | oom 0.000 | wall 676 | train_wall 29355
# | epoch 044 | valid on 'valid' subset | loss 3.884 | nll_loss 2.325 | ppl 5.01 | num_updates 49764 | best_loss 3.88384
# | saved checkpoint /content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint44.pt (epoch 44 @ 49764 updates) (writing took 19.008925914764404 seconds)
# | epoch 045:    100 / 1131 loss=3.335, nll_loss=1.845, ppl=3.59, wps=5848, ups=2, wpb=3536.970, bsz=143.129, num_updates=49865, lr=0.000141613, gnorm=0.843, clip=0.000, oom=0.000, wall=767, train_wall=29415
# | epoch 045:    200 / 1131 loss=3.326, nll_loss=1.835, ppl=3.57, wps=5880, ups=2, wpb=3538.562, bsz=150.965, num_updates=49965, lr=0.000141471, gnorm=0.845, clip=0.000, oom=0.000, wall=827, train_wall=29474
# | epoch 045:    300 / 1131 loss=3.334, nll_loss=1.845, ppl=3.59, wps=5887, ups=2, wpb=3526.136, bsz=149.794, num_updates=50065, lr=0.00014133, gnorm=0.847, clip=0.000, oom=0.000, wall=887, train_wall=29533
# | epoch 045:    400 / 1131 loss=3.340, nll_loss=1.851, ppl=3.61, wps=5902, ups=2, wpb=3530.988, bsz=147.132, num_updates=50165, lr=0.000141189, gnorm=0.847, clip=0.000, oom=0.000, wall=946, train_wall=29592
# | epoch 045:    500 / 1131 loss=3.346, nll_loss=1.858, ppl=3.63, wps=5917, ups=2, wpb=3530.908, bsz=147.784, num_updates=50265, lr=0.000141048, gnorm=0.848, clip=0.000, oom=0.000, wall=1005, train_wall=29651
# | epoch 045:    600 / 1131 loss=3.350, nll_loss=1.863, ppl=3.64, wps=5909, ups=2, wpb=3517.962, bsz=147.594, num_updates=50365, lr=0.000140908, gnorm=0.853, clip=0.000, oom=0.000, wall=1064, train_wall=29709
# | epoch 045:    700 / 1131 loss=3.353, nll_loss=1.866, ppl=3.65, wps=5898, ups=2, wpb=3507.130, bsz=146.670, num_updates=50465, lr=0.000140768, gnorm=0.856, clip=0.000, oom=0.000, wall=1123, train_wall=29768
# | epoch 045:    800 / 1131 loss=3.361, nll_loss=1.875, ppl=3.67, wps=5903, ups=2, wpb=3507.770, bsz=145.498, num_updates=50565, lr=0.000140629, gnorm=0.857, clip=0.000, oom=0.000, wall=1182, train_wall=29826
# | epoch 045:    900 / 1131 loss=3.366, nll_loss=1.880, ppl=3.68, wps=5894, ups=2, wpb=3500.382, bsz=143.609, num_updates=50665, lr=0.00014049, gnorm=0.862, clip=0.000, oom=0.000, wall=1241, train_wall=29885
# | epoch 045:   1000 / 1131 loss=3.371, nll_loss=1.886, ppl=3.70, wps=5890, ups=2, wpb=3496.919, bsz=142.241, num_updates=50765, lr=0.000140352, gnorm=0.866, clip=0.000, oom=0.000, wall=1300, train_wall=29943
# | epoch 045:   1100 / 1131 loss=3.372, nll_loss=1.888, ppl=3.70, wps=5889, ups=2, wpb=3492.069, bsz=142.604, num_updates=50865, lr=0.000140214, gnorm=0.867, clip=0.000, oom=0.000, wall=1359, train_wall=30002
# | epoch 045 | loss 3.375 | nll_loss 1.890 | ppl 3.71 | wps 5887 | ups 2 | wpb 3491.701 | bsz 141.679 | num_updates 50895 | lr 0.000140172 | gnorm 0.868 | clip 0.000 | oom 0.000 | wall 1377 | train_wall 30019
# | epoch 045 | valid on 'valid' subset | loss 3.888 | nll_loss 2.324 | ppl 5.01 | num_updates 50895 | best_loss 3.88384
# | saved checkpoint /content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint45.pt (epoch 45 @ 50895 updates) (writing took 4.406212329864502 seconds)
# | epoch 046:    100 / 1131 loss=3.355, nll_loss=1.867, ppl=3.65, wps=5927, ups=2, wpb=3548.713, bsz=135.525, num_updates=50996, lr=0.000140034, gnorm=0.849, clip=0.000, oom=0.000, wall=1453, train_wall=30079
# | epoch 046:    200 / 1131 loss=3.360, nll_loss=1.872, ppl=3.66, wps=5911, ups=2, wpb=3516.085, bsz=135.602, num_updates=51096, lr=0.000139896, gnorm=0.861, clip=0.000, oom=0.000, wall=1512, train_wall=30138
# | epoch 046:    300 / 1131 loss=3.350, nll_loss=1.861, ppl=3.63, wps=5921, ups=2, wpb=3524.973, bsz=139.588, num_updates=51196, lr=0.00013976, gnorm=0.855, clip=0.000, oom=0.000, wall=1572, train_wall=30197
# | epoch 046:    400 / 1131 loss=3.357, nll_loss=1.868, ppl=3.65, wps=5887, ups=2, wpb=3491.481, bsz=134.900, num_updates=51296, lr=0.000139623, gnorm=0.870, clip=0.000, oom=0.000, wall=1631, train_wall=30255
# | epoch 046:    500 / 1131 loss=3.354, nll_loss=1.865, ppl=3.64, wps=5892, ups=2, wpb=3492.611, bsz=135.918, num_updates=51396, lr=0.000139488, gnorm=0.867, clip=0.000, oom=0.000, wall=1690, train_wall=30314
# | epoch 046:    600 / 1131 loss=3.350, nll_loss=1.861, ppl=3.63, wps=5894, ups=2, wpb=3492.426, bsz=138.913, num_updates=51496, lr=0.000139352, gnorm=0.865, clip=0.000, oom=0.000, wall=1749, train_wall=30372
# | epoch 046:    700 / 1131 loss=3.352, nll_loss=1.863, ppl=3.64, wps=5886, ups=2, wpb=3483.922, bsz=139.320, num_updates=51596, lr=0.000139217, gnorm=0.867, clip=0.000, oom=0.000, wall=1808, train_wall=30431
# | epoch 046:    800 / 1131 loss=3.354, nll_loss=1.866, ppl=3.64, wps=5885, ups=2, wpb=3481.596, bsz=139.864, num_updates=51696, lr=0.000139082, gnorm=0.868, clip=0.000, oom=0.000, wall=1867, train_wall=30489
# | epoch 046:    900 / 1131 loss=3.352, nll_loss=1.864, ppl=3.64, wps=5877, ups=2, wpb=3479.482, bsz=142.436, num_updates=51796, lr=0.000138948, gnorm=0.868, clip=0.000, oom=0.000, wall=1926, train_wall=30548
# | epoch 046:   1000 / 1131 loss=3.357, nll_loss=1.870, ppl=3.66, wps=5888, ups=2, wpb=3488.467, bsz=143.216, num_updates=51896, lr=0.000138814, gnorm=0.867, clip=0.000, oom=0.000, wall=1986, train_wall=30607
# | epoch 046:   1100 / 1131 loss=3.361, nll_loss=1.874, ppl=3.67, wps=5890, ups=2, wpb=3494.111, bsz=142.161, num_updates=51996, lr=0.00013868, gnorm=0.868, clip=0.000, oom=0.000, wall=2046, train_wall=30667
# | epoch 046 | loss 3.363 | nll_loss 1.877 | ppl 3.67 | wps 5889 | ups 2 | wpb 3491.701 | bsz 141.679 | num_updates 52026 | lr 0.00013864 | gnorm 0.869 | clip 0.000 | oom 0.000 | wall 2064 | train_wall 30684
# | epoch 046 | valid on 'valid' subset | loss 3.895 | nll_loss 2.330 | ppl 5.03 | num_updates 52026 | best_loss 3.88384
# | saved checkpoint /content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint46.pt (epoch 46 @ 52026 updates) (writing took 4.749977111816406 seconds)
# | epoch 047:    100 / 1131 loss=3.328, nll_loss=1.836, ppl=3.57, wps=5829, ups=2, wpb=3494.762, bsz=140.752, num_updates=52127, lr=0.000138506, gnorm=0.860, clip=0.000, oom=0.000, wall=2140, train_wall=30744
# | epoch 047:    200 / 1131 loss=3.338, nll_loss=1.846, ppl=3.60, wps=5876, ups=2, wpb=3504.751, bsz=136.796, num_updates=52227, lr=0.000138373, gnorm=0.867, clip=0.000, oom=0.000, wall=2200, train_wall=30803
# | epoch 047:    300 / 1131 loss=3.335, nll_loss=1.844, ppl=3.59, wps=5884, ups=2, wpb=3509.013, bsz=139.801, num_updates=52327, lr=0.000138241, gnorm=0.868, clip=0.000, oom=0.000, wall=2259, train_wall=30862
# | epoch 047:    400 / 1131 loss=3.334, nll_loss=1.843, ppl=3.59, wps=5878, ups=2, wpb=3505.815, bsz=142.005, num_updates=52427, lr=0.000138109, gnorm=0.865, clip=0.000, oom=0.000, wall=2319, train_wall=30921
# | epoch 047:    500 / 1131 loss=3.338, nll_loss=1.848, ppl=3.60, wps=5875, ups=2, wpb=3507.607, bsz=141.780, num_updates=52527, lr=0.000137978, gnorm=0.865, clip=0.000, oom=0.000, wall=2379, train_wall=30980
# | epoch 047:    600 / 1131 loss=3.340, nll_loss=1.849, ppl=3.60, wps=5866, ups=2, wpb=3499.255, bsz=140.512, num_updates=52627, lr=0.000137846, gnorm=0.867, clip=0.000, oom=0.000, wall=2438, train_wall=31039
# | epoch 047:    700 / 1131 loss=3.338, nll_loss=1.847, ppl=3.60, wps=5862, ups=2, wpb=3497.016, bsz=142.094, num_updates=52727, lr=0.000137716, gnorm=0.866, clip=0.000, oom=0.000, wall=2498, train_wall=31098
# | epoch 047:    800 / 1131 loss=3.344, nll_loss=1.854, ppl=3.62, wps=5872, ups=2, wpb=3505.682, bsz=142.262, num_updates=52827, lr=0.000137585, gnorm=0.866, clip=0.000, oom=0.000, wall=2558, train_wall=31158
# | epoch 047:    900 / 1131 loss=3.345, nll_loss=1.856, ppl=3.62, wps=5862, ups=2, wpb=3495.222, bsz=141.683, num_updates=52927, lr=0.000137455, gnorm=0.869, clip=0.000, oom=0.000, wall=2617, train_wall=31216
# | epoch 047:   1000 / 1131 loss=3.348, nll_loss=1.859, ppl=3.63, wps=5855, ups=2, wpb=3488.815, bsz=141.641, num_updates=53027, lr=0.000137326, gnorm=0.873, clip=0.000, oom=0.000, wall=2676, train_wall=31275
# | epoch 047:   1100 / 1131 loss=3.352, nll_loss=1.864, ppl=3.64, wps=5856, ups=2, wpb=3488.280, bsz=141.100, num_updates=53127, lr=0.000137196, gnorm=0.874, clip=0.000, oom=0.000, wall=2736, train_wall=31334
# | epoch 047 | loss 3.352 | nll_loss 1.864 | ppl 3.64 | wps 5860 | ups 2 | wpb 3491.701 | bsz 141.679 | num_updates 53157 | lr 0.000137158 | gnorm 0.873 | clip 0.000 | oom 0.000 | wall 2754 | train_wall 31352
# | epoch 047 | valid on 'valid' subset | loss 3.889 | nll_loss 2.326 | ppl 5.01 | num_updates 53157 | best_loss 3.88384
# | saved checkpoint /content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint47.pt (epoch 47 @ 53157 updates) (writing took 5.011613130569458 seconds)
# | epoch 048:    100 / 1131 loss=3.353, nll_loss=1.865, ppl=3.64, wps=5813, ups=2, wpb=3472.436, bsz=131.327, num_updates=53258, lr=0.000137027, gnorm=0.877, clip=0.000, oom=0.000, wall=2831, train_wall=31411
# | epoch 048:    200 / 1131 loss=3.332, nll_loss=1.841, ppl=3.58, wps=5847, ups=2, wpb=3482.582, bsz=142.209, num_updates=53358, lr=0.000136899, gnorm=0.866, clip=0.000, oom=0.000, wall=2890, train_wall=31470
# | epoch 048:    300 / 1131 loss=3.329, nll_loss=1.836, ppl=3.57, wps=5838, ups=2, wpb=3479.063, bsz=138.924, num_updates=53458, lr=0.000136771, gnorm=0.869, clip=0.000, oom=0.000, wall=2950, train_wall=31529
# | epoch 048:    400 / 1131 loss=3.324, nll_loss=1.831, ppl=3.56, wps=5844, ups=2, wpb=3480.579, bsz=140.289, num_updates=53558, lr=0.000136643, gnorm=0.869, clip=0.000, oom=0.000, wall=3009, train_wall=31588
# | epoch 048:    500 / 1131 loss=3.332, nll_loss=1.840, ppl=3.58, wps=5847, ups=2, wpb=3482.242, bsz=137.852, num_updates=53658, lr=0.000136516, gnorm=0.873, clip=0.000, oom=0.000, wall=3069, train_wall=31647
# | epoch 048:    600 / 1131 loss=3.330, nll_loss=1.838, ppl=3.58, wps=5855, ups=2, wpb=3485.710, bsz=139.700, num_updates=53758, lr=0.000136389, gnorm=0.872, clip=0.000, oom=0.000, wall=3128, train_wall=31706
# | epoch 048:    700 / 1131 loss=3.331, nll_loss=1.840, ppl=3.58, wps=5866, ups=2, wpb=3492.549, bsz=140.542, num_updates=53858, lr=0.000136262, gnorm=0.870, clip=0.000, oom=0.000, wall=3188, train_wall=31765
# | epoch 048:    800 / 1131 loss=3.339, nll_loss=1.849, ppl=3.60, wps=5864, ups=2, wpb=3490.466, bsz=138.337, num_updates=53958, lr=0.000136136, gnorm=0.875, clip=0.000, oom=0.000, wall=3247, train_wall=31824
# | epoch 048:    900 / 1131 loss=3.343, nll_loss=1.852, ppl=3.61, wps=5863, ups=2, wpb=3490.554, bsz=138.680, num_updates=54058, lr=0.00013601, gnorm=0.876, clip=0.000, oom=0.000, wall=3307, train_wall=31883
# | epoch 048:   1000 / 1131 loss=3.341, nll_loss=1.851, ppl=3.61, wps=5856, ups=2, wpb=3484.944, bsz=140.035, num_updates=54158, lr=0.000135884, gnorm=0.875, clip=0.000, oom=0.000, wall=3366, train_wall=31942
# | epoch 048:   1100 / 1131 loss=3.341, nll_loss=1.850, ppl=3.61, wps=5858, ups=2, wpb=3487.076, bsz=141.587, num_updates=54258, lr=0.000135759, gnorm=0.874, clip=0.000, oom=0.000, wall=3426, train_wall=32001
# | epoch 048 | loss 3.342 | nll_loss 1.852 | ppl 3.61 | wps 5864 | ups 2 | wpb 3491.701 | bsz 141.679 | num_updates 54288 | lr 0.000135721 | gnorm 0.873 | clip 0.000 | oom 0.000 | wall 3444 | train_wall 32019
# | epoch 048 | valid on 'valid' subset | loss 3.882 | nll_loss 2.322 | ppl 5.00 | num_updates 54288 | best_loss 3.88226
# | saved checkpoint /content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint48.pt (epoch 48 @ 54288 updates) (writing took 7.528382778167725 seconds)
# | epoch 049:    100 / 1131 loss=3.254, nll_loss=1.752, ppl=3.37, wps=5784, ups=2, wpb=3506.307, bsz=153.584, num_updates=54389, lr=0.000135595, gnorm=0.846, clip=0.000, oom=0.000, wall=3524, train_wall=32080
# | epoch 049:    200 / 1131 loss=3.281, nll_loss=1.782, ppl=3.44, wps=5840, ups=2, wpb=3508.995, bsz=144.716, num_updates=54489, lr=0.000135471, gnorm=0.860, clip=0.000, oom=0.000, wall=3583, train_wall=32139
# | epoch 049:    300 / 1131 loss=3.292, nll_loss=1.795, ppl=3.47, wps=5872, ups=2, wpb=3524.266, bsz=146.419, num_updates=54589, lr=0.000135347, gnorm=0.859, clip=0.000, oom=0.000, wall=3643, train_wall=32198
# | epoch 049:    400 / 1131 loss=3.302, nll_loss=1.807, ppl=3.50, wps=5876, ups=2, wpb=3517.145, bsz=145.616, num_updates=54689, lr=0.000135223, gnorm=0.863, clip=0.000, oom=0.000, wall=3703, train_wall=32257
# | epoch 049:    500 / 1131 loss=3.316, nll_loss=1.822, ppl=3.54, wps=5874, ups=2, wpb=3501.198, bsz=142.164, num_updates=54789, lr=0.000135099, gnorm=0.872, clip=0.000, oom=0.000, wall=3761, train_wall=32315
# | epoch 049:    600 / 1131 loss=3.315, nll_loss=1.822, ppl=3.54, wps=5876, ups=2, wpb=3504.017, bsz=143.787, num_updates=54889, lr=0.000134976, gnorm=0.870, clip=0.000, oom=0.000, wall=3821, train_wall=32374
# | epoch 049:    700 / 1131 loss=3.320, nll_loss=1.827, ppl=3.55, wps=5873, ups=2, wpb=3490.618, bsz=142.437, num_updates=54989, lr=0.000134853, gnorm=0.873, clip=0.000, oom=0.000, wall=3879, train_wall=32432
# | epoch 049:    800 / 1131 loss=3.327, nll_loss=1.835, ppl=3.57, wps=5861, ups=2, wpb=3479.742, bsz=140.134, num_updates=55089, lr=0.000134731, gnorm=0.879, clip=0.000, oom=0.000, wall=3938, train_wall=32490
# | epoch 049:    900 / 1131 loss=3.328, nll_loss=1.836, ppl=3.57, wps=5864, ups=2, wpb=3484.286, bsz=140.820, num_updates=55189, lr=0.000134609, gnorm=0.877, clip=0.000, oom=0.000, wall=3998, train_wall=32550
# | epoch 049:   1000 / 1131 loss=3.332, nll_loss=1.841, ppl=3.58, wps=5869, ups=2, wpb=3489.884, bsz=140.459, num_updates=55289, lr=0.000134487, gnorm=0.878, clip=0.000, oom=0.000, wall=4058, train_wall=32609
# | epoch 049:   1100 / 1131 loss=3.334, nll_loss=1.843, ppl=3.59, wps=5874, ups=2, wpb=3492.064, bsz=140.366, num_updates=55389, lr=0.000134366, gnorm=0.879, clip=0.000, oom=0.000, wall=4117, train_wall=32668
# | epoch 049 | loss 3.333 | nll_loss 1.841 | ppl 3.58 | wps 5873 | ups 2 | wpb 3491.701 | bsz 141.679 | num_updates 55419 | lr 0.000134329 | gnorm 0.879 | clip 0.000 | oom 0.000 | wall 4135 | train_wall 32685
# | epoch 049 | valid on 'valid' subset | loss 3.891 | nll_loss 2.324 | ppl 5.01 | num_updates 55419 | best_loss 3.88226
# | saved checkpoint /content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint49.pt (epoch 49 @ 55419 updates) (writing took 5.448601484298706 seconds)
# | epoch 050:    100 / 1131 loss=3.280, nll_loss=1.780, ppl=3.43, wps=5837, ups=2, wpb=3470.980, bsz=140.436, num_updates=55520, lr=0.000134207, gnorm=0.871, clip=0.000, oom=0.000, wall=4212, train_wall=32745
# | epoch 050:    200 / 1131 loss=3.285, nll_loss=1.786, ppl=3.45, wps=5846, ups=2, wpb=3467.259, bsz=142.209, num_updates=55620, lr=0.000134086, gnorm=0.873, clip=0.000, oom=0.000, wall=4271, train_wall=32804
# | epoch 050:    300 / 1131 loss=3.291, nll_loss=1.793, ppl=3.46, wps=5876, ups=2, wpb=3484.007, bsz=141.076, num_updates=55720, lr=0.000133966, gnorm=0.878, clip=0.000, oom=0.000, wall=4331, train_wall=32862
# | epoch 050:    400 / 1131 loss=3.299, nll_loss=1.801, ppl=3.49, wps=5881, ups=2, wpb=3493.367, bsz=139.192, num_updates=55820, lr=0.000133846, gnorm=0.877, clip=0.000, oom=0.000, wall=4390, train_wall=32921
# | epoch 050:    500 / 1131 loss=3.304, nll_loss=1.807, ppl=3.50, wps=5869, ups=2, wpb=3488.888, bsz=137.996, num_updates=55920, lr=0.000133726, gnorm=0.880, clip=0.000, oom=0.000, wall=4450, train_wall=32981
# | epoch 050:    600 / 1131 loss=3.306, nll_loss=1.810, ppl=3.51, wps=5886, ups=2, wpb=3503.136, bsz=139.248, num_updates=56020, lr=0.000133607, gnorm=0.875, clip=0.000, oom=0.000, wall=4510, train_wall=33040
# | epoch 050:    700 / 1131 loss=3.308, nll_loss=1.813, ppl=3.51, wps=5881, ups=2, wpb=3495.462, bsz=140.725, num_updates=56120, lr=0.000133488, gnorm=0.877, clip=0.000, oom=0.000, wall=4569, train_wall=33098
# | epoch 050:    800 / 1131 loss=3.313, nll_loss=1.818, ppl=3.53, wps=5886, ups=2, wpb=3495.978, bsz=142.081, num_updates=56220, lr=0.000133369, gnorm=0.878, clip=0.000, oom=0.000, wall=4628, train_wall=33157
# | epoch 050:    900 / 1131 loss=3.316, nll_loss=1.822, ppl=3.54, wps=5881, ups=2, wpb=3493.577, bsz=142.472, num_updates=56320, lr=0.00013325, gnorm=0.879, clip=0.000, oom=0.000, wall=4687, train_wall=33216
# | epoch 050:   1000 / 1131 loss=3.319, nll_loss=1.825, ppl=3.54, wps=5879, ups=2, wpb=3495.459, bsz=143.240, num_updates=56420, lr=0.000133132, gnorm=0.878, clip=0.000, oom=0.000, wall=4747, train_wall=33275
# | epoch 050:   1100 / 1131 loss=3.321, nll_loss=1.828, ppl=3.55, wps=5873, ups=2, wpb=3494.235, bsz=142.350, num_updates=56520, lr=0.000133014, gnorm=0.879, clip=0.000, oom=0.000, wall=4807, train_wall=33335
# | epoch 050 | loss 3.323 | nll_loss 1.830 | ppl 3.56 | wps 5869 | ups 2 | wpb 3491.701 | bsz 141.679 | num_updates 56550 | lr 0.000132979 | gnorm 0.881 | clip 0.000 | oom 0.000 | wall 4825 | train_wall 33352
# | epoch 050 | valid on 'valid' subset | loss 3.905 | nll_loss 2.339 | ppl 5.06 | num_updates 56550 | best_loss 3.88226
# | saved checkpoint /content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint50.pt (epoch 50 @ 56550 updates) (writing took 4.8310675621032715 seconds)
# | epoch 051:    100 / 1131 loss=3.274, nll_loss=1.774, ppl=3.42, wps=5845, ups=2, wpb=3522.119, bsz=152.792, num_updates=56651, lr=0.000132861, gnorm=0.849, clip=0.000, oom=0.000, wall=4902, train_wall=33413
# | epoch 051:    200 / 1131 loss=3.267, nll_loss=1.767, ppl=3.40, wps=5822, ups=2, wpb=3501.955, bsz=153.950, num_updates=56751, lr=0.000132743, gnorm=0.856, clip=0.000, oom=0.000, wall=4962, train_wall=33472
# | epoch 051:    300 / 1131 loss=3.279, nll_loss=1.780, ppl=3.43, wps=5841, ups=2, wpb=3514.475, bsz=149.741, num_updates=56851, lr=0.000132627, gnorm=0.863, clip=0.000, oom=0.000, wall=5022, train_wall=33532
# | epoch 051:    400 / 1131 loss=3.286, nll_loss=1.788, ppl=3.45, wps=5861, ups=2, wpb=3521.958, bsz=148.549, num_updates=56951, lr=0.00013251, gnorm=0.865, clip=0.000, oom=0.000, wall=5082, train_wall=33591
# | epoch 051:    500 / 1131 loss=3.293, nll_loss=1.796, ppl=3.47, wps=5859, ups=2, wpb=3517.357, bsz=146.699, num_updates=57051, lr=0.000132394, gnorm=0.870, clip=0.000, oom=0.000, wall=5142, train_wall=33650
# | epoch 051:    600 / 1131 loss=3.299, nll_loss=1.802, ppl=3.49, wps=5852, ups=2, wpb=3504.730, bsz=143.719, num_updates=57151, lr=0.000132278, gnorm=0.876, clip=0.000, oom=0.000, wall=5201, train_wall=33709
# | epoch 051:    700 / 1131 loss=3.300, nll_loss=1.804, ppl=3.49, wps=5849, ups=2, wpb=3497.414, bsz=143.884, num_updates=57251, lr=0.000132163, gnorm=0.879, clip=0.000, oom=0.000, wall=5261, train_wall=33768
# | epoch 051:    800 / 1131 loss=3.304, nll_loss=1.809, ppl=3.50, wps=5848, ups=2, wpb=3497.276, bsz=143.549, num_updates=57351, lr=0.000132047, gnorm=0.881, clip=0.000, oom=0.000, wall=5320, train_wall=33827
# | epoch 051:    900 / 1131 loss=3.307, nll_loss=1.812, ppl=3.51, wps=5842, ups=2, wpb=3494.695, bsz=142.667, num_updates=57451, lr=0.000131932, gnorm=0.882, clip=0.000, oom=0.000, wall=5380, train_wall=33886
# | epoch 051:   1000 / 1131 loss=3.311, nll_loss=1.816, ppl=3.52, wps=5839, ups=2, wpb=3490.664, bsz=142.536, num_updates=57551, lr=0.000131818, gnorm=0.885, clip=0.000, oom=0.000, wall=5440, train_wall=33945
# | epoch 051:   1100 / 1131 loss=3.313, nll_loss=1.818, ppl=3.53, wps=5836, ups=2, wpb=3487.847, bsz=142.081, num_updates=57651, lr=0.000131703, gnorm=0.886, clip=0.000, oom=0.000, wall=5499, train_wall=34004
# | epoch 051 | loss 3.314 | nll_loss 1.820 | ppl 3.53 | wps 5838 | ups 2 | wpb 3491.701 | bsz 141.679 | num_updates 57681 | lr 0.000131669 | gnorm 0.886 | clip 0.000 | oom 0.000 | wall 5518 | train_wall 34023
# | epoch 051 | valid on 'valid' subset | loss 3.895 | nll_loss 2.330 | ppl 5.03 | num_updates 57681 | best_loss 3.88226
# | saved checkpoint /content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint51.pt (epoch 51 @ 57681 updates) (writing took 4.559823036193848 seconds)
# | epoch 052:    100 / 1131 loss=3.243, nll_loss=1.738, ppl=3.34, wps=5786, ups=2, wpb=3485.901, bsz=146.455, num_updates=57782, lr=0.000131554, gnorm=0.860, clip=0.000, oom=0.000, wall=5595, train_wall=34083
# | epoch 052:    200 / 1131 loss=3.274, nll_loss=1.773, ppl=3.42, wps=5840, ups=2, wpb=3502.448, bsz=142.682, num_updates=57882, lr=0.00013144, gnorm=0.872, clip=0.000, oom=0.000, wall=5654, train_wall=34142
# | epoch 052:    300 / 1131 loss=3.281, nll_loss=1.780, ppl=3.44, wps=5838, ups=2, wpb=3497.465, bsz=139.664, num_updates=57982, lr=0.000131327, gnorm=0.882, clip=0.000, oom=0.000, wall=5714, train_wall=34201
# | epoch 052:    400 / 1131 loss=3.283, nll_loss=1.782, ppl=3.44, wps=5839, ups=2, wpb=3490.810, bsz=140.766, num_updates=58082, lr=0.000131214, gnorm=0.884, clip=0.000, oom=0.000, wall=5774, train_wall=34260
# | epoch 052:    500 / 1131 loss=3.290, nll_loss=1.790, ppl=3.46, wps=5843, ups=2, wpb=3480.387, bsz=138.920, num_updates=58182, lr=0.000131101, gnorm=0.890, clip=0.000, oom=0.000, wall=5832, train_wall=34318
# | epoch 052:    600 / 1131 loss=3.294, nll_loss=1.796, ppl=3.47, wps=5854, ups=2, wpb=3488.579, bsz=138.354, num_updates=58282, lr=0.000130988, gnorm=0.888, clip=0.000, oom=0.000, wall=5892, train_wall=34378
# | epoch 052:    700 / 1131 loss=3.297, nll_loss=1.799, ppl=3.48, wps=5853, ups=2, wpb=3484.184, bsz=138.258, num_updates=58382, lr=0.000130876, gnorm=0.888, clip=0.000, oom=0.000, wall=5951, train_wall=34436
# | epoch 052:    800 / 1131 loss=3.303, nll_loss=1.806, ppl=3.50, wps=5856, ups=2, wpb=3483.719, bsz=137.856, num_updates=58482, lr=0.000130764, gnorm=0.891, clip=0.000, oom=0.000, wall=6010, train_wall=34495
# | epoch 052:    900 / 1131 loss=3.301, nll_loss=1.804, ppl=3.49, wps=5861, ups=2, wpb=3486.403, bsz=140.243, num_updates=58582, lr=0.000130653, gnorm=0.890, clip=0.000, oom=0.000, wall=6070, train_wall=34554
# | epoch 052:   1000 / 1131 loss=3.301, nll_loss=1.805, ppl=3.49, wps=5863, ups=2, wpb=3488.975, bsz=141.402, num_updates=58682, lr=0.000130541, gnorm=0.888, clip=0.000, oom=0.000, wall=6130, train_wall=34613
# | epoch 052:   1100 / 1131 loss=3.304, nll_loss=1.808, ppl=3.50, wps=5871, ups=2, wpb=3492.639, bsz=141.543, num_updates=58782, lr=0.00013043, gnorm=0.887, clip=0.000, oom=0.000, wall=6189, train_wall=34672
# | epoch 052 | loss 3.305 | nll_loss 1.809 | ppl 3.50 | wps 5870 | ups 2 | wpb 3491.701 | bsz 141.679 | num_updates 58812 | lr 0.000130397 | gnorm 0.888 | clip 0.000 | oom 0.000 | wall 6207 | train_wall 34689
# | epoch 052 | valid on 'valid' subset | loss 3.894 | nll_loss 2.328 | ppl 5.02 | num_updates 58812 | best_loss 3.88226
# | saved checkpoint /content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint52.pt (epoch 52 @ 58812 updates) (writing took 5.300499677658081 seconds)
# | epoch 053:    100 / 1131 loss=3.263, nll_loss=1.758, ppl=3.38, wps=5777, ups=2, wpb=3487.842, bsz=131.406, num_updates=58913, lr=0.000130285, gnorm=0.882, clip=0.000, oom=0.000, wall=6285, train_wall=34750
# | epoch 053:    200 / 1131 loss=3.254, nll_loss=1.750, ppl=3.36, wps=5792, ups=2, wpb=3492.736, bsz=140.652, num_updates=59013, lr=0.000130175, gnorm=0.873, clip=0.000, oom=0.000, wall=6345, train_wall=34809
# | epoch 053:    300 / 1131 loss=3.259, nll_loss=1.756, ppl=3.38, wps=5835, ups=2, wpb=3514.724, bsz=143.784, num_updates=59113, lr=0.000130064, gnorm=0.873, clip=0.000, oom=0.000, wall=6405, train_wall=34869
# | epoch 053:    400 / 1131 loss=3.273, nll_loss=1.772, ppl=3.41, wps=5836, ups=2, wpb=3505.681, bsz=139.050, num_updates=59213, lr=0.000129955, gnorm=0.882, clip=0.000, oom=0.000, wall=6464, train_wall=34928
# | epoch 053:    500 / 1131 loss=3.283, nll_loss=1.783, ppl=3.44, wps=5837, ups=2, wpb=3496.164, bsz=139.463, num_updates=59313, lr=0.000129845, gnorm=0.885, clip=0.000, oom=0.000, wall=6524, train_wall=34987
# | epoch 053:    600 / 1131 loss=3.282, nll_loss=1.783, ppl=3.44, wps=5844, ups=2, wpb=3499.436, bsz=141.509, num_updates=59413, lr=0.000129736, gnorm=0.884, clip=0.000, oom=0.000, wall=6583, train_wall=35046
# | epoch 053:    700 / 1131 loss=3.285, nll_loss=1.786, ppl=3.45, wps=5846, ups=2, wpb=3501.114, bsz=141.648, num_updates=59513, lr=0.000129627, gnorm=0.885, clip=0.000, oom=0.000, wall=6643, train_wall=35105
# | epoch 053:    800 / 1131 loss=3.286, nll_loss=1.788, ppl=3.45, wps=5839, ups=2, wpb=3495.496, bsz=142.221, num_updates=59613, lr=0.000129518, gnorm=0.887, clip=0.000, oom=0.000, wall=6703, train_wall=35165
# | epoch 053:    900 / 1131 loss=3.290, nll_loss=1.792, ppl=3.46, wps=5840, ups=2, wpb=3492.007, bsz=141.406, num_updates=59713, lr=0.000129409, gnorm=0.890, clip=0.000, oom=0.000, wall=6762, train_wall=35223
# | epoch 053:   1000 / 1131 loss=3.293, nll_loss=1.795, ppl=3.47, wps=5843, ups=2, wpb=3494.007, bsz=141.218, num_updates=59813, lr=0.000129301, gnorm=0.889, clip=0.000, oom=0.000, wall=6822, train_wall=35283
# | epoch 053:   1100 / 1131 loss=3.297, nll_loss=1.800, ppl=3.48, wps=5843, ups=2, wpb=3489.706, bsz=140.606, num_updates=59913, lr=0.000129193, gnorm=0.892, clip=0.000, oom=0.000, wall=6881, train_wall=35341
# | epoch 053 | loss 3.296 | nll_loss 1.799 | ppl 3.48 | wps 5845 | ups 2 | wpb 3491.701 | bsz 141.679 | num_updates 59943 | lr 0.000129161 | gnorm 0.891 | clip 0.000 | oom 0.000 | wall 6899 | train_wall 35359
# | epoch 053 | valid on 'valid' subset | loss 3.896 | nll_loss 2.328 | ppl 5.02 | num_updates 59943 | best_loss 3.88226
# | saved checkpoint /content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint53.pt (epoch 53 @ 59943 updates) (writing took 5.092042446136475 seconds)
# | epoch 054:    100 / 1131 loss=3.235, nll_loss=1.728, ppl=3.31, wps=5795, ups=2, wpb=3490.891, bsz=140.119, num_updates=60044, lr=0.000129052, gnorm=0.875, clip=0.000, oom=0.000, wall=6977, train_wall=35420
# ...
# | epoch 066:    200 / 1131 loss=3.141, nll_loss=1.621, ppl=3.08, wps=5887, ups=2, wpb=3515.418, bsz=158.169, num_updates=73716, lr=0.000116471, gnorm=0.891, clip=0.000, oom=0.000, wall=15384, train_wall=43550
# | epoch 066:    300 / 1131 loss=3.156, nll_loss=1.638, ppl=3.11, wps=5913, ups=2, wpb=3514.578, bsz=153.090, num_updates=73816, lr=0.000116392, gnorm=0.903, clip=0.000, oom=0.000, wall=15442, train_wall=43609
# | epoch 066:    400 / 1131 loss=3.172, nll_loss=1.655, ppl=3.15, wps=5902, ups=2, wpb=3500.903, bsz=145.955, num_updates=73916, lr=0.000116314, gnorm=0.915, clip=0.000, oom=0.000, wall=15501, train_wall=43667
# | epoch 066:    500 / 1131 loss=3.176, nll_loss=1.660, ppl=3.16, wps=5912, ups=2, wpb=3507.727, bsz=143.170, num_updates=74016, lr=0.000116235, gnorm=0.917, clip=0.000, oom=0.000, wall=15561, train_wall=43726
# | epoch 066:    600 / 1131 loss=3.181, nll_loss=1.665, ppl=3.17, wps=5891, ups=2, wpb=3490.569, bsz=140.125, num_updates=74116, lr=0.000116157, gnorm=0.925, clip=0.000, oom=0.000, wall=15620, train_wall=43784
# | epoch 066:    700 / 1131 loss=3.183, nll_loss=1.667, ppl=3.18, wps=5881, ups=2, wpb=3478.927, bsz=139.000, num_updates=74216, lr=0.000116078, gnorm=0.929, clip=0.000, oom=0.000, wall=15678, train_wall=43842
# | epoch 066:    800 / 1131 loss=3.186, nll_loss=1.671, ppl=3.18, wps=5894, ups=2, wpb=3486.007, bsz=140.253, num_updates=74316, lr=0.000116, gnorm=0.927, clip=0.000, oom=0.000, wall=15737, train_wall=43901
# | epoch 066:    900 / 1131 loss=3.188, nll_loss=1.672, ppl=3.19, wps=5897, ups=2, wpb=3486.852, bsz=140.572, num_updates=74416, lr=0.000115922, gnorm=0.926, clip=0.000, oom=0.000, wall=15796, train_wall=43959
# | epoch 066:   1000 / 1131 loss=3.189, nll_loss=1.675, ppl=3.19, wps=5899, ups=2, wpb=3486.021, bsz=141.777, num_updates=74516, lr=0.000115844, gnorm=0.926, clip=0.000, oom=0.000, wall=15855, train_wall=44018
# | epoch 066:   1100 / 1131 loss=3.192, nll_loss=1.678, ppl=3.20, wps=5902, ups=2, wpb=3491.772, bsz=141.921, num_updates=74616, lr=0.000115767, gnorm=0.926, clip=0.000, oom=0.000, wall=15915, train_wall=44077
# | epoch 066 | loss 3.193 | nll_loss 1.679 | ppl 3.20 | wps 5901 | ups 2 | wpb 3491.701 | bsz 141.679 | num_updates 74646 | lr 0.000115744 | gnorm 0.926 | clip 0.000 | oom 0.000 | wall 15933 | train_wall 44095
# | epoch 066 | valid on 'valid' subset | loss 3.895 | nll_loss 2.332 | ppl 5.04 | num_updates 74646 | best_loss 3.88226
# | saved checkpoint /content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint66.pt (epoch 66 @ 74646 updates) (writing took 5.454550743103027 seconds)
# | epoch 067:    100 / 1131 loss=3.142, nll_loss=1.620, ppl=3.07, wps=5697, ups=2, wpb=3457.465, bsz=147.485, num_updates=74747, lr=0.000115665, gnorm=0.918, clip=0.000, oom=0.000, wall=16011, train_wall=44156
# | epoch 067:    200 / 1131 loss=3.157, nll_loss=1.637, ppl=3.11, wps=5786, ups=2, wpb=3498.095, bsz=144.597, num_updates=74847, lr=0.000115588, gnorm=0.910, clip=0.000, oom=0.000, wall=16072, train_wall=44215
# | epoch 067:    300 / 1131 loss=3.167, nll_loss=1.649, ppl=3.14, wps=5803, ups=2, wpb=3494.645, bsz=145.542, num_updates=74947, lr=0.000115511, gnorm=0.913, clip=0.000, oom=0.000, wall=16131, train_wall=44275
# | epoch 067:    400 / 1131 loss=3.166, nll_loss=1.647, ppl=3.13, wps=5808, ups=2, wpb=3498.633, bsz=143.082, num_updates=75047, lr=0.000115434, gnorm=0.916, clip=0.000, oom=0.000, wall=16192, train_wall=44334
# | epoch 067:    500 / 1131 loss=3.169, nll_loss=1.651, ppl=3.14, wps=5803, ups=2, wpb=3485.311, bsz=142.068, num_updates=75147, lr=0.000115357, gnorm=0.921, clip=0.000, oom=0.000, wall=16251, train_wall=44393
# | epoch 067:    600 / 1131 loss=3.173, nll_loss=1.656, ppl=3.15, wps=5786, ups=2, wpb=3470.980, bsz=141.098, num_updates=75247, lr=0.00011528, gnorm=0.926, clip=0.000, oom=0.000, wall=16311, train_wall=44452
# | epoch 067:    700 / 1131 loss=3.173, nll_loss=1.656, ppl=3.15, wps=5789, ups=2, wpb=3476.916, bsz=142.459, num_updates=75347, lr=0.000115204, gnorm=0.926, clip=0.000, oom=0.000, wall=16371, train_wall=44512
# | epoch 067:    800 / 1131 loss=3.175, nll_loss=1.659, ppl=3.16, wps=5798, ups=2, wpb=3483.320, bsz=143.541, num_updates=75447, lr=0.000115127, gnorm=0.924, clip=0.000, oom=0.000, wall=16431, train_wall=44572
# | epoch 067:    900 / 1131 loss=3.176, nll_loss=1.660, ppl=3.16, wps=5791, ups=2, wpb=3480.265, bsz=143.679, num_updates=75547, lr=0.000115051, gnorm=0.927, clip=0.000, oom=0.000, wall=16492, train_wall=44632
# | epoch 067:   1000 / 1131 loss=3.181, nll_loss=1.665, ppl=3.17, wps=5798, ups=2, wpb=3482.611, bsz=142.169, num_updates=75647, lr=0.000114975, gnorm=0.928, clip=0.000, oom=0.000, wall=16551, train_wall=44691
# | epoch 067:   1100 / 1131 loss=3.182, nll_loss=1.667, ppl=3.17, wps=5802, ups=2, wpb=3487.232, bsz=141.827, num_updates=75747, lr=0.000114899, gnorm=0.927, clip=0.000, oom=0.000, wall=16612, train_wall=44751
# | epoch 067 | loss 3.185 | nll_loss 1.670 | ppl 3.18 | wps 5810 | ups 2 | wpb 3491.701 | bsz 141.679 | num_updates 75777 | lr 0.000114877 | gnorm 0.926 | clip 0.000 | oom 0.000 | wall 16630 | train_wall 44769
# | epoch 067 | valid on 'valid' subset | loss 3.899 | nll_loss 2.336 | ppl 5.05 | num_updates 75777 | best_loss 3.88226
# | saved checkpoint /content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint67.pt (epoch 67 @ 75777 updates) (writing took 4.8422462940216064 seconds)
# | epoch 068:    100 / 1131 loss=3.127, nll_loss=1.603, ppl=3.04, wps=5765, ups=2, wpb=3507.228, bsz=147.871, num_updates=75878, lr=0.0001148, gnorm=0.913, clip=0.000, oom=0.000, wall=16708, train_wall=44830
# | epoch 068:    200 / 1131 loss=3.136, nll_loss=1.613, ppl=3.06, wps=5774, ups=2, wpb=3483.338, bsz=149.368, num_updates=75978, lr=0.000114724, gnorm=0.920, clip=0.000, oom=0.000, wall=16768, train_wall=44889
# | epoch 068:    300 / 1131 loss=3.146, nll_loss=1.624, ppl=3.08, wps=5761, ups=2, wpb=3460.973, bsz=144.980, num_updates=76078, lr=0.000114649, gnorm=0.927, clip=0.000, oom=0.000, wall=16827, train_wall=44948
# | epoch 068:    400 / 1131 loss=3.151, nll_loss=1.630, ppl=3.10, wps=5783, ups=2, wpb=3471.606, bsz=143.020, num_updates=76178, lr=0.000114574, gnorm=0.926, clip=0.000, oom=0.000, wall=16887, train_wall=45007
# | epoch 068:    500 / 1131 loss=3.155, nll_loss=1.635, ppl=3.11, wps=5786, ups=2, wpb=3466.351, bsz=144.014, num_updates=76278, lr=0.000114499, gnorm=0.929, clip=0.000, oom=0.000, wall=16946, train_wall=45066
# | epoch 068:    600 / 1131 loss=3.163, nll_loss=1.644, ppl=3.13, wps=5797, ups=2, wpb=3470.925, bsz=142.374, num_updates=76378, lr=0.000114424, gnorm=0.930, clip=0.000, oom=0.000, wall=17006, train_wall=45125
# | epoch 068:    700 / 1131 loss=3.163, nll_loss=1.644, ppl=3.13, wps=5798, ups=2, wpb=3472.773, bsz=143.542, num_updates=76478, lr=0.000114349, gnorm=0.929, clip=0.000, oom=0.000, wall=17066, train_wall=45185
# | epoch 068:    800 / 1131 loss=3.164, nll_loss=1.645, ppl=3.13, wps=5801, ups=2, wpb=3477.159, bsz=144.079, num_updates=76578, lr=0.000114274, gnorm=0.928, clip=0.000, oom=0.000, wall=17126, train_wall=45245
# | epoch 068:    900 / 1131 loss=3.169, nll_loss=1.651, ppl=3.14, wps=5813, ups=2, wpb=3485.371, bsz=144.168, num_updates=76678, lr=0.0001142, gnorm=0.927, clip=0.000, oom=0.000, wall=17187, train_wall=45304
# | epoch 068:   1000 / 1131 loss=3.175, nll_loss=1.658, ppl=3.16, wps=5821, ups=2, wpb=3489.949, bsz=141.865, num_updates=76778, lr=0.000114125, gnorm=0.929, clip=0.000, oom=0.000, wall=17246, train_wall=45364
# | epoch 068:   1100 / 1131 loss=3.177, nll_loss=1.661, ppl=3.16, wps=5824, ups=2, wpb=3492.989, bsz=142.037, num_updates=76878, lr=0.000114051, gnorm=0.930, clip=0.000, oom=0.000, wall=17307, train_wall=45423
# | epoch 068 | loss 3.178 | nll_loss 1.662 | ppl 3.16 | wps 5822 | ups 2 | wpb 3491.701 | bsz 141.679 | num_updates 76908 | lr 0.000114029 | gnorm 0.931 | clip 0.000 | oom 0.000 | wall 17325 | train_wall 45441
# | epoch 068 | valid on 'valid' subset | loss 3.900 | nll_loss 2.333 | ppl 5.04 | num_updates 76908 | best_loss 3.88226
# | saved checkpoint /content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint68.pt (epoch 68 @ 76908 updates) (writing took 5.500203609466553 seconds)
# | epoch 069:    100 / 1131 loss=3.172, nll_loss=1.650, ppl=3.14, wps=5742, ups=2, wpb=3466.881, bsz=113.505, num_updates=77009, lr=0.000113954, gnorm=0.946, clip=0.000, oom=0.000, wall=17403, train_wall=45501
# | epoch 069:    200 / 1131 loss=3.137, nll_loss=1.614, ppl=3.06, wps=5823, ups=2, wpb=3514.786, bsz=141.095, num_updates=77109, lr=0.00011388, gnorm=0.911, clip=0.000, oom=0.000, wall=17463, train_wall=45561
# | epoch 069:    300 / 1131 loss=3.142, nll_loss=1.620, ppl=3.07, wps=5826, ups=2, wpb=3505.093, bsz=143.096, num_updates=77209, lr=0.000113806, gnorm=0.914, clip=0.000, oom=0.000, wall=17523, train_wall=45621
# | epoch 069:    400 / 1131 loss=3.145, nll_loss=1.623, ppl=3.08, wps=5823, ups=2, wpb=3495.387, bsz=139.551, num_updates=77309, lr=0.000113733, gnorm=0.923, clip=0.000, oom=0.000, wall=17583, train_wall=45680
# | epoch 069:    500 / 1131 loss=3.148, nll_loss=1.627, ppl=3.09, wps=5812, ups=2, wpb=3483.715, bsz=141.589, num_updates=77409, lr=0.000113659, gnorm=0.925, clip=0.000, oom=0.000, wall=17642, train_wall=45739
# | epoch 069:    600 / 1131 loss=3.153, nll_loss=1.633, ppl=3.10, wps=5820, ups=2, wpb=3489.015, bsz=141.511, num_updates=77509, lr=0.000113586, gnorm=0.925, clip=0.000, oom=0.000, wall=17702, train_wall=45798
# | epoch 069:    700 / 1131 loss=3.159, nll_loss=1.640, ppl=3.12, wps=5821, ups=2, wpb=3489.437, bsz=141.432, num_updates=77609, lr=0.000113513, gnorm=0.927, clip=0.000, oom=0.000, wall=17762, train_wall=45857
# | epoch 069:    800 / 1131 loss=3.162, nll_loss=1.643, ppl=3.12, wps=5816, ups=2, wpb=3484.283, bsz=140.654, num_updates=77709, lr=0.00011344, gnorm=0.930, clip=0.000, oom=0.000, wall=17822, train_wall=45917
# | epoch 069:    900 / 1131 loss=3.165, nll_loss=1.646, ppl=3.13, wps=5818, ups=2, wpb=3489.194, bsz=140.972, num_updates=77809, lr=0.000113367, gnorm=0.931, clip=0.000, oom=0.000, wall=17882, train_wall=45977
# | epoch 069:   1000 / 1131 loss=3.168, nll_loss=1.650, ppl=3.14, wps=5819, ups=2, wpb=3491.696, bsz=141.082, num_updates=77909, lr=0.000113294, gnorm=0.932, clip=0.000, oom=0.000, wall=17942, train_wall=46036
# | epoch 069:   1100 / 1131 loss=3.170, nll_loss=1.653, ppl=3.14, wps=5823, ups=2, wpb=3492.420, bsz=142.161, num_updates=78009, lr=0.000113221, gnorm=0.932, clip=0.000, oom=0.000, wall=18002, train_wall=46095
# | epoch 069 | loss 3.172 | nll_loss 1.655 | ppl 3.15 | wps 5823 | ups 2 | wpb 3491.701 | bsz 141.679 | num_updates 78039 | lr 0.000113199 | gnorm 0.933 | clip 0.000 | oom 0.000 | wall 18020 | train_wall 46113
# | epoch 069 | valid on 'valid' subset | loss 3.900 | nll_loss 2.333 | ppl 5.04 | num_updates 78039 | best_loss 3.88226
# | saved checkpoint /content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint69.pt (epoch 69 @ 78039 updates) (writing took 5.140950679779053 seconds)
# | epoch 070:    100 / 1131 loss=3.152, nll_loss=1.629, ppl=3.09, wps=5857, ups=2, wpb=3565.832, bsz=133.376, num_updates=78140, lr=0.000113126, gnorm=0.913, clip=0.000, oom=0.000, wall=18098, train_wall=46174
# | epoch 070:    200 / 1131 loss=3.130, nll_loss=1.607, ppl=3.05, wps=5824, ups=2, wpb=3527.905, bsz=145.706, num_updates=78240, lr=0.000113054, gnorm=0.913, clip=0.000, oom=0.000, wall=18159, train_wall=46234
# | epoch 070:    300 / 1131 loss=3.133, nll_loss=1.609, ppl=3.05, wps=5809, ups=2, wpb=3515.645, bsz=144.236, num_updates=78340, lr=0.000112982, gnorm=0.918, clip=0.000, oom=0.000, wall=18219, train_wall=46294
# | epoch 070:    400 / 1131 loss=3.137, nll_loss=1.613, ppl=3.06, wps=5791, ups=2, wpb=3488.102, bsz=142.002, num_updates=78440, lr=0.00011291, gnorm=0.929, clip=0.000, oom=0.000, wall=18278, train_wall=46353
# | epoch 070:    500 / 1131 loss=3.144, nll_loss=1.622, ppl=3.08, wps=5795, ups=2, wpb=3490.705, bsz=139.463, num_updates=78540, lr=0.000112838, gnorm=0.930, clip=0.000, oom=0.000, wall=18339, train_wall=46412
# | epoch 070:    600 / 1131 loss=3.149, nll_loss=1.628, ppl=3.09, wps=5794, ups=2, wpb=3487.532, bsz=138.621, num_updates=78640, lr=0.000112766, gnorm=0.931, clip=0.000, oom=0.000, wall=18399, train_wall=46472
# | epoch 070:    700 / 1131 loss=3.152, nll_loss=1.631, ppl=3.10, wps=5794, ups=2, wpb=3487.160, bsz=140.609, num_updates=78740, lr=0.000112694, gnorm=0.931, clip=0.000, oom=0.000, wall=18459, train_wall=46531
# | epoch 070:    800 / 1131 loss=3.156, nll_loss=1.636, ppl=3.11, wps=5800, ups=2, wpb=3488.996, bsz=140.213, num_updates=78840, lr=0.000112623, gnorm=0.933, clip=0.000, oom=0.000, wall=18519, train_wall=46591
# | epoch 070:    900 / 1131 loss=3.157, nll_loss=1.637, ppl=3.11, wps=5793, ups=2, wpb=3485.284, bsz=140.891, num_updates=78940, lr=0.000112552, gnorm=0.934, clip=0.000, oom=0.000, wall=18579, train_wall=46650
# | epoch 070:   1000 / 1131 loss=3.160, nll_loss=1.641, ppl=3.12, wps=5794, ups=2, wpb=3483.398, bsz=141.649, num_updates=79040, lr=0.00011248, gnorm=0.935, clip=0.000, oom=0.000, wall=18639, train_wall=46710
# | epoch 070:   1100 / 1131 loss=3.166, nll_loss=1.647, ppl=3.13, wps=5803, ups=2, wpb=3488.809, bsz=141.194, num_updates=79140, lr=0.000112409, gnorm=0.936, clip=0.000, oom=0.000, wall=18699, train_wall=46769
# | epoch 070 | loss 3.165 | nll_loss 1.647 | ppl 3.13 | wps 5805 | ups 2 | wpb 3491.701 | bsz 141.679 | num_updates 79170 | lr 0.000112388 | gnorm 0.935 | clip 0.000 | oom 0.000 | wall 18717 | train_wall 46787
# | epoch 070 | valid on 'valid' subset | loss 3.897 | nll_loss 2.332 | ppl 5.04 | num_updates 79170 | best_loss 3.88226
# | saved checkpoint /content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint70.pt (epoch 70 @ 79170 updates) (writing took 5.495676279067993 seconds)
# | epoch 071:    100 / 1131 loss=3.159, nll_loss=1.638, ppl=3.11, wps=5839, ups=2, wpb=3532.198, bsz=123.802, num_updates=79271, lr=0.000112316, gnorm=0.928, clip=0.000, oom=0.000, wall=18795, train_wall=46848
# | epoch 071:    200 / 1131 loss=3.153, nll_loss=1.629, ppl=3.09, wps=5811, ups=2, wpb=3508.274, bsz=125.413, num_updates=79371, lr=0.000112246, gnorm=0.934, clip=0.000, oom=0.000, wall=18856, train_wall=46908
# | epoch 071:    300 / 1131 loss=3.140, nll_loss=1.616, ppl=3.06, wps=5807, ups=2, wpb=3499.458, bsz=133.100, num_updates=79471, lr=0.000112175, gnorm=0.930, clip=0.000, oom=0.000, wall=18916, train_wall=46967
# | epoch 071:    400 / 1131 loss=3.146, nll_loss=1.624, ppl=3.08, wps=5813, ups=2, wpb=3499.095, bsz=133.364, num_updates=79571, lr=0.000112104, gnorm=0.931, clip=0.000, oom=0.000, wall=18976, train_wall=47027
# | epoch 071:    500 / 1131 loss=3.141, nll_loss=1.618, ppl=3.07, wps=5802, ups=2, wpb=3493.263, bsz=136.317, num_updates=79671, lr=0.000112034, gnorm=0.930, clip=0.000, oom=0.000, wall=19036, train_wall=47087
# | epoch 071:    600 / 1131 loss=3.143, nll_loss=1.621, ppl=3.07, wps=5803, ups=2, wpb=3488.458, bsz=136.730, num_updates=79771, lr=0.000111964, gnorm=0.933, clip=0.000, oom=0.000, wall=19096, train_wall=47146
# | epoch 071:    700 / 1131 loss=3.149, nll_loss=1.628, ppl=3.09, wps=5814, ups=2, wpb=3494.026, bsz=136.775, num_updates=79871, lr=0.000111894, gnorm=0.934, clip=0.000, oom=0.000, wall=19156, train_wall=47205
# | epoch 071:    800 / 1131 loss=3.151, nll_loss=1.630, ppl=3.10, wps=5809, ups=2, wpb=3489.373, bsz=137.557, num_updates=79971, lr=0.000111824, gnorm=0.936, clip=0.000, oom=0.000, wall=19215, train_wall=47265
# | epoch 071 | loss 3.152 | nll_loss 1.631 | ppl 3.10 | wps 5808 | ups 2 | wpb 3488.035 | bsz 138.630 | num_updates 80000 | lr 0.000111803 | gnorm 0.936 | clip 0.000 | oom 0.000 | wall 19233 | train_wall 47282
# | epoch 071 | valid on 'valid' subset | loss 3.906 | nll_loss 2.339 | ppl 5.06 | num_updates 80000 | best_loss 3.88226
# | saved checkpoint /content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint_last.pt (epoch 71 @ 80000 updates) (writing took 2.4644997119903564 seconds)
# | done training in 19245.1 seconds

# %%
# !python scripts/average_checkpoints.py --inputs "{SAVE}" \
    --num-epoch-checkpoints 10 --output "{SAVE}/checkpoint_last10_avg.pt"

# Evaluation
# !CUDA_VISIBLE_DEVICES=0 fairseq-generate data-bin/iwslt14.tokenized.de-en --path "{SAVE}/checkpoint_last10_avg.pt" --batch-size 128 --beam 4 --remove-bpe --lenpen 1 --gen-subset test --quiet
# Out:
# Namespace(checkpoint_upper_bound=None, inputs=['/content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt'], num_epoch_checkpoints=10, num_update_checkpoints=None, output='/content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint_last10_avg.pt')
# averaging checkpoints:  ['/content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint70.pt', '/content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint69.pt', '/content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint68.pt', '/content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint67.pt', '/content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint66.pt', '/content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint65.pt', '/content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint64.pt', '/content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint63.pt', '/content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint62.pt', '/content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint61.pt']
# Finished writing averaged checkpoint to /content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint_last10_avg.pt.
# Namespace(beam=4, bpe=None, cpu=False, criterion='cross_entropy', data='data-bin/iwslt14.tokenized.de-en', dataset_impl=None, decoding_format=None, diverse_beam_groups=-1, diverse_beam_strength=0.5, empty_cache_freq=0, force_anneal=None, fp16=False, fp16_init_scale=128, fp16_scale_tolerance=0.0, fp16_scale_window=None, gen_subset='test', iter_decode_eos_penalty=0.0, iter_decode_force_max_iter=False, iter_decode_max_iter=10, lazy_load=False, left_pad_source='True', left_pad_target='False', lenpen=1.0, load_alignments=False, log_format=None, log_interval=1000, lr_scheduler='fixed', lr_shrink=0.1, match_source_len=False, max_len_a=0, max_len_b=200, max_sentences=128, max_source_positions=1024, max_target_positions=1024, max_tokens=None, memory_efficient_fp16=False, min_len=1, min_loss_scale=0.0001, model_overrides='{}', momentum=0.99, nbest=1, no_beamable_mm=False, no_early_stop=False, no_progress_bar=False, no_repeat_ngram_size=0, num_shards=1, num_workers=1, optimizer='nag', path='/content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint_last10_avg.pt', prefix_size=0, print_alignment=False, print_step=False, quiet=True, raw_text=False, remove_bpe='@@ ', replace_unk=None, required_batch_size_multiple=8, results_path=None, sacrebleu=False, sampling=False, sampling_topk=-1, sampling_topp=-1.0, score_reference=False, seed=1, shard_id=0, skip_invalid_size_inputs_valid_test=False, source_lang=None, target_lang=None, task='translation', tbmf_wrapper=False, temperature=1.0, tensorboard_logdir='', threshold_loss_scale=None, tokenizer=None, unkpen=0, unnormalized=False, upsample_primary=1, user_dir=None, warmup_updates=0, weight_decay=0.0)
# | [de] dictionary: 8848 types
# | [en] dictionary: 6632 types
# | loaded 6750 examples from: data-bin/iwslt14.tokenized.de-en/test.de-en.de
# | loaded 6750 examples from: data-bin/iwslt14.tokenized.de-en/test.de-en.en
# | data-bin/iwslt14.tokenized.de-en test de-en 6750 examples
# | loading model(s) from /content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint_last10_avg.pt
# | Translated 6750 sentences (149022 tokens) in 74.4s (90.73 sentences/s, 2002.97 tokens/s)
# | Generate test with beam=4: BLEU4 = 35.44, 69.4/43.9/29.8/20.7 (BP=0.958, ratio=0.958, syslen=125712, reflen=131161)

# %%
# Evaluation
# !CUDA_VISIBLE_DEVICES=0 fairseq-generate data-bin/iwslt14.tokenized.de-en --path "{SAVE}/checkpoint_best.pt" --batch-size 128 --beam 4 --remove-bpe --lenpen 1 --gen-subset test --quiet
# Out:
# Namespace(beam=4, bpe=None, cpu=False, criterion='cross_entropy', data='data-bin/iwslt14.tokenized.de-en', dataset_impl=None, decoding_format=None, diverse_beam_groups=-1, diverse_beam_strength=0.5, empty_cache_freq=0, force_anneal=None, fp16=False, fp16_init_scale=128, fp16_scale_tolerance=0.0, fp16_scale_window=None, gen_subset='test', iter_decode_eos_penalty=0.0, iter_decode_force_max_iter=False, iter_decode_max_iter=10, lazy_load=False, left_pad_source='True', left_pad_target='False', lenpen=1.0, load_alignments=False, log_format=None, log_interval=1000, lr_scheduler='fixed', lr_shrink=0.1, match_source_len=False, max_len_a=0, max_len_b=200, max_sentences=128, max_source_positions=1024, max_target_positions=1024, max_tokens=None, memory_efficient_fp16=False, min_len=1, min_loss_scale=0.0001, model_overrides='{}', momentum=0.99, nbest=1, no_beamable_mm=False, no_early_stop=False, no_progress_bar=False, no_repeat_ngram_size=0, num_shards=1, num_workers=1, optimizer='nag', path='/content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint_best.pt', prefix_size=0, print_alignment=False, print_step=False, quiet=True, raw_text=False, remove_bpe='@@ ', replace_unk=None, required_batch_size_multiple=8, results_path=None, sacrebleu=False, sampling=False, sampling_topk=-1, sampling_topp=-1.0, score_reference=False, seed=1, shard_id=0, skip_invalid_size_inputs_valid_test=False, source_lang=None, target_lang=None, task='translation', tbmf_wrapper=False, temperature=1.0, tensorboard_logdir='', threshold_loss_scale=None, tokenizer=None, unkpen=0, unnormalized=False, upsample_primary=1, user_dir=None, warmup_updates=0, weight_decay=0.0)
# | [de] dictionary: 8848 types
# | [en] dictionary: 6632 types
# | loaded 6750 examples from: data-bin/iwslt14.tokenized.de-en/test.de-en.de
# | loaded 6750 examples from: data-bin/iwslt14.tokenized.de-en/test.de-en.en
# | data-bin/iwslt14.tokenized.de-en test de-en 6750 examples
# | loading model(s) from /content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint_best.pt
# | Translated 6750 sentences (149187 tokens) in 74.3s (90.90 sentences/s, 2009.03 tokens/s)
# | Generate test with beam=4: BLEU4 = 34.93, 68.9/43.3/29.3/20.1 (BP=0.959, ratio=0.960, syslen=125917, reflen=131161)
