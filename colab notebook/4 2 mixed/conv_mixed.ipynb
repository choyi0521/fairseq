# %%
from google.colab import drive
drive.mount('/content/gdrive')

# To install fairseq from source and develop locally:
# !git clone https://github.com/choyi0521/fairseq
# %cd /content/fairseq
# !pip install --editable .
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive
# Cloning into 'fairseq'...
# remote: Enumerating objects: 12164, done.
# remote: Total 12164 (delta 0), reused 0 (delta 0), pack-reused 12164
# Receiving objects: 100% (12164/12164), 5.69 MiB | 7.40 MiB/s, done.
# Resolving deltas: 100% (8955/8955), done.
# /content/fairseq
# Obtaining file:///content/fairseq
# Requirement already satisfied: cffi in /usr/local/lib/python3.6/dist-packages (from fairseq==0.8.0) (1.13.2)
# Requirement already satisfied: cython in /usr/local/lib/python3.6/dist-packages (from fairseq==0.8.0) (0.29.14)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from fairseq==0.8.0) (1.17.4)
# Collecting regex
#   Downloading https://files.pythonhosted.org/packages/e3/8e/cbf2295643d7265e7883326fb4654e643bfc93b3a8a8274d8010a39d8804/regex-2019.11.1-cp36-cp36m-manylinux1_x86_64.whl (643kB)
#      |████████████████████████████████| 645kB 6.4MB/s
# Collecting sacrebleu
#   Downloading https://files.pythonhosted.org/packages/0e/e5/93d252182f7cbd4b59bb3ec5797e2ce33cfd6f5aadaf327db170cf4b7887/sacrebleu-1.4.2-py3-none-any.whl
# Requirement already satisfied: torch in /usr/local/lib/python3.6/dist-packages (from fairseq==0.8.0) (1.3.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from fairseq==0.8.0) (4.28.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.6/dist-packages (from cffi->fairseq==0.8.0) (2.19)
# Requirement already satisfied: typing in /usr/local/lib/python3.6/dist-packages (from sacrebleu->fairseq==0.8.0) (3.6.6)
# Collecting portalocker
#   Downloading https://files.pythonhosted.org/packages/91/db/7bc703c0760df726839e0699b7f78a4d8217fdc9c7fcb1b51b39c5a22a4e/portalocker-1.5.2-py2.py3-none-any.whl
# Installing collected packages: regex, portalocker, sacrebleu, fairseq
#   Running setup.py develop for fairseq
# Successfully installed fairseq portalocker-1.5.2 regex-2019.11.1 sacrebleu-1.4.2

# %%
# !git checkout dev4
# !git pull origin dev4
# Out:
# Branch 'dev4' set up to track remote branch 'dev4' from 'origin'.
# Switched to a new branch 'dev4'
# From https://github.com/choyi0521/fairseq
#  * branch            dev4       -> FETCH_HEAD
# Already up to date.

# %%
# Download and prepare the data
# %cd /content/fairseq
# %cd examples/translation/
# !bash prepare-iwslt14.sh
# %cd ../..

# Preprocess/binarize the data
TEXT="examples/translation/iwslt14.tokenized.de-en"
# !fairseq-preprocess --source-lang de --target-lang en \
    --trainpref $TEXT/train --validpref $TEXT/valid --testpref $TEXT/test \
    --destdir data-bin/iwslt14.tokenized.de-en \
    --workers 20
# Out:
# /content/fairseq
# /content/fairseq/examples/translation
# Cloning Moses github repository (for tokenization scripts)...
# Cloning into 'mosesdecoder'...
# remote: Enumerating objects: 169, done.
# remote: Counting objects: 100% (169/169), done.
# remote: Compressing objects: 100% (89/89), done.
# remote: Total 147464 (delta 104), reused 118 (delta 74), pack-reused 147295
# Receiving objects: 100% (147464/147464), 129.73 MiB | 19.08 MiB/s, done.
# Resolving deltas: 100% (113938/113938), done.
# Cloning Subword NMT repository (for BPE pre-processing)...
# Cloning into 'subword-nmt'...
# remote: Enumerating objects: 29, done.
# remote: Counting objects: 100% (29/29), done.
# remote: Compressing objects: 100% (22/22), done.
# remote: Total 538 (delta 10), reused 21 (delta 7), pack-reused 509
# Receiving objects: 100% (538/538), 226.98 KiB | 873.00 KiB/s, done.
# Resolving deltas: 100% (316/316), done.
# Downloading data from https://wit3.fbk.eu/archive/2014-01/texts/de/en/de-en.tgz...
# --2019-11-26 14:26:43--  https://wit3.fbk.eu/archive/2014-01/texts/de/en/de-en.tgz
# Resolving wit3.fbk.eu (wit3.fbk.eu)... 217.77.80.8
# Connecting to wit3.fbk.eu (wit3.fbk.eu)|217.77.80.8|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 19982877 (19M) [application/x-gzip]
# Saving to: ‘de-en.tgz’
#
# de-en.tgz           100%[===================>]  19.06M  34.6MB/s    in 0.6s
#
# 2019-11-26 14:26:43 (34.6 MB/s) - ‘de-en.tgz’ saved [19982877/19982877]
#
# Data successfully downloaded.
# de-en/
# de-en/IWSLT14.TED.dev2010.de-en.de.xml
# de-en/IWSLT14.TED.dev2010.de-en.en.xml
# de-en/IWSLT14.TED.tst2010.de-en.de.xml
# de-en/IWSLT14.TED.tst2010.de-en.en.xml
# de-en/IWSLT14.TED.tst2011.de-en.de.xml
# de-en/IWSLT14.TED.tst2011.de-en.en.xml
# de-en/IWSLT14.TED.tst2012.de-en.de.xml
# de-en/IWSLT14.TED.tst2012.de-en.en.xml
# de-en/IWSLT14.TEDX.dev2012.de-en.de.xml
# de-en/IWSLT14.TEDX.dev2012.de-en.en.xml
# de-en/README
# de-en/train.en
# de-en/train.tags.de-en.de
# de-en/train.tags.de-en.en
# pre-processing train data...
# Tokenizer Version 1.1
# Language: de
# Number of threads: 8
#
# Tokenizer Version 1.1
# Language: en
# Number of threads: 8
#
# clean-corpus.perl: processing iwslt14.tokenized.de-en/tmp/train.tags.de-en.tok.de & .en to iwslt14.tokenized.de-en/tmp/train.tags.de-en.clean, cutoff 1-175, ratio 1.5
# ..........(100000).......
# Input sentences: 174443  Output sentences:  167522
# pre-processing valid/test data...
# orig/de-en/IWSLT14.TED.dev2010.de-en.de.xml iwslt14.tokenized.de-en/tmp/IWSLT14.TED.dev2010.de-en.de
# Tokenizer Version 1.1
# Language: de
# Number of threads: 8
#
# orig/de-en/IWSLT14.TED.tst2010.de-en.de.xml iwslt14.tokenized.de-en/tmp/IWSLT14.TED.tst2010.de-en.de
# Tokenizer Version 1.1
# Language: de
# Number of threads: 8
#
# orig/de-en/IWSLT14.TED.tst2011.de-en.de.xml iwslt14.tokenized.de-en/tmp/IWSLT14.TED.tst2011.de-en.de
# Tokenizer Version 1.1
# Language: de
# Number of threads: 8
#
# orig/de-en/IWSLT14.TED.tst2012.de-en.de.xml iwslt14.tokenized.de-en/tmp/IWSLT14.TED.tst2012.de-en.de
# Tokenizer Version 1.1
# Language: de
# Number of threads: 8
#
# orig/de-en/IWSLT14.TEDX.dev2012.de-en.de.xml iwslt14.tokenized.de-en/tmp/IWSLT14.TEDX.dev2012.de-en.de
# Tokenizer Version 1.1
# Language: de
# Number of threads: 8
#
# orig/de-en/IWSLT14.TED.dev2010.de-en.en.xml iwslt14.tokenized.de-en/tmp/IWSLT14.TED.dev2010.de-en.en
# Tokenizer Version 1.1
# Language: en
# Number of threads: 8
#
# orig/de-en/IWSLT14.TED.tst2010.de-en.en.xml iwslt14.tokenized.de-en/tmp/IWSLT14.TED.tst2010.de-en.en
# Tokenizer Version 1.1
# Language: en
# Number of threads: 8
#
# orig/de-en/IWSLT14.TED.tst2011.de-en.en.xml iwslt14.tokenized.de-en/tmp/IWSLT14.TED.tst2011.de-en.en
# Tokenizer Version 1.1
# Language: en
# Number of threads: 8
#
# orig/de-en/IWSLT14.TED.tst2012.de-en.en.xml iwslt14.tokenized.de-en/tmp/IWSLT14.TED.tst2012.de-en.en
# Tokenizer Version 1.1
# Language: en
# Number of threads: 8
#
# orig/de-en/IWSLT14.TEDX.dev2012.de-en.en.xml iwslt14.tokenized.de-en/tmp/IWSLT14.TEDX.dev2012.de-en.en
# Tokenizer Version 1.1
# Language: en
# Number of threads: 8
#
# creating train, valid, test...
# learn_bpe.py on iwslt14.tokenized.de-en/tmp/train.en-de...
# subword-nmt/learn_bpe.py:267: DeprecationWarning: this script's location has moved to /content/fairseq/examples/translation/subword-nmt/subword_nmt. This symbolic link will be removed in a future version. Please point to the new location, or install the package and use the command 'subword-nmt'
#   DeprecationWarning
# apply_bpe.py to train.de...
# subword-nmt/apply_bpe.py:328: DeprecationWarning: this script's location has moved to /content/fairseq/examples/translation/subword-nmt/subword_nmt. This symbolic link will be removed in a future version. Please point to the new location, or install the package and use the command 'subword-nmt'
#   DeprecationWarning
# subword-nmt/apply_bpe.py:345: ResourceWarning: unclosed file <_io.TextIOWrapper name='iwslt14.tokenized.de-en/code' mode='r' encoding='UTF-8'>
#   args.codes = codecs.open(args.codes.name, encoding='utf-8')
# apply_bpe.py to valid.de...
# subword-nmt/apply_bpe.py:328: DeprecationWarning: this script's location has moved to /content/fairseq/examples/translation/subword-nmt/subword_nmt. This symbolic link will be removed in a future version. Please point to the new location, or install the package and use the command 'subword-nmt'
#   DeprecationWarning
# subword-nmt/apply_bpe.py:345: ResourceWarning: unclosed file <_io.TextIOWrapper name='iwslt14.tokenized.de-en/code' mode='r' encoding='UTF-8'>
#   args.codes = codecs.open(args.codes.name, encoding='utf-8')
# apply_bpe.py to test.de...
# subword-nmt/apply_bpe.py:328: DeprecationWarning: this script's location has moved to /content/fairseq/examples/translation/subword-nmt/subword_nmt. This symbolic link will be removed in a future version. Please point to the new location, or install the package and use the command 'subword-nmt'
#   DeprecationWarning
# subword-nmt/apply_bpe.py:345: ResourceWarning: unclosed file <_io.TextIOWrapper name='iwslt14.tokenized.de-en/code' mode='r' encoding='UTF-8'>
#   args.codes = codecs.open(args.codes.name, encoding='utf-8')
# apply_bpe.py to train.en...
# subword-nmt/apply_bpe.py:328: DeprecationWarning: this script's location has moved to /content/fairseq/examples/translation/subword-nmt/subword_nmt. This symbolic link will be removed in a future version. Please point to the new location, or install the package and use the command 'subword-nmt'
#   DeprecationWarning
# subword-nmt/apply_bpe.py:345: ResourceWarning: unclosed file <_io.TextIOWrapper name='iwslt14.tokenized.de-en/code' mode='r' encoding='UTF-8'>
#   args.codes = codecs.open(args.codes.name, encoding='utf-8')
# apply_bpe.py to valid.en...
# subword-nmt/apply_bpe.py:328: DeprecationWarning: this script's location has moved to /content/fairseq/examples/translation/subword-nmt/subword_nmt. This symbolic link will be removed in a future version. Please point to the new location, or install the package and use the command 'subword-nmt'
#   DeprecationWarning
# subword-nmt/apply_bpe.py:345: ResourceWarning: unclosed file <_io.TextIOWrapper name='iwslt14.tokenized.de-en/code' mode='r' encoding='UTF-8'>
#   args.codes = codecs.open(args.codes.name, encoding='utf-8')
# apply_bpe.py to test.en...
# subword-nmt/apply_bpe.py:328: DeprecationWarning: this script's location has moved to /content/fairseq/examples/translation/subword-nmt/subword_nmt. This symbolic link will be removed in a future version. Please point to the new location, or install the package and use the command 'subword-nmt'
#   DeprecationWarning
# subword-nmt/apply_bpe.py:345: ResourceWarning: unclosed file <_io.TextIOWrapper name='iwslt14.tokenized.de-en/code' mode='r' encoding='UTF-8'>
#   args.codes = codecs.open(args.codes.name, encoding='utf-8')
# /content/fairseq
# Namespace(align_suffix=None, alignfile=None, bpe=None, cpu=False, criterion='cross_entropy', dataset_impl='mmap', destdir='data-bin/iwslt14.tokenized.de-en', empty_cache_freq=0, fp16=False, fp16_init_scale=128, fp16_scale_tolerance=0.0, fp16_scale_window=None, joined_dictionary=False, log_format=None, log_interval=1000, lr_scheduler='fixed', memory_efficient_fp16=False, min_loss_scale=0.0001, no_progress_bar=False, nwordssrc=-1, nwordstgt=-1, only_source=False, optimizer='nag', padding_factor=8, seed=1, source_lang='de', srcdict=None, target_lang='en', task='translation', tbmf_wrapper=False, tensorboard_logdir='', testpref='examples/translation/iwslt14.tokenized.de-en/test', tgtdict=None, threshold_loss_scale=None, thresholdsrc=0, thresholdtgt=0, tokenizer=None, trainpref='examples/translation/iwslt14.tokenized.de-en/train', user_dir=None, validpref='examples/translation/iwslt14.tokenized.de-en/valid', workers=20)
# | [de] Dictionary: 8847 types
# | [de] examples/translation/iwslt14.tokenized.de-en/train.de: 160239 sents, 4035591 tokens, 0.0% replaced by <unk>
# | [de] Dictionary: 8847 types
# | [de] examples/translation/iwslt14.tokenized.de-en/valid.de: 7283 sents, 182592 tokens, 0.0192% replaced by <unk>
# | [de] Dictionary: 8847 types
# | [de] examples/translation/iwslt14.tokenized.de-en/test.de: 6750 sents, 161838 tokens, 0.0636% replaced by <unk>
# | [en] Dictionary: 6631 types
# | [en] examples/translation/iwslt14.tokenized.de-en/train.en: 160239 sents, 3949114 tokens, 0.0% replaced by <unk>
# | [en] Dictionary: 6631 types
# | [en] examples/translation/iwslt14.tokenized.de-en/valid.en: 7283 sents, 178622 tokens, 0.00448% replaced by <unk>
# | [en] Dictionary: 6631 types
# | [en] examples/translation/iwslt14.tokenized.de-en/test.en: 6750 sents, 156928 tokens, 0.00892% replaced by <unk>
# | Wrote preprocessed data to data-bin/iwslt14.tokenized.de-en

# %%
SAVE="/content/gdrive/My Drive/colab/payless/save_dev4/dynamic_conv_iwslt"

# Training
# %cd /content/fairseq
# !mkdir -p "{SAVE}" 
# !CUDA_VISIBLE_DEVICES=0 $(which fairseq-train) data-bin/iwslt14.tokenized.de-en \
    --encoder-conv-type ddynamic --decoder-conv-type ddynamic \
    --clip-norm 0 --optimizer adam --lr 0.0005 \
    --source-lang de --target-lang en --max-tokens 4000 --no-progress-bar \
    --log-interval 100 --min-lr '1e-09' --weight-decay 0.0001 \
    --criterion label_smoothed_cross_entropy --label-smoothing 0.1 \
    --lr-scheduler inverse_sqrt \
    --ddp-backend=no_c10d \
    --max-update 50000 --warmup-updates 4000 --warmup-init-lr '1e-07' \
    --adam-betas '(0.9, 0.98)' --keep-last-epochs 10 \
    -a lightconv_iwslt_de_en --save-dir "{SAVE}" \
    --dropout 0.3 --attention-dropout 0.1 --weight-dropout 0.1 \
    --encoder-glu 1 --decoder-glu 1 \
    --conv-mixed 1 \
    --encoder-attention-heads 4 --decoder-attention-heads 4 \
    --encoder-attention-proj-heads 2 --decoder-attention-proj-heads 2 \
    --encoder-layers 7 --encoder-kernel-size-list [3,7,15,31,31,31,31] \
    2>&1 | tee "{SAVE}/train0.log"
# Out:
# /content/fairseq
# Namespace(adam_betas='(0.9, 0.98)', adam_eps=1e-08, adaptive_softmax_cutoff=None, adaptive_softmax_dropout=0, arch='lightconv_iwslt_de_en', attention_dropout=0.1, best_checkpoint_metric='loss', bpe=None, bucket_cap_mb=25, clip_norm=0.0, conv_mixed=True, cpu=False, criterion='label_smoothed_cross_entropy', curriculum=0, data='data-bin/iwslt14.tokenized.de-en', dataset_impl=None, ddp_backend='no_c10d', decoder_attention_heads=4, decoder_attention_proj_heads=2, decoder_conv_dim=512, decoder_conv_type='ddynamic', decoder_embed_dim=512, decoder_embed_path=None, decoder_ffn_embed_dim=1024, decoder_glu=True, decoder_input_dim=512, decoder_kernel_size_list=[3, 7, 15, 31, 31, 31], decoder_layers=6, decoder_learned_pos=False, decoder_normalize_before=False, decoder_output_dim=512, device_id=0, disable_validation=False, distributed_backend='nccl', distributed_init_method=None, distributed_no_spawn=False, distributed_port=-1, distributed_rank=0, distributed_world_size=1, dropout=0.3, empty_cache_freq=0, encoder_attention_heads=4, encoder_attention_proj_heads=2, encoder_conv_dim=512, encoder_conv_type='ddynamic', encoder_embed_dim=512, encoder_embed_path=None, encoder_ffn_embed_dim=1024, encoder_glu=True, encoder_kernel_size_list=[3, 7, 15, 31, 31, 31, 31], encoder_layers=7, encoder_learned_pos=False, encoder_normalize_before=False, fast_stat_sync=False, find_unused_parameters=False, fix_batches_to_gpus=False, fixed_validation_seed=None, fp16=False, fp16_init_scale=128, fp16_scale_tolerance=0.0, fp16_scale_window=None, input_dropout=0.0, keep_interval_updates=-1, keep_last_epochs=10, label_smoothing=0.1, lazy_load=False, left_pad_source='True', left_pad_target='False', load_alignments=False, log_format=None, log_interval=100, lr=[0.0005], lr_scheduler='inverse_sqrt', max_epoch=0, max_sentences=None, max_sentences_valid=None, max_source_positions=1024, max_target_positions=1024, max_tokens=4000, max_tokens_valid=4000, max_update=50000, maximize_best_checkpoint_metric=False, memory_efficient_fp16=False, min_loss_scale=0.0001, min_lr=1e-09, no_epoch_checkpoints=False, no_last_checkpoints=False, no_progress_bar=True, no_save=False, no_save_optimizer_state=False, no_token_positional_embeddings=False, num_workers=1, optimizer='adam', optimizer_overrides='{}', raw_text=False, relu_dropout=0.0, required_batch_size_multiple=8, reset_dataloader=False, reset_lr_scheduler=False, reset_meters=False, reset_optimizer=False, restore_file='checkpoint_last.pt', save_dir='/content/gdrive/My Drive/colab/payless/save_dev4/dynamic_conv_iwslt', save_interval=1, save_interval_updates=0, seed=1, sentence_avg=False, share_all_embeddings=False, share_decoder_input_output_embed=False, skip_invalid_size_inputs_valid_test=False, source_lang='de', target_lang='en', task='translation', tbmf_wrapper=False, tensorboard_logdir='', threshold_loss_scale=None, tokenizer=None, train_subset='train', update_freq=[1], upsample_primary=1, use_bmuf=False, user_dir=None, valid_subset='valid', validate_interval=1, warmup_init_lr=1e-07, warmup_updates=4000, weight_decay=0.0001, weight_dropout=0.1, weight_softmax=True)
# | [de] dictionary: 8848 types
# | [en] dictionary: 6632 types
# | loaded 7283 examples from: data-bin/iwslt14.tokenized.de-en/valid.de-en.de
# | loaded 7283 examples from: data-bin/iwslt14.tokenized.de-en/valid.de-en.en
# | data-bin/iwslt14.tokenized.de-en valid de-en 7283 examples
# LightConvModel(
#   (encoder): LightConvEncoder(
#     (embed_tokens): Embedding(8848, 512, padding_idx=1)
#     (embed_positions): SinusoidalPositionalEmbedding()
#     (layers): ModuleList(
#       (0): LightConvEncoderLayer(
#         dropout=0.3, relu_dropout=0.0, input_dropout=0.0, normalize_before=False
#         (linear1): Linear(in_features=512, out_features=1024, bias=True)
#         (act): GLU(dim=-1)
#         (conv): DDynamicConv1dTBC(
#           512, kernel_size=3, padding_l=1, num_heads=4, num_proj_heads=2, conv_mixed=True, weight_softmax=True, conv_bias=False, renorm_padding=False, in_proj=False, weight_dropout=0.1
#           (weight_linear): Linear(in_features=256, out_features=24, bias=False)
#         )
#         (linear2): Linear(in_features=512, out_features=512, bias=True)
#         (fc1): Linear(in_features=512, out_features=1024, bias=True)
#         (fc2): Linear(in_features=1024, out_features=512, bias=True)
#         (layer_norms): ModuleList(
#           (0): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#       (1): LightConvEncoderLayer(
#         dropout=0.3, relu_dropout=0.0, input_dropout=0.0, normalize_before=False
#         (linear1): Linear(in_features=512, out_features=1024, bias=True)
#         (act): GLU(dim=-1)
#         (conv): DDynamicConv1dTBC(
#           512, kernel_size=7, padding_l=3, num_heads=4, num_proj_heads=2, conv_mixed=True, weight_softmax=True, conv_bias=False, renorm_padding=False, in_proj=False, weight_dropout=0.1
#           (weight_linear): Linear(in_features=256, out_features=56, bias=False)
#         )
#         (linear2): Linear(in_features=512, out_features=512, bias=True)
#         (fc1): Linear(in_features=512, out_features=1024, bias=True)
#         (fc2): Linear(in_features=1024, out_features=512, bias=True)
#         (layer_norms): ModuleList(
#           (0): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#       (2): LightConvEncoderLayer(
#         dropout=0.3, relu_dropout=0.0, input_dropout=0.0, normalize_before=False
#         (linear1): Linear(in_features=512, out_features=1024, bias=True)
#         (act): GLU(dim=-1)
#         (conv): DDynamicConv1dTBC(
#           512, kernel_size=15, padding_l=7, num_heads=4, num_proj_heads=2, conv_mixed=True, weight_softmax=True, conv_bias=False, renorm_padding=False, in_proj=False, weight_dropout=0.1
#           (weight_linear): Linear(in_features=256, out_features=120, bias=False)
#         )
#         (linear2): Linear(in_features=512, out_features=512, bias=True)
#         (fc1): Linear(in_features=512, out_features=1024, bias=True)
#         (fc2): Linear(in_features=1024, out_features=512, bias=True)
#         (layer_norms): ModuleList(
#           (0): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#       (3): LightConvEncoderLayer(
#         dropout=0.3, relu_dropout=0.0, input_dropout=0.0, normalize_before=False
#         (linear1): Linear(in_features=512, out_features=1024, bias=True)
#         (act): GLU(dim=-1)
#         (conv): DDynamicConv1dTBC(
#           512, kernel_size=31, padding_l=15, num_heads=4, num_proj_heads=2, conv_mixed=True, weight_softmax=True, conv_bias=False, renorm_padding=False, in_proj=False, weight_dropout=0.1
#           (weight_linear): Linear(in_features=256, out_features=248, bias=False)
#         )
#         (linear2): Linear(in_features=512, out_features=512, bias=True)
#         (fc1): Linear(in_features=512, out_features=1024, bias=True)
#         (fc2): Linear(in_features=1024, out_features=512, bias=True)
#         (layer_norms): ModuleList(
#           (0): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#       (4): LightConvEncoderLayer(
#         dropout=0.3, relu_dropout=0.0, input_dropout=0.0, normalize_before=False
#         (linear1): Linear(in_features=512, out_features=1024, bias=True)
#         (act): GLU(dim=-1)
#         (conv): DDynamicConv1dTBC(
#           512, kernel_size=31, padding_l=15, num_heads=4, num_proj_heads=2, conv_mixed=True, weight_softmax=True, conv_bias=False, renorm_padding=False, in_proj=False, weight_dropout=0.1
#           (weight_linear): Linear(in_features=256, out_features=248, bias=False)
#         )
#         (linear2): Linear(in_features=512, out_features=512, bias=True)
#         (fc1): Linear(in_features=512, out_features=1024, bias=True)
#         (fc2): Linear(in_features=1024, out_features=512, bias=True)
#         (layer_norms): ModuleList(
#           (0): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#       (5): LightConvEncoderLayer(
#         dropout=0.3, relu_dropout=0.0, input_dropout=0.0, normalize_before=False
#         (linear1): Linear(in_features=512, out_features=1024, bias=True)
#         (act): GLU(dim=-1)
#         (conv): DDynamicConv1dTBC(
#           512, kernel_size=31, padding_l=15, num_heads=4, num_proj_heads=2, conv_mixed=True, weight_softmax=True, conv_bias=False, renorm_padding=False, in_proj=False, weight_dropout=0.1
#           (weight_linear): Linear(in_features=256, out_features=248, bias=False)
#         )
#         (linear2): Linear(in_features=512, out_features=512, bias=True)
#         (fc1): Linear(in_features=512, out_features=1024, bias=True)
#         (fc2): Linear(in_features=1024, out_features=512, bias=True)
#         (layer_norms): ModuleList(
#           (0): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#       (6): LightConvEncoderLayer(
#         dropout=0.3, relu_dropout=0.0, input_dropout=0.0, normalize_before=False
#         (linear1): Linear(in_features=512, out_features=1024, bias=True)
#         (act): GLU(dim=-1)
#         (conv): DDynamicConv1dTBC(
#           512, kernel_size=31, padding_l=15, num_heads=4, num_proj_heads=2, conv_mixed=True, weight_softmax=True, conv_bias=False, renorm_padding=False, in_proj=False, weight_dropout=0.1
#           (weight_linear): Linear(in_features=256, out_features=248, bias=False)
#         )
#         (linear2): Linear(in_features=512, out_features=512, bias=True)
#         (fc1): Linear(in_features=512, out_features=1024, bias=True)
#         (fc2): Linear(in_features=1024, out_features=512, bias=True)
#         (layer_norms): ModuleList(
#           (0): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#     )
#   )
#   (decoder): LightConvDecoder(
#     (embed_tokens): Embedding(6632, 512, padding_idx=1)
#     (embed_positions): SinusoidalPositionalEmbedding()
#     (layers): ModuleList(
#       (0): LightConvDecoderLayer(
#         dropout=0.3, relu_dropout=0.0, input_dropout=0.0, normalize_before=False
#         (linear1): Linear(in_features=512, out_features=1024, bias=True)
#         (act): GLU(dim=-1)
#         (conv): DDynamicConv1dTBC(
#           512, kernel_size=3, padding_l=2, num_heads=4, num_proj_heads=2, conv_mixed=True, weight_softmax=True, conv_bias=False, renorm_padding=False, in_proj=False, weight_dropout=0.1
#           (weight_linear): Linear(in_features=256, out_features=24, bias=False)
#         )
#         (linear2): Linear(in_features=512, out_features=512, bias=True)
#         (conv_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): MultiheadAttention(
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=1024, bias=True)
#         (fc2): Linear(in_features=1024, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (1): LightConvDecoderLayer(
#         dropout=0.3, relu_dropout=0.0, input_dropout=0.0, normalize_before=False
#         (linear1): Linear(in_features=512, out_features=1024, bias=True)
#         (act): GLU(dim=-1)
#         (conv): DDynamicConv1dTBC(
#           512, kernel_size=7, padding_l=6, num_heads=4, num_proj_heads=2, conv_mixed=True, weight_softmax=True, conv_bias=False, renorm_padding=False, in_proj=False, weight_dropout=0.1
#           (weight_linear): Linear(in_features=256, out_features=56, bias=False)
#         )
#         (linear2): Linear(in_features=512, out_features=512, bias=True)
#         (conv_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): MultiheadAttention(
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=1024, bias=True)
#         (fc2): Linear(in_features=1024, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (2): LightConvDecoderLayer(
#         dropout=0.3, relu_dropout=0.0, input_dropout=0.0, normalize_before=False
#         (linear1): Linear(in_features=512, out_features=1024, bias=True)
#         (act): GLU(dim=-1)
#         (conv): DDynamicConv1dTBC(
#           512, kernel_size=15, padding_l=14, num_heads=4, num_proj_heads=2, conv_mixed=True, weight_softmax=True, conv_bias=False, renorm_padding=False, in_proj=False, weight_dropout=0.1
#           (weight_linear): Linear(in_features=256, out_features=120, bias=False)
#         )
#         (linear2): Linear(in_features=512, out_features=512, bias=True)
#         (conv_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): MultiheadAttention(
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=1024, bias=True)
#         (fc2): Linear(in_features=1024, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (3): LightConvDecoderLayer(
#         dropout=0.3, relu_dropout=0.0, input_dropout=0.0, normalize_before=False
#         (linear1): Linear(in_features=512, out_features=1024, bias=True)
#         (act): GLU(dim=-1)
#         (conv): DDynamicConv1dTBC(
#           512, kernel_size=31, padding_l=30, num_heads=4, num_proj_heads=2, conv_mixed=True, weight_softmax=True, conv_bias=False, renorm_padding=False, in_proj=False, weight_dropout=0.1
#           (weight_linear): Linear(in_features=256, out_features=248, bias=False)
#         )
#         (linear2): Linear(in_features=512, out_features=512, bias=True)
#         (conv_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): MultiheadAttention(
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=1024, bias=True)
#         (fc2): Linear(in_features=1024, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (4): LightConvDecoderLayer(
#         dropout=0.3, relu_dropout=0.0, input_dropout=0.0, normalize_before=False
#         (linear1): Linear(in_features=512, out_features=1024, bias=True)
#         (act): GLU(dim=-1)
#         (conv): DDynamicConv1dTBC(
#           512, kernel_size=31, padding_l=30, num_heads=4, num_proj_heads=2, conv_mixed=True, weight_softmax=True, conv_bias=False, renorm_padding=False, in_proj=False, weight_dropout=0.1
#           (weight_linear): Linear(in_features=256, out_features=248, bias=False)
#         )
#         (linear2): Linear(in_features=512, out_features=512, bias=True)
#         (conv_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): MultiheadAttention(
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=1024, bias=True)
#         (fc2): Linear(in_features=1024, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (5): LightConvDecoderLayer(
#         dropout=0.3, relu_dropout=0.0, input_dropout=0.0, normalize_before=False
#         (linear1): Linear(in_features=512, out_features=1024, bias=True)
#         (act): GLU(dim=-1)
#         (conv): DDynamicConv1dTBC(
#           512, kernel_size=31, padding_l=30, num_heads=4, num_proj_heads=2, conv_mixed=True, weight_softmax=True, conv_bias=False, renorm_padding=False, in_proj=False, weight_dropout=0.1
#           (weight_linear): Linear(in_features=256, out_features=248, bias=False)
#         )
#         (linear2): Linear(in_features=512, out_features=512, bias=True)
#         (conv_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): MultiheadAttention(
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=1024, bias=True)
#         (fc2): Linear(in_features=1024, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#   )
# )
# | model lightconv_iwslt_de_en, criterion LabelSmoothedCrossEntropyCriterion
# | num. model params: 42106368 (num. trained: 42099712)
# | training on 1 GPUs
# | max tokens per GPU = 4000 and max sentences per GPU = None
# | no existing checkpoint found /content/gdrive/My Drive/colab/payless/save_dev4/dynamic_conv_iwslt/checkpoint_last.pt
# | loading train data for epoch 0
# | loaded 160239 examples from: data-bin/iwslt14.tokenized.de-en/train.de-en.de
# | loaded 160239 examples from: data-bin/iwslt14.tokenized.de-en/train.de-en.en
# | data-bin/iwslt14.tokenized.de-en train de-en 160239 examples
# | epoch 001:    100 / 1131 loss=12.231, nll_loss=12.094, ppl=4371.66, wps=4887, ups=1, wpb=3503.178, bsz=123.723, num_updates=101, lr=1.27225e-05, gnorm=2.788, clip=0.000, oom=0.000, wall=74, train_wall=72
# | epoch 001:    200 / 1131 loss=11.452, nll_loss=11.220, ppl=2385.71, wps=4874, ups=1, wpb=3464.259, bsz=133.095, num_updates=201, lr=2.522e-05, gnorm=2.140, clip=0.000, oom=0.000, wall=145, train_wall=142
# | epoch 001:    300 / 1131 loss=10.937, nll_loss=10.637, ppl=1591.94, wps=4896, ups=1, wpb=3481.402, bsz=132.306, num_updates=301, lr=3.77175e-05, gnorm=1.837, clip=0.000, oom=0.000, wall=216, train_wall=213
# | epoch 001:    400 / 1131 loss=10.571, nll_loss=10.214, ppl=1188.00, wps=4916, ups=1, wpb=3496.042, bsz=134.943, num_updates=401, lr=5.0215e-05, gnorm=1.742, clip=0.000, oom=0.000, wall=287, train_wall=283
# | epoch 001:    500 / 1131 loss=10.278, nll_loss=9.874, ppl=938.14, wps=4919, ups=1, wpb=3502.858, bsz=141.395, num_updates=501, lr=6.27125e-05, gnorm=1.713, clip=0.000, oom=0.000, wall=359, train_wall=355
# | epoch 001:    600 / 1131 loss=10.069, nll_loss=9.630, ppl=792.62, wps=4911, ups=1, wpb=3490.700, bsz=141.243, num_updates=601, lr=7.521e-05, gnorm=1.655, clip=0.000, oom=0.000, wall=429, train_wall=424
# | epoch 001:    700 / 1131 loss=9.875, nll_loss=9.405, ppl=678.07, wps=4920, ups=1, wpb=3488.882, bsz=142.937, num_updates=701, lr=8.77075e-05, gnorm=1.618, clip=0.000, oom=0.000, wall=499, train_wall=494
# | epoch 001:    800 / 1131 loss=9.727, nll_loss=9.233, ppl=601.74, wps=4917, ups=1, wpb=3485.935, bsz=141.782, num_updates=801, lr=0.000100205, gnorm=1.581, clip=0.000, oom=0.000, wall=570, train_wall=564
# | epoch 001:    900 / 1131 loss=9.582, nll_loss=9.064, ppl=535.29, wps=4921, ups=1, wpb=3492.103, bsz=142.294, num_updates=901, lr=0.000112702, gnorm=1.552, clip=0.000, oom=0.000, wall=641, train_wall=635
# | epoch 001:   1000 / 1131 loss=9.458, nll_loss=8.920, ppl=484.29, wps=4919, ups=1, wpb=3490.413, bsz=142.249, num_updates=1001, lr=0.0001252, gnorm=1.518, clip=0.000, oom=0.000, wall=712, train_wall=706
# | epoch 001:   1100 / 1131 loss=9.342, nll_loss=8.786, ppl=441.32, wps=4919, ups=1, wpb=3491.418, bsz=141.870, num_updates=1101, lr=0.000137697, gnorm=1.487, clip=0.000, oom=0.000, wall=783, train_wall=776
# | epoch 001 | loss 9.310 | nll_loss 8.748 | ppl 429.90 | wps 4919 | ups 1 | wpb 3491.701 | bsz 141.679 | num_updates 1131 | lr 0.000141447 | gnorm 1.479 | clip 0.000 | oom 0.000 | wall 805 | train_wall 798
# | epoch 001 | valid on 'valid' subset | loss 7.883 | nll_loss 6.996 | ppl 127.61 | num_updates 1131
# | saved checkpoint /content/gdrive/My Drive/colab/payless/save_dev4/dynamic_conv_iwslt/checkpoint1.pt (epoch 1 @ 1131 updates) (writing took 6.622398138046265 seconds)
# | epoch 002:    100 / 1131 loss=7.950, nll_loss=7.170, ppl=143.98, wps=4928, ups=1, wpb=3517.208, bsz=135.040, num_updates=1232, lr=0.000154069, gnorm=1.138, clip=0.000, oom=0.000, wall=896, train_wall=869
# | epoch 002:    200 / 1131 loss=7.827, nll_loss=7.028, ppl=130.53, wps=4930, ups=1, wpb=3513.721, bsz=150.920, num_updates=1332, lr=0.000166567, gnorm=1.202, clip=0.000, oom=0.000, wall=967, train_wall=940
# | epoch 002:    300 / 1131 loss=7.794, nll_loss=6.990, ppl=127.13, wps=4898, ups=1, wpb=3481.591, bsz=147.585, num_updates=1432, lr=0.000179064, gnorm=1.215, clip=0.000, oom=0.000, wall=1038, train_wall=1010
# | epoch 002:    400 / 1131 loss=7.739, nll_loss=6.926, ppl=121.58, wps=4922, ups=1, wpb=3501.506, bsz=146.012, num_updates=1532, lr=0.000191562, gnorm=1.199, clip=0.000, oom=0.000, wall=1109, train_wall=1081
# | epoch 002:    500 / 1131 loss=7.688, nll_loss=6.867, ppl=116.74, wps=4926, ups=1, wpb=3497.337, bsz=143.727, num_updates=1632, lr=0.000204059, gnorm=1.193, clip=0.000, oom=0.000, wall=1180, train_wall=1151
# | epoch 002:    600 / 1131 loss=7.627, nll_loss=6.797, ppl=111.23, wps=4931, ups=1, wpb=3500.067, bsz=143.945, num_updates=1732, lr=0.000216557, gnorm=1.186, clip=0.000, oom=0.000, wall=1251, train_wall=1222
# | epoch 002:    700 / 1131 loss=7.553, nll_loss=6.712, ppl=104.84, wps=4940, ups=1, wpb=3506.722, bsz=145.151, num_updates=1832, lr=0.000229054, gnorm=1.180, clip=0.000, oom=0.000, wall=1322, train_wall=1292
# | epoch 002:    800 / 1131 loss=7.503, nll_loss=6.654, ppl=100.73, wps=4933, ups=1, wpb=3498.361, bsz=143.390, num_updates=1932, lr=0.000241552, gnorm=1.171, clip=0.000, oom=0.000, wall=1392, train_wall=1362
# | epoch 002:    900 / 1131 loss=7.443, nll_loss=6.586, ppl=96.05, wps=4932, ups=1, wpb=3495.448, bsz=143.306, num_updates=2032, lr=0.000254049, gnorm=1.162, clip=0.000, oom=0.000, wall=1463, train_wall=1432
# | epoch 002:   1000 / 1131 loss=7.386, nll_loss=6.520, ppl=91.75, wps=4934, ups=1, wpb=3496.944, bsz=142.664, num_updates=2132, lr=0.000266547, gnorm=1.156, clip=0.000, oom=0.000, wall=1534, train_wall=1503
# | epoch 002:   1100 / 1131 loss=7.328, nll_loss=6.453, ppl=87.58, wps=4930, ups=1, wpb=3492.152, bsz=142.669, num_updates=2232, lr=0.000279044, gnorm=1.147, clip=0.000, oom=0.000, wall=1604, train_wall=1572
# | epoch 002 | loss 7.314 | nll_loss 6.437 | ppl 86.65 | wps 4930 | ups 1 | wpb 3491.701 | bsz 141.679 | num_updates 2262 | lr 0.000282793 | gnorm 1.144 | clip 0.000 | oom 0.000 | wall 1625 | train_wall 1594
# | epoch 002 | valid on 'valid' subset | loss 6.382 | nll_loss 5.251 | ppl 38.08 | num_updates 2262 | best_loss 6.3816
# | saved checkpoint /content/gdrive/My Drive/colab/payless/save_dev4/dynamic_conv_iwslt/checkpoint2.pt (epoch 2 @ 2262 updates) (writing took 7.303324222564697 seconds)
# | epoch 003:    100 / 1131 loss=6.480, nll_loss=5.475, ppl=44.49, wps=4905, ups=1, wpb=3504.099, bsz=146.535, num_updates=2363, lr=0.000295416, gnorm=1.038, clip=0.000, oom=0.000, wall=1717, train_wall=1665
# | epoch 003:    200 / 1131 loss=6.511, nll_loss=5.509, ppl=45.54, wps=4911, ups=1, wpb=3486.910, bsz=136.358, num_updates=2463, lr=0.000307913, gnorm=1.051, clip=0.000, oom=0.000, wall=1788, train_wall=1735
# | epoch 003:    300 / 1131 loss=6.458, nll_loss=5.448, ppl=43.64, wps=4889, ups=1, wpb=3470.525, bsz=135.894, num_updates=2563, lr=0.000320411, gnorm=1.036, clip=0.000, oom=0.000, wall=1859, train_wall=1806
# | epoch 003:    400 / 1131 loss=6.374, nll_loss=5.351, ppl=40.81, wps=4907, ups=1, wpb=3482.204, bsz=138.813, num_updates=2663, lr=0.000332908, gnorm=1.022, clip=0.000, oom=0.000, wall=1929, train_wall=1876
# | epoch 003:    500 / 1131 loss=6.343, nll_loss=5.314, ppl=39.79, wps=4909, ups=1, wpb=3480.048, bsz=136.830, num_updates=2763, lr=0.000345406, gnorm=1.020, clip=0.000, oom=0.000, wall=2000, train_wall=1946
# | epoch 003:    600 / 1131 loss=6.286, nll_loss=5.247, ppl=37.97, wps=4919, ups=1, wpb=3482.953, bsz=138.329, num_updates=2863, lr=0.000357903, gnorm=1.015, clip=0.000, oom=0.000, wall=2070, train_wall=2016
# | epoch 003:    700 / 1131 loss=6.225, nll_loss=5.176, ppl=36.16, wps=4929, ups=1, wpb=3493.351, bsz=141.398, num_updates=2963, lr=0.000370401, gnorm=1.015, clip=0.000, oom=0.000, wall=2142, train_wall=2087
# | epoch 003:    800 / 1131 loss=6.179, nll_loss=5.122, ppl=34.83, wps=4928, ups=1, wpb=3490.936, bsz=141.353, num_updates=3063, lr=0.000382898, gnorm=1.007, clip=0.000, oom=0.000, wall=2212, train_wall=2157
# | epoch 003:    900 / 1131 loss=6.134, nll_loss=5.070, ppl=33.59, wps=4934, ups=1, wpb=3491.760, bsz=140.786, num_updates=3163, lr=0.000395396, gnorm=0.998, clip=0.000, oom=0.000, wall=2283, train_wall=2227
# | epoch 003:   1000 / 1131 loss=6.087, nll_loss=5.015, ppl=32.32, wps=4935, ups=1, wpb=3489.918, bsz=140.963, num_updates=3263, lr=0.000407893, gnorm=0.991, clip=0.000, oom=0.000, wall=2353, train_wall=2297
# | epoch 003:   1100 / 1131 loss=6.040, nll_loss=4.959, ppl=31.11, wps=4938, ups=1, wpb=3492.458, bsz=141.777, num_updates=3363, lr=0.000420391, gnorm=0.987, clip=0.000, oom=0.000, wall=2424, train_wall=2367
# | epoch 003 | loss 6.030 | nll_loss 4.948 | ppl 30.88 | wps 4937 | ups 1 | wpb 3491.701 | bsz 141.679 | num_updates 3393 | lr 0.00042414 | gnorm 0.986 | clip 0.000 | oom 0.000 | wall 2445 | train_wall 2388
# | epoch 003 | valid on 'valid' subset | loss 5.292 | nll_loss 3.952 | ppl 15.48 | num_updates 3393 | best_loss 5.29161
# | saved checkpoint /content/gdrive/My Drive/colab/payless/save_dev4/dynamic_conv_iwslt/checkpoint3.pt (epoch 3 @ 3393 updates) (writing took 7.0799720287323 seconds)
# | epoch 004:    100 / 1131 loss=5.374, nll_loss=4.184, ppl=18.18, wps=4945, ups=1, wpb=3496.941, bsz=142.099, num_updates=3494, lr=0.000436763, gnorm=0.872, clip=0.000, oom=0.000, wall=2536, train_wall=2459
# | epoch 004:    200 / 1131 loss=5.382, nll_loss=4.191, ppl=18.27, wps=4936, ups=1, wpb=3487.055, bsz=138.866, num_updates=3594, lr=0.00044926, gnorm=0.883, clip=0.000, oom=0.000, wall=2606, train_wall=2529
# | epoch 004:    300 / 1131 loss=5.347, nll_loss=4.150, ppl=17.75, wps=4940, ups=1, wpb=3490.502, bsz=137.276, num_updates=3694, lr=0.000461758, gnorm=0.880, clip=0.000, oom=0.000, wall=2677, train_wall=2599
# | epoch 004:    400 / 1131 loss=5.336, nll_loss=4.136, ppl=17.58, wps=4946, ups=1, wpb=3496.112, bsz=135.678, num_updates=3794, lr=0.000474255, gnorm=0.877, clip=0.000, oom=0.000, wall=2748, train_wall=2670
# | epoch 004:    500 / 1131 loss=5.322, nll_loss=4.119, ppl=17.37, wps=4941, ups=1, wpb=3485.806, bsz=135.263, num_updates=3894, lr=0.000486753, gnorm=0.878, clip=0.000, oom=0.000, wall=2818, train_wall=2739
# | epoch 004:    600 / 1131 loss=5.298, nll_loss=4.091, ppl=17.04, wps=4939, ups=1, wpb=3485.730, bsz=136.038, num_updates=3994, lr=0.00049925, gnorm=0.876, clip=0.000, oom=0.000, wall=2888, train_wall=2809
# | epoch 004:    700 / 1131 loss=5.264, nll_loss=4.052, ppl=16.59, wps=4949, ups=1, wpb=3494.829, bsz=138.281, num_updates=4094, lr=0.000494227, gnorm=0.869, clip=0.000, oom=0.000, wall=2959, train_wall=2880
# | epoch 004:    800 / 1131 loss=5.241, nll_loss=4.025, ppl=16.28, wps=4941, ups=1, wpb=3486.479, bsz=138.516, num_updates=4194, lr=0.000488299, gnorm=0.867, clip=0.000, oom=0.000, wall=3030, train_wall=2950
# | epoch 004:    900 / 1131 loss=5.212, nll_loss=3.991, ppl=15.90, wps=4942, ups=1, wpb=3486.191, bsz=139.746, num_updates=4294, lr=0.00048258, gnorm=0.861, clip=0.000, oom=0.000, wall=3100, train_wall=3019
# | epoch 004:   1000 / 1131 loss=5.182, nll_loss=3.957, ppl=15.53, wps=4939, ups=1, wpb=3487.905, bsz=140.922, num_updates=4394, lr=0.000477057, gnorm=0.857, clip=0.000, oom=0.000, wall=3171, train_wall=3090
# | epoch 004:   1100 / 1131 loss=5.155, nll_loss=3.925, ppl=15.19, wps=4941, ups=1, wpb=3491.833, bsz=141.209, num_updates=4494, lr=0.000471719, gnorm=0.849, clip=0.000, oom=0.000, wall=3242, train_wall=3161
# | epoch 004 | loss 5.146 | nll_loss 3.915 | ppl 15.08 | wps 4939 | ups 1 | wpb 3491.701 | bsz 141.679 | num_updates 4524 | lr 0.000470152 | gnorm 0.847 | clip 0.000 | oom 0.000 | wall 3264 | train_wall 3182
# | epoch 004 | valid on 'valid' subset | loss 4.740 | nll_loss 3.291 | ppl 9.79 | num_updates 4524 | best_loss 4.73963
# | saved checkpoint /content/gdrive/My Drive/colab/payless/save_dev4/dynamic_conv_iwslt/checkpoint4.pt (epoch 4 @ 4524 updates) (writing took 7.6129090785980225 seconds)
# | epoch 005:    100 / 1131 loss=4.730, nll_loss=3.437, ppl=10.83, wps=4890, ups=1, wpb=3472.307, bsz=145.584, num_updates=4625, lr=0.000464991, gnorm=0.767, clip=0.000, oom=0.000, wall=3356, train_wall=3254
# | epoch 005:    200 / 1131 loss=4.745, nll_loss=3.453, ppl=10.95, wps=4885, ups=1, wpb=3458.662, bsz=140.020, num_updates=4725, lr=0.000460044, gnorm=0.777, clip=0.000, oom=0.000, wall=3426, train_wall=3324
# | epoch 005:    300 / 1131 loss=4.704, nll_loss=3.406, ppl=10.60, wps=4914, ups=1, wpb=3485.987, bsz=146.339, num_updates=4825, lr=0.000455251, gnorm=0.765, clip=0.000, oom=0.000, wall=3498, train_wall=3394
# | epoch 005:    400 / 1131 loss=4.705, nll_loss=3.407, ppl=10.60, wps=4919, ups=1, wpb=3486.753, bsz=142.843, num_updates=4925, lr=0.000450606, gnorm=0.764, clip=0.000, oom=0.000, wall=3568, train_wall=3465
# | epoch 005:    500 / 1131 loss=4.704, nll_loss=3.405, ppl=10.60, wps=4928, ups=1, wpb=3491.852, bsz=140.375, num_updates=5025, lr=0.0004461, gnorm=0.757, clip=0.000, oom=0.000, wall=3639, train_wall=3535
# | epoch 005:    600 / 1131 loss=4.708, nll_loss=3.410, ppl=10.63, wps=4926, ups=1, wpb=3488.155, bsz=137.784, num_updates=5125, lr=0.000441726, gnorm=0.760, clip=0.000, oom=0.000, wall=3710, train_wall=3605
# | epoch 005:    700 / 1131 loss=4.682, nll_loss=3.380, ppl=10.41, wps=4936, ups=1, wpb=3497.107, bsz=141.238, num_updates=5225, lr=0.000437479, gnorm=0.754, clip=0.000, oom=0.000, wall=3781, train_wall=3676
# | epoch 005:    800 / 1131 loss=4.670, nll_loss=3.367, ppl=10.32, wps=4939, ups=1, wpb=3500.608, bsz=141.432, num_updates=5325, lr=0.000433351, gnorm=0.750, clip=0.000, oom=0.000, wall=3852, train_wall=3746
# | epoch 005:    900 / 1131 loss=4.659, nll_loss=3.355, ppl=10.23, wps=4942, ups=1, wpb=3502.876, bsz=142.365, num_updates=5425, lr=0.000429339, gnorm=0.749, clip=0.000, oom=0.000, wall=3923, train_wall=3817
# | epoch 005:   1000 / 1131 loss=4.655, nll_loss=3.350, ppl=10.20, wps=4934, ups=1, wpb=3492.042, bsz=141.673, num_updates=5525, lr=0.000425436, gnorm=0.749, clip=0.000, oom=0.000, wall=3992, train_wall=3886
# | epoch 005:   1100 / 1131 loss=4.643, nll_loss=3.337, ppl=10.11, wps=4935, ups=1, wpb=3491.882, bsz=141.623, num_updates=5625, lr=0.000421637, gnorm=0.745, clip=0.000, oom=0.000, wall=4063, train_wall=3956
# | epoch 005 | loss 4.641 | nll_loss 3.335 | ppl 10.09 | wps 4936 | ups 1 | wpb 3491.701 | bsz 141.679 | num_updates 5655 | lr 0.000420517 | gnorm 0.745 | clip 0.000 | oom 0.000 | wall 4084 | train_wall 3977
# | epoch 005 | valid on 'valid' subset | loss 4.477 | nll_loss 2.990 | ppl 7.95 | num_updates 5655 | best_loss 4.47695
# | saved checkpoint /content/gdrive/My Drive/colab/payless/save_dev4/dynamic_conv_iwslt/checkpoint5.pt (epoch 5 @ 5655 updates) (writing took 7.364912033081055 seconds)
# | epoch 006:    100 / 1131 loss=4.344, nll_loss=2.996, ppl=7.98, wps=4919, ups=1, wpb=3537.505, bsz=142.881, num_updates=5756, lr=0.000416811, gnorm=0.682, clip=0.000, oom=0.000, wall=4177, train_wall=4049
# | epoch 006:    200 / 1131 loss=4.350, nll_loss=3.002, ppl=8.01, wps=4927, ups=1, wpb=3503.806, bsz=147.776, num_updates=5856, lr=0.000413237, gnorm=0.696, clip=0.000, oom=0.000, wall=4247, train_wall=4119
# | epoch 006:    300 / 1131 loss=4.376, nll_loss=3.032, ppl=8.18, wps=4904, ups=1, wpb=3469.272, bsz=143.704, num_updates=5956, lr=0.000409753, gnorm=0.705, clip=0.000, oom=0.000, wall=4317, train_wall=4188
# | epoch 006:    400 / 1131 loss=4.372, nll_loss=3.028, ppl=8.16, wps=4902, ups=1, wpb=3467.115, bsz=142.860, num_updates=6056, lr=0.000406356, gnorm=0.701, clip=0.000, oom=0.000, wall=4387, train_wall=4259
# | epoch 006:    500 / 1131 loss=4.376, nll_loss=3.032, ppl=8.18, wps=4929, ups=1, wpb=3481.910, bsz=142.098, num_updates=6156, lr=0.000403042, gnorm=0.699, clip=0.000, oom=0.000, wall=4458, train_wall=4328
# | epoch 006:    600 / 1131 loss=4.377, nll_loss=3.034, ppl=8.19, wps=4928, ups=1, wpb=3479.839, bsz=140.364, num_updates=6256, lr=0.000399808, gnorm=0.697, clip=0.000, oom=0.000, wall=4528, train_wall=4398
# | epoch 006:    700 / 1131 loss=4.371, nll_loss=3.027, ppl=8.15, wps=4934, ups=1, wpb=3481.966, bsz=142.298, num_updates=6356, lr=0.000396651, gnorm=0.699, clip=0.000, oom=0.000, wall=4599, train_wall=4468
# | epoch 006:    800 / 1131 loss=4.360, nll_loss=3.015, ppl=8.08, wps=4941, ups=1, wpb=3491.240, bsz=143.479, num_updates=6456, lr=0.000393567, gnorm=0.694, clip=0.000, oom=0.000, wall=4670, train_wall=4539
# | epoch 006:    900 / 1131 loss=4.358, nll_loss=3.013, ppl=8.07, wps=4948, ups=1, wpb=3495.008, bsz=143.120, num_updates=6556, lr=0.000390553, gnorm=0.694, clip=0.000, oom=0.000, wall=4740, train_wall=4609
# | epoch 006:   1000 / 1131 loss=4.359, nll_loss=3.014, ppl=8.08, wps=4941, ups=1, wpb=3489.187, bsz=142.105, num_updates=6656, lr=0.000387609, gnorm=0.693, clip=0.000, oom=0.000, wall=4811, train_wall=4679
# | epoch 006:   1100 / 1131 loss=4.351, nll_loss=3.004, ppl=8.02, wps=4942, ups=1, wpb=3493.069, bsz=142.459, num_updates=6756, lr=0.000384729, gnorm=0.691, clip=0.000, oom=0.000, wall=4882, train_wall=4750
# | epoch 006 | loss 4.353 | nll_loss 3.007 | ppl 8.04 | wps 4942 | ups 1 | wpb 3491.701 | bsz 141.679 | num_updates 6786 | lr 0.000383878 | gnorm 0.691 | clip 0.000 | oom 0.000 | wall 4903 | train_wall 4771
# | epoch 006 | valid on 'valid' subset | loss 4.284 | nll_loss 2.775 | ppl 6.84 | num_updates 6786 | best_loss 4.28389
# | saved checkpoint /content/gdrive/My Drive/colab/payless/save_dev4/dynamic_conv_iwslt/checkpoint6.pt (epoch 6 @ 6786 updates) (writing took 8.220543146133423 seconds)
# | epoch 007:    100 / 1131 loss=4.159, nll_loss=2.786, ppl=6.90, wps=4963, ups=1, wpb=3537.089, bsz=143.366, num_updates=6887, lr=0.000381053, gnorm=0.642, clip=0.000, oom=0.000, wall=4996, train_wall=4842
# | epoch 007:    200 / 1131 loss=4.138, nll_loss=2.762, ppl=6.79, wps=4961, ups=1, wpb=3535.478, bsz=148.259, num_updates=6987, lr=0.000378316, gnorm=0.646, clip=0.000, oom=0.000, wall=5067, train_wall=4913
# | epoch 007:    300 / 1131 loss=4.127, nll_loss=2.750, ppl=6.73, wps=4956, ups=1, wpb=3526.950, bsz=150.671, num_updates=7087, lr=0.000375637, gnorm=0.655, clip=0.000, oom=0.000, wall=5138, train_wall=4984
# | epoch 007:    400 / 1131 loss=4.135, nll_loss=2.759, ppl=6.77, wps=4951, ups=1, wpb=3517.384, bsz=148.449, num_updates=7187, lr=0.000373015, gnorm=0.659, clip=0.000, oom=0.000, wall=5209, train_wall=5054
# | epoch 007:    500 / 1131 loss=4.153, nll_loss=2.779, ppl=6.86, wps=4938, ups=1, wpb=3502.467, bsz=143.984, num_updates=7287, lr=0.000370447, gnorm=0.663, clip=0.000, oom=0.000, wall=5279, train_wall=5124
# | epoch 007:    600 / 1131 loss=4.160, nll_loss=2.787, ppl=6.90, wps=4939, ups=1, wpb=3498.038, bsz=142.536, num_updates=7387, lr=0.000367931, gnorm=0.664, clip=0.000, oom=0.000, wall=5350, train_wall=5194
# | epoch 007:    700 / 1131 loss=4.169, nll_loss=2.797, ppl=6.95, wps=4929, ups=1, wpb=3484.919, bsz=140.974, num_updates=7487, lr=0.000365465, gnorm=0.668, clip=0.000, oom=0.000, wall=5420, train_wall=5263
# | epoch 007:    800 / 1131 loss=4.169, nll_loss=2.798, ppl=6.96, wps=4942, ups=1, wpb=3489.649, bsz=141.382, num_updates=7587, lr=0.000363049, gnorm=0.667, clip=0.000, oom=0.000, wall=5490, train_wall=5333
# | epoch 007:    900 / 1131 loss=4.167, nll_loss=2.796, ppl=6.94, wps=4949, ups=1, wpb=3494.154, bsz=141.797, num_updates=7687, lr=0.00036068, gnorm=0.666, clip=0.000, oom=0.000, wall=5560, train_wall=5403
# | epoch 007:   1000 / 1131 loss=4.166, nll_loss=2.795, ppl=6.94, wps=4950, ups=1, wpb=3495.764, bsz=141.657, num_updates=7787, lr=0.000358356, gnorm=0.665, clip=0.000, oom=0.000, wall=5631, train_wall=5473
# | epoch 007:   1100 / 1131 loss=4.166, nll_loss=2.795, ppl=6.94, wps=4948, ups=1, wpb=3492.284, bsz=141.609, num_updates=7887, lr=0.000356077, gnorm=0.665, clip=0.000, oom=0.000, wall=5701, train_wall=5543
# | epoch 007 | loss 4.164 | nll_loss 2.793 | ppl 6.93 | wps 4948 | ups 1 | wpb 3491.701 | bsz 141.679 | num_updates 7917 | lr 0.000355402 | gnorm 0.664 | clip 0.000 | oom 0.000 | wall 5722 | train_wall 5564
# | epoch 007 | valid on 'valid' subset | loss 4.215 | nll_loss 2.687 | ppl 6.44 | num_updates 7917 | best_loss 4.21481
# | saved checkpoint /content/gdrive/My Drive/colab/payless/save_dev4/dynamic_conv_iwslt/checkpoint7.pt (epoch 7 @ 7917 updates) (writing took 7.904502630233765 seconds)
# | epoch 008:    100 / 1131 loss=3.937, nll_loss=2.534, ppl=5.79, wps=4915, ups=1, wpb=3504.495, bsz=159.129, num_updates=8018, lr=0.000353156, gnorm=0.635, clip=0.000, oom=0.000, wall=5815, train_wall=5635
# | epoch 008:    200 / 1131 loss=3.975, nll_loss=2.576, ppl=5.96, wps=4957, ups=1, wpb=3526.134, bsz=153.194, num_updates=8118, lr=0.000350974, gnorm=0.636, clip=0.000, oom=0.000, wall=5885, train_wall=5706
# | epoch 008:    300 / 1131 loss=3.994, nll_loss=2.599, ppl=6.06, wps=4957, ups=1, wpb=3517.824, bsz=147.744, num_updates=8218, lr=0.000348832, gnorm=0.639, clip=0.000, oom=0.000, wall=5956, train_wall=5776
# | epoch 008:    400 / 1131 loss=4.005, nll_loss=2.611, ppl=6.11, wps=4955, ups=1, wpb=3509.683, bsz=145.594, num_updates=8318, lr=0.000346729, gnorm=0.640, clip=0.000, oom=0.000, wall=6027, train_wall=5846
# | epoch 008:    500 / 1131 loss=4.009, nll_loss=2.615, ppl=6.13, wps=4932, ups=1, wpb=3485.583, bsz=145.275, num_updates=8418, lr=0.000344664, gnorm=0.646, clip=0.000, oom=0.000, wall=6097, train_wall=5915
# | epoch 008:    600 / 1131 loss=4.016, nll_loss=2.624, ppl=6.17, wps=4935, ups=1, wpb=3485.967, bsz=144.691, num_updates=8518, lr=0.000342635, gnorm=0.648, clip=0.000, oom=0.000, wall=6167, train_wall=5985
# | epoch 008:    700 / 1131 loss=4.018, nll_loss=2.626, ppl=6.17, wps=4938, ups=1, wpb=3486.106, bsz=144.866, num_updates=8618, lr=0.000340641, gnorm=0.648, clip=0.000, oom=0.000, wall=6237, train_wall=6055
# | epoch 008:    800 / 1131 loss=4.017, nll_loss=2.626, ppl=6.17, wps=4945, ups=1, wpb=3494.222, bsz=144.668, num_updates=8718, lr=0.000338682, gnorm=0.648, clip=0.000, oom=0.000, wall=6308, train_wall=6126
# | epoch 008:    900 / 1131 loss=4.025, nll_loss=2.635, ppl=6.21, wps=4946, ups=1, wpb=3491.938, bsz=142.232, num_updates=8818, lr=0.000336756, gnorm=0.649, clip=0.000, oom=0.000, wall=6379, train_wall=6196
# | epoch 008:   1000 / 1131 loss=4.023, nll_loss=2.633, ppl=6.20, wps=4946, ups=1, wpb=3495.145, bsz=142.249, num_updates=8918, lr=0.000334862, gnorm=0.648, clip=0.000, oom=0.000, wall=6450, train_wall=6266
# | epoch 008:   1100 / 1131 loss=4.026, nll_loss=2.636, ppl=6.22, wps=4940, ups=1, wpb=3489.301, bsz=141.797, num_updates=9018, lr=0.000333, gnorm=0.649, clip=0.000, oom=0.000, wall=6520, train_wall=6336
# | epoch 008 | loss 4.027 | nll_loss 2.637 | ppl 6.22 | wps 4944 | ups 1 | wpb 3491.701 | bsz 141.679 | num_updates 9048 | lr 0.000332448 | gnorm 0.649 | clip 0.000 | oom 0.000 | wall 6541 | train_wall 6357
# | epoch 008 | valid on 'valid' subset | loss 4.128 | nll_loss 2.597 | ppl 6.05 | num_updates 9048 | best_loss 4.12758
# | saved checkpoint /content/gdrive/My Drive/colab/payless/save_dev4/dynamic_conv_iwslt/checkpoint8.pt (epoch 8 @ 9048 updates) (writing took 8.503289222717285 seconds)
# | epoch 009:    100 / 1131 loss=3.869, nll_loss=2.457, ppl=5.49, wps=4869, ups=1, wpb=3468.772, bsz=140.277, num_updates=9149, lr=0.000330608, gnorm=0.635, clip=0.000, oom=0.000, wall=6634, train_wall=6429
# | epoch 009:    200 / 1131 loss=3.874, nll_loss=2.461, ppl=5.51, wps=4920, ups=1, wpb=3505.562, bsz=139.741, num_updates=9249, lr=0.000328816, gnorm=0.630, clip=0.000, oom=0.000, wall=6705, train_wall=6499
# | epoch 009:    300 / 1131 loss=3.881, nll_loss=2.469, ppl=5.54, wps=4922, ups=1, wpb=3501.282, bsz=142.379, num_updates=9349, lr=0.000327052, gnorm=0.639, clip=0.000, oom=0.000, wall=6776, train_wall=6570
# | epoch 009:    400 / 1131 loss=3.897, nll_loss=2.487, ppl=5.61, wps=4947, ups=1, wpb=3509.037, bsz=140.688, num_updates=9449, lr=0.000325317, gnorm=0.636, clip=0.000, oom=0.000, wall=6847, train_wall=6640
# | epoch 009:    500 / 1131 loss=3.902, nll_loss=2.494, ppl=5.63, wps=4947, ups=1, wpb=3501.331, bsz=142.164, num_updates=9549, lr=0.000323609, gnorm=0.636, clip=0.000, oom=0.000, wall=6917, train_wall=6709
# | epoch 009:    600 / 1131 loss=3.908, nll_loss=2.500, ppl=5.66, wps=4943, ups=1, wpb=3495.923, bsz=142.561, num_updates=9649, lr=0.000321928, gnorm=0.638, clip=0.000, oom=0.000, wall=6987, train_wall=6779
# | epoch 009:    700 / 1131 loss=3.914, nll_loss=2.507, ppl=5.69, wps=4938, ups=1, wpb=3491.205, bsz=140.552, num_updates=9749, lr=0.000320273, gnorm=0.640, clip=0.000, oom=0.000, wall=7058, train_wall=6849
# | epoch 009:    800 / 1131 loss=3.916, nll_loss=2.510, ppl=5.69, wps=4946, ups=1, wpb=3499.643, bsz=141.742, num_updates=9849, lr=0.000318643, gnorm=0.640, clip=0.000, oom=0.000, wall=7129, train_wall=6920
# | epoch 009:    900 / 1131 loss=3.917, nll_loss=2.511, ppl=5.70, wps=4945, ups=1, wpb=3495.212, bsz=141.992, num_updates=9949, lr=0.000317037, gnorm=0.643, clip=0.000, oom=0.000, wall=7199, train_wall=6990
# | epoch 009:   1000 / 1131 loss=3.918, nll_loss=2.513, ppl=5.71, wps=4938, ups=1, wpb=3488.602, bsz=141.857, num_updates=10049, lr=0.000315456, gnorm=0.643, clip=0.000, oom=0.000, wall=7269, train_wall=7060
# | epoch 009:   1100 / 1131 loss=3.921, nll_loss=2.517, ppl=5.72, wps=4944, ups=1, wpb=3491.737, bsz=141.311, num_updates=10149, lr=0.000313898, gnorm=0.641, clip=0.000, oom=0.000, wall=7340, train_wall=7130
# | epoch 009 | loss 3.921 | nll_loss 2.517 | ppl 5.72 | wps 4945 | ups 1 | wpb 3491.701 | bsz 141.679 | num_updates 10179 | lr 0.000313435 | gnorm 0.642 | clip 0.000 | oom 0.000 | wall 7361 | train_wall 7150
# | epoch 009 | valid on 'valid' subset | loss 4.081 | nll_loss 2.542 | ppl 5.82 | num_updates 10179 | best_loss 4.08099
# | saved checkpoint /content/gdrive/My Drive/colab/payless/save_dev4/dynamic_conv_iwslt/checkpoint9.pt (epoch 9 @ 10179 updates) (writing took 8.194063663482666 seconds)
# | epoch 010:    100 / 1131 loss=3.764, nll_loss=2.338, ppl=5.06, wps=4958, ups=1, wpb=3571.129, bsz=153.505, num_updates=10280, lr=0.000311891, gnorm=0.608, clip=0.000, oom=0.000, wall=7454, train_wall=7223
# | epoch 010:    200 / 1131 loss=3.801, nll_loss=2.379, ppl=5.20, wps=4933, ups=1, wpb=3507.100, bsz=141.373, num_updates=10380, lr=0.000310385, gnorm=0.623, clip=0.000, oom=0.000, wall=7524, train_wall=7292
# | epoch 010:    300 / 1131 loss=3.806, nll_loss=2.385, ppl=5.22, wps=4953, ups=1, wpb=3520.950, bsz=142.485, num_updates=10480, lr=0.000308901, gnorm=0.622, clip=0.000, oom=0.000, wall=7595, train_wall=7363
# | epoch 010:    400 / 1131 loss=3.802, nll_loss=2.380, ppl=5.21, wps=4953, ups=1, wpb=3516.070, bsz=144.459, num_updates=10580, lr=0.000307438, gnorm=0.623, clip=0.000, oom=0.000, wall=7666, train_wall=7433
# | epoch 010:    500 / 1131 loss=3.816, nll_loss=2.396, ppl=5.26, wps=4939, ups=1, wpb=3495.551, bsz=142.084, num_updates=10680, lr=0.000305995, gnorm=0.629, clip=0.000, oom=0.000, wall=7736, train_wall=7503
# | epoch 010:    600 / 1131 loss=3.823, nll_loss=2.404, ppl=5.29, wps=4946, ups=1, wpb=3496.346, bsz=141.351, num_updates=10780, lr=0.000304572, gnorm=0.629, clip=0.000, oom=0.000, wall=7806, train_wall=7572
# | epoch 010:    700 / 1131 loss=3.826, nll_loss=2.407, ppl=5.30, wps=4942, ups=1, wpb=3491.471, bsz=141.912, num_updates=10880, lr=0.00030317, gnorm=0.631, clip=0.000, oom=0.000, wall=7877, train_wall=7642
# | epoch 010:    800 / 1131 loss=3.828, nll_loss=2.411, ppl=5.32, wps=4944, ups=1, wpb=3493.187, bsz=141.393, num_updates=10980, lr=0.000301786, gnorm=0.631, clip=0.000, oom=0.000, wall=7947, train_wall=7713
# | epoch 010:    900 / 1131 loss=3.832, nll_loss=2.415, ppl=5.33, wps=4951, ups=1, wpb=3500.839, bsz=140.767, num_updates=11080, lr=0.000300421, gnorm=0.630, clip=0.000, oom=0.000, wall=8018, train_wall=7783
# | epoch 010:   1000 / 1131 loss=3.830, nll_loss=2.413, ppl=5.32, wps=4950, ups=1, wpb=3498.915, bsz=141.857, num_updates=11180, lr=0.000299074, gnorm=0.631, clip=0.000, oom=0.000, wall=8089, train_wall=7853
# | epoch 010:   1100 / 1131 loss=3.828, nll_loss=2.411, ppl=5.32, wps=4945, ups=1, wpb=3492.833, bsz=142.851, num_updates=11280, lr=0.000297746, gnorm=0.631, clip=0.000, oom=0.000, wall=8159, train_wall=7923
# | epoch 010 | loss 3.831 | nll_loss 2.414 | ppl 5.33 | wps 4943 | ups 1 | wpb 3491.701 | bsz 141.679 | num_updates 11310 | lr 0.000297351 | gnorm 0.632 | clip 0.000 | oom 0.000 | wall 8180 | train_wall 7944
# | epoch 010 | valid on 'valid' subset | loss 4.038 | nll_loss 2.498 | ppl 5.65 | num_updates 11310 | best_loss 4.03845
# | saved checkpoint /content/gdrive/My Drive/colab/payless/save_dev4/dynamic_conv_iwslt/checkpoint10.pt (epoch 10 @ 11310 updates) (writing took 8.897311449050903 seconds)
# | epoch 011:    100 / 1131 loss=3.764, nll_loss=2.336, ppl=5.05, wps=4892, ups=1, wpb=3450.624, bsz=129.426, num_updates=11411, lr=0.000296032, gnorm=0.634, clip=0.000, oom=0.000, wall=8273, train_wall=8015
# | epoch 011:    200 / 1131 loss=3.755, nll_loss=2.326, ppl=5.01, wps=4874, ups=1, wpb=3423.697, bsz=135.085, num_updates=11511, lr=0.000294743, gnorm=0.637, clip=0.000, oom=0.000, wall=8343, train_wall=8084
# | epoch 011:    300 / 1131 loss=3.764, nll_loss=2.335, ppl=5.05, wps=4930, ups=1, wpb=3476.498, bsz=134.698, num_updates=11611, lr=0.000293471, gnorm=0.629, clip=0.000, oom=0.000, wall=8414, train_wall=8155
# | epoch 011:    400 / 1131 loss=3.755, nll_loss=2.326, ppl=5.02, wps=4946, ups=1, wpb=3486.007, bsz=138.414, num_updates=11711, lr=0.000292215, gnorm=0.628, clip=0.000, oom=0.000, wall=8484, train_wall=8225
# | epoch 011:    500 / 1131 loss=3.749, nll_loss=2.319, ppl=4.99, wps=4940, ups=1, wpb=3482.870, bsz=141.844, num_updates=11811, lr=0.000290976, gnorm=0.630, clip=0.000, oom=0.000, wall=8555, train_wall=8295
# | epoch 011:    600 / 1131 loss=3.744, nll_loss=2.314, ppl=4.97, wps=4941, ups=1, wpb=3483.607, bsz=144.932, num_updates=11911, lr=0.000289752, gnorm=0.629, clip=0.000, oom=0.000, wall=8625, train_wall=8365
# ...
# | epoch 039:   1000 / 1131 loss=3.023, nll_loss=1.478, ppl=2.79, wps=4984, ups=1, wpb=3497.826, bsz=142.009, num_updates=43979, lr=0.000150792, gnorm=0.717, clip=0.000, oom=0.000, wall=31690, train_wall=30765
# | epoch 039:   1100 / 1131 loss=3.025, nll_loss=1.481, ppl=2.79, wps=4981, ups=1, wpb=3494.713, bsz=141.885, num_updates=44079, lr=0.000150621, gnorm=0.718, clip=0.000, oom=0.000, wall=31759, train_wall=30835
# | epoch 039 | loss 3.027 | nll_loss 1.483 | ppl 2.80 | wps 4979 | ups 1 | wpb 3491.701 | bsz 141.679 | num_updates 44109 | lr 0.000150569 | gnorm 0.719 | clip 0.000 | oom 0.000 | wall 31780 | train_wall 30855
# | epoch 039 | valid on 'valid' subset | loss 3.960 | nll_loss 2.395 | ppl 5.26 | num_updates 44109 | best_loss 3.9092
# | saved checkpoint /content/gdrive/My Drive/colab/payless/save_dev4/dynamic_conv_iwslt/checkpoint39.pt (epoch 39 @ 44109 updates) (writing took 4.968691825866699 seconds)
# | epoch 040:    100 / 1131 loss=2.988, nll_loss=1.435, ppl=2.70, wps=4882, ups=1, wpb=3412.040, bsz=123.723, num_updates=44210, lr=0.000150397, gnorm=0.724, clip=0.000, oom=0.000, wall=31868, train_wall=30926
# | epoch 040:    200 / 1131 loss=2.979, nll_loss=1.426, ppl=2.69, wps=4910, ups=1, wpb=3427.199, bsz=132.697, num_updates=44310, lr=0.000150227, gnorm=0.719, clip=0.000, oom=0.000, wall=31938, train_wall=30995
# | epoch 040:    300 / 1131 loss=2.985, nll_loss=1.432, ppl=2.70, wps=4926, ups=1, wpb=3446.910, bsz=131.907, num_updates=44410, lr=0.000150058, gnorm=0.719, clip=0.000, oom=0.000, wall=32009, train_wall=31065
# | epoch 040:    400 / 1131 loss=2.996, nll_loss=1.445, ppl=2.72, wps=4949, ups=1, wpb=3465.671, bsz=131.070, num_updates=44510, lr=0.000149889, gnorm=0.721, clip=0.000, oom=0.000, wall=32079, train_wall=31135
# | epoch 040:    500 / 1131 loss=3.001, nll_loss=1.451, ppl=2.73, wps=4955, ups=1, wpb=3467.411, bsz=132.772, num_updates=44610, lr=0.000149721, gnorm=0.723, clip=0.000, oom=0.000, wall=32149, train_wall=31204
# | epoch 040:    600 / 1131 loss=3.001, nll_loss=1.452, ppl=2.74, wps=4958, ups=1, wpb=3469.631, bsz=135.493, num_updates=44710, lr=0.000149554, gnorm=0.722, clip=0.000, oom=0.000, wall=32218, train_wall=31273
# | epoch 040:    700 / 1131 loss=3.001, nll_loss=1.452, ppl=2.74, wps=4960, ups=1, wpb=3474.101, bsz=137.699, num_updates=44810, lr=0.000149387, gnorm=0.721, clip=0.000, oom=0.000, wall=32289, train_wall=31343
# | epoch 040:    800 / 1131 loss=3.006, nll_loss=1.457, ppl=2.75, wps=4966, ups=1, wpb=3478.930, bsz=138.286, num_updates=44910, lr=0.00014922, gnorm=0.722, clip=0.000, oom=0.000, wall=32359, train_wall=31413
# | epoch 040:    900 / 1131 loss=3.009, nll_loss=1.462, ppl=2.75, wps=4965, ups=1, wpb=3476.736, bsz=138.982, num_updates=45010, lr=0.000149055, gnorm=0.723, clip=0.000, oom=0.000, wall=32429, train_wall=31482
# | epoch 040:   1000 / 1131 loss=3.013, nll_loss=1.466, ppl=2.76, wps=4970, ups=1, wpb=3479.652, bsz=139.388, num_updates=45110, lr=0.000148889, gnorm=0.723, clip=0.000, oom=0.000, wall=32499, train_wall=31552
# | epoch 040:   1100 / 1131 loss=3.015, nll_loss=1.469, ppl=2.77, wps=4981, ups=1, wpb=3491.003, bsz=141.856, num_updates=45210, lr=0.000148725, gnorm=0.722, clip=0.000, oom=0.000, wall=32570, train_wall=31622
# | epoch 040 | loss 3.016 | nll_loss 1.470 | ppl 2.77 | wps 4980 | ups 1 | wpb 3491.701 | bsz 141.679 | num_updates 45240 | lr 0.000148675 | gnorm 0.722 | clip 0.000 | oom 0.000 | wall 32591 | train_wall 31644
# | epoch 040 | valid on 'valid' subset | loss 3.968 | nll_loss 2.403 | ppl 5.29 | num_updates 45240 | best_loss 3.9092
# | saved checkpoint /content/gdrive/My Drive/colab/payless/save_dev4/dynamic_conv_iwslt/checkpoint40.pt (epoch 40 @ 45240 updates) (writing took 5.324512004852295 seconds)
# | epoch 041:    100 / 1131 loss=2.967, nll_loss=1.414, ppl=2.66, wps=5011, ups=1, wpb=3551.337, bsz=148.356, num_updates=45341, lr=0.00014851, gnorm=0.698, clip=0.000, oom=0.000, wall=32680, train_wall=31715
# | epoch 041:    200 / 1131 loss=2.965, nll_loss=1.411, ppl=2.66, wps=4990, ups=1, wpb=3516.055, bsz=146.070, num_updates=45441, lr=0.000148346, gnorm=0.704, clip=0.000, oom=0.000, wall=32750, train_wall=31785
# | epoch 041:    300 / 1131 loss=2.965, nll_loss=1.412, ppl=2.66, wps=4981, ups=1, wpb=3501.797, bsz=147.402, num_updates=45541, lr=0.000148183, gnorm=0.707, clip=0.000, oom=0.000, wall=32820, train_wall=31854
# | epoch 041:    400 / 1131 loss=2.973, nll_loss=1.420, ppl=2.68, wps=4995, ups=1, wpb=3513.100, bsz=146.015, num_updates=45641, lr=0.000148021, gnorm=0.708, clip=0.000, oom=0.000, wall=32891, train_wall=31924
# | epoch 041:    500 / 1131 loss=2.980, nll_loss=1.429, ppl=2.69, wps=5001, ups=1, wpb=3520.152, bsz=144.094, num_updates=45741, lr=0.000147859, gnorm=0.710, clip=0.000, oom=0.000, wall=32961, train_wall=31994
# | epoch 041:    600 / 1131 loss=2.986, nll_loss=1.435, ppl=2.70, wps=5002, ups=1, wpb=3517.977, bsz=144.930, num_updates=45841, lr=0.000147697, gnorm=0.714, clip=0.000, oom=0.000, wall=33031, train_wall=32064
# | epoch 041:    700 / 1131 loss=2.989, nll_loss=1.439, ppl=2.71, wps=4988, ups=1, wpb=3503.223, bsz=144.341, num_updates=45941, lr=0.000147537, gnorm=0.717, clip=0.000, oom=0.000, wall=33101, train_wall=32133
# | epoch 041:    800 / 1131 loss=2.989, nll_loss=1.439, ppl=2.71, wps=4982, ups=1, wpb=3496.377, bsz=145.517, num_updates=46041, lr=0.000147376, gnorm=0.720, clip=0.000, oom=0.000, wall=33171, train_wall=32202
# | epoch 041:    900 / 1131 loss=2.994, nll_loss=1.445, ppl=2.72, wps=4982, ups=1, wpb=3493.572, bsz=143.679, num_updates=46141, lr=0.000147217, gnorm=0.722, clip=0.000, oom=0.000, wall=33241, train_wall=32272
# | epoch 041:   1000 / 1131 loss=2.999, nll_loss=1.450, ppl=2.73, wps=4977, ups=1, wpb=3489.206, bsz=142.009, num_updates=46241, lr=0.000147057, gnorm=0.724, clip=0.000, oom=0.000, wall=33310, train_wall=32341
# | epoch 041:   1100 / 1131 loss=3.003, nll_loss=1.455, ppl=2.74, wps=4983, ups=1, wpb=3491.368, bsz=142.052, num_updates=46341, lr=0.000146898, gnorm=0.725, clip=0.000, oom=0.000, wall=33380, train_wall=32411
# | epoch 041 | loss 3.004 | nll_loss 1.456 | ppl 2.74 | wps 4984 | ups 1 | wpb 3491.701 | bsz 141.679 | num_updates 46371 | lr 0.000146851 | gnorm 0.726 | clip 0.000 | oom 0.000 | wall 33401 | train_wall 32431
# | epoch 041 | valid on 'valid' subset | loss 3.966 | nll_loss 2.398 | ppl 5.27 | num_updates 46371 | best_loss 3.9092
# | saved checkpoint /content/gdrive/My Drive/colab/payless/save_dev4/dynamic_conv_iwslt/checkpoint41.pt (epoch 41 @ 46371 updates) (writing took 4.849077224731445 seconds)
# | epoch 042:    100 / 1131 loss=2.961, nll_loss=1.405, ppl=2.65, wps=4955, ups=1, wpb=3474.871, bsz=136.634, num_updates=46472, lr=0.000146691, gnorm=0.717, clip=0.000, oom=0.000, wall=33489, train_wall=32502
# | epoch 042:    200 / 1131 loss=2.962, nll_loss=1.406, ppl=2.65, wps=4949, ups=1, wpb=3466.796, bsz=135.363, num_updates=46572, lr=0.000146534, gnorm=0.720, clip=0.000, oom=0.000, wall=33559, train_wall=32571
# | epoch 042:    300 / 1131 loss=2.971, nll_loss=1.417, ppl=2.67, wps=4951, ups=1, wpb=3454.854, bsz=136.133, num_updates=46672, lr=0.000146377, gnorm=0.726, clip=0.000, oom=0.000, wall=33628, train_wall=32640
# | epoch 042:    400 / 1131 loss=2.975, nll_loss=1.421, ppl=2.68, wps=4949, ups=1, wpb=3454.192, bsz=133.845, num_updates=46772, lr=0.00014622, gnorm=0.728, clip=0.000, oom=0.000, wall=33698, train_wall=32709
# | epoch 042:    500 / 1131 loss=2.979, nll_loss=1.426, ppl=2.69, wps=4962, ups=1, wpb=3468.475, bsz=134.180, num_updates=46872, lr=0.000146064, gnorm=0.728, clip=0.000, oom=0.000, wall=33769, train_wall=32779
# | epoch 042:    600 / 1131 loss=2.983, nll_loss=1.431, ppl=2.70, wps=4967, ups=1, wpb=3472.639, bsz=133.617, num_updates=46972, lr=0.000145908, gnorm=0.730, clip=0.000, oom=0.000, wall=33839, train_wall=32849
# | epoch 042:    700 / 1131 loss=2.985, nll_loss=1.433, ppl=2.70, wps=4964, ups=1, wpb=3471.826, bsz=136.331, num_updates=47072, lr=0.000145753, gnorm=0.730, clip=0.000, oom=0.000, wall=33909, train_wall=32919
# | epoch 042:    800 / 1131 loss=2.986, nll_loss=1.435, ppl=2.70, wps=4978, ups=1, wpb=3488.954, bsz=137.788, num_updates=47172, lr=0.000145599, gnorm=0.727, clip=0.000, oom=0.000, wall=33980, train_wall=32989
# | epoch 042:    900 / 1131 loss=2.988, nll_loss=1.437, ppl=2.71, wps=4971, ups=1, wpb=3483.915, bsz=139.747, num_updates=47272, lr=0.000145445, gnorm=0.728, clip=0.000, oom=0.000, wall=34050, train_wall=33059
# | epoch 042:   1000 / 1131 loss=2.990, nll_loss=1.440, ppl=2.71, wps=4972, ups=1, wpb=3483.971, bsz=140.899, num_updates=47372, lr=0.000145291, gnorm=0.728, clip=0.000, oom=0.000, wall=34120, train_wall=33128
# | epoch 042:   1100 / 1131 loss=2.993, nll_loss=1.443, ppl=2.72, wps=4973, ups=1, wpb=3489.008, bsz=141.238, num_updates=47472, lr=0.000145138, gnorm=0.728, clip=0.000, oom=0.000, wall=34191, train_wall=33199
# | epoch 042 | loss 2.993 | nll_loss 1.444 | ppl 2.72 | wps 4974 | ups 1 | wpb 3491.701 | bsz 141.679 | num_updates 47502 | lr 0.000145092 | gnorm 0.728 | clip 0.000 | oom 0.000 | wall 34212 | train_wall 33220
# | epoch 042 | valid on 'valid' subset | loss 3.988 | nll_loss 2.418 | ppl 5.34 | num_updates 47502 | best_loss 3.9092
# | saved checkpoint /content/gdrive/My Drive/colab/payless/save_dev4/dynamic_conv_iwslt/checkpoint42.pt (epoch 42 @ 47502 updates) (writing took 4.933032512664795 seconds)
# | epoch 043:    100 / 1131 loss=2.961, nll_loss=1.406, ppl=2.65, wps=5011, ups=1, wpb=3535.822, bsz=139.881, num_updates=47603, lr=0.000144938, gnorm=0.712, clip=0.000, oom=0.000, wall=34301, train_wall=33291
# | epoch 043:    200 / 1131 loss=2.952, nll_loss=1.398, ppl=2.63, wps=4965, ups=1, wpb=3490.214, bsz=153.075, num_updates=47703, lr=0.000144786, gnorm=0.713, clip=0.000, oom=0.000, wall=34371, train_wall=33361
# | epoch 043:    300 / 1131 loss=2.958, nll_loss=1.403, ppl=2.64, wps=4957, ups=1, wpb=3472.080, bsz=146.179, num_updates=47803, lr=0.000144635, gnorm=0.722, clip=0.000, oom=0.000, wall=34440, train_wall=33430
# | epoch 043:    400 / 1131 loss=2.960, nll_loss=1.404, ppl=2.65, wps=4964, ups=1, wpb=3480.132, bsz=140.948, num_updates=47903, lr=0.000144484, gnorm=0.723, clip=0.000, oom=0.000, wall=34511, train_wall=33500
# | epoch 043:    500 / 1131 loss=2.963, nll_loss=1.408, ppl=2.65, wps=4966, ups=1, wpb=3486.631, bsz=139.289, num_updates=48003, lr=0.000144333, gnorm=0.724, clip=0.000, oom=0.000, wall=34581, train_wall=33570
# | epoch 043:    600 / 1131 loss=2.969, nll_loss=1.414, ppl=2.67, wps=4965, ups=1, wpb=3485.351, bsz=139.754, num_updates=48103, lr=0.000144183, gnorm=0.727, clip=0.000, oom=0.000, wall=34651, train_wall=33640
# | epoch 043:    700 / 1131 loss=2.971, nll_loss=1.417, ppl=2.67, wps=4964, ups=1, wpb=3479.439, bsz=140.257, num_updates=48203, lr=0.000144033, gnorm=0.729, clip=0.000, oom=0.000, wall=34721, train_wall=33709
# | epoch 043:    800 / 1131 loss=2.976, nll_loss=1.423, ppl=2.68, wps=4970, ups=1, wpb=3483.483, bsz=141.831, num_updates=48303, lr=0.000143884, gnorm=0.730, clip=0.000, oom=0.000, wall=34791, train_wall=33778
# | epoch 043:    900 / 1131 loss=2.978, nll_loss=1.425, ppl=2.69, wps=4968, ups=1, wpb=3483.055, bsz=141.042, num_updates=48403, lr=0.000143735, gnorm=0.731, clip=0.000, oom=0.000, wall=34861, train_wall=33848
# | epoch 043:   1000 / 1131 loss=2.981, nll_loss=1.428, ppl=2.69, wps=4974, ups=1, wpb=3487.145, bsz=140.970, num_updates=48503, lr=0.000143587, gnorm=0.731, clip=0.000, oom=0.000, wall=34931, train_wall=33918
# | epoch 043:   1100 / 1131 loss=2.982, nll_loss=1.431, ppl=2.70, wps=4978, ups=1, wpb=3493.742, bsz=141.848, num_updates=48603, lr=0.000143439, gnorm=0.730, clip=0.000, oom=0.000, wall=35002, train_wall=33988
# | epoch 043 | loss 2.982 | nll_loss 1.431 | ppl 2.70 | wps 4975 | ups 1 | wpb 3491.701 | bsz 141.679 | num_updates 48633 | lr 0.000143395 | gnorm 0.731 | clip 0.000 | oom 0.000 | wall 35023 | train_wall 34009
# | epoch 043 | valid on 'valid' subset | loss 3.988 | nll_loss 2.420 | ppl 5.35 | num_updates 48633 | best_loss 3.9092
# | saved checkpoint /content/gdrive/My Drive/colab/payless/save_dev4/dynamic_conv_iwslt/checkpoint43.pt (epoch 43 @ 48633 updates) (writing took 4.906738042831421 seconds)
# | epoch 044:    100 / 1131 loss=2.932, nll_loss=1.371, ppl=2.59, wps=4975, ups=1, wpb=3522.752, bsz=134.495, num_updates=48734, lr=0.000143246, gnorm=0.720, clip=0.000, oom=0.000, wall=35112, train_wall=34081
# | epoch 044:    200 / 1131 loss=2.932, nll_loss=1.370, ppl=2.59, wps=4940, ups=1, wpb=3462.562, bsz=136.199, num_updates=48834, lr=0.0001431, gnorm=0.727, clip=0.000, oom=0.000, wall=35182, train_wall=34149
# | epoch 044:    300 / 1131 loss=2.936, nll_loss=1.375, ppl=2.59, wps=4930, ups=1, wpb=3452.455, bsz=139.000, num_updates=48934, lr=0.000142953, gnorm=0.728, clip=0.000, oom=0.000, wall=35252, train_wall=34219
# | epoch 044:    400 / 1131 loss=2.938, nll_loss=1.380, ppl=2.60, wps=4962, ups=1, wpb=3479.928, bsz=149.663, num_updates=49034, lr=0.000142808, gnorm=0.724, clip=0.000, oom=0.000, wall=35322, train_wall=34289
# | epoch 044:    500 / 1131 loss=2.949, nll_loss=1.392, ppl=2.62, wps=4974, ups=1, wpb=3496.986, bsz=146.329, num_updates=49134, lr=0.000142662, gnorm=0.725, clip=0.000, oom=0.000, wall=35393, train_wall=34359
# | epoch 044:    600 / 1131 loss=2.954, nll_loss=1.398, ppl=2.63, wps=4983, ups=1, wpb=3507.433, bsz=145.569, num_updates=49234, lr=0.000142517, gnorm=0.724, clip=0.000, oom=0.000, wall=35464, train_wall=34430
# | epoch 044:    700 / 1131 loss=2.960, nll_loss=1.405, ppl=2.65, wps=4988, ups=1, wpb=3507.509, bsz=145.437, num_updates=49334, lr=0.000142373, gnorm=0.726, clip=0.000, oom=0.000, wall=35534, train_wall=34499
# | epoch 044:    800 / 1131 loss=2.963, nll_loss=1.409, ppl=2.65, wps=4982, ups=1, wpb=3501.464, bsz=143.589, num_updates=49434, lr=0.000142229, gnorm=0.728, clip=0.000, oom=0.000, wall=35604, train_wall=34569
# | epoch 044:    900 / 1131 loss=2.963, nll_loss=1.409, ppl=2.66, wps=4972, ups=1, wpb=3491.553, bsz=144.123, num_updates=49534, lr=0.000142085, gnorm=0.730, clip=0.000, oom=0.000, wall=35674, train_wall=34638
# | epoch 044:   1000 / 1131 loss=2.967, nll_loss=1.413, ppl=2.66, wps=4966, ups=1, wpb=3485.258, bsz=142.600, num_updates=49634, lr=0.000141942, gnorm=0.732, clip=0.000, oom=0.000, wall=35743, train_wall=34708
# | epoch 044:   1100 / 1131 loss=2.971, nll_loss=1.418, ppl=2.67, wps=4974, ups=1, wpb=3491.745, bsz=141.340, num_updates=49734, lr=0.000141799, gnorm=0.733, clip=0.000, oom=0.000, wall=35814, train_wall=34778
# | epoch 044 | loss 2.973 | nll_loss 1.419 | ppl 2.67 | wps 4976 | ups 1 | wpb 3491.701 | bsz 141.679 | num_updates 49764 | lr 0.000141756 | gnorm 0.733 | clip 0.000 | oom 0.000 | wall 35834 | train_wall 34798
# | epoch 044 | valid on 'valid' subset | loss 3.973 | nll_loss 2.407 | ppl 5.30 | num_updates 49764 | best_loss 3.9092
# | saved checkpoint /content/gdrive/My Drive/colab/payless/save_dev4/dynamic_conv_iwslt/checkpoint44.pt (epoch 44 @ 49764 updates) (writing took 4.894705057144165 seconds)
# | epoch 045:    100 / 1131 loss=2.933, nll_loss=1.373, ppl=2.59, wps=4993, ups=1, wpb=3536.970, bsz=143.129, num_updates=49865, lr=0.000141613, gnorm=0.717, clip=0.000, oom=0.000, wall=35923, train_wall=34869
# | epoch 045:    200 / 1131 loss=2.925, nll_loss=1.365, ppl=2.58, wps=4994, ups=1, wpb=3538.562, bsz=150.965, num_updates=49965, lr=0.000141471, gnorm=0.715, clip=0.000, oom=0.000, wall=35994, train_wall=34940
# | epoch 045 | loss 2.924 | nll_loss 1.364 | ppl 2.57 | wps 4988 | ups 1 | wpb 3526.945 | bsz 148.576 | num_updates 50000 | lr 0.000141421 | gnorm 0.717 | clip 0.000 | oom 0.000 | wall 36019 | train_wall 34964
# | epoch 045 | valid on 'valid' subset | loss 3.990 | nll_loss 2.420 | ppl 5.35 | num_updates 50000 | best_loss 3.9092
# | saved checkpoint /content/gdrive/My Drive/colab/payless/save_dev4/dynamic_conv_iwslt/checkpoint_last.pt (epoch 45 @ 50000 updates) (writing took 2.3291015625 seconds)
# | done training in 36031.7 seconds

# %%
# !python scripts/average_checkpoints.py --inputs "{SAVE}" \
    --num-epoch-checkpoints 10 --output "{SAVE}/checkpoint_last10_avg.pt"

# Evaluation
# !CUDA_VISIBLE_DEVICES=0 fairseq-generate data-bin/iwslt14.tokenized.de-en --path "{SAVE}/checkpoint_last10_avg.pt" --batch-size 128 --beam 4 --remove-bpe --lenpen 1 --gen-subset test --quiet
# Out:
# Namespace(checkpoint_upper_bound=None, inputs=['/content/gdrive/My Drive/colab/payless/save_dev4/dynamic_conv_iwslt'], num_epoch_checkpoints=10, num_update_checkpoints=None, output='/content/gdrive/My Drive/colab/payless/save_dev4/dynamic_conv_iwslt/checkpoint_last10_avg.pt')
# averaging checkpoints:  ['/content/gdrive/My Drive/colab/payless/save_dev4/dynamic_conv_iwslt/checkpoint44.pt', '/content/gdrive/My Drive/colab/payless/save_dev4/dynamic_conv_iwslt/checkpoint43.pt', '/content/gdrive/My Drive/colab/payless/save_dev4/dynamic_conv_iwslt/checkpoint42.pt', '/content/gdrive/My Drive/colab/payless/save_dev4/dynamic_conv_iwslt/checkpoint41.pt', '/content/gdrive/My Drive/colab/payless/save_dev4/dynamic_conv_iwslt/checkpoint40.pt', '/content/gdrive/My Drive/colab/payless/save_dev4/dynamic_conv_iwslt/checkpoint39.pt', '/content/gdrive/My Drive/colab/payless/save_dev4/dynamic_conv_iwslt/checkpoint38.pt', '/content/gdrive/My Drive/colab/payless/save_dev4/dynamic_conv_iwslt/checkpoint37.pt', '/content/gdrive/My Drive/colab/payless/save_dev4/dynamic_conv_iwslt/checkpoint36.pt', '/content/gdrive/My Drive/colab/payless/save_dev4/dynamic_conv_iwslt/checkpoint35.pt']
# Finished writing averaged checkpoint to /content/gdrive/My Drive/colab/payless/save_dev4/dynamic_conv_iwslt/checkpoint_last10_avg.pt.
# Namespace(beam=4, bpe=None, cpu=False, criterion='cross_entropy', data='data-bin/iwslt14.tokenized.de-en', dataset_impl=None, decoding_format=None, diverse_beam_groups=-1, diverse_beam_strength=0.5, empty_cache_freq=0, force_anneal=None, fp16=False, fp16_init_scale=128, fp16_scale_tolerance=0.0, fp16_scale_window=None, gen_subset='test', iter_decode_eos_penalty=0.0, iter_decode_force_max_iter=False, iter_decode_max_iter=10, lazy_load=False, left_pad_source='True', left_pad_target='False', lenpen=1.0, load_alignments=False, log_format=None, log_interval=1000, lr_scheduler='fixed', lr_shrink=0.1, match_source_len=False, max_len_a=0, max_len_b=200, max_sentences=128, max_source_positions=1024, max_target_positions=1024, max_tokens=None, memory_efficient_fp16=False, min_len=1, min_loss_scale=0.0001, model_overrides='{}', momentum=0.99, nbest=1, no_beamable_mm=False, no_early_stop=False, no_progress_bar=False, no_repeat_ngram_size=0, num_shards=1, num_workers=1, optimizer='nag', path='/content/gdrive/My Drive/colab/payless/save_dev4/dynamic_conv_iwslt/checkpoint_last10_avg.pt', prefix_size=0, print_alignment=False, print_step=False, quiet=True, raw_text=False, remove_bpe='@@ ', replace_unk=None, required_batch_size_multiple=8, results_path=None, sacrebleu=False, sampling=False, sampling_topk=-1, sampling_topp=-1.0, score_reference=False, seed=1, shard_id=0, skip_invalid_size_inputs_valid_test=False, source_lang=None, target_lang=None, task='translation', tbmf_wrapper=False, temperature=1.0, tensorboard_logdir='', threshold_loss_scale=None, tokenizer=None, unkpen=0, unnormalized=False, upsample_primary=1, user_dir=None, warmup_updates=0, weight_decay=0.0)
# | [de] dictionary: 8848 types
# | [en] dictionary: 6632 types
# | loaded 6750 examples from: data-bin/iwslt14.tokenized.de-en/test.de-en.de
# | loaded 6750 examples from: data-bin/iwslt14.tokenized.de-en/test.de-en.en
# | data-bin/iwslt14.tokenized.de-en test de-en 6750 examples
# | loading model(s) from /content/gdrive/My Drive/colab/payless/save_dev4/dynamic_conv_iwslt/checkpoint_last10_avg.pt
# | Translated 6750 sentences (148274 tokens) in 76.0s (88.77 sentences/s, 1950.00 tokens/s)
# | Generate test with beam=4: BLEU4 = 34.61, 69.0/43.3/29.2/20.1 (BP=0.951, ratio=0.952, syslen=124878, reflen=131161)
