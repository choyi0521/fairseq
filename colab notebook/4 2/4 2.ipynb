# %%
from google.colab import drive
drive.mount('/content/gdrive')

# To install fairseq from source and develop locally:
# !git clone https://github.com/choyi0521/fairseq
# %cd /content/fairseq
# !pip install --editable .
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive
# Cloning into 'fairseq'...
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 12169 (delta 0), reused 1 (delta 0), pack-reused 12164
# Receiving objects: 100% (12169/12169), 5.69 MiB | 3.99 MiB/s, done.
# Resolving deltas: 100% (8965/8965), done.
# /content/fairseq
# Obtaining file:///content/fairseq
# Requirement already satisfied: cffi in /usr/local/lib/python3.6/dist-packages (from fairseq==0.8.0) (1.13.2)
# Requirement already satisfied: cython in /usr/local/lib/python3.6/dist-packages (from fairseq==0.8.0) (0.29.14)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from fairseq==0.8.0) (1.17.4)
# Collecting regex
#   Downloading https://files.pythonhosted.org/packages/e3/8e/cbf2295643d7265e7883326fb4654e643bfc93b3a8a8274d8010a39d8804/regex-2019.11.1-cp36-cp36m-manylinux1_x86_64.whl (643kB)
#      |████████████████████████████████| 645kB 2.0MB/s
# Collecting sacrebleu
#   Downloading https://files.pythonhosted.org/packages/0e/e5/93d252182f7cbd4b59bb3ec5797e2ce33cfd6f5aadaf327db170cf4b7887/sacrebleu-1.4.2-py3-none-any.whl
# Requirement already satisfied: torch in /usr/local/lib/python3.6/dist-packages (from fairseq==0.8.0) (1.3.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from fairseq==0.8.0) (4.28.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.6/dist-packages (from cffi->fairseq==0.8.0) (2.19)
# Requirement already satisfied: typing in /usr/local/lib/python3.6/dist-packages (from sacrebleu->fairseq==0.8.0) (3.6.6)
# Collecting portalocker
#   Downloading https://files.pythonhosted.org/packages/91/db/7bc703c0760df726839e0699b7f78a4d8217fdc9c7fcb1b51b39c5a22a4e/portalocker-1.5.2-py2.py3-none-any.whl
# Installing collected packages: regex, portalocker, sacrebleu, fairseq
#   Running setup.py develop for fairseq
# Successfully installed fairseq portalocker-1.5.2 regex-2019.11.1 sacrebleu-1.4.2

# %%
# !git checkout dev5
# !git pull origin dev5
# Out:
# Branch 'dev5' set up to track remote branch 'dev5' from 'origin'.
# Switched to a new branch 'dev5'
# From https://github.com/choyi0521/fairseq
#  * branch            dev5       -> FETCH_HEAD
# Already up to date.

# %%
# Download and prepare the data
# %cd /content/fairseq
# %cd examples/translation/
# !bash prepare-iwslt14.sh
# %cd ../..

# Preprocess/binarize the data
TEXT="examples/translation/iwslt14.tokenized.de-en"
# !fairseq-preprocess --source-lang de --target-lang en \
    --trainpref $TEXT/train --validpref $TEXT/valid --testpref $TEXT/test \
    --destdir data-bin/iwslt14.tokenized.de-en \
    --workers 20
# Out:
# /content/fairseq
# /content/fairseq/examples/translation
# Cloning Moses github repository (for tokenization scripts)...
# Cloning into 'mosesdecoder'...
# remote: Enumerating objects: 169, done.
# remote: Counting objects: 100% (169/169), done.
# remote: Compressing objects: 100% (89/89), done.
# remote: Total 147464 (delta 104), reused 118 (delta 74), pack-reused 147295
# Receiving objects: 100% (147464/147464), 129.73 MiB | 10.90 MiB/s, done.
# Resolving deltas: 100% (113938/113938), done.
# Cloning Subword NMT repository (for BPE pre-processing)...
# Cloning into 'subword-nmt'...
# remote: Enumerating objects: 29, done.
# remote: Counting objects: 100% (29/29), done.
# remote: Compressing objects: 100% (22/22), done.
# remote: Total 538 (delta 10), reused 21 (delta 7), pack-reused 509
# Receiving objects: 100% (538/538), 226.98 KiB | 629.00 KiB/s, done.
# Resolving deltas: 100% (316/316), done.
# Downloading data from https://wit3.fbk.eu/archive/2014-01/texts/de/en/de-en.tgz...
# --2019-12-01 15:03:02--  https://wit3.fbk.eu/archive/2014-01/texts/de/en/de-en.tgz
# Resolving wit3.fbk.eu (wit3.fbk.eu)... 217.77.80.8
# Connecting to wit3.fbk.eu (wit3.fbk.eu)|217.77.80.8|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 19982877 (19M) [application/x-gzip]
# Saving to: ‘de-en.tgz’
#
# de-en.tgz           100%[===================>]  19.06M  3.46MB/s    in 8.1s
#
# 2019-12-01 15:03:12 (2.35 MB/s) - ‘de-en.tgz’ saved [19982877/19982877]
#
# Data successfully downloaded.
# de-en/
# de-en/IWSLT14.TED.dev2010.de-en.de.xml
# de-en/IWSLT14.TED.dev2010.de-en.en.xml
# de-en/IWSLT14.TED.tst2010.de-en.de.xml
# de-en/IWSLT14.TED.tst2010.de-en.en.xml
# de-en/IWSLT14.TED.tst2011.de-en.de.xml
# de-en/IWSLT14.TED.tst2011.de-en.en.xml
# de-en/IWSLT14.TED.tst2012.de-en.de.xml
# de-en/IWSLT14.TED.tst2012.de-en.en.xml
# de-en/IWSLT14.TEDX.dev2012.de-en.de.xml
# de-en/IWSLT14.TEDX.dev2012.de-en.en.xml
# de-en/README
# de-en/train.en
# de-en/train.tags.de-en.de
# de-en/train.tags.de-en.en
# pre-processing train data...
# Tokenizer Version 1.1
# Language: de
# Number of threads: 8
#
# Tokenizer Version 1.1
# Language: en
# Number of threads: 8
#
# clean-corpus.perl: processing iwslt14.tokenized.de-en/tmp/train.tags.de-en.tok.de & .en to iwslt14.tokenized.de-en/tmp/train.tags.de-en.clean, cutoff 1-175, ratio 1.5
# ..........(100000).......
# Input sentences: 174443  Output sentences:  167522
# pre-processing valid/test data...
# orig/de-en/IWSLT14.TED.dev2010.de-en.de.xml iwslt14.tokenized.de-en/tmp/IWSLT14.TED.dev2010.de-en.de
# Tokenizer Version 1.1
# Language: de
# Number of threads: 8
#
# orig/de-en/IWSLT14.TED.tst2010.de-en.de.xml iwslt14.tokenized.de-en/tmp/IWSLT14.TED.tst2010.de-en.de
# Tokenizer Version 1.1
# Language: de
# Number of threads: 8
#
# orig/de-en/IWSLT14.TED.tst2011.de-en.de.xml iwslt14.tokenized.de-en/tmp/IWSLT14.TED.tst2011.de-en.de
# Tokenizer Version 1.1
# Language: de
# Number of threads: 8
#
# orig/de-en/IWSLT14.TED.tst2012.de-en.de.xml iwslt14.tokenized.de-en/tmp/IWSLT14.TED.tst2012.de-en.de
# Tokenizer Version 1.1
# Language: de
# Number of threads: 8
#
# orig/de-en/IWSLT14.TEDX.dev2012.de-en.de.xml iwslt14.tokenized.de-en/tmp/IWSLT14.TEDX.dev2012.de-en.de
# Tokenizer Version 1.1
# Language: de
# Number of threads: 8
#
# orig/de-en/IWSLT14.TED.dev2010.de-en.en.xml iwslt14.tokenized.de-en/tmp/IWSLT14.TED.dev2010.de-en.en
# Tokenizer Version 1.1
# Language: en
# Number of threads: 8
#
# orig/de-en/IWSLT14.TED.tst2010.de-en.en.xml iwslt14.tokenized.de-en/tmp/IWSLT14.TED.tst2010.de-en.en
# Tokenizer Version 1.1
# Language: en
# Number of threads: 8
#
# orig/de-en/IWSLT14.TED.tst2011.de-en.en.xml iwslt14.tokenized.de-en/tmp/IWSLT14.TED.tst2011.de-en.en
# Tokenizer Version 1.1
# Language: en
# Number of threads: 8
#
# orig/de-en/IWSLT14.TED.tst2012.de-en.en.xml iwslt14.tokenized.de-en/tmp/IWSLT14.TED.tst2012.de-en.en
# Tokenizer Version 1.1
# Language: en
# Number of threads: 8
#
# orig/de-en/IWSLT14.TEDX.dev2012.de-en.en.xml iwslt14.tokenized.de-en/tmp/IWSLT14.TEDX.dev2012.de-en.en
# Tokenizer Version 1.1
# Language: en
# Number of threads: 8
#
# creating train, valid, test...
# learn_bpe.py on iwslt14.tokenized.de-en/tmp/train.en-de...
# subword-nmt/learn_bpe.py:267: DeprecationWarning: this script's location has moved to /content/fairseq/examples/translation/subword-nmt/subword_nmt. This symbolic link will be removed in a future version. Please point to the new location, or install the package and use the command 'subword-nmt'
#   DeprecationWarning
# apply_bpe.py to train.de...
# subword-nmt/apply_bpe.py:328: DeprecationWarning: this script's location has moved to /content/fairseq/examples/translation/subword-nmt/subword_nmt. This symbolic link will be removed in a future version. Please point to the new location, or install the package and use the command 'subword-nmt'
#   DeprecationWarning
# subword-nmt/apply_bpe.py:345: ResourceWarning: unclosed file <_io.TextIOWrapper name='iwslt14.tokenized.de-en/code' mode='r' encoding='UTF-8'>
#   args.codes = codecs.open(args.codes.name, encoding='utf-8')
# apply_bpe.py to valid.de...
# subword-nmt/apply_bpe.py:328: DeprecationWarning: this script's location has moved to /content/fairseq/examples/translation/subword-nmt/subword_nmt. This symbolic link will be removed in a future version. Please point to the new location, or install the package and use the command 'subword-nmt'
#   DeprecationWarning
# subword-nmt/apply_bpe.py:345: ResourceWarning: unclosed file <_io.TextIOWrapper name='iwslt14.tokenized.de-en/code' mode='r' encoding='UTF-8'>
#   args.codes = codecs.open(args.codes.name, encoding='utf-8')
# apply_bpe.py to test.de...
# subword-nmt/apply_bpe.py:328: DeprecationWarning: this script's location has moved to /content/fairseq/examples/translation/subword-nmt/subword_nmt. This symbolic link will be removed in a future version. Please point to the new location, or install the package and use the command 'subword-nmt'
#   DeprecationWarning
# subword-nmt/apply_bpe.py:345: ResourceWarning: unclosed file <_io.TextIOWrapper name='iwslt14.tokenized.de-en/code' mode='r' encoding='UTF-8'>
#   args.codes = codecs.open(args.codes.name, encoding='utf-8')
# apply_bpe.py to train.en...
# subword-nmt/apply_bpe.py:328: DeprecationWarning: this script's location has moved to /content/fairseq/examples/translation/subword-nmt/subword_nmt. This symbolic link will be removed in a future version. Please point to the new location, or install the package and use the command 'subword-nmt'
#   DeprecationWarning
# subword-nmt/apply_bpe.py:345: ResourceWarning: unclosed file <_io.TextIOWrapper name='iwslt14.tokenized.de-en/code' mode='r' encoding='UTF-8'>
#   args.codes = codecs.open(args.codes.name, encoding='utf-8')
# apply_bpe.py to valid.en...
# subword-nmt/apply_bpe.py:328: DeprecationWarning: this script's location has moved to /content/fairseq/examples/translation/subword-nmt/subword_nmt. This symbolic link will be removed in a future version. Please point to the new location, or install the package and use the command 'subword-nmt'
#   DeprecationWarning
# subword-nmt/apply_bpe.py:345: ResourceWarning: unclosed file <_io.TextIOWrapper name='iwslt14.tokenized.de-en/code' mode='r' encoding='UTF-8'>
#   args.codes = codecs.open(args.codes.name, encoding='utf-8')
# apply_bpe.py to test.en...
# subword-nmt/apply_bpe.py:328: DeprecationWarning: this script's location has moved to /content/fairseq/examples/translation/subword-nmt/subword_nmt. This symbolic link will be removed in a future version. Please point to the new location, or install the package and use the command 'subword-nmt'
#   DeprecationWarning
# subword-nmt/apply_bpe.py:345: ResourceWarning: unclosed file <_io.TextIOWrapper name='iwslt14.tokenized.de-en/code' mode='r' encoding='UTF-8'>
#   args.codes = codecs.open(args.codes.name, encoding='utf-8')
# /content/fairseq
# Namespace(align_suffix=None, alignfile=None, bpe=None, cpu=False, criterion='cross_entropy', dataset_impl='mmap', destdir='data-bin/iwslt14.tokenized.de-en', empty_cache_freq=0, fp16=False, fp16_init_scale=128, fp16_scale_tolerance=0.0, fp16_scale_window=None, joined_dictionary=False, log_format=None, log_interval=1000, lr_scheduler='fixed', memory_efficient_fp16=False, min_loss_scale=0.0001, no_progress_bar=False, nwordssrc=-1, nwordstgt=-1, only_source=False, optimizer='nag', padding_factor=8, seed=1, source_lang='de', srcdict=None, target_lang='en', task='translation', tbmf_wrapper=False, tensorboard_logdir='', testpref='examples/translation/iwslt14.tokenized.de-en/test', tgtdict=None, threshold_loss_scale=None, thresholdsrc=0, thresholdtgt=0, tokenizer=None, trainpref='examples/translation/iwslt14.tokenized.de-en/train', user_dir=None, validpref='examples/translation/iwslt14.tokenized.de-en/valid', workers=20)
# | [de] Dictionary: 8847 types
# | [de] examples/translation/iwslt14.tokenized.de-en/train.de: 160239 sents, 4035591 tokens, 0.0% replaced by <unk>
# | [de] Dictionary: 8847 types
# | [de] examples/translation/iwslt14.tokenized.de-en/valid.de: 7283 sents, 182592 tokens, 0.0192% replaced by <unk>
# | [de] Dictionary: 8847 types
# | [de] examples/translation/iwslt14.tokenized.de-en/test.de: 6750 sents, 161838 tokens, 0.0636% replaced by <unk>
# | [en] Dictionary: 6631 types
# | [en] examples/translation/iwslt14.tokenized.de-en/train.en: 160239 sents, 3949114 tokens, 0.0% replaced by <unk>
# | [en] Dictionary: 6631 types
# | [en] examples/translation/iwslt14.tokenized.de-en/valid.en: 7283 sents, 178622 tokens, 0.00448% replaced by <unk>
# | [en] Dictionary: 6631 types
# | [en] examples/translation/iwslt14.tokenized.de-en/test.en: 6750 sents, 156928 tokens, 0.00892% replaced by <unk>
# | Wrote preprocessed data to data-bin/iwslt14.tokenized.de-en

# %%
SAVE="/content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt"

# Training
# %cd /content/fairseq
# !mkdir -p "{SAVE}" 
# !CUDA_VISIBLE_DEVICES=0 $(which fairseq-train) data-bin/iwslt14.tokenized.de-en \
    --encoder-conv-type ddynamic --decoder-conv-type ddynamic \
    --clip-norm 0 --optimizer adam --lr 0.0005 \
    --source-lang de --target-lang en --max-tokens 4000 --no-progress-bar \
    --log-interval 100 --min-lr '1e-09' --weight-decay 0.0001 \
    --criterion label_smoothed_cross_entropy --label-smoothing 0.1 \
    --lr-scheduler inverse_sqrt \
    --ddp-backend=no_c10d \
    --max-update 50000 --warmup-updates 4000 --warmup-init-lr '1e-07' \
    --adam-betas '(0.9, 0.98)' --keep-last-epochs 10 \
    -a lightconv_iwslt_de_en --save-dir "{SAVE}" \
    --dropout 0.3 --attention-dropout 0.1 --weight-dropout 0.1 \
    --encoder-glu 0 --decoder-glu 0 \
    --encoder-gau 0 --decoder-gau 0 \
    --conv-mixed 0 \
    --encoder-attention-heads 4 --decoder-attention-heads 4 \
    --encoder-attention-proj-heads 2 --decoder-attention-proj-heads 2 \
    2>&1 | tee "{SAVE}/train1.log"
# Out:
# /content/fairseq
# Namespace(adam_betas='(0.9, 0.98)', adam_eps=1e-08, adaptive_softmax_cutoff=None, adaptive_softmax_dropout=0, arch='lightconv_iwslt_de_en', attention_dropout=0.1, best_checkpoint_metric='loss', bpe=None, bucket_cap_mb=25, clip_norm=0.0, conv_mixed=False, cpu=False, criterion='label_smoothed_cross_entropy', curriculum=0, data='data-bin/iwslt14.tokenized.de-en', dataset_impl=None, ddp_backend='no_c10d', decoder_attention_heads=4, decoder_attention_proj_heads=2, decoder_conv_dim=512, decoder_conv_type='ddynamic', decoder_embed_dim=512, decoder_embed_path=None, decoder_ffn_embed_dim=1024, decoder_gau=False, decoder_glu=False, decoder_input_dim=512, decoder_kernel_size_list=[3, 7, 15, 31, 31, 31], decoder_layers=6, decoder_learned_pos=False, decoder_normalize_before=False, decoder_output_dim=512, device_id=0, disable_validation=False, distributed_backend='nccl', distributed_init_method=None, distributed_no_spawn=False, distributed_port=-1, distributed_rank=0, distributed_world_size=1, dropout=0.3, empty_cache_freq=0, encoder_attention_heads=4, encoder_attention_proj_heads=2, encoder_conv_dim=512, encoder_conv_type='ddynamic', encoder_embed_dim=512, encoder_embed_path=None, encoder_ffn_embed_dim=1024, encoder_gau=False, encoder_glu=False, encoder_kernel_size_list=[3, 7, 15, 31, 31, 31, 31], encoder_layers=7, encoder_learned_pos=False, encoder_normalize_before=False, fast_stat_sync=False, find_unused_parameters=False, fix_batches_to_gpus=False, fixed_validation_seed=None, fp16=False, fp16_init_scale=128, fp16_scale_tolerance=0.0, fp16_scale_window=None, input_dropout=0.0, keep_interval_updates=-1, keep_last_epochs=10, label_smoothing=0.1, lazy_load=False, left_pad_source='True', left_pad_target='False', load_alignments=False, log_format=None, log_interval=100, lr=[0.0005], lr_scheduler='inverse_sqrt', max_epoch=0, max_sentences=None, max_sentences_valid=None, max_source_positions=1024, max_target_positions=1024, max_tokens=4000, max_tokens_valid=4000, max_update=50000, maximize_best_checkpoint_metric=False, memory_efficient_fp16=False, min_loss_scale=0.0001, min_lr=1e-09, no_epoch_checkpoints=False, no_last_checkpoints=False, no_progress_bar=True, no_save=False, no_save_optimizer_state=False, no_token_positional_embeddings=False, num_workers=1, optimizer='adam', optimizer_overrides='{}', raw_text=False, relu_dropout=0.0, required_batch_size_multiple=8, reset_dataloader=False, reset_lr_scheduler=False, reset_meters=False, reset_optimizer=False, restore_file='checkpoint_last.pt', save_dir='/content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt', save_interval=1, save_interval_updates=0, seed=1, sentence_avg=False, share_all_embeddings=False, share_decoder_input_output_embed=False, skip_invalid_size_inputs_valid_test=False, source_lang='de', target_lang='en', task='translation', tbmf_wrapper=False, tensorboard_logdir='', threshold_loss_scale=None, tokenizer=None, train_subset='train', update_freq=[1], upsample_primary=1, use_bmuf=False, user_dir=None, valid_subset='valid', validate_interval=1, warmup_init_lr=1e-07, warmup_updates=4000, weight_decay=0.0001, weight_dropout=0.1, weight_softmax=True)
# | [de] dictionary: 8848 types
# | [en] dictionary: 6632 types
# | loaded 7283 examples from: data-bin/iwslt14.tokenized.de-en/valid.de-en.de
# | loaded 7283 examples from: data-bin/iwslt14.tokenized.de-en/valid.de-en.en
# | data-bin/iwslt14.tokenized.de-en valid de-en 7283 examples
# LightConvModel(
#   (encoder): LightConvEncoder(
#     (embed_tokens): Embedding(8848, 512, padding_idx=1)
#     (embed_positions): SinusoidalPositionalEmbedding()
#     (layers): ModuleList(
#       (0): LightConvEncoderLayer(
#         dropout=0.3, relu_dropout=0.0, input_dropout=0.0, normalize_before=False
#         (linear1): Linear(in_features=512, out_features=512, bias=True)
#         (conv): DDynamicConv1dTBC(
#           512, kernel_size=3, padding_l=1, num_heads=4, num_proj_heads=2, conv_mixed=False, weight_softmax=True, conv_bias=False, renorm_padding=False, in_proj=False, weight_dropout=0.1
#           (weight_linear): Linear(in_features=256, out_features=24, bias=False)
#         )
#         (linear2): Linear(in_features=512, out_features=512, bias=True)
#         (fc1): Linear(in_features=512, out_features=1024, bias=True)
#         (fc2): Linear(in_features=1024, out_features=512, bias=True)
#         (layer_norms): ModuleList(
#           (0): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#       (1): LightConvEncoderLayer(
#         dropout=0.3, relu_dropout=0.0, input_dropout=0.0, normalize_before=False
#         (linear1): Linear(in_features=512, out_features=512, bias=True)
#         (conv): DDynamicConv1dTBC(
#           512, kernel_size=7, padding_l=3, num_heads=4, num_proj_heads=2, conv_mixed=False, weight_softmax=True, conv_bias=False, renorm_padding=False, in_proj=False, weight_dropout=0.1
#           (weight_linear): Linear(in_features=256, out_features=56, bias=False)
#         )
#         (linear2): Linear(in_features=512, out_features=512, bias=True)
#         (fc1): Linear(in_features=512, out_features=1024, bias=True)
#         (fc2): Linear(in_features=1024, out_features=512, bias=True)
#         (layer_norms): ModuleList(
#           (0): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#       (2): LightConvEncoderLayer(
#         dropout=0.3, relu_dropout=0.0, input_dropout=0.0, normalize_before=False
#         (linear1): Linear(in_features=512, out_features=512, bias=True)
#         (conv): DDynamicConv1dTBC(
#           512, kernel_size=15, padding_l=7, num_heads=4, num_proj_heads=2, conv_mixed=False, weight_softmax=True, conv_bias=False, renorm_padding=False, in_proj=False, weight_dropout=0.1
#           (weight_linear): Linear(in_features=256, out_features=120, bias=False)
#         )
#         (linear2): Linear(in_features=512, out_features=512, bias=True)
#         (fc1): Linear(in_features=512, out_features=1024, bias=True)
#         (fc2): Linear(in_features=1024, out_features=512, bias=True)
#         (layer_norms): ModuleList(
#           (0): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#       (3): LightConvEncoderLayer(
#         dropout=0.3, relu_dropout=0.0, input_dropout=0.0, normalize_before=False
#         (linear1): Linear(in_features=512, out_features=512, bias=True)
#         (conv): DDynamicConv1dTBC(
#           512, kernel_size=31, padding_l=15, num_heads=4, num_proj_heads=2, conv_mixed=False, weight_softmax=True, conv_bias=False, renorm_padding=False, in_proj=False, weight_dropout=0.1
#           (weight_linear): Linear(in_features=256, out_features=248, bias=False)
#         )
#         (linear2): Linear(in_features=512, out_features=512, bias=True)
#         (fc1): Linear(in_features=512, out_features=1024, bias=True)
#         (fc2): Linear(in_features=1024, out_features=512, bias=True)
#         (layer_norms): ModuleList(
#           (0): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#       (4): LightConvEncoderLayer(
#         dropout=0.3, relu_dropout=0.0, input_dropout=0.0, normalize_before=False
#         (linear1): Linear(in_features=512, out_features=512, bias=True)
#         (conv): DDynamicConv1dTBC(
#           512, kernel_size=31, padding_l=15, num_heads=4, num_proj_heads=2, conv_mixed=False, weight_softmax=True, conv_bias=False, renorm_padding=False, in_proj=False, weight_dropout=0.1
#           (weight_linear): Linear(in_features=256, out_features=248, bias=False)
#         )
#         (linear2): Linear(in_features=512, out_features=512, bias=True)
#         (fc1): Linear(in_features=512, out_features=1024, bias=True)
#         (fc2): Linear(in_features=1024, out_features=512, bias=True)
#         (layer_norms): ModuleList(
#           (0): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#       (5): LightConvEncoderLayer(
#         dropout=0.3, relu_dropout=0.0, input_dropout=0.0, normalize_before=False
#         (linear1): Linear(in_features=512, out_features=512, bias=True)
#         (conv): DDynamicConv1dTBC(
#           512, kernel_size=31, padding_l=15, num_heads=4, num_proj_heads=2, conv_mixed=False, weight_softmax=True, conv_bias=False, renorm_padding=False, in_proj=False, weight_dropout=0.1
#           (weight_linear): Linear(in_features=256, out_features=248, bias=False)
#         )
#         (linear2): Linear(in_features=512, out_features=512, bias=True)
#         (fc1): Linear(in_features=512, out_features=1024, bias=True)
#         (fc2): Linear(in_features=1024, out_features=512, bias=True)
#         (layer_norms): ModuleList(
#           (0): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#       (6): LightConvEncoderLayer(
#         dropout=0.3, relu_dropout=0.0, input_dropout=0.0, normalize_before=False
#         (linear1): Linear(in_features=512, out_features=512, bias=True)
#         (conv): DDynamicConv1dTBC(
#           512, kernel_size=31, padding_l=15, num_heads=4, num_proj_heads=2, conv_mixed=False, weight_softmax=True, conv_bias=False, renorm_padding=False, in_proj=False, weight_dropout=0.1
#           (weight_linear): Linear(in_features=256, out_features=248, bias=False)
#         )
#         (linear2): Linear(in_features=512, out_features=512, bias=True)
#         (fc1): Linear(in_features=512, out_features=1024, bias=True)
#         (fc2): Linear(in_features=1024, out_features=512, bias=True)
#         (layer_norms): ModuleList(
#           (0): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#     )
#   )
#   (decoder): LightConvDecoder(
#     (embed_tokens): Embedding(6632, 512, padding_idx=1)
#     (embed_positions): SinusoidalPositionalEmbedding()
#     (layers): ModuleList(
#       (0): LightConvDecoderLayer(
#         dropout=0.3, relu_dropout=0.0, input_dropout=0.0, normalize_before=False
#         (linear1): Linear(in_features=512, out_features=512, bias=True)
#         (conv): DDynamicConv1dTBC(
#           512, kernel_size=3, padding_l=2, num_heads=4, num_proj_heads=2, conv_mixed=False, weight_softmax=True, conv_bias=False, renorm_padding=False, in_proj=False, weight_dropout=0.1
#           (weight_linear): Linear(in_features=256, out_features=24, bias=False)
#         )
#         (linear2): Linear(in_features=512, out_features=512, bias=True)
#         (conv_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): MultiheadAttention(
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=1024, bias=True)
#         (fc2): Linear(in_features=1024, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (1): LightConvDecoderLayer(
#         dropout=0.3, relu_dropout=0.0, input_dropout=0.0, normalize_before=False
#         (linear1): Linear(in_features=512, out_features=512, bias=True)
#         (conv): DDynamicConv1dTBC(
#           512, kernel_size=7, padding_l=6, num_heads=4, num_proj_heads=2, conv_mixed=False, weight_softmax=True, conv_bias=False, renorm_padding=False, in_proj=False, weight_dropout=0.1
#           (weight_linear): Linear(in_features=256, out_features=56, bias=False)
#         )
#         (linear2): Linear(in_features=512, out_features=512, bias=True)
#         (conv_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): MultiheadAttention(
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=1024, bias=True)
#         (fc2): Linear(in_features=1024, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (2): LightConvDecoderLayer(
#         dropout=0.3, relu_dropout=0.0, input_dropout=0.0, normalize_before=False
#         (linear1): Linear(in_features=512, out_features=512, bias=True)
#         (conv): DDynamicConv1dTBC(
#           512, kernel_size=15, padding_l=14, num_heads=4, num_proj_heads=2, conv_mixed=False, weight_softmax=True, conv_bias=False, renorm_padding=False, in_proj=False, weight_dropout=0.1
#           (weight_linear): Linear(in_features=256, out_features=120, bias=False)
#         )
#         (linear2): Linear(in_features=512, out_features=512, bias=True)
#         (conv_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): MultiheadAttention(
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=1024, bias=True)
#         (fc2): Linear(in_features=1024, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (3): LightConvDecoderLayer(
#         dropout=0.3, relu_dropout=0.0, input_dropout=0.0, normalize_before=False
#         (linear1): Linear(in_features=512, out_features=512, bias=True)
#         (conv): DDynamicConv1dTBC(
#           512, kernel_size=31, padding_l=30, num_heads=4, num_proj_heads=2, conv_mixed=False, weight_softmax=True, conv_bias=False, renorm_padding=False, in_proj=False, weight_dropout=0.1
#           (weight_linear): Linear(in_features=256, out_features=248, bias=False)
#         )
#         (linear2): Linear(in_features=512, out_features=512, bias=True)
#         (conv_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): MultiheadAttention(
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=1024, bias=True)
#         (fc2): Linear(in_features=1024, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (4): LightConvDecoderLayer(
#         dropout=0.3, relu_dropout=0.0, input_dropout=0.0, normalize_before=False
#         (linear1): Linear(in_features=512, out_features=512, bias=True)
#         (conv): DDynamicConv1dTBC(
#           512, kernel_size=31, padding_l=30, num_heads=4, num_proj_heads=2, conv_mixed=False, weight_softmax=True, conv_bias=False, renorm_padding=False, in_proj=False, weight_dropout=0.1
#           (weight_linear): Linear(in_features=256, out_features=248, bias=False)
#         )
#         (linear2): Linear(in_features=512, out_features=512, bias=True)
#         (conv_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): MultiheadAttention(
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=1024, bias=True)
#         (fc2): Linear(in_features=1024, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (5): LightConvDecoderLayer(
#         dropout=0.3, relu_dropout=0.0, input_dropout=0.0, normalize_before=False
#         (linear1): Linear(in_features=512, out_features=512, bias=True)
#         (conv): DDynamicConv1dTBC(
#           512, kernel_size=31, padding_l=30, num_heads=4, num_proj_heads=2, conv_mixed=False, weight_softmax=True, conv_bias=False, renorm_padding=False, in_proj=False, weight_dropout=0.1
#           (weight_linear): Linear(in_features=256, out_features=248, bias=False)
#         )
#         (linear2): Linear(in_features=512, out_features=512, bias=True)
#         (conv_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): MultiheadAttention(
#           (k_proj): Linear(in_features=512, out_features=512, bias=True)
#           (v_proj): Linear(in_features=512, out_features=512, bias=True)
#           (q_proj): Linear(in_features=512, out_features=512, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=1024, bias=True)
#         (fc2): Linear(in_features=1024, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#   )
# )
# | model lightconv_iwslt_de_en, criterion LabelSmoothedCrossEntropyCriterion
# | num. model params: 38685184 (num. trained: 38685184)
# | training on 1 GPUs
# | max tokens per GPU = 4000 and max sentences per GPU = None
# | loaded checkpoint /content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint_last.pt (epoch 19 @ 21489 updates)
# | loading train data for epoch 19
# | loaded 160239 examples from: data-bin/iwslt14.tokenized.de-en/train.de-en.de
# | loaded 160239 examples from: data-bin/iwslt14.tokenized.de-en/train.de-en.en
# | data-bin/iwslt14.tokenized.de-en train de-en 160239 examples
# | epoch 020:    100 / 1131 loss=3.415, nll_loss=1.936, ppl=3.83, wps=6310, ups=2, wpb=3459.000, bsz=135.921, num_updates=21590, lr=0.000215216, gnorm=0.705, clip=0.000, oom=0.000, wall=57, train_wall=4436
# | epoch 020:    200 / 1131 loss=3.421, nll_loss=1.942, ppl=3.84, wps=6267, ups=2, wpb=3470.358, bsz=135.562, num_updates=21690, lr=0.000214719, gnorm=0.704, clip=0.000, oom=0.000, wall=113, train_wall=4491
# | epoch 020:    300 / 1131 loss=3.433, nll_loss=1.956, ppl=3.88, wps=6255, ups=2, wpb=3484.900, bsz=136.106, num_updates=21790, lr=0.000214226, gnorm=0.706, clip=0.000, oom=0.000, wall=170, train_wall=4547
# | epoch 020:    400 / 1131 loss=3.434, nll_loss=1.957, ppl=3.88, wps=6236, ups=2, wpb=3490.249, bsz=138.252, num_updates=21890, lr=0.000213736, gnorm=0.706, clip=0.000, oom=0.000, wall=226, train_wall=4603
# | epoch 020:    500 / 1131 loss=3.437, nll_loss=1.961, ppl=3.89, wps=6235, ups=2, wpb=3498.699, bsz=140.277, num_updates=21990, lr=0.000213249, gnorm=0.705, clip=0.000, oom=0.000, wall=283, train_wall=4660
# | epoch 020:    600 / 1131 loss=3.438, nll_loss=1.963, ppl=3.90, wps=6227, ups=2, wpb=3498.932, bsz=143.240, num_updates=22090, lr=0.000212766, gnorm=0.705, clip=0.000, oom=0.000, wall=340, train_wall=4716
# | epoch 020:    700 / 1131 loss=3.439, nll_loss=1.963, ppl=3.90, wps=6226, ups=2, wpb=3501.904, bsz=143.074, num_updates=22190, lr=0.000212286, gnorm=0.704, clip=0.000, oom=0.000, wall=396, train_wall=4772
# | epoch 020:    800 / 1131 loss=3.444, nll_loss=1.969, ppl=3.92, wps=6205, ups=2, wpb=3490.060, bsz=141.222, num_updates=22290, lr=0.000211809, gnorm=0.707, clip=0.000, oom=0.000, wall=452, train_wall=4828
# | epoch 020:    900 / 1131 loss=3.446, nll_loss=1.972, ppl=3.92, wps=6203, ups=2, wpb=3492.119, bsz=140.714, num_updates=22390, lr=0.000211336, gnorm=0.706, clip=0.000, oom=0.000, wall=509, train_wall=4884
# | epoch 020:   1000 / 1131 loss=3.448, nll_loss=1.974, ppl=3.93, wps=6205, ups=2, wpb=3493.976, bsz=141.817, num_updates=22490, lr=0.000210865, gnorm=0.707, clip=0.000, oom=0.000, wall=565, train_wall=4940
# | epoch 020:   1100 / 1131 loss=3.451, nll_loss=1.977, ppl=3.94, wps=6202, ups=2, wpb=3492.361, bsz=141.863, num_updates=22590, lr=0.000210398, gnorm=0.707, clip=0.000, oom=0.000, wall=622, train_wall=4996
# | epoch 020 | loss 3.452 | nll_loss 1.978 | ppl 3.94 | wps 6200 | ups 2 | wpb 3491.701 | bsz 141.679 | num_updates 22620 | lr 0.000210259 | gnorm 0.708 | clip 0.000 | oom 0.000 | wall 639 | train_wall 5013
# | epoch 020 | valid on 'valid' subset | loss 3.911 | nll_loss 2.349 | ppl 5.10 | num_updates 22620 | best_loss 3.90886
# | saved checkpoint /content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint20.pt (epoch 20 @ 22620 updates) (writing took 3.910651683807373 seconds)
# | epoch 021:    100 / 1131 loss=3.356, nll_loss=1.868, ppl=3.65, wps=6132, ups=2, wpb=3515.366, bsz=148.356, num_updates=22721, lr=0.000209791, gnorm=0.682, clip=0.000, oom=0.000, wall=712, train_wall=5070
# | epoch 021:    200 / 1131 loss=3.373, nll_loss=1.887, ppl=3.70, wps=6138, ups=2, wpb=3483.294, bsz=145.910, num_updates=22821, lr=0.000209331, gnorm=0.695, clip=0.000, oom=0.000, wall=768, train_wall=5126
# | epoch 021:    300 / 1131 loss=3.382, nll_loss=1.898, ppl=3.73, wps=6154, ups=2, wpb=3491.385, bsz=146.738, num_updates=22921, lr=0.000208873, gnorm=0.697, clip=0.000, oom=0.000, wall=825, train_wall=5182
# | epoch 021:    400 / 1131 loss=3.395, nll_loss=1.913, ppl=3.77, wps=6147, ups=2, wpb=3475.751, bsz=142.803, num_updates=23021, lr=0.000208419, gnorm=0.705, clip=0.000, oom=0.000, wall=881, train_wall=5238
# | epoch 021:    500 / 1131 loss=3.401, nll_loss=1.920, ppl=3.78, wps=6159, ups=2, wpb=3477.473, bsz=143.138, num_updates=23121, lr=0.000207968, gnorm=0.706, clip=0.000, oom=0.000, wall=937, train_wall=5293
# | epoch 021:    600 / 1131 loss=3.405, nll_loss=1.924, ppl=3.79, wps=6168, ups=2, wpb=3482.561, bsz=141.444, num_updates=23221, lr=0.00020752, gnorm=0.706, clip=0.000, oom=0.000, wall=993, train_wall=5349
# | epoch 021:    700 / 1131 loss=3.411, nll_loss=1.931, ppl=3.81, wps=6168, ups=2, wpb=3483.415, bsz=141.591, num_updates=23321, lr=0.000207074, gnorm=0.708, clip=0.000, oom=0.000, wall=1050, train_wall=5405
# | epoch 021:    800 / 1131 loss=3.416, nll_loss=1.936, ppl=3.83, wps=6159, ups=2, wpb=3472.457, bsz=141.332, num_updates=23421, lr=0.000206632, gnorm=0.711, clip=0.000, oom=0.000, wall=1105, train_wall=5461
# | epoch 021:    900 / 1131 loss=3.419, nll_loss=1.940, ppl=3.84, wps=6172, ups=2, wpb=3483.905, bsz=142.125, num_updates=23521, lr=0.000206192, gnorm=0.710, clip=0.000, oom=0.000, wall=1162, train_wall=5517
# | epoch 021:   1000 / 1131 loss=3.420, nll_loss=1.941, ppl=3.84, wps=6170, ups=2, wpb=3486.550, bsz=142.265, num_updates=23621, lr=0.000205755, gnorm=0.709, clip=0.000, oom=0.000, wall=1219, train_wall=5574
# | epoch 021:   1100 / 1131 loss=3.421, nll_loss=1.943, ppl=3.85, wps=6176, ups=2, wpb=3491.718, bsz=142.953, num_updates=23721, lr=0.000205321, gnorm=0.709, clip=0.000, oom=0.000, wall=1276, train_wall=5630
# | epoch 021 | loss 3.425 | nll_loss 1.947 | ppl 3.86 | wps 6176 | ups 2 | wpb 3491.701 | bsz 141.679 | num_updates 23751 | lr 0.000205191 | gnorm 0.710 | clip 0.000 | oom 0.000 | wall 1293 | train_wall 5647
# | epoch 021 | valid on 'valid' subset | loss 3.905 | nll_loss 2.342 | ppl 5.07 | num_updates 23751 | best_loss 3.90541
# | saved checkpoint /content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint21.pt (epoch 21 @ 23751 updates) (writing took 9.514415502548218 seconds)
# | epoch 022:    100 / 1131 loss=3.380, nll_loss=1.893, ppl=3.71, wps=6050, ups=2, wpb=3432.436, bsz=126.733, num_updates=23852, lr=0.000204756, gnorm=0.719, clip=0.000, oom=0.000, wall=1371, train_wall=5704
# | epoch 022:    200 / 1131 loss=3.362, nll_loss=1.874, ppl=3.67, wps=6156, ups=2, wpb=3494.234, bsz=140.577, num_updates=23952, lr=0.000204329, gnorm=0.703, clip=0.000, oom=0.000, wall=1428, train_wall=5760
# | epoch 022:    300 / 1131 loss=3.371, nll_loss=1.885, ppl=3.69, wps=6170, ups=2, wpb=3487.462, bsz=141.236, num_updates=24052, lr=0.000203903, gnorm=0.705, clip=0.000, oom=0.000, wall=1484, train_wall=5816
# | epoch 022:    400 / 1131 loss=3.363, nll_loss=1.876, ppl=3.67, wps=6145, ups=2, wpb=3468.918, bsz=145.975, num_updates=24152, lr=0.000203481, gnorm=0.707, clip=0.000, oom=0.000, wall=1540, train_wall=5872
# | epoch 022:    500 / 1131 loss=3.370, nll_loss=1.884, ppl=3.69, wps=6162, ups=2, wpb=3477.263, bsz=144.894, num_updates=24252, lr=0.000203061, gnorm=0.708, clip=0.000, oom=0.000, wall=1597, train_wall=5928
# | epoch 022:    600 / 1131 loss=3.381, nll_loss=1.897, ppl=3.72, wps=6176, ups=2, wpb=3485.371, bsz=143.281, num_updates=24352, lr=0.000202644, gnorm=0.711, clip=0.000, oom=0.000, wall=1653, train_wall=5984
# | epoch 022:    700 / 1131 loss=3.380, nll_loss=1.895, ppl=3.72, wps=6179, ups=2, wpb=3488.231, bsz=143.726, num_updates=24452, lr=0.000202229, gnorm=0.710, clip=0.000, oom=0.000, wall=1710, train_wall=6040
# | epoch 022:    800 / 1131 loss=3.382, nll_loss=1.898, ppl=3.73, wps=6184, ups=2, wpb=3495.121, bsz=144.779, num_updates=24552, lr=0.000201816, gnorm=0.710, clip=0.000, oom=0.000, wall=1767, train_wall=6096
# | epoch 022:    900 / 1131 loss=3.390, nll_loss=1.906, ppl=3.75, wps=6180, ups=2, wpb=3491.502, bsz=143.306, num_updates=24652, lr=0.000201407, gnorm=0.712, clip=0.000, oom=0.000, wall=1823, train_wall=6152
# | epoch 022:   1000 / 1131 loss=3.397, nll_loss=1.915, ppl=3.77, wps=6174, ups=2, wpb=3487.072, bsz=140.666, num_updates=24752, lr=0.000200999, gnorm=0.715, clip=0.000, oom=0.000, wall=1879, train_wall=6208
# | epoch 022:   1100 / 1131 loss=3.399, nll_loss=1.918, ppl=3.78, wps=6182, ups=2, wpb=3491.807, bsz=141.558, num_updates=24852, lr=0.000200595, gnorm=0.715, clip=0.000, oom=0.000, wall=1936, train_wall=6264
# | epoch 022 | loss 3.401 | nll_loss 1.920 | ppl 3.78 | wps 6182 | ups 2 | wpb 3491.701 | bsz 141.679 | num_updates 24882 | lr 0.000200474 | gnorm 0.715 | clip 0.000 | oom 0.000 | wall 1953 | train_wall 6281
# | epoch 022 | valid on 'valid' subset | loss 3.910 | nll_loss 2.346 | ppl 5.08 | num_updates 24882 | best_loss 3.90541
# | saved checkpoint /content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint22.pt (epoch 22 @ 24882 updates) (writing took 4.205172538757324 seconds)
# | epoch 023:    100 / 1131 loss=3.335, nll_loss=1.844, ppl=3.59, wps=6129, ups=2, wpb=3500.772, bsz=146.851, num_updates=24983, lr=0.000200068, gnorm=0.697, clip=0.000, oom=0.000, wall=2026, train_wall=6338
# | epoch 023:    200 / 1131 loss=3.355, nll_loss=1.865, ppl=3.64, wps=6211, ups=2, wpb=3535.856, bsz=140.100, num_updates=25083, lr=0.000199669, gnorm=0.700, clip=0.000, oom=0.000, wall=2082, train_wall=6394
# | epoch 023:    300 / 1131 loss=3.363, nll_loss=1.875, ppl=3.67, wps=6195, ups=2, wpb=3507.266, bsz=138.445, num_updates=25183, lr=0.000199272, gnorm=0.708, clip=0.000, oom=0.000, wall=2138, train_wall=6450
# | epoch 023:    400 / 1131 loss=3.354, nll_loss=1.865, ppl=3.64, wps=6183, ups=2, wpb=3491.818, bsz=141.387, num_updates=25283, lr=0.000198878, gnorm=0.709, clip=0.000, oom=0.000, wall=2194, train_wall=6506
# | epoch 023:    500 / 1131 loss=3.356, nll_loss=1.867, ppl=3.65, wps=6194, ups=2, wpb=3503.709, bsz=142.739, num_updates=25383, lr=0.000198485, gnorm=0.708, clip=0.000, oom=0.000, wall=2251, train_wall=6562
# | epoch 023:    600 / 1131 loss=3.370, nll_loss=1.883, ppl=3.69, wps=6192, ups=2, wpb=3496.461, bsz=138.394, num_updates=25483, lr=0.000198096, gnorm=0.714, clip=0.000, oom=0.000, wall=2307, train_wall=6618
# | epoch 023:    700 / 1131 loss=3.375, nll_loss=1.888, ppl=3.70, wps=6187, ups=2, wpb=3492.546, bsz=137.688, num_updates=25583, lr=0.000197708, gnorm=0.716, clip=0.000, oom=0.000, wall=2364, train_wall=6673
# | epoch 023:    800 / 1131 loss=3.374, nll_loss=1.888, ppl=3.70, wps=6186, ups=2, wpb=3489.687, bsz=139.644, num_updates=25683, lr=0.000197323, gnorm=0.717, clip=0.000, oom=0.000, wall=2420, train_wall=6729
# | epoch 023:    900 / 1131 loss=3.377, nll_loss=1.891, ppl=3.71, wps=6184, ups=2, wpb=3489.576, bsz=139.808, num_updates=25783, lr=0.00019694, gnorm=0.717, clip=0.000, oom=0.000, wall=2476, train_wall=6785
# | epoch 023:   1000 / 1131 loss=3.377, nll_loss=1.891, ppl=3.71, wps=6184, ups=2, wpb=3489.438, bsz=140.403, num_updates=25883, lr=0.000196559, gnorm=0.717, clip=0.000, oom=0.000, wall=2533, train_wall=6841
# | epoch 023:   1100 / 1131 loss=3.377, nll_loss=1.891, ppl=3.71, wps=6180, ups=2, wpb=3490.091, bsz=141.231, num_updates=25983, lr=0.00019618, gnorm=0.717, clip=0.000, oom=0.000, wall=2590, train_wall=6898
# | epoch 023 | loss 3.377 | nll_loss 1.891 | ppl 3.71 | wps 6181 | ups 2 | wpb 3491.701 | bsz 141.679 | num_updates 26013 | lr 0.000196067 | gnorm 0.717 | clip 0.000 | oom 0.000 | wall 2607 | train_wall 6915
# | epoch 023 | valid on 'valid' subset | loss 3.907 | nll_loss 2.343 | ppl 5.07 | num_updates 26013 | best_loss 3.90541
# | saved checkpoint /content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint23.pt (epoch 23 @ 26013 updates) (writing took 4.315961837768555 seconds)
# | epoch 024:    100 / 1131 loss=3.301, nll_loss=1.804, ppl=3.49, wps=6075, ups=2, wpb=3474.535, bsz=149.307, num_updates=26114, lr=0.000195688, gnorm=0.707, clip=0.000, oom=0.000, wall=2680, train_wall=6972
# | epoch 024:    200 / 1131 loss=3.324, nll_loss=1.830, ppl=3.56, wps=6150, ups=2, wpb=3489.632, bsz=141.970, num_updates=26214, lr=0.000195314, gnorm=0.711, clip=0.000, oom=0.000, wall=2736, train_wall=7028
# | epoch 024:    300 / 1131 loss=3.338, nll_loss=1.846, ppl=3.59, wps=6171, ups=2, wpb=3489.027, bsz=138.179, num_updates=26314, lr=0.000194943, gnorm=0.716, clip=0.000, oom=0.000, wall=2792, train_wall=7084
# | epoch 024:    400 / 1131 loss=3.336, nll_loss=1.843, ppl=3.59, wps=6167, ups=2, wpb=3487.040, bsz=139.012, num_updates=26414, lr=0.000194573, gnorm=0.718, clip=0.000, oom=0.000, wall=2849, train_wall=7140
# | epoch 024:    500 / 1131 loss=3.341, nll_loss=1.848, ppl=3.60, wps=6171, ups=2, wpb=3485.293, bsz=139.257, num_updates=26514, lr=0.000194206, gnorm=0.720, clip=0.000, oom=0.000, wall=2905, train_wall=7195
# | epoch 024:    600 / 1131 loss=3.345, nll_loss=1.853, ppl=3.61, wps=6178, ups=2, wpb=3486.499, bsz=139.913, num_updates=26614, lr=0.000193841, gnorm=0.721, clip=0.000, oom=0.000, wall=2961, train_wall=7251
# | epoch 024:    700 / 1131 loss=3.345, nll_loss=1.854, ppl=3.61, wps=6185, ups=2, wpb=3494.181, bsz=140.371, num_updates=26714, lr=0.000193478, gnorm=0.719, clip=0.000, oom=0.000, wall=3018, train_wall=7308
# | epoch 024:    800 / 1131 loss=3.347, nll_loss=1.856, ppl=3.62, wps=6186, ups=2, wpb=3496.223, bsz=140.365, num_updates=26814, lr=0.000193116, gnorm=0.720, clip=0.000, oom=0.000, wall=3075, train_wall=7364
# | epoch 024:    900 / 1131 loss=3.349, nll_loss=1.859, ppl=3.63, wps=6181, ups=2, wpb=3491.495, bsz=141.052, num_updates=26914, lr=0.000192757, gnorm=0.721, clip=0.000, oom=0.000, wall=3131, train_wall=7420
# | epoch 024:   1000 / 1131 loss=3.352, nll_loss=1.862, ppl=3.63, wps=6181, ups=2, wpb=3493.110, bsz=141.801, num_updates=27014, lr=0.0001924, gnorm=0.722, clip=0.000, oom=0.000, wall=3188, train_wall=7476
# | epoch 024:   1100 / 1131 loss=3.355, nll_loss=1.866, ppl=3.64, wps=6181, ups=2, wpb=3491.548, bsz=142.117, num_updates=27114, lr=0.000192045, gnorm=0.722, clip=0.000, oom=0.000, wall=3244, train_wall=7532
# | epoch 024 | loss 3.356 | nll_loss 1.867 | ppl 3.65 | wps 6181 | ups 2 | wpb 3491.701 | bsz 141.679 | num_updates 27144 | lr 0.000191939 | gnorm 0.722 | clip 0.000 | oom 0.000 | wall 3261 | train_wall 7549
# | epoch 024 | valid on 'valid' subset | loss 3.906 | nll_loss 2.338 | ppl 5.06 | num_updates 27144 | best_loss 3.90541
# | saved checkpoint /content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint24.pt (epoch 24 @ 27144 updates) (writing took 4.9086620807647705 seconds)
# | epoch 025:    100 / 1131 loss=3.276, nll_loss=1.773, ppl=3.42, wps=6042, ups=2, wpb=3426.891, bsz=133.782, num_updates=27245, lr=0.000191583, gnorm=0.719, clip=0.000, oom=0.000, wall=3334, train_wall=7605
# | epoch 025:    200 / 1131 loss=3.285, nll_loss=1.784, ppl=3.44, wps=6161, ups=2, wpb=3499.294, bsz=142.368, num_updates=27345, lr=0.000191232, gnorm=0.712, clip=0.000, oom=0.000, wall=3391, train_wall=7662
# | epoch 025:    300 / 1131 loss=3.292, nll_loss=1.792, ppl=3.46, wps=6179, ups=2, wpb=3502.631, bsz=143.256, num_updates=27445, lr=0.000190883, gnorm=0.712, clip=0.000, oom=0.000, wall=3448, train_wall=7718
# | epoch 025:    400 / 1131 loss=3.298, nll_loss=1.799, ppl=3.48, wps=6168, ups=2, wpb=3491.853, bsz=141.903, num_updates=27545, lr=0.000190537, gnorm=0.720, clip=0.000, oom=0.000, wall=3504, train_wall=7774
# | epoch 025:    500 / 1131 loss=3.308, nll_loss=1.811, ppl=3.51, wps=6170, ups=2, wpb=3490.461, bsz=141.395, num_updates=27645, lr=0.000190192, gnorm=0.722, clip=0.000, oom=0.000, wall=3560, train_wall=7830
# | epoch 025:    600 / 1131 loss=3.316, nll_loss=1.821, ppl=3.53, wps=6193, ups=2, wpb=3506.962, bsz=140.391, num_updates=27745, lr=0.000189849, gnorm=0.721, clip=0.000, oom=0.000, wall=3617, train_wall=7886
# | epoch 025:    700 / 1131 loss=3.323, nll_loss=1.829, ppl=3.55, wps=6182, ups=2, wpb=3497.418, bsz=138.954, num_updates=27845, lr=0.000189507, gnorm=0.725, clip=0.000, oom=0.000, wall=3674, train_wall=7942
# | epoch 025:    800 / 1131 loss=3.327, nll_loss=1.833, ppl=3.56, wps=6179, ups=2, wpb=3494.496, bsz=137.996, num_updates=27945, lr=0.000189168, gnorm=0.725, clip=0.000, oom=0.000, wall=3730, train_wall=7998
# | epoch 025:    900 / 1131 loss=3.329, nll_loss=1.835, ppl=3.57, wps=6170, ups=2, wpb=3490.186, bsz=139.195, num_updates=28045, lr=0.000188831, gnorm=0.725, clip=0.000, oom=0.000, wall=3787, train_wall=8054
# | epoch 025:   1000 / 1131 loss=3.328, nll_loss=1.834, ppl=3.57, wps=6172, ups=2, wpb=3494.894, bsz=141.282, num_updates=28145, lr=0.000188495, gnorm=0.723, clip=0.000, oom=0.000, wall=3844, train_wall=8111
# | epoch 025:   1100 / 1131 loss=3.334, nll_loss=1.842, ppl=3.58, wps=6179, ups=2, wpb=3495.530, bsz=141.667, num_updates=28245, lr=0.000188161, gnorm=0.725, clip=0.000, oom=0.000, wall=3900, train_wall=8167
# | epoch 025 | loss 3.335 | nll_loss 1.843 | ppl 3.59 | wps 6176 | ups 2 | wpb 3491.701 | bsz 141.679 | num_updates 28275 | lr 0.000188061 | gnorm 0.726 | clip 0.000 | oom 0.000 | wall 3916 | train_wall 8183
# | epoch 025 | valid on 'valid' subset | loss 3.908 | nll_loss 2.341 | ppl 5.07 | num_updates 28275 | best_loss 3.90541
# | saved checkpoint /content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint25.pt (epoch 25 @ 28275 updates) (writing took 4.157628059387207 seconds)
# | epoch 026:    100 / 1131 loss=3.220, nll_loss=1.712, ppl=3.28, wps=6132, ups=2, wpb=3507.564, bsz=164.911, num_updates=28376, lr=0.000187726, gnorm=0.694, clip=0.000, oom=0.000, wall=3989, train_wall=8240
# | epoch 026:    200 / 1131 loss=3.256, nll_loss=1.752, ppl=3.37, wps=6183, ups=2, wpb=3520.706, bsz=150.965, num_updates=28476, lr=0.000187396, gnorm=0.707, clip=0.000, oom=0.000, wall=4046, train_wall=8297
# | epoch 026:    300 / 1131 loss=3.263, nll_loss=1.759, ppl=3.39, wps=6184, ups=2, wpb=3510.867, bsz=150.166, num_updates=28576, lr=0.000187068, gnorm=0.710, clip=0.000, oom=0.000, wall=4103, train_wall=8353
# | epoch 026:    400 / 1131 loss=3.276, nll_loss=1.774, ppl=3.42, wps=6171, ups=2, wpb=3498.486, bsz=144.399, num_updates=28676, lr=0.000186741, gnorm=0.717, clip=0.000, oom=0.000, wall=4159, train_wall=8409
# | epoch 026:    500 / 1131 loss=3.286, nll_loss=1.786, ppl=3.45, wps=6162, ups=2, wpb=3487.733, bsz=142.723, num_updates=28776, lr=0.000186417, gnorm=0.721, clip=0.000, oom=0.000, wall=4215, train_wall=8464
# | epoch 026:    600 / 1131 loss=3.290, nll_loss=1.790, ppl=3.46, wps=6155, ups=2, wpb=3486.950, bsz=142.083, num_updates=28876, lr=0.000186094, gnorm=0.723, clip=0.000, oom=0.000, wall=4272, train_wall=8521
# | epoch 026:    700 / 1131 loss=3.297, nll_loss=1.798, ppl=3.48, wps=6163, ups=2, wpb=3489.291, bsz=141.444, num_updates=28976, lr=0.000185772, gnorm=0.725, clip=0.000, oom=0.000, wall=4329, train_wall=8577
# | epoch 026:    800 / 1131 loss=3.304, nll_loss=1.806, ppl=3.50, wps=6168, ups=2, wpb=3487.793, bsz=140.335, num_updates=29076, lr=0.000185452, gnorm=0.727, clip=0.000, oom=0.000, wall=4385, train_wall=8632
# | epoch 026:    900 / 1131 loss=3.306, nll_loss=1.808, ppl=3.50, wps=6177, ups=2, wpb=3493.284, bsz=141.496, num_updates=29176, lr=0.000185134, gnorm=0.726, clip=0.000, oom=0.000, wall=4441, train_wall=8689
# | epoch 026:   1000 / 1131 loss=3.314, nll_loss=1.818, ppl=3.53, wps=6190, ups=2, wpb=3496.195, bsz=142.018, num_updates=29276, lr=0.000184818, gnorm=0.727, clip=0.000, oom=0.000, wall=4497, train_wall=8744
# | epoch 026:   1100 / 1131 loss=3.314, nll_loss=1.819, ppl=3.53, wps=6188, ups=2, wpb=3494.808, bsz=142.358, num_updates=29376, lr=0.000184503, gnorm=0.728, clip=0.000, oom=0.000, wall=4553, train_wall=8800
# | epoch 026 | loss 3.315 | nll_loss 1.820 | ppl 3.53 | wps 6183 | ups 2 | wpb 3491.701 | bsz 141.679 | num_updates 29406 | lr 0.000184409 | gnorm 0.729 | clip 0.000 | oom 0.000 | wall 4570 | train_wall 8817
# | epoch 026 | valid on 'valid' subset | loss 3.914 | nll_loss 2.348 | ppl 5.09 | num_updates 29406 | best_loss 3.90541
# | saved checkpoint /content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint26.pt (epoch 26 @ 29406 updates) (writing took 4.4299421310424805 seconds)
# | epoch 027:    100 / 1131 loss=3.244, nll_loss=1.737, ppl=3.33, wps=6171, ups=2, wpb=3522.356, bsz=141.465, num_updates=29507, lr=0.000184093, gnorm=0.714, clip=0.000, oom=0.000, wall=4643, train_wall=8874
# | epoch 027:    200 / 1131 loss=3.248, nll_loss=1.743, ppl=3.35, wps=6157, ups=2, wpb=3486.831, bsz=149.612, num_updates=29607, lr=0.000183782, gnorm=0.720, clip=0.000, oom=0.000, wall=4700, train_wall=8930
# | epoch 027:    300 / 1131 loss=3.258, nll_loss=1.753, ppl=3.37, wps=6150, ups=2, wpb=3481.243, bsz=145.037, num_updates=29707, lr=0.000183472, gnorm=0.724, clip=0.000, oom=0.000, wall=4756, train_wall=8986
# | epoch 027:    400 / 1131 loss=3.268, nll_loss=1.765, ppl=3.40, wps=6165, ups=2, wpb=3488.297, bsz=143.122, num_updates=29807, lr=0.000183164, gnorm=0.724, clip=0.000, oom=0.000, wall=4813, train_wall=9042
# | epoch 027:    500 / 1131 loss=3.270, nll_loss=1.767, ppl=3.40, wps=6171, ups=2, wpb=3495.521, bsz=143.026, num_updates=29907, lr=0.000182858, gnorm=0.725, clip=0.000, oom=0.000, wall=4869, train_wall=9098
# | epoch 027:    600 / 1131 loss=3.273, nll_loss=1.771, ppl=3.41, wps=6187, ups=2, wpb=3500.369, bsz=144.200, num_updates=30007, lr=0.000182553, gnorm=0.726, clip=0.000, oom=0.000, wall=4926, train_wall=9154
# | epoch 027:    700 / 1131 loss=3.283, nll_loss=1.782, ppl=3.44, wps=6193, ups=2, wpb=3499.906, bsz=142.231, num_updates=30107, lr=0.000182249, gnorm=0.729, clip=0.000, oom=0.000, wall=4982, train_wall=9210
# | epoch 027:    800 / 1131 loss=3.285, nll_loss=1.785, ppl=3.45, wps=6183, ups=2, wpb=3490.444, bsz=142.341, num_updates=30207, lr=0.000181948, gnorm=0.731, clip=0.000, oom=0.000, wall=5038, train_wall=9265
# | epoch 027:    900 / 1131 loss=3.290, nll_loss=1.790, ppl=3.46, wps=6189, ups=2, wpb=3494.223, bsz=142.587, num_updates=30307, lr=0.000181647, gnorm=0.731, clip=0.000, oom=0.000, wall=5094, train_wall=9321
# | epoch 027:   1000 / 1131 loss=3.293, nll_loss=1.794, ppl=3.47, wps=6186, ups=2, wpb=3493.848, bsz=141.505, num_updates=30407, lr=0.000181348, gnorm=0.732, clip=0.000, oom=0.000, wall=5151, train_wall=9378
# | epoch 027:   1100 / 1131 loss=3.296, nll_loss=1.797, ppl=3.48, wps=6181, ups=2, wpb=3490.492, bsz=141.144, num_updates=30507, lr=0.000181051, gnorm=0.734, clip=0.000, oom=0.000, wall=5207, train_wall=9433
# | epoch 027 | loss 3.296 | nll_loss 1.797 | ppl 3.47 | wps 6182 | ups 2 | wpb 3491.701 | bsz 141.679 | num_updates 30537 | lr 0.000180962 | gnorm 0.733 | clip 0.000 | oom 0.000 | wall 5224 | train_wall 9450
# | epoch 027 | valid on 'valid' subset | loss 3.919 | nll_loss 2.353 | ppl 5.11 | num_updates 30537 | best_loss 3.90541
# | saved checkpoint /content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint27.pt (epoch 27 @ 30537 updates) (writing took 4.603618860244751 seconds)
# | epoch 028:    100 / 1131 loss=3.242, nll_loss=1.733, ppl=3.32, wps=6099, ups=2, wpb=3475.762, bsz=133.465, num_updates=30638, lr=0.000180663, gnorm=0.734, clip=0.000, oom=0.000, wall=5298, train_wall=9508
# | epoch 028:    200 / 1131 loss=3.247, nll_loss=1.739, ppl=3.34, wps=6132, ups=2, wpb=3478.363, bsz=139.980, num_updates=30738, lr=0.000180369, gnorm=0.733, clip=0.000, oom=0.000, wall=5354, train_wall=9564
# | epoch 028:    300 / 1131 loss=3.246, nll_loss=1.739, ppl=3.34, wps=6135, ups=2, wpb=3468.638, bsz=139.615, num_updates=30838, lr=0.000180076, gnorm=0.734, clip=0.000, oom=0.000, wall=5410, train_wall=9619
# | epoch 028:    400 / 1131 loss=3.252, nll_loss=1.747, ppl=3.36, wps=6170, ups=2, wpb=3491.853, bsz=142.484, num_updates=30938, lr=0.000179785, gnorm=0.730, clip=0.000, oom=0.000, wall=5467, train_wall=9676
# | epoch 028:    500 / 1131 loss=3.257, nll_loss=1.751, ppl=3.37, wps=6145, ups=2, wpb=3473.112, bsz=139.527, num_updates=31038, lr=0.000179495, gnorm=0.737, clip=0.000, oom=0.000, wall=5523, train_wall=9731
# | epoch 028:    600 / 1131 loss=3.260, nll_loss=1.755, ppl=3.37, wps=6140, ups=2, wpb=3465.792, bsz=139.592, num_updates=31138, lr=0.000179207, gnorm=0.738, clip=0.000, oom=0.000, wall=5579, train_wall=9787
# | epoch 028:    700 / 1131 loss=3.259, nll_loss=1.754, ppl=3.37, wps=6154, ups=2, wpb=3479.250, bsz=142.173, num_updates=31238, lr=0.00017892, gnorm=0.735, clip=0.000, oom=0.000, wall=5636, train_wall=9844
# | epoch 028:    800 / 1131 loss=3.265, nll_loss=1.761, ppl=3.39, wps=6161, ups=2, wpb=3482.266, bsz=141.002, num_updates=31338, lr=0.000178634, gnorm=0.736, clip=0.000, oom=0.000, wall=5693, train_wall=9900
# | epoch 028:    900 / 1131 loss=3.268, nll_loss=1.764, ppl=3.40, wps=6162, ups=2, wpb=3483.667, bsz=141.131, num_updates=31438, lr=0.00017835, gnorm=0.736, clip=0.000, oom=0.000, wall=5749, train_wall=9956
# | epoch 028:   1000 / 1131 loss=3.273, nll_loss=1.770, ppl=3.41, wps=6166, ups=2, wpb=3484.015, bsz=141.466, num_updates=31538, lr=0.000178067, gnorm=0.736, clip=0.000, oom=0.000, wall=5806, train_wall=10012
# | epoch 028:   1100 / 1131 loss=3.275, nll_loss=1.773, ppl=3.42, wps=6175, ups=2, wpb=3491.555, bsz=142.052, num_updates=31638, lr=0.000177785, gnorm=0.736, clip=0.000, oom=0.000, wall=5863, train_wall=10068
# | epoch 028 | loss 3.278 | nll_loss 1.777 | ppl 3.43 | wps 6178 | ups 2 | wpb 3491.701 | bsz 141.679 | num_updates 31668 | lr 0.000177701 | gnorm 0.736 | clip 0.000 | oom 0.000 | wall 5879 | train_wall 10085
# | epoch 028 | valid on 'valid' subset | loss 3.887 | nll_loss 2.319 | ppl 4.99 | num_updates 31668 | best_loss 3.88732
# | saved checkpoint /content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint28.pt (epoch 28 @ 31668 updates) (writing took 7.6145713329315186 seconds)
# | epoch 029:    100 / 1131 loss=3.230, nll_loss=1.720, ppl=3.30, wps=6107, ups=2, wpb=3485.089, bsz=143.762, num_updates=31769, lr=0.000177418, gnorm=0.732, clip=0.000, oom=0.000, wall=5956, train_wall=10142
# | epoch 029:    200 / 1131 loss=3.238, nll_loss=1.728, ppl=3.31, wps=6099, ups=2, wpb=3461.169, bsz=134.766, num_updates=31869, lr=0.00017714, gnorm=0.738, clip=0.000, oom=0.000, wall=6012, train_wall=10198
# | epoch 029:    300 / 1131 loss=3.234, nll_loss=1.724, ppl=3.30, wps=6134, ups=2, wpb=3483.983, bsz=139.110, num_updates=31969, lr=0.000176862, gnorm=0.731, clip=0.000, oom=0.000, wall=6069, train_wall=10254
# | epoch 029:    400 / 1131 loss=3.240, nll_loss=1.731, ppl=3.32, wps=6131, ups=2, wpb=3466.546, bsz=138.554, num_updates=32069, lr=0.000176586, gnorm=0.738, clip=0.000, oom=0.000, wall=6125, train_wall=10310
# | epoch 029:    500 / 1131 loss=3.240, nll_loss=1.732, ppl=3.32, wps=6154, ups=2, wpb=3488.327, bsz=141.860, num_updates=32169, lr=0.000176312, gnorm=0.733, clip=0.000, oom=0.000, wall=6182, train_wall=10366
# | epoch 029:    600 / 1131 loss=3.245, nll_loss=1.738, ppl=3.34, wps=6173, ups=2, wpb=3498.110, bsz=143.148, num_updates=32269, lr=0.000176038, gnorm=0.734, clip=0.000, oom=0.000, wall=6239, train_wall=10423
# | epoch 029:    700 / 1131 loss=3.247, nll_loss=1.740, ppl=3.34, wps=6185, ups=2, wpb=3505.790, bsz=144.217, num_updates=32369, lr=0.000175766, gnorm=0.734, clip=0.000, oom=0.000, wall=6295, train_wall=10479
# | epoch 029:    800 / 1131 loss=3.251, nll_loss=1.745, ppl=3.35, wps=6173, ups=2, wpb=3489.056, bsz=141.433, num_updates=32469, lr=0.000175495, gnorm=0.739, clip=0.000, oom=0.000, wall=6351, train_wall=10534
# | epoch 029:    900 / 1131 loss=3.256, nll_loss=1.750, ppl=3.36, wps=6157, ups=2, wpb=3477.526, bsz=140.625, num_updates=32569, lr=0.000175226, gnorm=0.743, clip=0.000, oom=0.000, wall=6407, train_wall=10590
# | epoch 029:   1000 / 1131 loss=3.258, nll_loss=1.753, ppl=3.37, wps=6174, ups=2, wpb=3490.198, bsz=142.385, num_updates=32669, lr=0.000174957, gnorm=0.740, clip=0.000, oom=0.000, wall=6464, train_wall=10646
# | epoch 029:   1100 / 1131 loss=3.262, nll_loss=1.757, ppl=3.38, wps=6175, ups=2, wpb=3490.081, bsz=141.645, num_updates=32769, lr=0.00017469, gnorm=0.742, clip=0.000, oom=0.000, wall=6520, train_wall=10702
# | epoch 029 | loss 3.262 | nll_loss 1.758 | ppl 3.38 | wps 6178 | ups 2 | wpb 3491.701 | bsz 141.679 | num_updates 32799 | lr 0.00017461 | gnorm 0.742 | clip 0.000 | oom 0.000 | wall 6537 | train_wall 10719
# | epoch 029 | valid on 'valid' subset | loss 3.904 | nll_loss 2.335 | ppl 5.04 | num_updates 32799 | best_loss 3.88732
# | saved checkpoint /content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint29.pt (epoch 29 @ 32799 updates) (writing took 4.568575143814087 seconds)
# | epoch 030:    100 / 1131 loss=3.221, nll_loss=1.710, ppl=3.27, wps=6101, ups=2, wpb=3476.911, bsz=136.000, num_updates=32900, lr=0.000174342, gnorm=0.733, clip=0.000, oom=0.000, wall=6610, train_wall=10776
# | epoch 030:    200 / 1131 loss=3.223, nll_loss=1.710, ppl=3.27, wps=6137, ups=2, wpb=3492.085, bsz=131.697, num_updates=33000, lr=0.000174078, gnorm=0.737, clip=0.000, oom=0.000, wall=6667, train_wall=10832
# | epoch 030:    300 / 1131 loss=3.215, nll_loss=1.703, ppl=3.26, wps=6172, ups=2, wpb=3506.146, bsz=141.233, num_updates=33100, lr=0.000173814, gnorm=0.733, clip=0.000, oom=0.000, wall=6724, train_wall=10889
# | epoch 030:    400 / 1131 loss=3.224, nll_loss=1.713, ppl=3.28, wps=6176, ups=2, wpb=3498.469, bsz=143.160, num_updates=33200, lr=0.000173553, gnorm=0.738, clip=0.000, oom=0.000, wall=6780, train_wall=10944
# | epoch 030:    500 / 1131 loss=3.224, nll_loss=1.713, ppl=3.28, wps=6172, ups=2, wpb=3494.319, bsz=142.353, num_updates=33300, lr=0.000173292, gnorm=0.738, clip=0.000, oom=0.000, wall=6836, train_wall=11000
# | epoch 030:    600 / 1131 loss=3.227, nll_loss=1.716, ppl=3.29, wps=6178, ups=2, wpb=3498.735, bsz=142.401, num_updates=33400, lr=0.000173032, gnorm=0.739, clip=0.000, oom=0.000, wall=6893, train_wall=11057
# | epoch 030:    700 / 1131 loss=3.231, nll_loss=1.721, ppl=3.30, wps=6165, ups=2, wpb=3485.933, bsz=141.602, num_updates=33500, lr=0.000172774, gnorm=0.743, clip=0.000, oom=0.000, wall=6949, train_wall=11112
# ...
# | epoch 039:   1000 / 1131 loss=3.123, nll_loss=1.595, ppl=3.02, wps=6178, ups=2, wpb=3497.826, bsz=142.009, num_updates=43979, lr=0.000150792, gnorm=0.773, clip=0.000, oom=0.000, wall=13013, train_wall=16987
# | epoch 039:   1100 / 1131 loss=3.124, nll_loss=1.596, ppl=3.02, wps=6173, ups=2, wpb=3494.713, bsz=141.885, num_updates=44079, lr=0.000150621, gnorm=0.773, clip=0.000, oom=0.000, wall=13070, train_wall=17044
# | epoch 039 | loss 3.126 | nll_loss 1.599 | ppl 3.03 | wps 6172 | ups 2 | wpb 3491.701 | bsz 141.679 | num_updates 44109 | lr 0.000150569 | gnorm 0.774 | clip 0.000 | oom 0.000 | wall 13086 | train_wall 17060
# | epoch 039 | valid on 'valid' subset | loss 3.918 | nll_loss 2.349 | ppl 5.09 | num_updates 44109 | best_loss 3.88732
# | saved checkpoint /content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint39.pt (epoch 39 @ 44109 updates) (writing took 4.464856863021851 seconds)
# | epoch 040:    100 / 1131 loss=3.088, nll_loss=1.551, ppl=2.93, wps=6033, ups=2, wpb=3412.040, bsz=123.723, num_updates=44210, lr=0.000150397, gnorm=0.784, clip=0.000, oom=0.000, wall=13159, train_wall=17117
# | epoch 040:    200 / 1131 loss=3.079, nll_loss=1.542, ppl=2.91, wps=6079, ups=2, wpb=3427.199, bsz=132.697, num_updates=44310, lr=0.000150227, gnorm=0.777, clip=0.000, oom=0.000, wall=13215, train_wall=17172
# | epoch 040:    300 / 1131 loss=3.085, nll_loss=1.550, ppl=2.93, wps=6104, ups=2, wpb=3446.910, bsz=131.907, num_updates=44410, lr=0.000150058, gnorm=0.776, clip=0.000, oom=0.000, wall=13272, train_wall=17229
# | epoch 040:    400 / 1131 loss=3.097, nll_loss=1.563, ppl=2.95, wps=6135, ups=2, wpb=3465.671, bsz=131.070, num_updates=44510, lr=0.000149889, gnorm=0.779, clip=0.000, oom=0.000, wall=13328, train_wall=17285
# | epoch 040:    500 / 1131 loss=3.102, nll_loss=1.569, ppl=2.97, wps=6143, ups=2, wpb=3467.411, bsz=132.772, num_updates=44610, lr=0.000149721, gnorm=0.781, clip=0.000, oom=0.000, wall=13384, train_wall=17341
# | epoch 040:    600 / 1131 loss=3.102, nll_loss=1.569, ppl=2.97, wps=6146, ups=2, wpb=3469.631, bsz=135.493, num_updates=44710, lr=0.000149554, gnorm=0.781, clip=0.000, oom=0.000, wall=13441, train_wall=17397
# | epoch 040:    700 / 1131 loss=3.101, nll_loss=1.568, ppl=2.97, wps=6150, ups=2, wpb=3474.101, bsz=137.699, num_updates=44810, lr=0.000149387, gnorm=0.778, clip=0.000, oom=0.000, wall=13498, train_wall=17453
# | epoch 040:    800 / 1131 loss=3.105, nll_loss=1.574, ppl=2.98, wps=6159, ups=2, wpb=3478.930, bsz=138.286, num_updates=44910, lr=0.00014922, gnorm=0.779, clip=0.000, oom=0.000, wall=13554, train_wall=17509
# | epoch 040:    900 / 1131 loss=3.109, nll_loss=1.578, ppl=2.99, wps=6158, ups=2, wpb=3476.736, bsz=138.982, num_updates=45010, lr=0.000149055, gnorm=0.780, clip=0.000, oom=0.000, wall=13610, train_wall=17565
# | epoch 040:   1000 / 1131 loss=3.113, nll_loss=1.582, ppl=2.99, wps=6164, ups=2, wpb=3479.652, bsz=139.388, num_updates=45110, lr=0.000148889, gnorm=0.780, clip=0.000, oom=0.000, wall=13667, train_wall=17621
# | epoch 040:   1100 / 1131 loss=3.114, nll_loss=1.585, ppl=3.00, wps=6178, ups=2, wpb=3491.003, bsz=141.856, num_updates=45210, lr=0.000148725, gnorm=0.778, clip=0.000, oom=0.000, wall=13724, train_wall=17677
# | epoch 040 | loss 3.115 | nll_loss 1.585 | ppl 3.00 | wps 6177 | ups 2 | wpb 3491.701 | bsz 141.679 | num_updates 45240 | lr 0.000148675 | gnorm 0.778 | clip 0.000 | oom 0.000 | wall 13741 | train_wall 17694
# | epoch 040 | valid on 'valid' subset | loss 3.922 | nll_loss 2.353 | ppl 5.11 | num_updates 45240 | best_loss 3.88732
# | saved checkpoint /content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint40.pt (epoch 40 @ 45240 updates) (writing took 4.4826765060424805 seconds)
# | epoch 041:    100 / 1131 loss=3.066, nll_loss=1.529, ppl=2.89, wps=6185, ups=2, wpb=3551.337, bsz=148.356, num_updates=45341, lr=0.00014851, gnorm=0.753, clip=0.000, oom=0.000, wall=13814, train_wall=17752
# | epoch 041:    200 / 1131 loss=3.062, nll_loss=1.525, ppl=2.88, wps=6175, ups=2, wpb=3516.055, bsz=146.070, num_updates=45441, lr=0.000148346, gnorm=0.759, clip=0.000, oom=0.000, wall=13871, train_wall=17808
# | epoch 041:    300 / 1131 loss=3.063, nll_loss=1.526, ppl=2.88, wps=6168, ups=2, wpb=3501.797, bsz=147.402, num_updates=45541, lr=0.000148183, gnorm=0.762, clip=0.000, oom=0.000, wall=13927, train_wall=17864
# | epoch 041:    400 / 1131 loss=3.070, nll_loss=1.534, ppl=2.90, wps=6187, ups=2, wpb=3513.100, bsz=146.015, num_updates=45641, lr=0.000148021, gnorm=0.762, clip=0.000, oom=0.000, wall=13984, train_wall=17920
# | epoch 041:    500 / 1131 loss=3.079, nll_loss=1.544, ppl=2.92, wps=6194, ups=2, wpb=3520.152, bsz=144.094, num_updates=45741, lr=0.000147859, gnorm=0.764, clip=0.000, oom=0.000, wall=14041, train_wall=17977
# | epoch 041:    600 / 1131 loss=3.084, nll_loss=1.550, ppl=2.93, wps=6194, ups=2, wpb=3517.977, bsz=144.930, num_updates=45841, lr=0.000147697, gnorm=0.769, clip=0.000, oom=0.000, wall=14098, train_wall=18033
# | epoch 041:    700 / 1131 loss=3.088, nll_loss=1.555, ppl=2.94, wps=6180, ups=2, wpb=3503.223, bsz=144.341, num_updates=45941, lr=0.000147537, gnorm=0.772, clip=0.000, oom=0.000, wall=14154, train_wall=18089
# | epoch 041:    800 / 1131 loss=3.088, nll_loss=1.555, ppl=2.94, wps=6174, ups=2, wpb=3496.377, bsz=145.517, num_updates=46041, lr=0.000147376, gnorm=0.775, clip=0.000, oom=0.000, wall=14210, train_wall=18144
# | epoch 041:    900 / 1131 loss=3.094, nll_loss=1.561, ppl=2.95, wps=6173, ups=2, wpb=3493.572, bsz=143.679, num_updates=46141, lr=0.000147217, gnorm=0.778, clip=0.000, oom=0.000, wall=14266, train_wall=18200
# | epoch 041:   1000 / 1131 loss=3.099, nll_loss=1.567, ppl=2.96, wps=6168, ups=2, wpb=3489.206, bsz=142.009, num_updates=46241, lr=0.000147057, gnorm=0.780, clip=0.000, oom=0.000, wall=14323, train_wall=18256
# | epoch 041:   1100 / 1131 loss=3.103, nll_loss=1.572, ppl=2.97, wps=6174, ups=2, wpb=3491.368, bsz=142.052, num_updates=46341, lr=0.000146898, gnorm=0.781, clip=0.000, oom=0.000, wall=14379, train_wall=18312
# | epoch 041 | loss 3.104 | nll_loss 1.574 | ppl 2.98 | wps 6176 | ups 2 | wpb 3491.701 | bsz 141.679 | num_updates 46371 | lr 0.000146851 | gnorm 0.781 | clip 0.000 | oom 0.000 | wall 14396 | train_wall 18329
# | epoch 041 | valid on 'valid' subset | loss 3.917 | nll_loss 2.347 | ppl 5.09 | num_updates 46371 | best_loss 3.88732
# | saved checkpoint /content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint41.pt (epoch 41 @ 46371 updates) (writing took 4.44721531867981 seconds)
# | epoch 042:    100 / 1131 loss=3.058, nll_loss=1.519, ppl=2.87, wps=6113, ups=2, wpb=3474.871, bsz=136.634, num_updates=46472, lr=0.000146691, gnorm=0.770, clip=0.000, oom=0.000, wall=14469, train_wall=18386
# | epoch 042:    200 / 1131 loss=3.061, nll_loss=1.522, ppl=2.87, wps=6128, ups=2, wpb=3466.796, bsz=135.363, num_updates=46572, lr=0.000146534, gnorm=0.774, clip=0.000, oom=0.000, wall=14525, train_wall=18442
# | epoch 042:    300 / 1131 loss=3.072, nll_loss=1.535, ppl=2.90, wps=6136, ups=2, wpb=3454.854, bsz=136.133, num_updates=46672, lr=0.000146377, gnorm=0.781, clip=0.000, oom=0.000, wall=14581, train_wall=18497
# | epoch 042:    400 / 1131 loss=3.075, nll_loss=1.538, ppl=2.90, wps=6135, ups=2, wpb=3454.192, bsz=133.845, num_updates=46772, lr=0.00014622, gnorm=0.785, clip=0.000, oom=0.000, wall=14637, train_wall=18553
# | epoch 042:    500 / 1131 loss=3.080, nll_loss=1.543, ppl=2.91, wps=6155, ups=2, wpb=3468.475, bsz=134.180, num_updates=46872, lr=0.000146064, gnorm=0.785, clip=0.000, oom=0.000, wall=14694, train_wall=18609
# | epoch 042:    600 / 1131 loss=3.084, nll_loss=1.548, ppl=2.92, wps=6163, ups=2, wpb=3472.639, bsz=133.617, num_updates=46972, lr=0.000145908, gnorm=0.786, clip=0.000, oom=0.000, wall=14750, train_wall=18665
# | epoch 042:    700 / 1131 loss=3.085, nll_loss=1.550, ppl=2.93, wps=6160, ups=2, wpb=3471.826, bsz=136.331, num_updates=47072, lr=0.000145753, gnorm=0.786, clip=0.000, oom=0.000, wall=14806, train_wall=18721
# | epoch 042:    800 / 1131 loss=3.086, nll_loss=1.552, ppl=2.93, wps=6178, ups=2, wpb=3488.954, bsz=137.788, num_updates=47172, lr=0.000145599, gnorm=0.782, clip=0.000, oom=0.000, wall=14864, train_wall=18778
# | epoch 042:    900 / 1131 loss=3.088, nll_loss=1.554, ppl=2.94, wps=6171, ups=2, wpb=3483.915, bsz=139.747, num_updates=47272, lr=0.000145445, gnorm=0.784, clip=0.000, oom=0.000, wall=14920, train_wall=18833
# | epoch 042:   1000 / 1131 loss=3.090, nll_loss=1.556, ppl=2.94, wps=6172, ups=2, wpb=3483.971, bsz=140.899, num_updates=47372, lr=0.000145291, gnorm=0.784, clip=0.000, oom=0.000, wall=14976, train_wall=18889
# | epoch 042:   1100 / 1131 loss=3.093, nll_loss=1.560, ppl=2.95, wps=6174, ups=2, wpb=3489.008, bsz=141.238, num_updates=47472, lr=0.000145138, gnorm=0.784, clip=0.000, oom=0.000, wall=15034, train_wall=18946
# | epoch 042 | loss 3.093 | nll_loss 1.560 | ppl 2.95 | wps 6176 | ups 2 | wpb 3491.701 | bsz 141.679 | num_updates 47502 | lr 0.000145092 | gnorm 0.783 | clip 0.000 | oom 0.000 | wall 15051 | train_wall 18963
# | epoch 042 | valid on 'valid' subset | loss 3.943 | nll_loss 2.372 | ppl 5.18 | num_updates 47502 | best_loss 3.88732
# | saved checkpoint /content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint42.pt (epoch 42 @ 47502 updates) (writing took 4.115642547607422 seconds)
# | epoch 043:    100 / 1131 loss=3.066, nll_loss=1.528, ppl=2.88, wps=6192, ups=2, wpb=3535.822, bsz=139.881, num_updates=47603, lr=0.000144938, gnorm=0.768, clip=0.000, oom=0.000, wall=15124, train_wall=19020
# | epoch 043:    200 / 1131 loss=3.054, nll_loss=1.516, ppl=2.86, wps=6147, ups=2, wpb=3490.214, bsz=153.075, num_updates=47703, lr=0.000144786, gnorm=0.770, clip=0.000, oom=0.000, wall=15180, train_wall=19076
# | epoch 043:    300 / 1131 loss=3.061, nll_loss=1.523, ppl=2.87, wps=6142, ups=2, wpb=3472.080, bsz=146.179, num_updates=47803, lr=0.000144635, gnorm=0.781, clip=0.000, oom=0.000, wall=15236, train_wall=19132
# | epoch 043:    400 / 1131 loss=3.063, nll_loss=1.525, ppl=2.88, wps=6156, ups=2, wpb=3480.132, bsz=140.948, num_updates=47903, lr=0.000144484, gnorm=0.783, clip=0.000, oom=0.000, wall=15293, train_wall=19188
# | epoch 043:    500 / 1131 loss=3.065, nll_loss=1.527, ppl=2.88, wps=6161, ups=2, wpb=3486.631, bsz=139.289, num_updates=48003, lr=0.000144333, gnorm=0.782, clip=0.000, oom=0.000, wall=15349, train_wall=19244
# | epoch 043:    600 / 1131 loss=3.071, nll_loss=1.534, ppl=2.89, wps=6161, ups=2, wpb=3485.351, bsz=139.754, num_updates=48103, lr=0.000144183, gnorm=0.785, clip=0.000, oom=0.000, wall=15406, train_wall=19300
# | epoch 043:    700 / 1131 loss=3.073, nll_loss=1.536, ppl=2.90, wps=6161, ups=2, wpb=3479.439, bsz=140.257, num_updates=48203, lr=0.000144033, gnorm=0.787, clip=0.000, oom=0.000, wall=15462, train_wall=19356
# | epoch 043:    800 / 1131 loss=3.077, nll_loss=1.541, ppl=2.91, wps=6169, ups=2, wpb=3483.483, bsz=141.831, num_updates=48303, lr=0.000143884, gnorm=0.787, clip=0.000, oom=0.000, wall=15518, train_wall=19412
# | epoch 043:    900 / 1131 loss=3.079, nll_loss=1.544, ppl=2.92, wps=6168, ups=2, wpb=3483.055, bsz=141.042, num_updates=48403, lr=0.000143735, gnorm=0.788, clip=0.000, oom=0.000, wall=15575, train_wall=19468
# | epoch 043:   1000 / 1131 loss=3.082, nll_loss=1.547, ppl=2.92, wps=6176, ups=2, wpb=3487.145, bsz=140.970, num_updates=48503, lr=0.000143587, gnorm=0.789, clip=0.000, oom=0.000, wall=15631, train_wall=19524
# | epoch 043:   1100 / 1131 loss=3.083, nll_loss=1.549, ppl=2.93, wps=6181, ups=2, wpb=3493.742, bsz=141.848, num_updates=48603, lr=0.000143439, gnorm=0.787, clip=0.000, oom=0.000, wall=15688, train_wall=19580
# | epoch 043 | loss 3.083 | nll_loss 1.549 | ppl 2.93 | wps 6177 | ups 2 | wpb 3491.701 | bsz 141.679 | num_updates 48633 | lr 0.000143395 | gnorm 0.788 | clip 0.000 | oom 0.000 | wall 15705 | train_wall 19597
# | epoch 043 | valid on 'valid' subset | loss 3.937 | nll_loss 2.363 | ppl 5.14 | num_updates 48633 | best_loss 3.88732
# | saved checkpoint /content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint43.pt (epoch 43 @ 48633 updates) (writing took 4.931373119354248 seconds)
# | epoch 044:    100 / 1131 loss=3.030, nll_loss=1.485, ppl=2.80, wps=6158, ups=2, wpb=3522.752, bsz=134.495, num_updates=48734, lr=0.000143246, gnorm=0.778, clip=0.000, oom=0.000, wall=15779, train_wall=19655
# | epoch 044:    200 / 1131 loss=3.032, nll_loss=1.488, ppl=2.80, wps=6121, ups=2, wpb=3462.562, bsz=136.199, num_updates=48834, lr=0.0001431, gnorm=0.785, clip=0.000, oom=0.000, wall=15835, train_wall=19710
# | epoch 044:    300 / 1131 loss=3.038, nll_loss=1.495, ppl=2.82, wps=6110, ups=2, wpb=3452.455, bsz=139.000, num_updates=48934, lr=0.000142953, gnorm=0.788, clip=0.000, oom=0.000, wall=15891, train_wall=19766
# | epoch 044:    400 / 1131 loss=3.038, nll_loss=1.497, ppl=2.82, wps=6151, ups=2, wpb=3479.928, bsz=149.663, num_updates=49034, lr=0.000142808, gnorm=0.782, clip=0.000, oom=0.000, wall=15948, train_wall=19822
# | epoch 044:    500 / 1131 loss=3.049, nll_loss=1.509, ppl=2.85, wps=6168, ups=2, wpb=3496.986, bsz=146.329, num_updates=49134, lr=0.000142662, gnorm=0.782, clip=0.000, oom=0.000, wall=16005, train_wall=19879
# | epoch 044:    600 / 1131 loss=3.053, nll_loss=1.514, ppl=2.86, wps=6181, ups=2, wpb=3507.433, bsz=145.569, num_updates=49234, lr=0.000142517, gnorm=0.781, clip=0.000, oom=0.000, wall=16062, train_wall=19936
# | epoch 044:    700 / 1131 loss=3.060, nll_loss=1.522, ppl=2.87, wps=6187, ups=2, wpb=3507.509, bsz=145.437, num_updates=49334, lr=0.000142373, gnorm=0.782, clip=0.000, oom=0.000, wall=16119, train_wall=19992
# | epoch 044:    800 / 1131 loss=3.064, nll_loss=1.526, ppl=2.88, wps=6179, ups=2, wpb=3501.464, bsz=143.589, num_updates=49434, lr=0.000142229, gnorm=0.785, clip=0.000, oom=0.000, wall=16175, train_wall=20048
# | epoch 044:    900 / 1131 loss=3.064, nll_loss=1.526, ppl=2.88, wps=6166, ups=2, wpb=3491.553, bsz=144.123, num_updates=49534, lr=0.000142085, gnorm=0.786, clip=0.000, oom=0.000, wall=16231, train_wall=20104
# | epoch 044:   1000 / 1131 loss=3.067, nll_loss=1.530, ppl=2.89, wps=6158, ups=2, wpb=3485.258, bsz=142.600, num_updates=49634, lr=0.000141942, gnorm=0.789, clip=0.000, oom=0.000, wall=16288, train_wall=20159
# | epoch 044:   1100 / 1131 loss=3.072, nll_loss=1.535, ppl=2.90, wps=6169, ups=2, wpb=3491.745, bsz=141.340, num_updates=49734, lr=0.000141799, gnorm=0.790, clip=0.000, oom=0.000, wall=16344, train_wall=20216
# | epoch 044 | loss 3.073 | nll_loss 1.537 | ppl 2.90 | wps 6172 | ups 2 | wpb 3491.701 | bsz 141.679 | num_updates 49764 | lr 0.000141756 | gnorm 0.790 | clip 0.000 | oom 0.000 | wall 16361 | train_wall 20232
# | epoch 044 | valid on 'valid' subset | loss 3.930 | nll_loss 2.358 | ppl 5.13 | num_updates 49764 | best_loss 3.88732
# | saved checkpoint /content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint44.pt (epoch 44 @ 49764 updates) (writing took 4.477119207382202 seconds)
# | epoch 045:    100 / 1131 loss=3.030, nll_loss=1.487, ppl=2.80, wps=6177, ups=2, wpb=3536.970, bsz=143.129, num_updates=49865, lr=0.000141613, gnorm=0.771, clip=0.000, oom=0.000, wall=16435, train_wall=20290
# | epoch 045:    200 / 1131 loss=3.023, nll_loss=1.480, ppl=2.79, wps=6180, ups=2, wpb=3538.562, bsz=150.965, num_updates=49965, lr=0.000141471, gnorm=0.772, clip=0.000, oom=0.000, wall=16492, train_wall=20346
# | epoch 045 | loss 3.024 | nll_loss 1.480 | ppl 2.79 | wps 6172 | ups 2 | wpb 3526.945 | bsz 148.576 | num_updates 50000 | lr 0.000141421 | gnorm 0.773 | clip 0.000 | oom 0.000 | wall 16512 | train_wall 20366
# | epoch 045 | valid on 'valid' subset | loss 3.942 | nll_loss 2.369 | ppl 5.17 | num_updates 50000 | best_loss 3.88732
# | saved checkpoint /content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint_last.pt (epoch 45 @ 50000 updates) (writing took 2.7166385650634766 seconds)
# | done training in 16523.6 seconds

# %%
# !python scripts/average_checkpoints.py --inputs "{SAVE}" \
    --num-epoch-checkpoints 10 --output "{SAVE}/checkpoint_last10_avg.pt"

# Evaluation
# !CUDA_VISIBLE_DEVICES=0 fairseq-generate data-bin/iwslt14.tokenized.de-en --path "{SAVE}/checkpoint_last10_avg.pt" --batch-size 128 --beam 4 --remove-bpe --lenpen 1 --gen-subset test --quiet
# Out:
# Namespace(checkpoint_upper_bound=None, inputs=['/content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt'], num_epoch_checkpoints=10, num_update_checkpoints=None, output='/content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint_last10_avg.pt')
# averaging checkpoints:  ['/content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint44.pt', '/content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint43.pt', '/content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint42.pt', '/content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint41.pt', '/content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint40.pt', '/content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint39.pt', '/content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint38.pt', '/content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint37.pt', '/content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint36.pt', '/content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint35.pt']
# Finished writing averaged checkpoint to /content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint_last10_avg.pt.
# Namespace(beam=4, bpe=None, cpu=False, criterion='cross_entropy', data='data-bin/iwslt14.tokenized.de-en', dataset_impl=None, decoding_format=None, diverse_beam_groups=-1, diverse_beam_strength=0.5, empty_cache_freq=0, force_anneal=None, fp16=False, fp16_init_scale=128, fp16_scale_tolerance=0.0, fp16_scale_window=None, gen_subset='test', iter_decode_eos_penalty=0.0, iter_decode_force_max_iter=False, iter_decode_max_iter=10, lazy_load=False, left_pad_source='True', left_pad_target='False', lenpen=1.0, load_alignments=False, log_format=None, log_interval=1000, lr_scheduler='fixed', lr_shrink=0.1, match_source_len=False, max_len_a=0, max_len_b=200, max_sentences=128, max_source_positions=1024, max_target_positions=1024, max_tokens=None, memory_efficient_fp16=False, min_len=1, min_loss_scale=0.0001, model_overrides='{}', momentum=0.99, nbest=1, no_beamable_mm=False, no_early_stop=False, no_progress_bar=False, no_repeat_ngram_size=0, num_shards=1, num_workers=1, optimizer='nag', path='/content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint_last10_avg.pt', prefix_size=0, print_alignment=False, print_step=False, quiet=True, raw_text=False, remove_bpe='@@ ', replace_unk=None, required_batch_size_multiple=8, results_path=None, sacrebleu=False, sampling=False, sampling_topk=-1, sampling_topp=-1.0, score_reference=False, seed=1, shard_id=0, skip_invalid_size_inputs_valid_test=False, source_lang=None, target_lang=None, task='translation', tbmf_wrapper=False, temperature=1.0, tensorboard_logdir='', threshold_loss_scale=None, tokenizer=None, unkpen=0, unnormalized=False, upsample_primary=1, user_dir=None, warmup_updates=0, weight_decay=0.0)
# | [de] dictionary: 8848 types
# | [en] dictionary: 6632 types
# | loaded 6750 examples from: data-bin/iwslt14.tokenized.de-en/test.de-en.de
# | loaded 6750 examples from: data-bin/iwslt14.tokenized.de-en/test.de-en.en
# | data-bin/iwslt14.tokenized.de-en test de-en 6750 examples
# | loading model(s) from /content/gdrive/My Drive/colab/payless/save_base/dynamic_conv_iwslt/checkpoint_last10_avg.pt
# | Translated 6750 sentences (148050 tokens) in 73.2s (92.19 sentences/s, 2021.97 tokens/s)
# | Generate test with beam=4: BLEU4 = 34.80, 69.3/43.6/29.5/20.2 (BP=0.950, ratio=0.951, syslen=124736, reflen=131161)
